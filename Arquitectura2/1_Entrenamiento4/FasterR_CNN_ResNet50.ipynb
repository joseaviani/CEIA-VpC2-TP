# %% [markdown]
# ### Faster R-CNN (ResNet50-FPN) ###
#
# Notebook diseñada para ejecutarse en Google Colab con aceleración GPU.

# %% [markdown]
# ---

# %% [markdown]
# TODO:JA Descripción de los parámetros y caracteristicas del modelo de esta corrida. Comparar con la corrida anterior

# %% [markdown]
# ---

# %%
# Montamos un google drive para guardar los resultados y el modelo entrenado.
from google.colab import drive
drive.mount('/content/drive')

OUT_BASE_DIR = "/content/drive/MyDrive/UBA/CEIA/Materias/Visión por Computadora II/google_colab_data/FasterR-CNN-ResNet50_notebook" # Setear el path Google Drive deseado
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %pip install gdown --quiet
# %pip install torch --quiet
# %pip install torchvision --quiet
# %pip install matplotlib --quiet
# %pip install pandas --quiet
# %pip install pillow --quiet
# %pip install numpy --quiet
# %pip install matplotlib --quiet
# %pip install torchmetrics --quiet

# %%
import os
import zipfile
import gdown
import shutil
import glob
import torch
import torchvision
import numpy as np
from collections import Counter
from PIL import Image
import random
import matplotlib.pyplot as plt
from torchvision.ops import box_convert
import matplotlib.patches as patches
import pandas as pd
from torch.utils.data import WeightedRandomSampler
import time
import math
from typing import List, Dict, Tuple, Any
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision
from torchvision.ops import box_iou
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
import torchvision.transforms as T
import datetime
import json
from torchmetrics.detection.mean_ap import MeanAveragePrecision
from torchvision.ops import batched_nms
from torchvision.transforms import v2 as Tv2
from torchvision.tv_tensors import BoundingBoxes
from torchvision.models.detection.anchor_utils import AnchorGenerator

# %%
# Reproducibilidad
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

# %%
INICIO_EJECUCION = datetime.datetime.now()
INICIO_STEP = datetime.datetime.now()

# %%
# ---------------------------------------
# 1) Descargar dataset
# ---------------------------------------

DATA_DIR = "/content/data"

def descargar_dataset(data_dir):

  # Verificar si exsite la carpeta
  if not os.path.exists(data_dir):

    try:
      # Nombre del archivo ZIP que se va a guardar
      ZIP_NAME = "kaggle-xray_baggage_scanner_anomaly_detection.zip"
      zip_path = os.path.join(data_dir, ZIP_NAME)

      # Crear carpeta data
      os.makedirs(data_dir, exist_ok=True)

      # Descargar el ZIP
      print("Descargando archivo zip ...")
      # Lo tomamos de Google Drive porque Kaggle requeire autenticación
      gdown.download(id="1IqPblTm7nmKFpHXtl4beopE_SajTBoI0", output=zip_path, quiet=False)
      print("Archivo zip descargado.")

      # Descomprimir el ZIP
      print("Descomprimiendo archivo ...")
      with zipfile.ZipFile(zip_path, "r") as zf:
          zf.extractall(data_dir)
      print("Archivo descomprimido.")
    except:
      # En caso de error, eliminar la carpeta creada
      shutil.rmtree(data_dir, ignore_errors=True)
      print("Ocurrió un error al descargar el dataset.")

  print(f"Dataset descargado en: '{data_dir}'")


# Descargar el dataset (solo si no existe la carpeta data)
descargar_dataset(DATA_DIR)
# Out:
# Dataset descargado en: '/content/data'

# %%
print(f"Tiempo descarga dataset: {datetime.datetime.now() - INICIO_STEP}")
INICIO_STEP = datetime.datetime.now()
# Out:
# Tiempo descarga dataset: 0:00:00.010938

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")
# Out:
# Device: cuda

# %%
# ---------------------------------------
# 2) Configuración de rutas y clases
# ---------------------------------------

CLASS_NAMES = ["Tijera", "Navaja", "Cuchillo", "Cutter", "Navaja multiuso"]
NUM_CLASSES = len(CLASS_NAMES)  # 5
NUM_CLASSES_WITH_BG = NUM_CLASSES + 1  # +1 background para Faster R-CNN

# Paths estándar de YOLO
SPLITS = {
    "train": {"images": os.path.join(DATA_DIR, "train", "images"),
              "labels": os.path.join(DATA_DIR, "train", "labels")},
    "valid": {"images": os.path.join(DATA_DIR, "valid", "images"),
              "labels": os.path.join(DATA_DIR, "valid", "labels")},
    "test":  {"images": os.path.join(DATA_DIR, "test",  "images"),
              "labels": os.path.join(DATA_DIR, "test",  "labels")},
}

# %%
# ---------------------------------------
# 3) Dataset: De YOLO a torchvision detection
# ---------------------------------------

class YoloDetectionDataset(Dataset):
    def __init__(self, images_dir, labels_dir, transforms=None):
        self.images = sorted(glob.glob(os.path.join(images_dir, "*")))
        self.labels_dir = labels_dir
        self.transforms = transforms

    def __len__(self):
        return len(self.images)

    def _read_yolo_txt(self, label_path):
        boxes_cxcywh = []
        labels = []
        if not os.path.exists(label_path):
            return torch.zeros((0, 4), dtype=torch.float32), torch.zeros((0,), dtype=torch.int64)

        with open(label_path, "r") as f:
            lines = [ln.strip() for ln in f.readlines() if ln.strip()]

        if not lines:
            return torch.zeros((0, 4), dtype=torch.float32), torch.zeros((0,), dtype=torch.int64)

        for ln in lines:
            parts = ln.split()
            if len(parts) != 5:
                continue
            c, cx, cy, w, h = parts
            labels.append(int(c))
            boxes_cxcywh.append([float(cx), float(cy), float(w), float(h)])

        if len(boxes_cxcywh) == 0:
            return torch.zeros((0, 4), dtype=torch.float32), torch.zeros((0,), dtype=torch.int64)

        return torch.tensor(boxes_cxcywh, dtype=torch.float32), torch.tensor(labels, dtype=torch.int64)

    def __getitem__(self, idx):
        img_path = self.images[idx]
        img = Image.open(img_path).convert("RGB")
        W, H = img.size  # PIL: (W,H)

        base = os.path.splitext(os.path.basename(img_path))[0]
        lbl_path = os.path.join(self.labels_dir, base + ".txt")
        boxes_cxcywh_norm, labels0 = self._read_yolo_txt(lbl_path)

        # Desnormalizar y convertir a XYXY en píxeles
        if boxes_cxcywh_norm.numel() > 0:
            scale = torch.tensor([W, H, W, H], dtype=torch.float32)
            boxes_cxcywh_px = boxes_cxcywh_norm * scale
            boxes_xyxy = box_convert(boxes_cxcywh_px, in_fmt="cxcywh", out_fmt="xyxy")
            boxes_xyxy[:, [0, 2]] = boxes_xyxy[:, [0, 2]].clamp(0, W)
            boxes_xyxy[:, [1, 3]] = boxes_xyxy[:, [1, 3]].clamp(0, H)
        else:
            boxes_xyxy = torch.zeros((0, 4), dtype=torch.float32)

        # labels YOLO: 0..K-1 -> torchvision: 1..K
        labels = (labels0 + 1) if labels0.numel() > 0 else torch.zeros((0,), dtype=torch.int64)

        target = {
            "boxes": boxes_xyxy,
            "labels": labels,
            "image_id": torch.tensor([idx]),
            "iscrowd": torch.zeros((len(labels),), dtype=torch.int64),
        }
        # area (si no hay boxes, tensor vacío)
        if boxes_xyxy.numel() > 0:
            target["area"] = (boxes_xyxy[:, 2] - boxes_xyxy[:, 0]) * (boxes_xyxy[:, 3] - boxes_xyxy[:, 1])
        else:
            target["area"] = torch.zeros((0,), dtype=torch.float32)

        # Tv2 transforms con boxes
        if self.transforms is not None:
            # Convertir boxes a tv_tensors para que Tv2 actualice coordenadas
            target = dict(target)
            target["boxes"] = BoundingBoxes(target["boxes"], format="XYXY", canvas_size=(H, W))

            img, target = self.transforms(img, target)

            # Volver a Tensor estándar (torchvision detection espera Tensor)
            target["boxes"] = target["boxes"].as_subclass(torch.Tensor)

        return img, target


def collate_fn(batch):
    imgs, targets = list(zip(*batch))
    return list(imgs), list(targets)

# %%
# ---------------------------------------
# 4) Transforms y DataLoaders
# ---------------------------------------

# Transforms
class RandomGammaDual(torch.nn.Module):
    def __init__(self, gamma_range=(0.85, 1.15), p=0.5):
        super().__init__()
        self.g0, self.g1 = gamma_range
        self.p = p

    def forward(self, img, target):
        if torch.rand(()) > self.p:
            return img, target
        g = torch.empty((), dtype=torch.float32).uniform_(self.g0, self.g1).item()
        img = torch.clamp(img, 0.0, 1.0) ** g
        return img, target

train_tfms = Tv2.Compose([
    Tv2.ToImage(),
    Tv2.ToDtype(torch.float32, scale=True),

    Tv2.RandomApply([Tv2.ColorJitter(brightness=0.15, contrast=0.20, saturation=0.0, hue=0.0)], p=0.8),
    RandomGammaDual((0.85, 1.15), p=0.5),

    # ruido gaussiano
    Tv2.RandomApply([Tv2.GaussianNoise(sigma=0.02)], p=0.5),

    Tv2.RandomAffine(degrees=3, translate=(0.02, 0.02), scale=(0.95, 1.05), shear=0, fill=0),
    Tv2.SanitizeBoundingBoxes(),
])

eval_tfms = Tv2.Compose([
    Tv2.ToImage(),
    Tv2.ToDtype(torch.float32, scale=True),
    Tv2.SanitizeBoundingBoxes(),
])

# Datasets
train_ds = YoloDetectionDataset(SPLITS["train"]["images"], SPLITS["train"]["labels"], transforms=train_tfms)
valid_ds = YoloDetectionDataset(SPLITS["valid"]["images"], SPLITS["valid"]["labels"], transforms=eval_tfms)
test_ds  = YoloDetectionDataset(SPLITS["test"]["images"],  SPLITS["test"]["labels"],  transforms=eval_tfms)

# DataLoaders
BATCH_SIZE = 4   # Ajustar según VRAM
NUM_WORKERS = 2

train_dl = DataLoader(
    train_ds, batch_size=BATCH_SIZE, shuffle=True,
    num_workers=NUM_WORKERS, collate_fn=collate_fn,
    pin_memory=True, persistent_workers=(NUM_WORKERS > 0), prefetch_factor=2
)
valid_dl = DataLoader(
    valid_ds, batch_size=BATCH_SIZE, shuffle=False,
    num_workers=NUM_WORKERS, collate_fn=collate_fn,
    pin_memory=True, persistent_workers=(NUM_WORKERS > 0), prefetch_factor=2
)
test_dl = DataLoader(
    test_ds, batch_size=BATCH_SIZE, shuffle=False,
    num_workers=NUM_WORKERS, collate_fn=collate_fn,
    pin_memory=True, persistent_workers=(NUM_WORKERS > 0), prefetch_factor=2
)

print(f"train: {len(train_ds)} imgs | valid: {len(valid_ds)} | test: {len(test_ds)}")
# Out:
# train: 6181 imgs | valid: 1766 | test: 883

# %%
print(f"Tiempo preparación dataset y dataloaders: {datetime.datetime.now() - INICIO_STEP}")
INICIO_STEP = datetime.datetime.now()
# Out:
# Tiempo preparación dataset y dataloaders: 0:00:00.095663

# %%
# ---------------------------------------
# 5) Modelo: Faster R-CNN (ResNet50-FPN preentrenado COCO)
# ---------------------------------------

def get_fasterrcnn_model(num_classes_with_bg: int):

    # Anchors: agregamos tamaños más chicos y ratios extremos para objetos alargados
    anchor_sizes = ((16,), (32,), (64,), (128,), (256,))
    aspect_ratios = ((0.2, 0.5, 1.0, 2.0, 5.0),) * len(anchor_sizes)
    rpn_anchor_generator = AnchorGenerator(
        sizes=anchor_sizes,
        aspect_ratios=aspect_ratios
    )

    # Cargamos backbone preentrenado, el resto queda random-init.
    model = torchvision.models.detection.fasterrcnn_resnet50_fpn(
        weights=None,
        weights_backbone="DEFAULT",
        rpn_anchor_generator=rpn_anchor_generator
    )

    in_features = model.roi_heads.box_predictor.cls_score.in_features
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes_with_bg)

    return model


model = get_fasterrcnn_model(NUM_CLASSES_WITH_BG)

# Más propuestas del RPN
model.rpn._pre_nms_top_n  = {"training": 2000, "testing": 2000}
model.rpn._post_nms_top_n = {"training": 2000, "testing": 2000}

model.to(device)
# Out:
# FasterRCNN(
#   (transform): GeneralizedRCNNTransform(
#       Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#       Resize(min_size=(800,), max_size=1333, mode='bilinear')
#   )
#   (backbone): BackboneWithFPN(
#     (body): IntermediateLayerGetter(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): FrozenBatchNorm2d(64, eps=1e-05)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=1e-05)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(256, eps=1e-05)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer2): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(512, eps=1e-05)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer3): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(1024, eps=1e-05)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (4): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (5): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer4): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=1e-05)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(2048, eps=1e-05)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#     (fpn): FeaturePyramidNetwork(
#       (inner_blocks): ModuleList(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (2): Conv2dNormActivation(
#           (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (3): Conv2dNormActivation(
#           (0): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#         )
#       )
#       (layer_blocks): ModuleList(
#         (0-3): 4 x Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (extra_blocks): LastLevelMaxPool()
#     )
#   )
#   (rpn): RegionProposalNetwork(
#     (anchor_generator): AnchorGenerator()
#     (head): RPNHead(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#           (1): ReLU(inplace=True)
#         )
#       )
#       (cls_logits): Conv2d(256, 5, kernel_size=(1, 1), stride=(1, 1))
#       (bbox_pred): Conv2d(256, 20, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (roi_heads): RoIHeads(
#     (box_roi_pool): MultiScaleRoIAlign(featmap_names=['0', '1', '2', '3'], output_size=(7, 7), sampling_ratio=2)
#     (box_head): TwoMLPHead(
#       (fc6): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc7): Linear(in_features=1024, out_features=1024, bias=True)
#     )
#     (box_predictor): FastRCNNPredictor(
#       (cls_score): Linear(in_features=1024, out_features=6, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=24, bias=True)
#     )
#   )
# )

# %%
# ---------------------------------------
# 6) Optimizador y scheduler
# ---------------------------------------
params = [p for p in model.parameters() if p.requires_grad]
LR = 5e-3
optimizer = optim.SGD(params, lr=LR, momentum=0.9, weight_decay=5e-4)
lr_sched = optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.1)

# %%
print(f"Tiempo preparación modelo, optimizor y scheduler: {datetime.datetime.now() - INICIO_STEP}")
INICIO_STEP = datetime.datetime.now()
# Out:
# Tiempo preparación modelo, optimizor y scheduler: 0:00:00.838650

# %%
EPOCHS = 20 # Setear epochs según corresponda

# ---------------------------------------
# 7) Entrenar y evaluar el modelo
# ---------------------------------------

def _loss_dict_to_scalars(loss_dict: Dict[str, torch.Tensor]) -> Dict[str, float]:
    # torchvision devuelve tensores escalares
    out = {
        "loss_classifier": float(loss_dict.get("loss_classifier", torch.tensor(0.0)).item()),
        "loss_box_reg": float(loss_dict.get("loss_box_reg", torch.tensor(0.0)).item()),
        "loss_objectness": float(loss_dict.get("loss_objectness", torch.tensor(0.0)).item()),
        "loss_rpn_box_reg": float(loss_dict.get("loss_rpn_box_reg", torch.tensor(0.0)).item()),
    }
    out["loss_total"] = out["loss_classifier"] + out["loss_box_reg"] + out["loss_objectness"] + out["loss_rpn_box_reg"]
    return out


def _avg_dicts(dicts: List[Dict[str, float]]) -> Dict[str, float]:
    if not dicts:
        return {}
    keys = dicts[0].keys()
    return {k: float(np.mean([d[k] for d in dicts])) for k in keys}


def fbeta(prec: float, rec: float, beta: float = 2.0) -> float:
    if prec + rec == 0:
        return 0.0
    b2 = beta * beta
    return (1 + b2) * (prec * rec) / (b2 * prec + rec)


def train_one_epoch(
    model,
    loader,
    optimizer,
    device,
    log_every: int = 50,
) -> Dict[str, float]:
    model.train()

    batch_losses = []
    batch_times = []
    start_t = time.time()

    for bi, (imgs, targets) in enumerate(loader, start=1):
        imgs = [img.to(device) for img in imgs]
        tgts = [{k: v.to(device) for k, v in t.items()} for t in targets]

        loss_dict = model(imgs, tgts)
        loss = sum(v for v in loss_dict.values())

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # timing/log
        bt = time.time() - start_t
        batch_times.append(bt)
        start_t = time.time()

        loss_scalars = _loss_dict_to_scalars(loss_dict)
        batch_losses.append(loss_scalars)

        if (bi % log_every == 0) or (bi == len(loader)):
            avg_loss_running = float(np.mean([d["loss_total"] for d in batch_losses[-50:]]))
            avg_bt = float(np.mean(batch_times[-50:])) if batch_times else 0.0
            eta_sec = max(0.0, (len(loader) - bi) * avg_bt)
            cur_lr = optimizer.param_groups[0]["lr"]

            imgs_per_sec = (len(imgs) / bt) if bt > 0 else 0.0
            gpu_mem = None
            if torch.cuda.is_available():
                torch.cuda.synchronize()
                gpu_mem = torch.cuda.max_memory_allocated() / (1024**2)  # MiB

            msg = (f"[batch {bi:4d}/{len(loader)}] "
                   f"loss(b)={loss_scalars['loss_total']:.4f} | loss(µ50)={avg_loss_running:.4f} | "
                   f"lr={cur_lr:.3g} | {imgs_per_sec:.1f} img/s | "
                   f"ETA~{int(eta_sec//60)}m{int(eta_sec%60)}s")
            if gpu_mem is not None:
                msg += f" | GPU~{gpu_mem:.0f} MiB"
            print(msg)

    return _avg_dicts(batch_losses)

EVAL_LOG_EVERY = 50

SCORE_THRESH = 0.5
IOU_THRESH   = 0.5

@torch.no_grad()
def compute_losses_no_grad(model, loader, device, log_every: int = 50):
    was_training = model.training
    model.train()

    batch_losses = []
    t0 = time.time()
    for bi, (imgs, targets) in enumerate(loader, start=1):
        imgs = [img.to(device) for img in imgs]
        tgts = [{k: v.to(device) for k, v in t.items()} for t in targets]

        loss_dict = model(imgs, tgts)
        loss_scalars = _loss_dict_to_scalars(loss_dict)
        batch_losses.append(loss_scalars)

        if bi % log_every == 0 or bi == len(loader):
            dt = time.time() - t0
            print(f"[val_loss {bi:4d}/{len(loader)}] loss={loss_scalars['loss_total']:.4f} | {bi/dt:.2f} it/s")

    if not was_training:
        model.eval()
    return _avg_dicts(batch_losses)


@torch.no_grad()
def evaluate_prf1_f2(model, loader, device, class_names, score_thresh=0.5, iou_thresh=0.5, log_every: int = 50):
    model.eval()

    K = len(class_names)
    TP = np.zeros(K + 1, dtype=np.int64)
    FP = np.zeros(K + 1, dtype=np.int64)
    FN = np.zeros(K + 1, dtype=np.int64)

    t0 = time.time()
    for bi, (imgs, targets) in enumerate(loader, start=1):
        imgs = [img.to(device) for img in imgs]
        outputs = model(imgs)

        for out, tgt in zip(outputs, targets):
            gt_boxes = tgt["boxes"].cpu()
            gt_labels = tgt["labels"].cpu()

            keep = out["scores"].cpu() >= score_thresh
            pred_boxes = out["boxes"].cpu()[keep]
            pred_labels = out["labels"].cpu()[keep]
            pred_scores = out["scores"].cpu()[keep]

            if len(gt_boxes) == 0 and len(pred_boxes) == 0:
                continue

            ious = box_iou(pred_boxes, gt_boxes) if (len(pred_boxes) > 0 and len(gt_boxes) > 0) else torch.zeros((len(pred_boxes), len(gt_boxes)))
            matched_gt, matched_pred = set(), set()

            order = torch.argsort(pred_scores, descending=True).cpu().numpy()
            for pi in order:
                best_j, best_iou = -1, 0.0
                for gj in range(len(gt_boxes)):
                    if gj in matched_gt:
                        continue
                    if pred_labels[pi].item() != gt_labels[gj].item():
                        continue
                    iou_val = float(ious[pi, gj].item())
                    if iou_val >= iou_thresh and iou_val > best_iou:
                        best_iou, best_j = iou_val, gj
                if best_j >= 0:
                    cls = int(pred_labels[pi].item())
                    TP[cls] += 1
                    matched_pred.add(pi)
                    matched_gt.add(best_j)

            for pi in range(len(pred_boxes)):
                if pi not in matched_pred:
                    cls = int(pred_labels[pi].item())
                    FP[cls] += 1

            for gj in range(len(gt_boxes)):
                if gj not in matched_gt:
                    cls = int(gt_labels[gj].item())
                    FN[cls] += 1

        if bi % log_every == 0 or bi == len(loader):
            dt = time.time() - t0
            print(f"[val_prf  {bi:4d}/{len(loader)}] {bi/dt:.2f} it/s | TP={TP.sum()} FP={FP.sum()} FN={FN.sum()}")

    per_class = []
    for cls in range(1, K + 1):
        tp, fp, fn = int(TP[cls]), int(FP[cls]), int(FN[cls])
        prec = tp / (tp + fp) if (tp + fp) > 0 else 0.0
        rec  = tp / (tp + fn) if (tp + fn) > 0 else 0.0
        f1   = 2 * prec * rec / (prec + rec) if (prec + rec) > 0 else 0.0
        f2   = fbeta(prec, rec, beta=2.0)
        per_class.append((class_names[cls - 1], tp, fp, fn, prec, rec, f1, f2))

    macro_prec = float(np.mean([r[4] for r in per_class])) if per_class else 0.0
    macro_rec  = float(np.mean([r[5] for r in per_class])) if per_class else 0.0
    macro_f1   = float(np.mean([r[6] for r in per_class])) if per_class else 0.0
    macro_f2   = float(np.mean([r[7] for r in per_class])) if per_class else 0.0

    return {
        "per_class": per_class,
        "macro": {"precision": macro_prec, "recall": macro_rec, "f1": macro_f1, "f2": macro_f2},
        "raw": {"TP": TP, "FP": FP, "FN": FN},
        "settings": {"score_thresh": score_thresh, "iou_thresh": iou_thresh},
    }



@torch.no_grad()
def evaluate_map_torchmetrics(model, loader, device, include_per_class: bool = True):

    model.eval()
    metric = MeanAveragePrecision(iou_type="bbox", class_metrics=include_per_class)

    for imgs, targets in loader:
        imgs = [img.to(device) for img in imgs]
        outputs = model(imgs)

        preds, gts = [], []
        for out, tgt in zip(outputs, targets):
            preds.append({
                "boxes": out["boxes"].detach().cpu(),
                "scores": out["scores"].detach().cpu(),
                "labels": out["labels"].detach().cpu(),
            })
            gts.append({
                "boxes": tgt["boxes"].detach().cpu(),
                "labels": tgt["labels"].detach().cpu(),
            })
        metric.update(preds, gts)

    res = metric.compute()

    out = {}
    for k, v in res.items():
        if isinstance(v, torch.Tensor):
            if v.ndim == 0:
                out[k] = float(v.item())
            elif include_per_class:
                out[k] = v.detach().cpu().tolist()

    return out


# Loop principal
history = []

for epoch in range(1, EPOCHS + 1):
    print("\n" + "=" * 80)
    print(f"INICIO ÉPOCA {epoch}/{EPOCHS}  |  train_batches: {len(train_dl)}  |  batch_size: {BATCH_SIZE}")
    if torch.cuda.is_available():
        print(f"GPU: {torch.cuda.get_device_name(0)}  |  VRAM total: {torch.cuda.get_device_properties(0).total_memory/(1024**3):.1f} GB")
        torch.cuda.reset_peak_memory_stats()
    print("=" * 80)

    t0 = time.time()

    # Train
    train_losses = train_one_epoch(model, train_dl, optimizer, device, log_every=50)
    print("FIN TRAIN ")

    # Valid
    valid_losses = None
    valid_pr = None
    valid_map = None

    print(f"INICIO val_loss (batches={len(valid_dl)}) ...")
    tv = time.time()
    valid_losses = compute_losses_no_grad(model, valid_dl, device, log_every=EVAL_LOG_EVERY)
    print(f"FIN val_loss  ({(time.time()-tv)/60:.1f} min)")

    print(f"INICIO val_prf (batches={len(valid_dl)}) ...")
    tv = time.time()
    valid_pr = evaluate_prf1_f2(model, valid_dl, device, CLASS_NAMES, score_thresh=SCORE_THRESH, iou_thresh=IOU_THRESH, log_every=EVAL_LOG_EVERY)
    print(f"FIN val_prf  ({(time.time()-tv)/60:.1f} min)")

    print(f"INICIO val_mAP (batches={len(valid_dl)}) ...")
    tv = time.time()
    valid_map = evaluate_map_torchmetrics(model, valid_dl, device)
    print(f"FIN val_mAP  ({(time.time()-tv)/60:.1f} min)")

    # Scheduler
    lr_sched.step()
    cur_lr = optimizer.param_groups[0]["lr"]

    dt = time.time() - t0
    msg = f"[RESUMEN ÉPOCA {epoch:02d}] lr→{cur_lr:.3g} | dur={dt/60:.1f} min | train_loss={train_losses['loss_total']:.4f}"
    if valid_losses is not None:
        msg += f" | val_loss={valid_losses['loss_total']:.4f}"
    if valid_pr is not None:
        msg += f" | val_rec={valid_pr['macro']['recall']:.3f} | val_f2={valid_pr['macro']['f2']:.3f}"
    if valid_map is not None:
        msg += f" | val_mAP50={valid_map['map_50']:.3f} | val_mAP={valid_map['map']:.3f}"
    print(msg)

    history.append({
        "epoch": epoch,
        "lr": float(cur_lr),
        "train": train_losses,
        "valid": valid_losses,
        "valid_macro": None if valid_pr is None else valid_pr["macro"],
        "valid_per_class": None if valid_pr is None else valid_pr["per_class"],
        "valid_map": valid_map,
        "settings": {"score_thresh": SCORE_THRESH, "iou_thresh": IOU_THRESH},
        "duration_sec": float(dt),
    })
# Out:
# ================================================================================
# INICIO ÉPOCA 1/20  |  train_batches: 1546  |  batch_size: 4
# GPU: NVIDIA A100-SXM4-40GB  |  VRAM total: 39.6 GB
# ================================================================================
# [batch   50/1546] loss(b)=0.0625 | loss(µ50)=0.2136 | lr=0.005 | 32.3 img/s | ETA~3m54s | GPU~2821 MiB
# [batch  100/1546] loss(b)=0.0793 | loss(µ50)=0.0976 | lr=0.005 | 31.5 img/s | ETA~3m9s | GPU~2821 MiB
# [batch  150/1546] loss(b)=0.1333 | loss(µ50)=0.1184 | lr=0.005 | 30.7 img/s | ETA~3m4s | GPU~2821 MiB
# [batch  200/1546] loss(b)=0.1004 | loss(µ50)=0.1285 | lr=0.005 | 30.6 img/s | ETA~2m56s | GPU~2821 MiB
# [batch  250/1546] loss(b)=0.1697 | loss(µ50)=0.1297 | lr=0.005 | 30.7 img/s | ETA~2m50s | GPU~2821 MiB
# [batch  300/1546] loss(b)=0.1487 | loss(µ50)=0.1212 | lr=0.005 | 31.7 img/s | ETA~2m43s | GPU~2821 MiB
# [batch  350/1546] loss(b)=0.0974 | loss(µ50)=0.1208 | lr=0.005 | 30.7 img/s | ETA~2m37s | GPU~2821 MiB
# [batch  400/1546] loss(b)=0.1326 | loss(µ50)=0.1215 | lr=0.005 | 30.3 img/s | ETA~2m30s | GPU~2821 MiB
# [batch  450/1546] loss(b)=0.1154 | loss(µ50)=0.1129 | lr=0.005 | 31.5 img/s | ETA~2m24s | GPU~2821 MiB
# [batch  500/1546] loss(b)=0.1263 | loss(µ50)=0.1125 | lr=0.005 | 30.6 img/s | ETA~2m17s | GPU~2821 MiB
# [batch  550/1546] loss(b)=0.0837 | loss(µ50)=0.1101 | lr=0.005 | 30.7 img/s | ETA~2m10s | GPU~2821 MiB
# [batch  600/1546] loss(b)=0.1220 | loss(µ50)=0.1130 | lr=0.005 | 31.3 img/s | ETA~2m5s | GPU~2821 MiB
# [batch  650/1546] loss(b)=0.0862 | loss(µ50)=0.1107 | lr=0.005 | 29.2 img/s | ETA~1m58s | GPU~2821 MiB
# [batch  700/1546] loss(b)=0.1152 | loss(µ50)=0.1077 | lr=0.005 | 29.6 img/s | ETA~1m52s | GPU~2821 MiB
# [batch  750/1546] loss(b)=0.1354 | loss(µ50)=0.1091 | lr=0.005 | 30.5 img/s | ETA~1m45s | GPU~2821 MiB
# [batch  800/1546] loss(b)=0.1005 | loss(µ50)=0.1163 | lr=0.005 | 30.6 img/s | ETA~1m38s | GPU~2821 MiB
# [batch  850/1546] loss(b)=0.0940 | loss(µ50)=0.1080 | lr=0.005 | 31.0 img/s | ETA~1m32s | GPU~2821 MiB
# [batch  900/1546] loss(b)=0.1119 | loss(µ50)=0.1065 | lr=0.005 | 29.7 img/s | ETA~1m25s | GPU~2821 MiB
# [batch  950/1546] loss(b)=0.0740 | loss(µ50)=0.1059 | lr=0.005 | 29.0 img/s | ETA~1m18s | GPU~2821 MiB
# [batch 1000/1546] loss(b)=0.1059 | loss(µ50)=0.1021 | lr=0.005 | 30.3 img/s | ETA~1m12s | GPU~2821 MiB
# [batch 1050/1546] loss(b)=0.1104 | loss(µ50)=0.1075 | lr=0.005 | 29.8 img/s | ETA~1m5s | GPU~2821 MiB
# [batch 1100/1546] loss(b)=0.0866 | loss(µ50)=0.1047 | lr=0.005 | 30.2 img/s | ETA~0m59s | GPU~2821 MiB
# [batch 1150/1546] loss(b)=0.0962 | loss(µ50)=0.1010 | lr=0.005 | 30.7 img/s | ETA~0m52s | GPU~2821 MiB
# [batch 1200/1546] loss(b)=0.0712 | loss(µ50)=0.1032 | lr=0.005 | 30.7 img/s | ETA~0m45s | GPU~2821 MiB
# [batch 1250/1546] loss(b)=0.0915 | loss(µ50)=0.0977 | lr=0.005 | 29.7 img/s | ETA~0m39s | GPU~2821 MiB
# [batch 1300/1546] loss(b)=0.1372 | loss(µ50)=0.0997 | lr=0.005 | 29.5 img/s | ETA~0m32s | GPU~2821 MiB
# [batch 1350/1546] loss(b)=0.1081 | loss(µ50)=0.0979 | lr=0.005 | 31.0 img/s | ETA~0m25s | GPU~2821 MiB
# [batch 1400/1546] loss(b)=0.0859 | loss(µ50)=0.0977 | lr=0.005 | 31.4 img/s | ETA~0m19s | GPU~2821 MiB
# [batch 1450/1546] loss(b)=0.0962 | loss(µ50)=0.1001 | lr=0.005 | 31.1 img/s | ETA~0m12s | GPU~2821 MiB
# [batch 1500/1546] loss(b)=0.1123 | loss(µ50)=0.1004 | lr=0.005 | 30.5 img/s | ETA~0m6s | GPU~2821 MiB
# [batch 1546/1546] loss(b)=0.1264 | loss(µ50)=0.1042 | lr=0.005 | 4.7 img/s | ETA~0m0s | GPU~2821 MiB
# FIN TRAIN
# INICIO val_loss (batches=442) ...
# [val_loss   50/442] loss=0.1404 | 12.25 it/s
# [val_loss  100/442] loss=0.1114 | 12.48 it/s
# [val_loss  150/442] loss=0.1036 | 12.55 it/s
# [val_loss  200/442] loss=0.0935 | 12.62 it/s
# [val_loss  250/442] loss=0.0850 | 12.66 it/s
# [val_loss  300/442] loss=0.1194 | 12.68 it/s
# [val_loss  350/442] loss=0.0699 | 12.70 it/s
# [val_loss  400/442] loss=0.1113 | 12.71 it/s
# [val_loss  442/442] loss=0.0716 | 12.71 it/s
# FIN val_loss  (0.6 min)
# INICIO val_prf (batches=442) ...
# [val_prf    50/442] 11.64 it/s | TP=26 FP=142 FN=174
# [val_prf   100/442] 11.70 it/s | TP=196 FP=261 FN=204
# [val_prf   150/442] 11.71 it/s | TP=378 FP=388 FN=222
# [val_prf   200/442] 11.71 it/s | TP=541 FP=490 FN=259
# [val_prf   250/442] 11.73 it/s | TP=699 FP=588 FN=301
# [val_prf   300/442] 11.73 it/s | TP=854 FP=669 FN=346
# [val_prf   350/442] 11.72 it/s | TP=999 FP=770 FN=401
# [val_prf   400/442] 11.73 it/s | TP=1146 FP=870 FN=454
# [val_prf   442/442] 11.74 it/s | TP=1261 FP=953 FN=505
# FIN val_prf  (0.6 min)
# INICIO val_mAP (batches=442) ...
# FIN val_mAP  (0.7 min)
# [RESUMEN ÉPOCA 01] lr→0.005 | dur=5.3 min | train_loss=0.1123 | val_loss=0.0995 | val_rec=0.664 | val_f2=0.623 | val_mAP50=0.637 | val_mAP=0.238
#
# ================================================================================
# INICIO ÉPOCA 2/20  |  train_batches: 1546  |  batch_size: 4
# GPU: NVIDIA A100-SXM4-40GB  |  VRAM total: 39.6 GB
# ================================================================================
# [batch   50/1546] loss(b)=0.0745 | loss(µ50)=0.0986 | lr=0.005 | 30.1 img/s | ETA~3m20s | GPU~2819 MiB
# [batch  100/1546] loss(b)=0.0745 | loss(µ50)=0.0963 | lr=0.005 | 30.8 img/s | ETA~3m10s | GPU~2819 MiB
# [batch  150/1546] loss(b)=0.1413 | loss(µ50)=0.0981 | lr=0.005 | 29.4 img/s | ETA~3m4s | GPU~2819 MiB
# [batch  200/1546] loss(b)=0.1367 | loss(µ50)=0.1009 | lr=0.005 | 31.3 img/s | ETA~2m56s | GPU~2820 MiB
# [batch  250/1546] loss(b)=0.0789 | loss(µ50)=0.0965 | lr=0.005 | 30.6 img/s | ETA~2m49s | GPU~2820 MiB
# [batch  300/1546] loss(b)=0.0920 | loss(µ50)=0.0891 | lr=0.005 | 30.6 img/s | ETA~2m43s | GPU~2820 MiB
# [batch  350/1546] loss(b)=0.1104 | loss(µ50)=0.0955 | lr=0.005 | 29.6 img/s | ETA~2m37s | GPU~2820 MiB
# [batch  400/1546] loss(b)=0.0762 | loss(µ50)=0.1034 | lr=0.005 | 30.4 img/s | ETA~2m30s | GPU~2820 MiB
# [batch  450/1546] loss(b)=0.0705 | loss(µ50)=0.0972 | lr=0.005 | 30.8 img/s | ETA~2m23s | GPU~2820 MiB
# [batch  500/1546] loss(b)=0.1050 | loss(µ50)=0.0968 | lr=0.005 | 30.1 img/s | ETA~2m18s | GPU~2820 MiB
# [batch  550/1546] loss(b)=0.1255 | loss(µ50)=0.0959 | lr=0.005 | 33.1 img/s | ETA~2m10s | GPU~2820 MiB
# [batch  600/1546] loss(b)=0.0904 | loss(µ50)=0.0992 | lr=0.005 | 29.6 img/s | ETA~2m3s | GPU~2820 MiB
# [batch  650/1546] loss(b)=0.1012 | loss(µ50)=0.0943 | lr=0.005 | 31.3 img/s | ETA~1m57s | GPU~2820 MiB
# [batch  700/1546] loss(b)=0.0844 | loss(µ50)=0.0912 | lr=0.005 | 29.2 img/s | ETA~1m51s | GPU~2820 MiB
# [batch  750/1546] loss(b)=0.1018 | loss(µ50)=0.0944 | lr=0.005 | 30.4 img/s | ETA~1m44s | GPU~2820 MiB
# [batch  800/1546] loss(b)=0.1342 | loss(µ50)=0.0923 | lr=0.005 | 30.9 img/s | ETA~1m38s | GPU~2820 MiB
# [batch  850/1546] loss(b)=0.1140 | loss(µ50)=0.0945 | lr=0.005 | 30.6 img/s | ETA~1m31s | GPU~2820 MiB
# [batch  900/1546] loss(b)=0.0757 | loss(µ50)=0.0857 | lr=0.005 | 29.6 img/s | ETA~1m25s | GPU~2820 MiB
# [batch  950/1546] loss(b)=0.1035 | loss(µ50)=0.0985 | lr=0.005 | 30.0 img/s | ETA~1m18s | GPU~2820 MiB
# [batch 1000/1546] loss(b)=0.0893 | loss(µ50)=0.0947 | lr=0.005 | 30.6 img/s | ETA~1m11s | GPU~2820 MiB
# [batch 1050/1546] loss(b)=0.1009 | loss(µ50)=0.0899 | lr=0.005 | 30.7 img/s | ETA~1m5s | GPU~2820 MiB
# [batch 1100/1546] loss(b)=0.1497 | loss(µ50)=0.0999 | lr=0.005 | 31.9 img/s | ETA~0m58s | GPU~2820 MiB
# [batch 1150/1546] loss(b)=0.0913 | loss(µ50)=0.0986 | lr=0.005 | 29.8 img/s | ETA~0m52s | GPU~2820 MiB
# [batch 1200/1546] loss(b)=0.1019 | loss(µ50)=0.1017 | lr=0.005 | 31.4 img/s | ETA~0m45s | GPU~2820 MiB
# [batch 1250/1546] loss(b)=0.1108 | loss(µ50)=0.1013 | lr=0.005 | 30.8 img/s | ETA~0m38s | GPU~2820 MiB
# [batch 1300/1546] loss(b)=0.0925 | loss(µ50)=0.0971 | lr=0.005 | 31.8 img/s | ETA~0m32s | GPU~2820 MiB
# [batch 1350/1546] loss(b)=0.1049 | loss(µ50)=0.0957 | lr=0.005 | 30.8 img/s | ETA~0m25s | GPU~2820 MiB
# [batch 1400/1546] loss(b)=0.0915 | loss(µ50)=0.0876 | lr=0.005 | 31.1 img/s | ETA~0m19s | GPU~2820 MiB
# [batch 1450/1546] loss(b)=0.0968 | loss(µ50)=0.0888 | lr=0.005 | 30.6 img/s | ETA~0m12s | GPU~2820 MiB
# [batch 1500/1546] loss(b)=0.0761 | loss(µ50)=0.0921 | lr=0.005 | 30.2 img/s | ETA~0m6s | GPU~2820 MiB
# [batch 1546/1546] loss(b)=0.1255 | loss(µ50)=0.0911 | lr=0.005 | 11.5 img/s | ETA~0m0s | GPU~2820 MiB
# FIN TRAIN
# INICIO val_loss (batches=442) ...
# [val_loss   50/442] loss=0.1279 | 12.69 it/s
# [val_loss  100/442] loss=0.0916 | 12.74 it/s
# [val_loss  150/442] loss=0.0880 | 12.77 it/s
# [val_loss  200/442] loss=0.0941 | 12.79 it/s
# [val_loss  250/442] loss=0.0847 | 12.81 it/s
# [val_loss  300/442] loss=0.1047 | 12.81 it/s
# [val_loss  350/442] loss=0.0857 | 12.82 it/s
# [val_loss  400/442] loss=0.0759 | 12.82 it/s
# [val_loss  442/442] loss=0.0592 | 12.84 it/s
# FIN val_loss  (0.6 min)
# INICIO val_prf (batches=442) ...
# [val_prf    50/442] 11.73 it/s | TP=84 FP=95 FN=116
# [val_prf   100/442] 11.77 it/s | TP=264 FP=143 FN=136
# [val_prf   150/442] 11.78 it/s | TP=454 FP=196 FN=146
# [val_prf   200/442] 11.80 it/s | TP=625 FP=268 FN=175
# [val_prf   250/442] 11.80 it/s | TP=798 FP=360 FN=202
# [val_prf   300/442] 11.80 it/s | TP=960 FP=430 FN=240
# [val_prf   350/442] 11.81 it/s | TP=1119 FP=517 FN=281
# [val_prf   400/442] 11.80 it/s | TP=1273 FP=607 FN=327
# [val_prf   442/442] 11.82 it/s | TP=1403 FP=675 FN=363
# FIN val_prf  (0.6 min)
# INICIO val_mAP (batches=442) ...
# FIN val_mAP  (0.7 min)
# [RESUMEN ÉPOCA 02] lr→0.005 | dur=5.3 min | train_loss=0.0954 | val_loss=0.0959 | val_rec=0.762 | val_f2=0.735 | val_mAP50=0.740 | val_mAP=0.294
#
# ================================================================================
# INICIO ÉPOCA 3/20  |  train_batches: 1546  |  batch_size: 4
# GPU: NVIDIA A100-SXM4-40GB  |  VRAM total: 39.6 GB
# ================================================================================
# [batch   50/1546] loss(b)=0.0911 | loss(µ50)=0.0958 | lr=0.005 | 29.8 img/s | ETA~3m20s | GPU~2820 MiB
# [batch  100/1546] loss(b)=0.0802 | loss(µ50)=0.0930 | lr=0.005 | 29.9 img/s | ETA~3m9s | GPU~2820 MiB
# [batch  150/1546] loss(b)=0.1096 | loss(µ50)=0.0877 | lr=0.005 | 30.2 img/s | ETA~3m3s | GPU~2820 MiB
# [batch  200/1546] loss(b)=0.0799 | loss(µ50)=0.0889 | lr=0.005 | 30.2 img/s | ETA~2m56s | GPU~2820 MiB
# [batch  250/1546] loss(b)=0.1303 | loss(µ50)=0.0963 | lr=0.005 | 32.7 img/s | ETA~2m50s | GPU~2820 MiB
# [batch  300/1546] loss(b)=0.1225 | loss(µ50)=0.0937 | lr=0.005 | 30.9 img/s | ETA~2m43s | GPU~2820 MiB
# [batch  350/1546] loss(b)=0.0919 | loss(µ50)=0.0886 | lr=0.005 | 31.5 img/s | ETA~2m36s | GPU~2820 MiB
# [batch  400/1546] loss(b)=0.0812 | loss(µ50)=0.0945 | lr=0.005 | 30.9 img/s | ETA~2m29s | GPU~2820 MiB
# [batch  450/1546] loss(b)=0.0970 | loss(µ50)=0.0984 | lr=0.005 | 32.0 img/s | ETA~2m23s | GPU~2820 MiB
# [batch  500/1546] loss(b)=0.0944 | loss(µ50)=0.0937 | lr=0.005 | 29.0 img/s | ETA~2m17s | GPU~2820 MiB
# [batch  550/1546] loss(b)=0.0664 | loss(µ50)=0.0995 | lr=0.005 | 30.9 img/s | ETA~2m10s | GPU~2820 MiB
# [batch  600/1546] loss(b)=0.0868 | loss(µ50)=0.0980 | lr=0.005 | 31.6 img/s | ETA~2m3s | GPU~2820 MiB
# [batch  650/1546] loss(b)=0.1066 | loss(µ50)=0.0959 | lr=0.005 | 30.9 img/s | ETA~1m56s | GPU~2820 MiB
# [batch  700/1546] loss(b)=0.0978 | loss(µ50)=0.0964 | lr=0.005 | 30.4 img/s | ETA~1m50s | GPU~2820 MiB
# [batch  750/1546] loss(b)=0.0800 | loss(µ50)=0.0960 | lr=0.005 | 30.5 img/s | ETA~1m43s | GPU~2820 MiB
# [batch  800/1546] loss(b)=0.0683 | loss(µ50)=0.0912 | lr=0.005 | 31.5 img/s | ETA~1m37s | GPU~2820 MiB
# [batch  850/1546] loss(b)=0.1030 | loss(µ50)=0.0906 | lr=0.005 | 32.1 img/s | ETA~1m30s | GPU~2820 MiB
# [batch  900/1546] loss(b)=0.0992 | loss(µ50)=0.0907 | lr=0.005 | 29.1 img/s | ETA~1m24s | GPU~2820 MiB
# [batch  950/1546] loss(b)=0.0814 | loss(µ50)=0.0929 | lr=0.005 | 30.4 img/s | ETA~1m17s | GPU~2820 MiB
# [batch 1000/1546] loss(b)=0.0942 | loss(µ50)=0.0975 | lr=0.005 | 31.0 img/s | ETA~1m11s | GPU~2820 MiB
# [batch 1050/1546] loss(b)=0.0805 | loss(µ50)=0.1001 | lr=0.005 | 30.8 img/s | ETA~1m5s | GPU~2820 MiB
# [batch 1100/1546] loss(b)=0.1154 | loss(µ50)=0.0944 | lr=0.005 | 31.6 img/s | ETA~0m58s | GPU~2820 MiB
# [batch 1150/1546] loss(b)=0.0980 | loss(µ50)=0.0955 | lr=0.005 | 30.0 img/s | ETA~0m51s | GPU~2820 MiB
# [batch 1200/1546] loss(b)=0.0876 | loss(µ50)=0.0971 | lr=0.005 | 29.3 img/s | ETA~0m45s | GPU~2820 MiB
# [batch 1250/1546] loss(b)=0.0918 | loss(µ50)=0.0984 | lr=0.005 | 30.6 img/s | ETA~0m38s | GPU~2820 MiB
# [batch 1300/1546] loss(b)=0.0665 | loss(µ50)=0.0945 | lr=0.005 | 29.0 img/s | ETA~0m32s | GPU~2820 MiB
# [batch 1350/1546] loss(b)=0.0945 | loss(µ50)=0.0903 | lr=0.005 | 30.2 img/s | ETA~0m25s | GPU~2820 MiB
# [batch 1400/1546] loss(b)=0.1192 | loss(µ50)=0.0966 | lr=0.005 | 32.1 img/s | ETA~0m19s | GPU~2820 MiB
# [batch 1450/1546] loss(b)=0.0785 | loss(µ50)=0.0965 | lr=0.005 | 29.9 img/s | ETA~0m12s | GPU~2820 MiB
# [batch 1500/1546] loss(b)=0.0731 | loss(µ50)=0.0925 | lr=0.005 | 30.9 img/s | ETA~0m6s | GPU~2820 MiB
# [batch 1546/1546] loss(b)=0.0589 | loss(µ50)=0.0970 | lr=0.005 | 11.6 img/s | ETA~0m0s | GPU~2820 MiB
# FIN TRAIN
# INICIO val_loss (batches=442) ...
# [val_loss   50/442] loss=0.1205 | 12.64 it/s
# [val_loss  100/442] loss=0.0953 | 12.75 it/s
# [val_loss  150/442] loss=0.0889 | 12.80 it/s
# [val_loss  200/442] loss=0.1128 | 12.82 it/s
# [val_loss  250/442] loss=0.0844 | 12.84 it/s
# [val_loss  300/442] loss=0.1254 | 12.85 it/s
# [val_loss  350/442] loss=0.0918 | 12.85 it/s
# [val_loss  400/442] loss=0.0773 | 12.85 it/s
# [val_loss  442/442] loss=0.0671 | 12.86 it/s
# FIN val_loss  (0.6 min)
# INICIO val_prf (batches=442) ...
# [val_prf    50/442] 11.68 it/s | TP=94 FP=163 FN=106
# [val_prf   100/442] 11.76 it/s | TP=275 FP=225 FN=125
# [val_prf   150/442] 11.80 it/s | TP=467 FP=289 FN=133
# [val_prf   200/442] 11.81 it/s | TP=647 FP=382 FN=153
# [val_prf   250/442] 11.83 it/s | TP=834 FP=472 FN=166
# [val_prf   300/442] 11.84 it/s | TP=1012 FP=575 FN=188
# [val_prf   350/442] 11.84 it/s | TP=1186 FP=678 FN=214
# [val_prf   400/442] 11.85 it/s | TP=1364 FP=790 FN=236
# [val_prf   442/442] 11.87 it/s | TP=1502 FP=878 FN=264
# FIN val_prf  (0.6 min)
# INICIO val_mAP (batches=442) ...
# FIN val_mAP  (0.7 min)
# [RESUMEN ÉPOCA 03] lr→0.005 | dur=5.2 min | train_loss=0.0946 | val_loss=0.0989 | val_rec=0.817 | val_f2=0.768 | val_mAP50=0.787 | val_mAP=0.314
#
# ================================================================================
# INICIO ÉPOCA 4/20  |  train_batches: 1546  |  batch_size: 4
# GPU: NVIDIA A100-SXM4-40GB  |  VRAM total: 39.6 GB
# ================================================================================
# [batch   50/1546] loss(b)=0.0784 | loss(µ50)=0.0907 | lr=0.005 | 29.3 img/s | ETA~3m21s | GPU~2820 MiB
# [batch  100/1546] loss(b)=0.1017 | loss(µ50)=0.0932 | lr=0.005 | 30.4 img/s | ETA~3m10s | GPU~2821 MiB
# [batch  150/1546] loss(b)=0.0625 | loss(µ50)=0.0897 | lr=0.005 | 30.6 img/s | ETA~3m3s | GPU~2821 MiB
# [batch  200/1546] loss(b)=0.0990 | loss(µ50)=0.0907 | lr=0.005 | 30.2 img/s | ETA~2m56s | GPU~2821 MiB
# [batch  250/1546] loss(b)=0.0855 | loss(µ50)=0.0884 | lr=0.005 | 31.2 img/s | ETA~2m53s | GPU~2821 MiB
# [batch  300/1546] loss(b)=0.1009 | loss(µ50)=0.0949 | lr=0.005 | 30.9 img/s | ETA~2m44s | GPU~2821 MiB
# [batch  350/1546] loss(b)=0.0935 | loss(µ50)=0.0901 | lr=0.005 | 30.6 img/s | ETA~2m37s | GPU~2821 MiB
# [batch  400/1546] loss(b)=0.0709 | loss(µ50)=0.0884 | lr=0.005 | 31.0 img/s | ETA~2m32s | GPU~2821 MiB
# [batch  450/1546] loss(b)=0.0760 | loss(µ50)=0.0944 | lr=0.005 | 30.7 img/s | ETA~2m23s | GPU~2821 MiB
# [batch  500/1546] loss(b)=0.0749 | loss(µ50)=0.0868 | lr=0.005 | 31.1 img/s | ETA~2m16s | GPU~2821 MiB
# [batch  550/1546] loss(b)=0.0880 | loss(µ50)=0.0918 | lr=0.005 | 29.7 img/s | ETA~2m10s | GPU~2821 MiB
# [batch  600/1546] loss(b)=0.0847 | loss(µ50)=0.0879 | lr=0.005 | 30.9 img/s | ETA~2m4s | GPU~2821 MiB
# [batch  650/1546] loss(b)=0.0800 | loss(µ50)=0.0962 | lr=0.005 | 30.8 img/s | ETA~1m57s | GPU~2821 MiB
# [batch  700/1546] loss(b)=0.0743 | loss(µ50)=0.0920 | lr=0.005 | 30.8 img/s | ETA~1m51s | GPU~2821 MiB
# [batch  750/1546] loss(b)=0.0930 | loss(µ50)=0.0931 | lr=0.005 | 28.0 img/s | ETA~1m46s | GPU~2821 MiB
# [batch  800/1546] loss(b)=0.0833 | loss(µ50)=0.0982 | lr=0.005 | 31.1 img/s | ETA~1m38s | GPU~2821 MiB
# [batch  850/1546] loss(b)=0.1050 | loss(µ50)=0.0903 | lr=0.005 | 31.1 img/s | ETA~1m31s | GPU~2821 MiB
# [batch  900/1546] loss(b)=0.0907 | loss(µ50)=0.0894 | lr=0.005 | 30.6 img/s | ETA~1m24s | GPU~2821 MiB
# [batch  950/1546] loss(b)=0.1260 | loss(µ50)=0.0964 | lr=0.005 | 30.3 img/s | ETA~1m18s | GPU~2821 MiB
# [batch 1000/1546] loss(b)=0.0907 | loss(µ50)=0.0950 | lr=0.005 | 30.9 img/s | ETA~1m11s | GPU~2821 MiB
# [batch 1050/1546] loss(b)=0.0967 | loss(µ50)=0.0883 | lr=0.005 | 30.8 img/s | ETA~1m5s | GPU~2821 MiB
# [batch 1100/1546] loss(b)=0.0870 | loss(µ50)=0.0935 | lr=0.005 | 30.1 img/s | ETA~0m58s | GPU~2821 MiB
# [batch 1150/1546] loss(b)=0.0954 | loss(µ50)=0.0903 | lr=0.005 | 30.6 img/s | ETA~0m52s | GPU~2821 MiB
# [batch 1200/1546] loss(b)=0.1037 | loss(µ50)=0.0932 | lr=0.005 | 29.3 img/s | ETA~0m45s | GPU~2821 MiB
# [batch 1250/1546] loss(b)=0.1155 | loss(µ50)=0.0951 | lr=0.005 | 30.8 img/s | ETA~0m38s | GPU~2821 MiB
# [batch 1300/1546] loss(b)=0.0965 | loss(µ50)=0.0897 | lr=0.005 | 30.4 img/s | ETA~0m32s | GPU~2821 MiB
# [batch 1350/1546] loss(b)=0.0898 | loss(µ50)=0.0898 | lr=0.005 | 31.3 img/s | ETA~0m25s | GPU~2821 MiB
# [batch 1400/1546] loss(b)=0.0980 | loss(µ50)=0.0921 | lr=0.005 | 30.0 img/s | ETA~0m19s | GPU~2821 MiB
# [batch 1450/1546] loss(b)=0.0887 | loss(µ50)=0.0891 | lr=0.005 | 29.7 img/s | ETA~0m12s | GPU~2821 MiB
# [batch 1500/1546] loss(b)=0.0826 | loss(µ50)=0.0914 | lr=0.005 | 30.0 img/s | ETA~0m6s | GPU~2821 MiB
# [batch 1546/1546] loss(b)=0.0840 | loss(µ50)=0.0919 | lr=0.005 | 11.6 img/s | ETA~0m0s | GPU~2821 MiB
# FIN TRAIN
# INICIO val_loss (batches=442) ...
# [val_loss   50/442] loss=0.1195 | 12.65 it/s
# [val_loss  100/442] loss=0.0867 | 12.78 it/s
# [val_loss  150/442] loss=0.0935 | 12.81 it/s
# [val_loss  200/442] loss=0.0963 | 12.84 it/s
# [val_loss  250/442] loss=0.0707 | 12.86 it/s
# [val_loss  300/442] loss=0.1195 | 12.87 it/s
# [val_loss  350/442] loss=0.0718 | 12.87 it/s
# [val_loss  400/442] loss=0.0826 | 12.88 it/s
# [val_loss  442/442] loss=0.0770 | 12.90 it/s
# FIN val_loss  (0.6 min)
# INICIO val_prf (batches=442) ...
# [val_prf    50/442] 11.77 it/s | TP=110 FP=83 FN=90
# [val_prf   100/442] 11.84 it/s | TP=290 FP=113 FN=110
# [val_prf   150/442] 11.86 it/s | TP=481 FP=144 FN=119
# [val_prf   200/442] 11.87 it/s | TP=658 FP=195 FN=142
# [val_prf   250/442] 11.88 it/s | TP=836 FP=249 FN=164
# [val_prf   300/442] 11.88 it/s | TP=1007 FP=294 FN=193
# [val_prf   350/442] 11.88 it/s | TP=1170 FP=350 FN=230
# [val_prf   400/442] 11.89 it/s | TP=1331 FP=403 FN=269
# [val_prf   442/442] 11.91 it/s | TP=1467 FP=439 FN=299
# FIN val_prf  (0.6 min)
# INICIO val_mAP (batches=442) ...
# FIN val_mAP  (0.7 min)
# [RESUMEN ÉPOCA 04] lr→0.005 | dur=5.2 min | train_loss=0.0917 | val_loss=0.0937 | val_rec=0.805 | val_f2=0.794 | val_mAP50=0.798 | val_mAP=0.321
#
# ================================================================================
# INICIO ÉPOCA 5/20  |  train_batches: 1546  |  batch_size: 4
# GPU: NVIDIA A100-SXM4-40GB  |  VRAM total: 39.6 GB
# ================================================================================
# [batch   50/1546] loss(b)=0.0631 | loss(µ50)=0.0838 | lr=0.005 | 29.9 img/s | ETA~3m20s | GPU~2821 MiB
# [batch  100/1546] loss(b)=0.1065 | loss(µ50)=0.0879 | lr=0.005 | 29.7 img/s | ETA~3m9s | GPU~2821 MiB
# [batch  150/1546] loss(b)=0.0958 | loss(µ50)=0.0878 | lr=0.005 | 31.2 img/s | ETA~3m3s | GPU~2821 MiB
# [batch  200/1546] loss(b)=0.0814 | loss(µ50)=0.0856 | lr=0.005 | 30.2 img/s | ETA~2m57s | GPU~2821 MiB
# [batch  250/1546] loss(b)=0.1042 | loss(µ50)=0.0905 | lr=0.005 | 30.8 img/s | ETA~2m49s | GPU~2821 MiB
# [batch  300/1546] loss(b)=0.0662 | loss(µ50)=0.0895 | lr=0.005 | 30.8 img/s | ETA~2m43s | GPU~2821 MiB
# [batch  350/1546] loss(b)=0.0745 | loss(µ50)=0.0912 | lr=0.005 | 30.6 img/s | ETA~2m37s | GPU~2821 MiB
# [batch  400/1546] loss(b)=0.1136 | loss(µ50)=0.0947 | lr=0.005 | 30.5 img/s | ETA~2m30s | GPU~2821 MiB
# [batch  450/1546] loss(b)=0.0982 | loss(µ50)=0.0894 | lr=0.005 | 30.4 img/s | ETA~2m23s | GPU~2821 MiB
# [batch  500/1546] loss(b)=0.1371 | loss(µ50)=0.0920 | lr=0.005 | 29.8 img/s | ETA~2m17s | GPU~2821 MiB
# [batch  550/1546] loss(b)=0.0951 | loss(µ50)=0.0935 | lr=0.005 | 29.1 img/s | ETA~2m10s | GPU~2821 MiB
# [batch  600/1546] loss(b)=0.0977 | loss(µ50)=0.0986 | lr=0.005 | 31.5 img/s | ETA~2m4s | GPU~2821 MiB
# [batch  650/1546] loss(b)=0.0868 | loss(µ50)=0.0941 | lr=0.005 | 30.1 img/s | ETA~1m57s | GPU~2821 MiB
# [batch  700/1546] loss(b)=0.0710 | loss(µ50)=0.0898 | lr=0.005 | 30.5 img/s | ETA~1m51s | GPU~2821 MiB
# [batch  750/1546] loss(b)=0.1118 | loss(µ50)=0.0856 | lr=0.005 | 31.4 img/s | ETA~1m44s | GPU~2821 MiB
# [batch  800/1546] loss(b)=0.0882 | loss(µ50)=0.0922 | lr=0.005 | 30.4 img/s | ETA~1m37s | GPU~2821 MiB
# [batch  850/1546] loss(b)=0.0791 | loss(µ50)=0.0944 | lr=0.005 | 29.0 img/s | ETA~1m31s | GPU~2821 MiB
# [batch  900/1546] loss(b)=0.0977 | loss(µ50)=0.0913 | lr=0.005 | 30.2 img/s | ETA~1m24s | GPU~2821 MiB
# [batch  950/1546] loss(b)=0.0920 | loss(µ50)=0.0868 | lr=0.005 | 31.9 img/s | ETA~1m19s | GPU~2821 MiB
# [batch 1000/1546] loss(b)=0.0789 | loss(µ50)=0.0859 | lr=0.005 | 31.7 img/s | ETA~1m11s | GPU~2821 MiB
# [batch 1050/1546] loss(b)=0.0821 | loss(µ50)=0.0969 | lr=0.005 | 30.9 img/s | ETA~1m5s | GPU~2821 MiB
# [batch 1100/1546] loss(b)=0.1084 | loss(µ50)=0.0908 | lr=0.005 | 30.8 img/s | ETA~0m58s | GPU~2821 MiB
# [batch 1150/1546] loss(b)=0.0898 | loss(µ50)=0.0870 | lr=0.005 | 29.6 img/s | ETA~0m52s | GPU~2821 MiB
# [batch 1200/1546] loss(b)=0.0887 | loss(µ50)=0.0842 | lr=0.005 | 30.7 img/s | ETA~0m45s | GPU~2821 MiB
# [batch 1250/1546] loss(b)=0.1117 | loss(µ50)=0.0962 | lr=0.005 | 30.9 img/s | ETA~0m38s | GPU~2821 MiB
# [batch 1300/1546] loss(b)=0.0938 | loss(µ50)=0.0900 | lr=0.005 | 31.6 img/s | ETA~0m32s | GPU~2821 MiB
# [batch 1350/1546] loss(b)=0.1104 | loss(µ50)=0.0955 | lr=0.005 | 30.1 img/s | ETA~0m25s | GPU~2821 MiB
# [batch 1400/1546] loss(b)=0.0814 | loss(µ50)=0.0876 | lr=0.005 | 29.7 img/s | ETA~0m19s | GPU~2821 MiB
# [batch 1450/1546] loss(b)=0.0672 | loss(µ50)=0.0902 | lr=0.005 | 30.8 img/s | ETA~0m12s | GPU~2821 MiB
# [batch 1500/1546] loss(b)=0.0736 | loss(µ50)=0.0929 | lr=0.005 | 30.2 img/s | ETA~0m6s | GPU~2821 MiB
# [batch 1546/1546] loss(b)=0.0925 | loss(µ50)=0.0950 | lr=0.005 | 11.6 img/s | ETA~0m0s | GPU~2821 MiB
# FIN TRAIN
# INICIO val_loss (batches=442) ...
# [val_loss   50/442] loss=0.1091 | 12.74 it/s
# [val_loss  100/442] loss=0.0989 | 12.80 it/s
# [val_loss  150/442] loss=0.0901 | 12.83 it/s
# [val_loss  200/442] loss=0.1233 | 12.85 it/s
# [val_loss  250/442] loss=0.0733 | 12.84 it/s
# [val_loss  300/442] loss=0.1163 | 12.84 it/s
# [val_loss  350/442] loss=0.0743 | 12.85 it/s
# [val_loss  400/442] loss=0.0897 | 12.85 it/s
# [val_loss  442/442] loss=0.0905 | 12.86 it/s
# FIN val_loss  (0.6 min)
# INICIO val_prf (batches=442) ...
# [val_prf    50/442] 11.76 it/s | TP=124 FP=163 FN=76
# [val_prf   100/442] 11.83 it/s | TP=312 FP=246 FN=88
# [val_prf   150/442] 11.83 it/s | TP=507 FP=330 FN=93
# [val_prf   200/442] 11.84 it/s | TP=689 FP=440 FN=111
# [val_prf   250/442] 11.85 it/s | TP=877 FP=548 FN=123
# [val_prf   300/442] 11.84 it/s | TP=1056 FP=666 FN=144
# [val_prf   350/442] 11.84 it/s | TP=1231 FP=794 FN=169
# [val_prf   400/442] 11.84 it/s | TP=1404 FP=919 FN=196
# [val_prf   442/442] 11.85 it/s | TP=1544 FP=1026 FN=222
# FIN val_prf  (0.6 min)
# INICIO val_mAP (batches=442) ...
# FIN val_mAP  (0.7 min)
# [RESUMEN ÉPOCA 05] lr→0.0005 | dur=5.3 min | train_loss=0.0906 | val_loss=0.0951 | val_rec=0.851 | val_f2=0.783 | val_mAP50=0.799 | val_mAP=0.335
#
# ================================================================================
# INICIO ÉPOCA 6/20  |  train_batches: 1546  |  batch_size: 4
# GPU: NVIDIA A100-SXM4-40GB  |  VRAM total: 39.6 GB
# ================================================================================
# [batch   50/1546] loss(b)=0.1123 | loss(µ50)=0.0860 | lr=0.0005 | 30.0 img/s | ETA~3m21s | GPU~2821 MiB
# [batch  100/1546] loss(b)=0.0899 | loss(µ50)=0.0828 | lr=0.0005 | 31.1 img/s | ETA~3m9s | GPU~2821 MiB
# [batch  150/1546] loss(b)=0.0768 | loss(µ50)=0.0829 | lr=0.0005 | 29.7 img/s | ETA~3m3s | GPU~2821 MiB
# [batch  200/1546] loss(b)=0.0906 | loss(µ50)=0.0816 | lr=0.0005 | 30.6 img/s | ETA~2m56s | GPU~2821 MiB
# [batch  250/1546] loss(b)=0.0565 | loss(µ50)=0.0790 | lr=0.0005 | 28.6 img/s | ETA~2m50s | GPU~2822 MiB
# [batch  300/1546] loss(b)=0.0958 | loss(µ50)=0.0834 | lr=0.0005 | 30.2 img/s | ETA~2m42s | GPU~2822 MiB
# [batch  350/1546] loss(b)=0.0765 | loss(µ50)=0.0793 | lr=0.0005 | 31.6 img/s | ETA~2m37s | GPU~2822 MiB
# [batch  400/1546] loss(b)=0.0765 | loss(µ50)=0.0788 | lr=0.0005 | 30.4 img/s | ETA~2m29s | GPU~2822 MiB
# [batch  450/1546] loss(b)=0.0596 | loss(µ50)=0.0793 | lr=0.0005 | 28.8 img/s | ETA~2m23s | GPU~2822 MiB
# [batch  500/1546] loss(b)=0.0615 | loss(µ50)=0.0777 | lr=0.0005 | 29.9 img/s | ETA~2m17s | GPU~2822 MiB
# [batch  550/1546] loss(b)=0.0733 | loss(µ50)=0.0807 | lr=0.0005 | 28.7 img/s | ETA~2m12s | GPU~2822 MiB
# [batch  600/1546] loss(b)=0.1002 | loss(µ50)=0.0836 | lr=0.0005 | 27.6 img/s | ETA~2m4s | GPU~2822 MiB
# [batch  650/1546] loss(b)=0.0815 | loss(µ50)=0.0825 | lr=0.0005 | 30.7 img/s | ETA~1m58s | GPU~2822 MiB
# [batch  700/1546] loss(b)=0.0843 | loss(µ50)=0.0852 | lr=0.0005 | 30.0 img/s | ETA~1m50s | GPU~2822 MiB
# [batch  750/1546] loss(b)=0.1330 | loss(µ50)=0.0848 | lr=0.0005 | 30.2 img/s | ETA~1m44s | GPU~2822 MiB
# [batch  800/1546] loss(b)=0.0722 | loss(µ50)=0.0795 | lr=0.0005 | 30.3 img/s | ETA~1m37s | GPU~2822 MiB
# [batch  850/1546] loss(b)=0.0701 | loss(µ50)=0.0836 | lr=0.0005 | 31.4 img/s | ETA~1m31s | GPU~2822 MiB
# [batch  900/1546] loss(b)=0.0809 | loss(µ50)=0.0783 | lr=0.0005 | 31.4 img/s | ETA~1m24s | GPU~2822 MiB
# [batch  950/1546] loss(b)=0.0783 | loss(µ50)=0.0797 | lr=0.0005 | 30.6 img/s | ETA~1m18s | GPU~2822 MiB
# [batch 1000/1546] loss(b)=0.0918 | loss(µ50)=0.0839 | lr=0.0005 | 30.2 img/s | ETA~1m11s | GPU~2822 MiB
# [batch 1050/1546] loss(b)=0.0752 | loss(µ50)=0.0827 | lr=0.0005 | 30.8 img/s | ETA~1m5s | GPU~2822 MiB
# [batch 1100/1546] loss(b)=0.1100 | loss(µ50)=0.0800 | lr=0.0005 | 31.0 img/s | ETA~0m58s | GPU~2822 MiB
# [batch 1150/1546] loss(b)=0.0684 | loss(µ50)=0.0820 | lr=0.0005 | 30.6 img/s | ETA~0m51s | GPU~2822 MiB
# [batch 1200/1546] loss(b)=0.0829 | loss(µ50)=0.0827 | lr=0.0005 | 29.7 img/s | ETA~0m45s | GPU~2822 MiB
# [batch 1250/1546] loss(b)=0.0975 | loss(µ50)=0.0810 | lr=0.0005 | 30.4 img/s | ETA~0m38s | GPU~2822 MiB
# [batch 1300/1546] loss(b)=0.0767 | loss(µ50)=0.0768 | lr=0.0005 | 29.3 img/s | ETA~0m32s | GPU~2822 MiB
# [batch 1350/1546] loss(b)=0.0785 | loss(µ50)=0.0824 | lr=0.0005 | 29.5 img/s | ETA~0m25s | GPU~2822 MiB
# [batch 1400/1546] loss(b)=0.0729 | loss(µ50)=0.0852 | lr=0.0005 | 29.9 img/s | ETA~0m19s | GPU~2822 MiB
# [batch 1450/1546] loss(b)=0.0857 | loss(µ50)=0.0816 | lr=0.0005 | 30.8 img/s | ETA~0m12s | GPU~2822 MiB
# [batch 1500/1546] loss(b)=0.0679 | loss(µ50)=0.0822 | lr=0.0005 | 30.1 img/s | ETA~0m6s | GPU~2822 MiB
# [batch 1546/1546] loss(b)=0.0509 | loss(µ50)=0.0825 | lr=0.0005 | 11.6 img/s | ETA~0m0s | GPU~2822 MiB
# FIN TRAIN
# INICIO val_loss (batches=442) ...
# [val_loss   50/442] loss=0.1039 | 12.80 it/s
# [val_loss  100/442] loss=0.0821 | 12.86 it/s
# [val_loss  150/442] loss=0.0835 | 12.88 it/s
# [val_loss  200/442] loss=0.1093 | 12.88 it/s
# [val_loss  250/442] loss=0.0690 | 12.88 it/s
# [val_loss  300/442] loss=0.0977 | 12.90 it/s
# [val_loss  350/442] loss=0.0543 | 12.90 it/s
# [val_loss  400/442] loss=0.0757 | 12.88 it/s
# [val_loss  442/442] loss=0.0542 | 12.88 it/s
# FIN val_loss  (0.6 min)
# INICIO val_prf (batches=442) ...
# [val_prf    50/442] 11.78 it/s | TP=124 FP=84 FN=76
# [val_prf   100/442] 11.83 it/s | TP=313 FP=110 FN=87
# [val_prf   150/442] 11.86 it/s | TP=508 FP=142 FN=92
# [val_prf   200/442] 11.87 it/s | TP=693 FP=193 FN=107
# [val_prf   250/442] 11.88 it/s | TP=882 FP=242 FN=118
# [val_prf   300/442] 11.88 it/s | TP=1064 FP=286 FN=136
# [val_prf   350/442] 11.88 it/s | TP=1249 FP=335 FN=151
# [val_prf   400/442] 11.88 it/s | TP=1427 FP=387 FN=173
# [val_prf   442/442] 11.90 it/s | TP=1571 FP=425 FN=195
# FIN val_prf  (0.6 min)
# INICIO val_mAP (batches=442) ...
# FIN val_mAP  (0.7 min)
# [RESUMEN ÉPOCA 06] lr→0.0005 | dur=5.2 min | train_loss=0.0817 | val_loss=0.0875 | val_rec=0.867 | val_f2=0.847 | val_mAP50=0.863 | val_mAP=0.368
#
# ================================================================================
# INICIO ÉPOCA 7/20  |  train_batches: 1546  |  batch_size: 4
# GPU: NVIDIA A100-SXM4-40GB  |  VRAM total: 39.6 GB
# ================================================================================
# [batch   50/1546] loss(b)=0.0531 | loss(µ50)=0.0755 | lr=0.0005 | 31.8 img/s | ETA~3m18s | GPU~2820 MiB
# [batch  100/1546] loss(b)=0.0625 | loss(µ50)=0.0804 | lr=0.0005 | 31.5 img/s | ETA~3m8s | GPU~2822 MiB
# [batch  150/1546] loss(b)=0.0746 | loss(µ50)=0.0797 | lr=0.0005 | 30.6 img/s | ETA~3m2s | GPU~2822 MiB
# [batch  200/1546] loss(b)=0.0745 | loss(µ50)=0.0801 | lr=0.0005 | 32.0 img/s | ETA~2m55s | GPU~2822 MiB
# [batch  250/1546] loss(b)=0.0666 | loss(µ50)=0.0825 | lr=0.0005 | 31.2 img/s | ETA~2m49s | GPU~2822 MiB
# [batch  300/1546] loss(b)=0.0870 | loss(µ50)=0.0811 | lr=0.0005 | 30.6 img/s | ETA~2m43s | GPU~2822 MiB
# [batch  350/1546] loss(b)=0.1097 | loss(µ50)=0.0819 | lr=0.0005 | 31.6 img/s | ETA~2m35s | GPU~2822 MiB
# [batch  400/1546] loss(b)=0.0841 | loss(µ50)=0.0853 | lr=0.0005 | 30.8 img/s | ETA~2m28s | GPU~2822 MiB
# [batch  450/1546] loss(b)=0.0564 | loss(µ50)=0.0858 | lr=0.0005 | 30.9 img/s | ETA~2m23s | GPU~2822 MiB
# [batch  500/1546] loss(b)=0.0813 | loss(µ50)=0.0818 | lr=0.0005 | 30.9 img/s | ETA~2m16s | GPU~2822 MiB
# [batch  550/1546] loss(b)=0.0566 | loss(µ50)=0.0843 | lr=0.0005 | 30.8 img/s | ETA~2m10s | GPU~2822 MiB
# [batch  600/1546] loss(b)=0.0699 | loss(µ50)=0.0805 | lr=0.0005 | 30.3 img/s | ETA~2m2s | GPU~2822 MiB
# [batch  650/1546] loss(b)=0.0930 | loss(µ50)=0.0811 | lr=0.0005 | 31.2 img/s | ETA~1m58s | GPU~2822 MiB
# [batch  700/1546] loss(b)=0.1071 | loss(µ50)=0.0829 | lr=0.0005 | 30.8 img/s | ETA~1m51s | GPU~2822 MiB
# [batch  750/1546] loss(b)=0.0677 | loss(µ50)=0.0785 | lr=0.0005 | 30.9 img/s | ETA~1m43s | GPU~2822 MiB
# [batch  800/1546] loss(b)=0.0746 | loss(µ50)=0.0785 | lr=0.0005 | 28.6 img/s | ETA~1m37s | GPU~2822 MiB
# [batch  850/1546] loss(b)=0.0891 | loss(µ50)=0.0767 | lr=0.0005 | 31.0 img/s | ETA~1m30s | GPU~2822 MiB
# [batch  900/1546] loss(b)=0.1088 | loss(µ50)=0.0846 | lr=0.0005 | 29.5 img/s | ETA~1m24s | GPU~2822 MiB
# [batch  950/1546] loss(b)=0.0938 | loss(µ50)=0.0831 | lr=0.0005 | 31.2 img/s | ETA~1m17s | GPU~2822 MiB
# [batch 1000/1546] loss(b)=0.0613 | loss(µ50)=0.0820 | lr=0.0005 | 31.2 img/s | ETA~1m11s | GPU~2822 MiB
# [batch 1050/1546] loss(b)=0.0616 | loss(µ50)=0.0795 | lr=0.0005 | 32.4 img/s | ETA~1m4s | GPU~2822 MiB
# [batch 1100/1546] loss(b)=0.1183 | loss(µ50)=0.0797 | lr=0.0005 | 29.3 img/s | ETA~0m58s | GPU~2822 MiB
# [batch 1150/1546] loss(b)=0.0733 | loss(µ50)=0.0827 | lr=0.0005 | 31.5 img/s | ETA~0m51s | GPU~2822 MiB
# [batch 1200/1546] loss(b)=0.0679 | loss(µ50)=0.0805 | lr=0.0005 | 29.8 img/s | ETA~0m45s | GPU~2822 MiB
# [batch 1250/1546] loss(b)=0.0774 | loss(µ50)=0.0805 | lr=0.0005 | 31.0 img/s | ETA~0m38s | GPU~2822 MiB
# [batch 1300/1546] loss(b)=0.1251 | loss(µ50)=0.0777 | lr=0.0005 | 30.9 img/s | ETA~0m31s | GPU~2822 MiB
# [batch 1350/1546] loss(b)=0.0703 | loss(µ50)=0.0826 | lr=0.0005 | 30.4 img/s | ETA~0m25s | GPU~2822 MiB
# [batch 1400/1546] loss(b)=0.0652 | loss(µ50)=0.0832 | lr=0.0005 | 30.9 img/s | ETA~0m19s | GPU~2822 MiB
# [batch 1450/1546] loss(b)=0.0773 | loss(µ50)=0.0785 | lr=0.0005 | 29.1 img/s | ETA~0m12s | GPU~2822 MiB
# [batch 1500/1546] loss(b)=0.0511 | loss(µ50)=0.0788 | lr=0.0005 | 30.8 img/s | ETA~0m6s | GPU~2822 MiB
# [batch 1546/1546] loss(b)=0.0460 | loss(µ50)=0.0852 | lr=0.0005 | 11.9 img/s | ETA~0m0s | GPU~2822 MiB
# FIN TRAIN
# INICIO val_loss (batches=442) ...
# [val_loss   50/442] loss=0.1107 | 12.72 it/s
# [val_loss  100/442] loss=0.0825 | 12.73 it/s
# [val_loss  150/442] loss=0.0795 | 12.68 it/s
# [val_loss  200/442] loss=0.1188 | 12.66 it/s
# [val_loss  250/442] loss=0.0683 | 12.70 it/s
# [val_loss  300/442] loss=0.1144 | 12.75 it/s
# [val_loss  350/442] loss=0.0601 | 12.78 it/s
# [val_loss  400/442] loss=0.0818 | 12.80 it/s
# [val_loss  442/442] loss=0.0625 | 12.82 it/s
# FIN val_loss  (0.6 min)
# INICIO val_prf (batches=442) ...
# [val_prf    50/442] 11.76 it/s | TP=127 FP=83 FN=73
# [val_prf   100/442] 11.80 it/s | TP=314 FP=111 FN=86
# [val_prf   150/442] 11.83 it/s | TP=508 FP=135 FN=92
# [val_prf   200/442] 11.85 it/s | TP=689 FP=178 FN=111
# [val_prf   250/442] 11.84 it/s | TP=877 FP=226 FN=123
# [val_prf   300/442] 11.85 it/s | TP=1058 FP=265 FN=142
# [val_prf   350/442] 11.86 it/s | TP=1242 FP=305 FN=158
# [val_prf   400/442] 11.85 it/s | TP=1419 FP=356 FN=181
# [val_prf   442/442] 11.87 it/s | TP=1565 FP=392 FN=201
# FIN val_prf  (0.6 min)
# INICIO val_mAP (batches=442) ...
# FIN val_mAP  (0.6 min)
# [RESUMEN ÉPOCA 07] lr→0.0005 | dur=5.2 min | train_loss=0.0812 | val_loss=0.0885 | val_rec=0.864 | val_f2=0.848 | val_mAP50=0.857 | val_mAP=0.372
#
# ================================================================================
# INICIO ÉPOCA 8/20  |  train_batches: 1546  |  batch_size: 4
# GPU: NVIDIA A100-SXM4-40GB  |  VRAM total: 39.6 GB
# ================================================================================
# [batch   50/1546] loss(b)=0.0898 | loss(µ50)=0.0812 | lr=0.0005 | 30.9 img/s | ETA~3m21s | GPU~2819 MiB
# [batch  100/1546] loss(b)=0.0791 | loss(µ50)=0.0826 | lr=0.0005 | 30.2 img/s | ETA~3m10s | GPU~2819 MiB
# [batch  150/1546] loss(b)=0.0777 | loss(µ50)=0.0774 | lr=0.0005 | 31.6 img/s | ETA~3m2s | GPU~2819 MiB
# [batch  200/1546] loss(b)=0.0857 | loss(µ50)=0.0803 | lr=0.0005 | 31.2 img/s | ETA~2m55s | GPU~2819 MiB
# [batch  250/1546] loss(b)=0.0465 | loss(µ50)=0.0784 | lr=0.0005 | 28.4 img/s | ETA~2m49s | GPU~2819 MiB
# [batch  300/1546] loss(b)=0.0644 | loss(µ50)=0.0819 | lr=0.0005 | 30.3 img/s | ETA~2m43s | GPU~2819 MiB
# [batch  350/1546] loss(b)=0.1167 | loss(µ50)=0.0827 | lr=0.0005 | 31.0 img/s | ETA~2m37s | GPU~2819 MiB
# [batch  400/1546] loss(b)=0.0639 | loss(µ50)=0.0817 | lr=0.0005 | 30.3 img/s | ETA~2m29s | GPU~2819 MiB
# [batch  450/1546] loss(b)=0.1087 | loss(µ50)=0.0794 | lr=0.0005 | 31.2 img/s | ETA~2m23s | GPU~2819 MiB
# [batch  500/1546] loss(b)=0.0856 | loss(µ50)=0.0812 | lr=0.0005 | 31.0 img/s | ETA~2m16s | GPU~2819 MiB
# [batch  550/1546] loss(b)=0.0737 | loss(µ50)=0.0772 | lr=0.0005 | 31.0 img/s | ETA~2m9s | GPU~2819 MiB
# [batch  600/1546] loss(b)=0.0732 | loss(µ50)=0.0793 | lr=0.0005 | 31.9 img/s | ETA~2m3s | GPU~2819 MiB
# [batch  650/1546] loss(b)=0.1003 | loss(µ50)=0.0840 | lr=0.0005 | 30.2 img/s | ETA~1m57s | GPU~2819 MiB
# [batch  700/1546] loss(b)=0.0943 | loss(µ50)=0.0788 | lr=0.0005 | 30.9 img/s | ETA~1m50s | GPU~2819 MiB
# [batch  750/1546] loss(b)=0.0898 | loss(µ50)=0.0826 | lr=0.0005 | 31.0 img/s | ETA~1m44s | GPU~2819 MiB
# [batch  800/1546] loss(b)=0.1154 | loss(µ50)=0.0828 | lr=0.0005 | 29.6 img/s | ETA~1m37s | GPU~2819 MiB
# [batch  850/1546] loss(b)=0.0757 | loss(µ50)=0.0796 | lr=0.0005 | 31.6 img/s | ETA~1m30s | GPU~2819 MiB
# [batch  900/1546] loss(b)=0.0801 | loss(µ50)=0.0799 | lr=0.0005 | 29.7 img/s | ETA~1m24s | GPU~2819 MiB
# [batch  950/1546] loss(b)=0.0662 | loss(µ50)=0.0763 | lr=0.0005 | 30.4 img/s | ETA~1m17s | GPU~2819 MiB
# [batch 1000/1546] loss(b)=0.0857 | loss(µ50)=0.0854 | lr=0.0005 | 29.1 img/s | ETA~1m11s | GPU~2819 MiB
# [batch 1050/1546] loss(b)=0.0671 | loss(µ50)=0.0807 | lr=0.0005 | 31.7 img/s | ETA~1m4s | GPU~2819 MiB
# [batch 1100/1546] loss(b)=0.0892 | loss(µ50)=0.0827 | lr=0.0005 | 31.3 img/s | ETA~0m58s | GPU~2819 MiB
# [batch 1150/1546] loss(b)=0.0641 | loss(µ50)=0.0815 | lr=0.0005 | 30.5 img/s | ETA~0m51s | GPU~2819 MiB
# [batch 1200/1546] loss(b)=0.0717 | loss(µ50)=0.0784 | lr=0.0005 | 31.3 img/s | ETA~0m45s | GPU~2819 MiB
# [batch 1250/1546] loss(b)=0.0840 | loss(µ50)=0.0821 | lr=0.0005 | 31.1 img/s | ETA~0m38s | GPU~2819 MiB
# [batch 1300/1546] loss(b)=0.0581 | loss(µ50)=0.0808 | lr=0.0005 | 31.4 img/s | ETA~0m32s | GPU~2819 MiB
# [batch 1350/1546] loss(b)=0.0913 | loss(µ50)=0.0840 | lr=0.0005 | 30.9 img/s | ETA~0m25s | GPU~2819 MiB
# [batch 1400/1546] loss(b)=0.0906 | loss(µ50)=0.0785 | lr=0.0005 | 30.5 img/s | ETA~0m19s | GPU~2819 MiB
# [batch 1450/1546] loss(b)=0.0976 | loss(µ50)=0.0806 | lr=0.0005 | 30.7 img/s | ETA~0m12s | GPU~2819 MiB
# [batch 1500/1546] loss(b)=0.0613 | loss(µ50)=0.0817 | lr=0.0005 | 30.3 img/s | ETA~0m6s | GPU~2819 MiB
# [batch 1546/1546] loss(b)=0.0728 | loss(µ50)=0.0853 | lr=0.0005 | 11.6 img/s | ETA~0m0s | GPU~2819 MiB
# FIN TRAIN
# INICIO val_loss (batches=442) ...
# [val_loss   50/442] loss=0.1125 | 12.52 it/s
# [val_loss  100/442] loss=0.0797 | 12.66 it/s
# [val_loss  150/442] loss=0.0803 | 12.70 it/s
# [val_loss  200/442] loss=0.1072 | 12.69 it/s
# [val_loss  250/442] loss=0.0647 | 12.71 it/s
# [val_loss  300/442] loss=0.0981 | 12.73 it/s
# [val_loss  350/442] loss=0.0593 | 12.74 it/s
# [val_loss  400/442] loss=0.0858 | 12.74 it/s
# [val_loss  442/442] loss=0.0552 | 12.76 it/s
# FIN val_loss  (0.6 min)
# INICIO val_prf (batches=442) ...
# [val_prf    50/442] 11.71 it/s | TP=127 FP=74 FN=73
# [val_prf   100/442] 11.73 it/s | TP=315 FP=101 FN=85
# [val_prf   150/442] 11.75 it/s | TP=509 FP=126 FN=91
# [val_prf   200/442] 11.77 it/s | TP=693 FP=165 FN=107
# [val_prf   250/442] 11.77 it/s | TP=882 FP=211 FN=118
# [val_prf   300/442] 11.77 it/s | TP=1064 FP=256 FN=136
# [val_prf   350/442] 11.77 it/s | TP=1250 FP=298 FN=150
# [val_prf   400/442] 11.77 it/s | TP=1424 FP=350 FN=176
# [val_prf   442/442] 11.78 it/s | TP=1570 FP=382 FN=196
# FIN val_prf  (0.6 min)
# INICIO val_mAP (batches=442) ...
# FIN val_mAP  (0.7 min)
# [RESUMEN ÉPOCA 08] lr→0.0005 | dur=5.2 min | train_loss=0.0809 | val_loss=0.0885 | val_rec=0.867 | val_f2=0.850 | val_mAP50=0.862 | val_mAP=0.373
#
# ================================================================================
# INICIO ÉPOCA 9/20  |  train_batches: 1546  |  batch_size: 4
# GPU: NVIDIA A100-SXM4-40GB  |  VRAM total: 39.6 GB
# ================================================================================
# [batch   50/1546] loss(b)=0.0594 | loss(µ50)=0.0780 | lr=0.0005 | 30.9 img/s | ETA~3m19s | GPU~2821 MiB
# [batch  100/1546] loss(b)=0.0823 | loss(µ50)=0.0825 | lr=0.0005 | 30.9 img/s | ETA~3m8s | GPU~2821 MiB
# [batch  150/1546] loss(b)=0.0878 | loss(µ50)=0.0811 | lr=0.0005 | 30.9 img/s | ETA~3m1s | GPU~2821 MiB
# [batch  200/1546] loss(b)=0.0691 | loss(µ50)=0.0812 | lr=0.0005 | 30.3 img/s | ETA~2m55s | GPU~2821 MiB
# [batch  250/1546] loss(b)=0.0832 | loss(µ50)=0.0789 | lr=0.0005 | 31.3 img/s | ETA~2m50s | GPU~2821 MiB
# [batch  300/1546] loss(b)=0.0878 | loss(µ50)=0.0829 | lr=0.0005 | 29.6 img/s | ETA~2m43s | GPU~2821 MiB
# [batch  350/1546] loss(b)=0.0699 | loss(µ50)=0.0827 | lr=0.0005 | 30.0 img/s | ETA~2m37s | GPU~2821 MiB
# [batch  400/1546] loss(b)=0.0661 | loss(µ50)=0.0769 | lr=0.0005 | 29.9 img/s | ETA~2m29s | GPU~2821 MiB
# [batch  450/1546] loss(b)=0.1044 | loss(µ50)=0.0837 | lr=0.0005 | 30.5 img/s | ETA~2m22s | GPU~2821 MiB
# [batch  500/1546] loss(b)=0.0829 | loss(µ50)=0.0798 | lr=0.0005 | 30.3 img/s | ETA~2m16s | GPU~2821 MiB
# [batch  550/1546] loss(b)=0.0861 | loss(µ50)=0.0808 | lr=0.0005 | 30.3 img/s | ETA~2m10s | GPU~2821 MiB
# [batch  600/1546] loss(b)=0.0806 | loss(µ50)=0.0822 | lr=0.0005 | 31.1 img/s | ETA~2m3s | GPU~2821 MiB
# [batch  650/1546] loss(b)=0.1270 | loss(µ50)=0.0835 | lr=0.0005 | 30.7 img/s | ETA~1m57s | GPU~2821 MiB
# [batch  700/1546] loss(b)=0.0969 | loss(µ50)=0.0798 | lr=0.0005 | 32.4 img/s | ETA~1m51s | GPU~2821 MiB
# [batch  750/1546] loss(b)=0.1044 | loss(µ50)=0.0820 | lr=0.0005 | 30.0 img/s | ETA~1m44s | GPU~2821 MiB
# [batch  800/1546] loss(b)=0.0898 | loss(µ50)=0.0816 | lr=0.0005 | 31.5 img/s | ETA~1m37s | GPU~2821 MiB
# [batch  850/1546] loss(b)=0.0797 | loss(µ50)=0.0796 | lr=0.0005 | 31.0 img/s | ETA~1m30s | GPU~2821 MiB
# [batch  900/1546] loss(b)=0.0556 | loss(µ50)=0.0801 | lr=0.0005 | 29.3 img/s | ETA~1m24s | GPU~2821 MiB
# [batch  950/1546] loss(b)=0.0964 | loss(µ50)=0.0847 | lr=0.0005 | 30.8 img/s | ETA~1m17s | GPU~2821 MiB
# [batch 1000/1546] loss(b)=0.1038 | loss(µ50)=0.0833 | lr=0.0005 | 30.9 img/s | ETA~1m11s | GPU~2821 MiB
# [batch 1050/1546] loss(b)=0.0705 | loss(µ50)=0.0834 | lr=0.0005 | 30.5 img/s | ETA~1m4s | GPU~2821 MiB
# [batch 1100/1546] loss(b)=0.0932 | loss(µ50)=0.0796 | lr=0.0005 | 30.9 img/s | ETA~0m58s | GPU~2821 MiB
# [batch 1150/1546] loss(b)=0.0868 | loss(µ50)=0.0771 | lr=0.0005 | 31.0 img/s | ETA~0m51s | GPU~2821 MiB
# [batch 1200/1546] loss(b)=0.0630 | loss(µ50)=0.0843 | lr=0.0005 | 32.6 img/s | ETA~0m45s | GPU~2821 MiB
# [batch 1250/1546] loss(b)=0.0819 | loss(µ50)=0.0802 | lr=0.0005 | 30.4 img/s | ETA~0m38s | GPU~2821 MiB
# [batch 1300/1546] loss(b)=0.0810 | loss(µ50)=0.0794 | lr=0.0005 | 30.3 img/s | ETA~0m32s | GPU~2821 MiB
# [batch 1350/1546] loss(b)=0.0932 | loss(µ50)=0.0844 | lr=0.0005 | 30.7 img/s | ETA~0m25s | GPU~2821 MiB
# [batch 1400/1546] loss(b)=0.0705 | loss(µ50)=0.0810 | lr=0.0005 | 30.9 img/s | ETA~0m19s | GPU~2821 MiB
# [batch 1450/1546] loss(b)=0.0996 | loss(µ50)=0.0852 | lr=0.0005 | 31.4 img/s | ETA~0m12s | GPU~2821 MiB
# [batch 1500/1546] loss(b)=0.0880 | loss(µ50)=0.0857 | lr=0.0005 | 33.2 img/s | ETA~0m6s | GPU~2821 MiB
# [batch 1546/1546] loss(b)=0.0569 | loss(µ50)=0.0819 | lr=0.0005 | 10.5 img/s | ETA~0m0s | GPU~2821 MiB
# FIN TRAIN
# INICIO val_loss (batches=442) ...
# [val_loss   50/442] loss=0.1055 | 12.72 it/s
# [val_loss  100/442] loss=0.0876 | 12.82 it/s
# [val_loss  150/442] loss=0.0871 | 12.87 it/s
# [val_loss  200/442] loss=0.1250 | 12.88 it/s
# [val_loss  250/442] loss=0.0643 | 12.90 it/s
# [val_loss  300/442] loss=0.1120 | 12.90 it/s
# [val_loss  350/442] loss=0.0593 | 12.89 it/s
# [val_loss  400/442] loss=0.0788 | 12.89 it/s
# [val_loss  442/442] loss=0.0588 | 12.91 it/s
# FIN val_loss  (0.6 min)
# INICIO val_prf (batches=442) ...
# [val_prf    50/442] 11.78 it/s | TP=128 FP=71 FN=72
# [val_prf   100/442] 11.79 it/s | TP=317 FP=92 FN=83
# [val_prf   150/442] 11.82 it/s | TP=511 FP=116 FN=89
# [val_prf   200/442] 11.82 it/s | TP=699 FP=152 FN=101
# [val_prf   250/442] 11.83 it/s | TP=887 FP=195 FN=113
# [val_prf   300/442] 11.84 it/s | TP=1067 FP=234 FN=133
# [val_prf   350/442] 11.85 it/s | TP=1253 FP=268 FN=147
# [val_prf   400/442] 11.84 it/s | TP=1428 FP=319 FN=172
# [val_prf   442/442] 11.86 it/s | TP=1571 FP=343 FN=195
# FIN val_prf  (0.6 min)
# INICIO val_mAP (batches=442) ...
# FIN val_mAP  (0.6 min)
# [RESUMEN ÉPOCA 09] lr→0.0005 | dur=5.2 min | train_loss=0.0815 | val_loss=0.0891 | val_rec=0.868 | val_f2=0.855 | val_mAP50=0.865 | val_mAP=0.371
#
# ================================================================================
# INICIO ÉPOCA 10/20  |  train_batches: 1546  |  batch_size: 4
# GPU: NVIDIA A100-SXM4-40GB  |  VRAM total: 39.6 GB
# ================================================================================
# [batch   50/1546] loss(b)=0.0798 | loss(µ50)=0.0818 | lr=0.0005 | 29.8 img/s | ETA~3m18s | GPU~2820 MiB
# [batch  100/1546] loss(b)=0.0737 | loss(µ50)=0.0828 | lr=0.0005 | 30.8 img/s | ETA~3m8s | GPU~2821 MiB
# [batch  150/1546] loss(b)=0.0675 | loss(µ50)=0.0817 | lr=0.0005 | 30.1 img/s | ETA~3m1s | GPU~2821 MiB
# [batch  200/1546] loss(b)=0.0650 | loss(µ50)=0.0822 | lr=0.0005 | 30.4 img/s | ETA~2m55s | GPU~2821 MiB
# [batch  250/1546] loss(b)=0.0564 | loss(µ50)=0.0826 | lr=0.0005 | 31.1 img/s | ETA~2m48s | GPU~2821 MiB
# [batch  300/1546] loss(b)=0.0671 | loss(µ50)=0.0813 | lr=0.0005 | 31.0 img/s | ETA~2m42s | GPU~2821 MiB
# [batch  350/1546] loss(b)=0.0647 | loss(µ50)=0.0800 | lr=0.0005 | 31.1 img/s | ETA~2m37s | GPU~2821 MiB
# [batch  400/1546] loss(b)=0.0627 | loss(µ50)=0.0842 | lr=0.0005 | 31.0 img/s | ETA~2m28s | GPU~2821 MiB
# [batch  450/1546] loss(b)=0.1066 | loss(µ50)=0.0784 | lr=0.0005 | 30.8 img/s | ETA~2m22s | GPU~2821 MiB
# [batch  500/1546] loss(b)=0.0864 | loss(µ50)=0.0805 | lr=0.0005 | 30.4 img/s | ETA~2m15s | GPU~2821 MiB
# [batch  550/1546] loss(b)=0.0705 | loss(µ50)=0.0803 | lr=0.0005 | 31.1 img/s | ETA~2m9s | GPU~2821 MiB
# [batch  600/1546] loss(b)=0.0946 | loss(µ50)=0.0805 | lr=0.0005 | 31.1 img/s | ETA~2m3s | GPU~2821 MiB
# [batch  650/1546] loss(b)=0.0958 | loss(µ50)=0.0806 | lr=0.0005 | 31.0 img/s | ETA~1m56s | GPU~2821 MiB
# [batch  700/1546] loss(b)=0.0843 | loss(µ50)=0.0826 | lr=0.0005 | 30.9 img/s | ETA~1m50s | GPU~2821 MiB
# [batch  750/1546] loss(b)=0.0880 | loss(µ50)=0.0775 | lr=0.0005 | 30.9 img/s | ETA~1m43s | GPU~2821 MiB
# [batch  800/1546] loss(b)=0.0831 | loss(µ50)=0.0778 | lr=0.0005 | 30.4 img/s | ETA~1m36s | GPU~2821 MiB
# [batch  850/1546] loss(b)=0.1166 | loss(µ50)=0.0805 | lr=0.0005 | 31.2 img/s | ETA~1m30s | GPU~2821 MiB
# [batch  900/1546] loss(b)=0.0630 | loss(µ50)=0.0829 | lr=0.0005 | 31.7 img/s | ETA~1m23s | GPU~2821 MiB
# [batch  950/1546] loss(b)=0.0803 | loss(µ50)=0.0828 | lr=0.0005 | 31.5 img/s | ETA~1m17s | GPU~2821 MiB
# [batch 1000/1546] loss(b)=0.0627 | loss(µ50)=0.0778 | lr=0.0005 | 29.4 img/s | ETA~1m11s | GPU~2821 MiB
# [batch 1050/1546] loss(b)=0.0777 | loss(µ50)=0.0818 | lr=0.0005 | 30.2 img/s | ETA~1m5s | GPU~2821 MiB
# [batch 1100/1546] loss(b)=0.0571 | loss(µ50)=0.0819 | lr=0.0005 | 31.0 img/s | ETA~0m58s | GPU~2821 MiB
# [batch 1150/1546] loss(b)=0.0909 | loss(µ50)=0.0796 | lr=0.0005 | 30.9 img/s | ETA~0m51s | GPU~2821 MiB
# [batch 1200/1546] loss(b)=0.0921 | loss(µ50)=0.0788 | lr=0.0005 | 30.8 img/s | ETA~0m45s | GPU~2821 MiB
# [batch 1250/1546] loss(b)=0.1050 | loss(µ50)=0.0803 | lr=0.0005 | 31.4 img/s | ETA~0m38s | GPU~2821 MiB
# [batch 1300/1546] loss(b)=0.0983 | loss(µ50)=0.0826 | lr=0.0005 | 31.8 img/s | ETA~0m32s | GPU~2821 MiB
# [batch 1350/1546] loss(b)=0.0709 | loss(µ50)=0.0805 | lr=0.0005 | 31.0 img/s | ETA~0m25s | GPU~2821 MiB
# [batch 1400/1546] loss(b)=0.0861 | loss(µ50)=0.0856 | lr=0.0005 | 31.1 img/s | ETA~0m19s | GPU~2821 MiB
# [batch 1450/1546] loss(b)=0.0607 | loss(µ50)=0.0800 | lr=0.0005 | 30.7 img/s | ETA~0m12s | GPU~2821 MiB
# [batch 1500/1546] loss(b)=0.0948 | loss(µ50)=0.0829 | lr=0.0005 | 29.6 img/s | ETA~0m6s | GPU~2821 MiB
# [batch 1546/1546] loss(b)=0.1391 | loss(µ50)=0.0786 | lr=0.0005 | 11.3 img/s | ETA~0m0s | GPU~2821 MiB
# FIN TRAIN
# INICIO val_loss (batches=442) ...
# [val_loss   50/442] loss=0.1087 | 12.69 it/s
# [val_loss  100/442] loss=0.0892 | 12.83 it/s
# [val_loss  150/442] loss=0.0883 | 12.88 it/s
# [val_loss  200/442] loss=0.1174 | 12.87 it/s
# [val_loss  250/442] loss=0.0666 | 12.85 it/s
# [val_loss  300/442] loss=0.1056 | 12.84 it/s
# [val_loss  350/442] loss=0.0521 | 12.82 it/s
# [val_loss  400/442] loss=0.0808 | 12.81 it/s
# [val_loss  442/442] loss=0.0680 | 12.82 it/s
# FIN val_loss  (0.6 min)
# INICIO val_prf (batches=442) ...
# [val_prf    50/442] 11.75 it/s | TP=126 FP=69 FN=74
# [val_prf   100/442] 11.83 it/s | TP=313 FP=90 FN=87
# [val_prf   150/442] 11.83 it/s | TP=505 FP=109 FN=95
# [val_prf   200/442] 11.85 it/s | TP=689 FP=143 FN=111
# [val_prf   250/442] 11.83 it/s | TP=876 FP=181 FN=124
# [val_prf   300/442] 11.85 it/s | TP=1058 FP=209 FN=142
# [val_prf   350/442] 11.86 it/s | TP=1243 FP=241 FN=157
# [val_prf   400/442] 11.86 it/s | TP=1418 FP=280 FN=182
# [val_prf   442/442] 11.88 it/s | TP=1560 FP=306 FN=206
# FIN val_prf  (0.6 min)
# INICIO val_mAP (batches=442) ...
# FIN val_mAP  (0.6 min)
# [RESUMEN ÉPOCA 10] lr→5e-05 | dur=5.2 min | train_loss=0.0810 | val_loss=0.0901 | val_rec=0.861 | val_f2=0.853 | val_mAP50=0.866 | val_mAP=0.372
#
# ================================================================================
# INICIO ÉPOCA 11/20  |  train_batches: 1546  |  batch_size: 4
# GPU: NVIDIA A100-SXM4-40GB  |  VRAM total: 39.6 GB
# ================================================================================
# [batch   50/1546] loss(b)=0.1046 | loss(µ50)=0.0780 | lr=5e-05 | 32.7 img/s | ETA~3m20s | GPU~2822 MiB
# [batch  100/1546] loss(b)=0.1205 | loss(µ50)=0.0806 | lr=5e-05 | 29.7 img/s | ETA~3m8s | GPU~2822 MiB
# [batch  150/1546] loss(b)=0.0670 | loss(µ50)=0.0796 | lr=5e-05 | 29.7 img/s | ETA~3m2s | GPU~2822 MiB
# [batch  200/1546] loss(b)=0.0719 | loss(µ50)=0.0797 | lr=5e-05 | 29.1 img/s | ETA~2m56s | GPU~2822 MiB
# [batch  250/1546] loss(b)=0.0642 | loss(µ50)=0.0790 | lr=5e-05 | 31.2 img/s | ETA~2m50s | GPU~2822 MiB
# [batch  300/1546] loss(b)=0.0615 | loss(µ50)=0.0776 | lr=5e-05 | 32.9 img/s | ETA~2m42s | GPU~2822 MiB
# [batch  350/1546] loss(b)=0.0609 | loss(µ50)=0.0759 | lr=5e-05 | 30.8 img/s | ETA~2m36s | GPU~2822 MiB
# ...
# [batch 1250/1546] loss(b)=0.0765 | loss(µ50)=0.0774 | lr=5e-06 | 30.9 img/s | ETA~0m38s | GPU~2823 MiB
# [batch 1300/1546] loss(b)=0.1248 | loss(µ50)=0.0818 | lr=5e-06 | 30.2 img/s | ETA~0m32s | GPU~2823 MiB
# [batch 1350/1546] loss(b)=0.0470 | loss(µ50)=0.0802 | lr=5e-06 | 30.4 img/s | ETA~0m25s | GPU~2823 MiB
# [batch 1400/1546] loss(b)=0.0752 | loss(µ50)=0.0801 | lr=5e-06 | 31.1 img/s | ETA~0m19s | GPU~2823 MiB
# [batch 1450/1546] loss(b)=0.0877 | loss(µ50)=0.0794 | lr=5e-06 | 30.1 img/s | ETA~0m12s | GPU~2823 MiB
# [batch 1500/1546] loss(b)=0.0463 | loss(µ50)=0.0797 | lr=5e-06 | 29.7 img/s | ETA~0m6s | GPU~2823 MiB
# [batch 1546/1546] loss(b)=0.0558 | loss(µ50)=0.0810 | lr=5e-06 | 11.7 img/s | ETA~0m0s | GPU~2823 MiB
# FIN TRAIN
# INICIO val_loss (batches=442) ...
# [val_loss   50/442] loss=0.1164 | 12.80 it/s
# [val_loss  100/442] loss=0.0873 | 12.88 it/s
# [val_loss  150/442] loss=0.0859 | 12.91 it/s
# [val_loss  200/442] loss=0.1146 | 12.94 it/s
# [val_loss  250/442] loss=0.0641 | 12.95 it/s
# [val_loss  300/442] loss=0.1201 | 12.95 it/s
# [val_loss  350/442] loss=0.0606 | 12.95 it/s
# [val_loss  400/442] loss=0.0812 | 12.95 it/s
# [val_loss  442/442] loss=0.0683 | 12.96 it/s
# FIN val_loss  (0.6 min)
# INICIO val_prf (batches=442) ...
# [val_prf    50/442] 11.80 it/s | TP=130 FP=65 FN=70
# [val_prf   100/442] 11.86 it/s | TP=320 FP=87 FN=80
# [val_prf   150/442] 11.87 it/s | TP=513 FP=108 FN=87
# [val_prf   200/442] 11.89 it/s | TP=699 FP=139 FN=101
# [val_prf   250/442] 11.90 it/s | TP=886 FP=183 FN=114
# [val_prf   300/442] 11.90 it/s | TP=1066 FP=220 FN=134
# [val_prf   350/442] 11.91 it/s | TP=1252 FP=258 FN=148
# [val_prf   400/442] 11.91 it/s | TP=1426 FP=307 FN=174
# [val_prf   442/442] 11.92 it/s | TP=1569 FP=337 FN=197
# FIN val_prf  (0.6 min)
# INICIO val_mAP (batches=442) ...
# FIN val_mAP  (0.6 min)
# [RESUMEN ÉPOCA 17] lr→5e-06 | dur=5.2 min | train_loss=0.0793 | val_loss=0.0891 | val_rec=0.868 | val_f2=0.856 | val_mAP50=0.871 | val_mAP=0.378
#
# ================================================================================
# INICIO ÉPOCA 18/20  |  train_batches: 1546  |  batch_size: 4
# GPU: NVIDIA A100-SXM4-40GB  |  VRAM total: 39.6 GB
# ================================================================================
# [batch   50/1546] loss(b)=0.0648 | loss(µ50)=0.0776 | lr=5e-06 | 31.1 img/s | ETA~3m19s | GPU~2821 MiB
# [batch  100/1546] loss(b)=0.0491 | loss(µ50)=0.0805 | lr=5e-06 | 30.3 img/s | ETA~3m10s | GPU~2822 MiB
# [batch  150/1546] loss(b)=0.0966 | loss(µ50)=0.0814 | lr=5e-06 | 29.8 img/s | ETA~3m2s | GPU~2822 MiB
# [batch  200/1546] loss(b)=0.0905 | loss(µ50)=0.0820 | lr=5e-06 | 31.1 img/s | ETA~2m56s | GPU~2822 MiB
# [batch  250/1546] loss(b)=0.0651 | loss(µ50)=0.0822 | lr=5e-06 | 30.7 img/s | ETA~2m49s | GPU~2822 MiB
# [batch  300/1546] loss(b)=0.0654 | loss(µ50)=0.0797 | lr=5e-06 | 31.9 img/s | ETA~2m43s | GPU~2822 MiB
# [batch  350/1546] loss(b)=0.1091 | loss(µ50)=0.0794 | lr=5e-06 | 30.5 img/s | ETA~2m36s | GPU~2822 MiB
# [batch  400/1546] loss(b)=0.1163 | loss(µ50)=0.0801 | lr=5e-06 | 31.3 img/s | ETA~2m30s | GPU~2822 MiB
# [batch  450/1546] loss(b)=0.0710 | loss(µ50)=0.0797 | lr=5e-06 | 29.4 img/s | ETA~2m24s | GPU~2822 MiB
# [batch  500/1546] loss(b)=0.0720 | loss(µ50)=0.0782 | lr=5e-06 | 30.9 img/s | ETA~2m17s | GPU~2822 MiB
# [batch  550/1546] loss(b)=0.0894 | loss(µ50)=0.0772 | lr=5e-06 | 30.1 img/s | ETA~2m9s | GPU~2822 MiB
# [batch  600/1546] loss(b)=0.0703 | loss(µ50)=0.0830 | lr=5e-06 | 31.1 img/s | ETA~2m3s | GPU~2822 MiB
# [batch  650/1546] loss(b)=0.0955 | loss(µ50)=0.0796 | lr=5e-06 | 32.6 img/s | ETA~1m57s | GPU~2822 MiB
# [batch  700/1546] loss(b)=0.0689 | loss(µ50)=0.0775 | lr=5e-06 | 30.2 img/s | ETA~1m50s | GPU~2822 MiB
# [batch  750/1546] loss(b)=0.0705 | loss(µ50)=0.0765 | lr=5e-06 | 29.4 img/s | ETA~1m44s | GPU~2822 MiB
# [batch  800/1546] loss(b)=0.0962 | loss(µ50)=0.0774 | lr=5e-06 | 30.8 img/s | ETA~1m37s | GPU~2822 MiB
# [batch  850/1546] loss(b)=0.0954 | loss(µ50)=0.0827 | lr=5e-06 | 30.6 img/s | ETA~1m30s | GPU~2822 MiB
# [batch  900/1546] loss(b)=0.1175 | loss(µ50)=0.0787 | lr=5e-06 | 31.3 img/s | ETA~1m24s | GPU~2822 MiB
# [batch  950/1546] loss(b)=0.0944 | loss(µ50)=0.0771 | lr=5e-06 | 30.9 img/s | ETA~1m18s | GPU~2822 MiB
# [batch 1000/1546] loss(b)=0.1036 | loss(µ50)=0.0819 | lr=5e-06 | 30.3 img/s | ETA~1m11s | GPU~2822 MiB
# [batch 1050/1546] loss(b)=0.0776 | loss(µ50)=0.0810 | lr=5e-06 | 30.8 img/s | ETA~1m4s | GPU~2822 MiB
# [batch 1100/1546] loss(b)=0.0855 | loss(µ50)=0.0811 | lr=5e-06 | 30.2 img/s | ETA~0m58s | GPU~2822 MiB
# [batch 1150/1546] loss(b)=0.0644 | loss(µ50)=0.0787 | lr=5e-06 | 30.4 img/s | ETA~0m52s | GPU~2822 MiB
# [batch 1200/1546] loss(b)=0.0642 | loss(µ50)=0.0792 | lr=5e-06 | 30.8 img/s | ETA~0m45s | GPU~2822 MiB
# [batch 1250/1546] loss(b)=0.0619 | loss(µ50)=0.0814 | lr=5e-06 | 33.2 img/s | ETA~0m38s | GPU~2822 MiB
# [batch 1300/1546] loss(b)=0.1160 | loss(µ50)=0.0815 | lr=5e-06 | 30.7 img/s | ETA~0m32s | GPU~2822 MiB
# [batch 1350/1546] loss(b)=0.0661 | loss(µ50)=0.0787 | lr=5e-06 | 30.4 img/s | ETA~0m25s | GPU~2822 MiB
# [batch 1400/1546] loss(b)=0.0806 | loss(µ50)=0.0754 | lr=5e-06 | 31.6 img/s | ETA~0m19s | GPU~2822 MiB
# [batch 1450/1546] loss(b)=0.0688 | loss(µ50)=0.0792 | lr=5e-06 | 30.9 img/s | ETA~0m12s | GPU~2822 MiB
# [batch 1500/1546] loss(b)=0.0736 | loss(µ50)=0.0820 | lr=5e-06 | 30.9 img/s | ETA~0m5s | GPU~2822 MiB
# [batch 1546/1546] loss(b)=0.1102 | loss(µ50)=0.0840 | lr=5e-06 | 11.8 img/s | ETA~0m0s | GPU~2822 MiB
# FIN TRAIN
# INICIO val_loss (batches=442) ...
# [val_loss   50/442] loss=0.1143 | 12.62 it/s
# [val_loss  100/442] loss=0.0867 | 12.66 it/s
# [val_loss  150/442] loss=0.0860 | 12.69 it/s
# [val_loss  200/442] loss=0.1192 | 12.74 it/s
# [val_loss  250/442] loss=0.0614 | 12.78 it/s
# [val_loss  300/442] loss=0.1201 | 12.80 it/s
# [val_loss  350/442] loss=0.0597 | 12.82 it/s
# [val_loss  400/442] loss=0.0822 | 12.83 it/s
# [val_loss  442/442] loss=0.0643 | 12.84 it/s
# FIN val_loss  (0.6 min)
# INICIO val_prf (batches=442) ...
# [val_prf    50/442] 11.76 it/s | TP=130 FP=65 FN=70
# [val_prf   100/442] 11.84 it/s | TP=320 FP=86 FN=80
# [val_prf   150/442] 11.84 it/s | TP=513 FP=107 FN=87
# [val_prf   200/442] 11.86 it/s | TP=698 FP=139 FN=102
# [val_prf   250/442] 11.87 it/s | TP=885 FP=183 FN=115
# [val_prf   300/442] 11.88 it/s | TP=1065 FP=220 FN=135
# [val_prf   350/442] 11.88 it/s | TP=1251 FP=257 FN=149
# [val_prf   400/442] 11.89 it/s | TP=1425 FP=307 FN=175
# [val_prf   442/442] 11.90 it/s | TP=1568 FP=337 FN=198
# FIN val_prf  (0.6 min)
# INICIO val_mAP (batches=442) ...
# FIN val_mAP  (0.6 min)
# [RESUMEN ÉPOCA 18] lr→5e-06 | dur=5.2 min | train_loss=0.0798 | val_loss=0.0892 | val_rec=0.868 | val_f2=0.855 | val_mAP50=0.871 | val_mAP=0.378
#
# ================================================================================
# INICIO ÉPOCA 19/20  |  train_batches: 1546  |  batch_size: 4
# GPU: NVIDIA A100-SXM4-40GB  |  VRAM total: 39.6 GB
# ================================================================================
# [batch   50/1546] loss(b)=0.0633 | loss(µ50)=0.0816 | lr=5e-06 | 30.9 img/s | ETA~3m20s | GPU~2821 MiB
# [batch  100/1546] loss(b)=0.0710 | loss(µ50)=0.0793 | lr=5e-06 | 30.8 img/s | ETA~3m10s | GPU~2821 MiB
# [batch  150/1546] loss(b)=0.0891 | loss(µ50)=0.0773 | lr=5e-06 | 29.9 img/s | ETA~3m3s | GPU~2821 MiB
# [batch  200/1546] loss(b)=0.0657 | loss(µ50)=0.0791 | lr=5e-06 | 30.2 img/s | ETA~2m56s | GPU~2821 MiB
# [batch  250/1546] loss(b)=0.0729 | loss(µ50)=0.0786 | lr=5e-06 | 30.5 img/s | ETA~2m48s | GPU~2821 MiB
# [batch  300/1546] loss(b)=0.1168 | loss(µ50)=0.0803 | lr=5e-06 | 30.5 img/s | ETA~2m42s | GPU~2821 MiB
# [batch  350/1546] loss(b)=0.0502 | loss(µ50)=0.0815 | lr=5e-06 | 30.8 img/s | ETA~2m36s | GPU~2821 MiB
# [batch  400/1546] loss(b)=0.0898 | loss(µ50)=0.0815 | lr=5e-06 | 30.9 img/s | ETA~2m30s | GPU~2821 MiB
# [batch  450/1546] loss(b)=0.0876 | loss(µ50)=0.0791 | lr=5e-06 | 29.7 img/s | ETA~2m24s | GPU~2821 MiB
# [batch  500/1546] loss(b)=0.0801 | loss(µ50)=0.0808 | lr=5e-06 | 27.6 img/s | ETA~2m17s | GPU~2821 MiB
# [batch  550/1546] loss(b)=0.0830 | loss(µ50)=0.0810 | lr=5e-06 | 30.3 img/s | ETA~2m10s | GPU~2821 MiB
# [batch  600/1546] loss(b)=0.0814 | loss(µ50)=0.0831 | lr=5e-06 | 30.2 img/s | ETA~2m3s | GPU~2821 MiB
# [batch  650/1546] loss(b)=0.0832 | loss(µ50)=0.0813 | lr=5e-06 | 30.9 img/s | ETA~1m57s | GPU~2821 MiB
# [batch  700/1546] loss(b)=0.0766 | loss(µ50)=0.0825 | lr=5e-06 | 30.7 img/s | ETA~1m50s | GPU~2821 MiB
# [batch  750/1546] loss(b)=0.0979 | loss(µ50)=0.0818 | lr=5e-06 | 29.3 img/s | ETA~1m44s | GPU~2821 MiB
# [batch  800/1546] loss(b)=0.0637 | loss(µ50)=0.0791 | lr=5e-06 | 30.8 img/s | ETA~1m38s | GPU~2821 MiB
# [batch  850/1546] loss(b)=0.0526 | loss(µ50)=0.0757 | lr=5e-06 | 30.5 img/s | ETA~1m30s | GPU~2821 MiB
# [batch  900/1546] loss(b)=0.0636 | loss(µ50)=0.0841 | lr=5e-06 | 30.6 img/s | ETA~1m23s | GPU~2821 MiB
# [batch  950/1546] loss(b)=0.0728 | loss(µ50)=0.0776 | lr=5e-06 | 30.9 img/s | ETA~1m17s | GPU~2821 MiB
# [batch 1000/1546] loss(b)=0.0896 | loss(µ50)=0.0765 | lr=5e-06 | 30.4 img/s | ETA~1m11s | GPU~2821 MiB
# [batch 1050/1546] loss(b)=0.0660 | loss(µ50)=0.0817 | lr=5e-06 | 30.9 img/s | ETA~1m4s | GPU~2821 MiB
# [batch 1100/1546] loss(b)=0.0749 | loss(µ50)=0.0771 | lr=5e-06 | 30.9 img/s | ETA~0m58s | GPU~2821 MiB
# [batch 1150/1546] loss(b)=0.0521 | loss(µ50)=0.0770 | lr=5e-06 | 31.3 img/s | ETA~0m52s | GPU~2821 MiB
# [batch 1200/1546] loss(b)=0.0575 | loss(µ50)=0.0767 | lr=5e-06 | 29.6 img/s | ETA~0m45s | GPU~2821 MiB
# [batch 1250/1546] loss(b)=0.0534 | loss(µ50)=0.0792 | lr=5e-06 | 28.4 img/s | ETA~0m38s | GPU~2821 MiB
# [batch 1300/1546] loss(b)=0.0629 | loss(µ50)=0.0759 | lr=5e-06 | 30.3 img/s | ETA~0m32s | GPU~2821 MiB
# [batch 1350/1546] loss(b)=0.0786 | loss(µ50)=0.0791 | lr=5e-06 | 33.5 img/s | ETA~0m25s | GPU~2821 MiB
# [batch 1400/1546] loss(b)=0.0570 | loss(µ50)=0.0786 | lr=5e-06 | 31.2 img/s | ETA~0m19s | GPU~2821 MiB
# [batch 1450/1546] loss(b)=0.0656 | loss(µ50)=0.0809 | lr=5e-06 | 31.0 img/s | ETA~0m12s | GPU~2821 MiB
# [batch 1500/1546] loss(b)=0.0849 | loss(µ50)=0.0760 | lr=5e-06 | 29.5 img/s | ETA~0m6s | GPU~2821 MiB
# [batch 1546/1546] loss(b)=0.0774 | loss(µ50)=0.0806 | lr=5e-06 | 11.8 img/s | ETA~0m0s | GPU~2821 MiB
# FIN TRAIN
# INICIO val_loss (batches=442) ...
# [val_loss   50/442] loss=0.1133 | 12.76 it/s
# [val_loss  100/442] loss=0.0873 | 12.79 it/s
# [val_loss  150/442] loss=0.0890 | 12.80 it/s
# [val_loss  200/442] loss=0.1097 | 12.83 it/s
# [val_loss  250/442] loss=0.0650 | 12.86 it/s
# [val_loss  300/442] loss=0.1113 | 12.86 it/s
# [val_loss  350/442] loss=0.0559 | 12.87 it/s
# [val_loss  400/442] loss=0.0808 | 12.88 it/s
# [val_loss  442/442] loss=0.0604 | 12.90 it/s
# FIN val_loss  (0.6 min)
# INICIO val_prf (batches=442) ...
# [val_prf    50/442] 11.85 it/s | TP=130 FP=65 FN=70
# [val_prf   100/442] 11.89 it/s | TP=320 FP=86 FN=80
# [val_prf   150/442] 11.89 it/s | TP=513 FP=107 FN=87
# [val_prf   200/442] 11.90 it/s | TP=698 FP=139 FN=102
# [val_prf   250/442] 11.90 it/s | TP=885 FP=183 FN=115
# [val_prf   300/442] 11.90 it/s | TP=1065 FP=220 FN=135
# [val_prf   350/442] 11.90 it/s | TP=1251 FP=257 FN=149
# [val_prf   400/442] 11.91 it/s | TP=1425 FP=307 FN=175
# [val_prf   442/442] 11.92 it/s | TP=1568 FP=337 FN=198
# FIN val_prf  (0.6 min)
# INICIO val_mAP (batches=442) ...
# FIN val_mAP  (0.7 min)
# [RESUMEN ÉPOCA 19] lr→5e-06 | dur=5.2 min | train_loss=0.0795 | val_loss=0.0891 | val_rec=0.868 | val_f2=0.855 | val_mAP50=0.871 | val_mAP=0.378
#
# ================================================================================
# INICIO ÉPOCA 20/20  |  train_batches: 1546  |  batch_size: 4
# GPU: NVIDIA A100-SXM4-40GB  |  VRAM total: 39.6 GB
# ================================================================================
# [batch   50/1546] loss(b)=0.0863 | loss(µ50)=0.0828 | lr=5e-06 | 31.0 img/s | ETA~3m18s | GPU~2820 MiB
# [batch  100/1546] loss(b)=0.1061 | loss(µ50)=0.0765 | lr=5e-06 | 30.9 img/s | ETA~3m9s | GPU~2820 MiB
# [batch  150/1546] loss(b)=0.0780 | loss(µ50)=0.0786 | lr=5e-06 | 31.7 img/s | ETA~3m2s | GPU~2820 MiB
# [batch  200/1546] loss(b)=0.0895 | loss(µ50)=0.0844 | lr=5e-06 | 29.2 img/s | ETA~2m57s | GPU~2820 MiB
# [batch  250/1546] loss(b)=0.0907 | loss(µ50)=0.0779 | lr=5e-06 | 31.3 img/s | ETA~2m50s | GPU~2820 MiB
# [batch  300/1546] loss(b)=0.0940 | loss(µ50)=0.0793 | lr=5e-06 | 31.2 img/s | ETA~2m42s | GPU~2820 MiB
# [batch  350/1546] loss(b)=0.0618 | loss(µ50)=0.0793 | lr=5e-06 | 29.7 img/s | ETA~2m35s | GPU~2820 MiB
# [batch  400/1546] loss(b)=0.0955 | loss(µ50)=0.0814 | lr=5e-06 | 30.9 img/s | ETA~2m29s | GPU~2820 MiB
# [batch  450/1546] loss(b)=0.0958 | loss(µ50)=0.0810 | lr=5e-06 | 30.4 img/s | ETA~2m23s | GPU~2820 MiB
# [batch  500/1546] loss(b)=0.0812 | loss(µ50)=0.0819 | lr=5e-06 | 30.5 img/s | ETA~2m16s | GPU~2820 MiB
# [batch  550/1546] loss(b)=0.0500 | loss(µ50)=0.0780 | lr=5e-06 | 31.3 img/s | ETA~2m10s | GPU~2820 MiB
# [batch  600/1546] loss(b)=0.0682 | loss(µ50)=0.0786 | lr=5e-06 | 30.9 img/s | ETA~2m3s | GPU~2820 MiB
# [batch  650/1546] loss(b)=0.0693 | loss(µ50)=0.0779 | lr=5e-06 | 30.8 img/s | ETA~1m57s | GPU~2820 MiB
# [batch  700/1546] loss(b)=0.0634 | loss(µ50)=0.0797 | lr=5e-06 | 29.6 img/s | ETA~1m51s | GPU~2820 MiB
# [batch  750/1546] loss(b)=0.0959 | loss(µ50)=0.0766 | lr=5e-06 | 29.3 img/s | ETA~1m44s | GPU~2820 MiB
# [batch  800/1546] loss(b)=0.0792 | loss(µ50)=0.0833 | lr=5e-06 | 30.5 img/s | ETA~1m37s | GPU~2820 MiB
# [batch  850/1546] loss(b)=0.0757 | loss(µ50)=0.0794 | lr=5e-06 | 32.0 img/s | ETA~1m30s | GPU~2820 MiB
# [batch  900/1546] loss(b)=0.0849 | loss(µ50)=0.0778 | lr=5e-06 | 30.9 img/s | ETA~1m24s | GPU~2820 MiB
# [batch  950/1546] loss(b)=0.0845 | loss(µ50)=0.0777 | lr=5e-06 | 30.8 img/s | ETA~1m18s | GPU~2820 MiB
# [batch 1000/1546] loss(b)=0.0694 | loss(µ50)=0.0801 | lr=5e-06 | 31.2 img/s | ETA~1m12s | GPU~2820 MiB
# [batch 1050/1546] loss(b)=0.0813 | loss(µ50)=0.0825 | lr=5e-06 | 30.2 img/s | ETA~1m5s | GPU~2820 MiB
# [batch 1100/1546] loss(b)=0.0849 | loss(µ50)=0.0752 | lr=5e-06 | 30.6 img/s | ETA~0m58s | GPU~2820 MiB
# [batch 1150/1546] loss(b)=0.1128 | loss(µ50)=0.0810 | lr=5e-06 | 31.2 img/s | ETA~0m52s | GPU~2820 MiB
# [batch 1200/1546] loss(b)=0.1153 | loss(µ50)=0.0820 | lr=5e-06 | 31.1 img/s | ETA~0m45s | GPU~2820 MiB
# [batch 1250/1546] loss(b)=0.0705 | loss(µ50)=0.0817 | lr=5e-06 | 32.6 img/s | ETA~0m39s | GPU~2820 MiB
# [batch 1300/1546] loss(b)=0.0669 | loss(µ50)=0.0814 | lr=5e-06 | 32.0 img/s | ETA~0m32s | GPU~2820 MiB
# [batch 1350/1546] loss(b)=0.0877 | loss(µ50)=0.0816 | lr=5e-06 | 30.3 img/s | ETA~0m25s | GPU~2820 MiB
# [batch 1400/1546] loss(b)=0.0563 | loss(µ50)=0.0794 | lr=5e-06 | 30.9 img/s | ETA~0m19s | GPU~2820 MiB
# [batch 1450/1546] loss(b)=0.0820 | loss(µ50)=0.0790 | lr=5e-06 | 30.2 img/s | ETA~0m12s | GPU~2820 MiB
# [batch 1500/1546] loss(b)=0.0794 | loss(µ50)=0.0756 | lr=5e-06 | 30.3 img/s | ETA~0m6s | GPU~2820 MiB
# [batch 1546/1546] loss(b)=0.0840 | loss(µ50)=0.0806 | lr=5e-06 | 11.6 img/s | ETA~0m0s | GPU~2820 MiB
# FIN TRAIN
# INICIO val_loss (batches=442) ...
# [val_loss   50/442] loss=0.1132 | 12.76 it/s
# [val_loss  100/442] loss=0.0865 | 12.81 it/s
# [val_loss  150/442] loss=0.0883 | 12.86 it/s
# [val_loss  200/442] loss=0.1169 | 12.87 it/s
# [val_loss  250/442] loss=0.0608 | 12.87 it/s
# [val_loss  300/442] loss=0.1184 | 12.87 it/s
# [val_loss  350/442] loss=0.0598 | 12.88 it/s
# [val_loss  400/442] loss=0.0801 | 12.89 it/s
# [val_loss  442/442] loss=0.0639 | 12.91 it/s
# FIN val_loss  (0.6 min)
# INICIO val_prf (batches=442) ...
# [val_prf    50/442] 11.81 it/s | TP=130 FP=64 FN=70
# [val_prf   100/442] 11.86 it/s | TP=320 FP=85 FN=80
# [val_prf   150/442] 11.84 it/s | TP=513 FP=108 FN=87
# [val_prf   200/442] 11.87 it/s | TP=698 FP=140 FN=102
# [val_prf   250/442] 11.87 it/s | TP=885 FP=185 FN=115
# [val_prf   300/442] 11.88 it/s | TP=1065 FP=222 FN=135
# [val_prf   350/442] 11.89 it/s | TP=1251 FP=259 FN=149
# [val_prf   400/442] 11.88 it/s | TP=1425 FP=309 FN=175
# [val_prf   442/442] 11.89 it/s | TP=1568 FP=340 FN=198
# FIN val_prf  (0.6 min)
# INICIO val_mAP (batches=442) ...
# FIN val_mAP  (0.6 min)
# [RESUMEN ÉPOCA 20] lr→5e-07 | dur=5.2 min | train_loss=0.0797 | val_loss=0.0890 | val_rec=0.868 | val_f2=0.855 | val_mAP50=0.871 | val_mAP=0.378

# %%
# -----------------------------
# 8) Calibración del operating point (score_thresh, nms_thresh, detections_per_img) en VALID
# -----------------------------

# Greedy match (class-agnostic)
def greedy_match_iou(pred_boxes: torch.Tensor, gt_boxes: torch.Tensor, iou_thresh: float = 0.5) -> int:
    if pred_boxes.numel() == 0 or gt_boxes.numel() == 0:
        return 0
    ious = box_iou(pred_boxes, gt_boxes)  # [P,G]
    P, G = ious.shape

    flat = []
    # construir lista de pares (p,g,iou)
    ious_np = ious.cpu().numpy()
    for i in range(P):
        for j in range(G):
            v = float(ious_np[i, j])
            if v >= iou_thresh:
                flat.append((i, j, v))
    if not flat:
        return 0

    flat.sort(key=lambda x: x[2], reverse=True)
    used_p, used_g = set(), set()
    matches = 0
    for i, j, v in flat:
        if i in used_p or j in used_g:
            continue
        used_p.add(i); used_g.add(j)
        matches += 1
    return matches

# Cache outputs
@torch.no_grad()
def cache_valid_outputs(model, loader, device, force_score_thresh=0.0, force_nms_thresh=1.0, force_det_per_img=1000):
    model.eval()

    # backup params
    roi = model.roi_heads
    b_score = getattr(roi, "score_thresh", None)
    b_nms   = getattr(roi, "nms_thresh", None)
    b_det   = getattr(roi, "detections_per_img", None)

    roi.score_thresh = float(force_score_thresh)
    roi.nms_thresh = float(force_nms_thresh)
    roi.detections_per_img = int(force_det_per_img)

    cached = []
    for imgs, targets in loader:
        imgs = [img.to(device) for img in imgs]
        outs = model(imgs)
        for out, tgt in zip(outs, targets):
            cached.append({
                "p_boxes":  out["boxes"].detach().cpu(),
                "p_scores": out["scores"].detach().cpu(),
                "p_labels": out["labels"].detach().cpu(),  # 1..K
                "g_boxes":  tgt["boxes"].detach().cpu(),
            })

    # Restore
    if b_score is not None: roi.score_thresh = b_score
    if b_nms is not None:   roi.nms_thresh = b_nms
    if b_det is not None:   roi.detections_per_img = b_det

    return cached

# Aplicar operating point offline (score + NMS + topK)
def apply_operating_point(p_boxes, p_scores, p_labels, score_thresh, nms_thresh, det_per_img):
    keep = p_scores >= score_thresh
    boxes = p_boxes[keep]
    scores = p_scores[keep]
    labels = p_labels[keep]

    if boxes.numel() == 0:
        return boxes, scores, labels

    # NMS por clase (como torchvision)
    if nms_thresh < 1.0:
        keep_idx = batched_nms(boxes, scores, labels, iou_threshold=float(nms_thresh))
        boxes, scores, labels = boxes[keep_idx], scores[keep_idx], labels[keep_idx]

    # top-k detections
    if det_per_img is not None and len(scores) > det_per_img:
        topk = torch.topk(scores, k=int(det_per_img)).indices
        boxes, scores, labels = boxes[topk], scores[topk], labels[topk]

    return boxes, scores, labels

# Evaluar (box-recall y FP/img)
def eval_box_recall_fp(cached, score_thresh, nms_thresh, det_per_img, iou_thresh=0.5):
    total_gt = 0
    total_matches = 0
    total_preds = 0

    for item in cached:
        g = item["g_boxes"]
        pb, ps, pl = apply_operating_point(
            item["p_boxes"], item["p_scores"], item["p_labels"],
            score_thresh=score_thresh, nms_thresh=nms_thresh, det_per_img=det_per_img
        )

        m = greedy_match_iou(pb, g, iou_thresh=iou_thresh)

        total_gt += int(len(g))
        total_matches += int(m)
        total_preds += int(len(pb))

    recall = total_matches / total_gt if total_gt > 0 else 0.0
    fp = total_preds - total_matches
    fp_per_img = fp / len(cached) if len(cached) > 0 else 0.0
    preds_per_img = total_preds / len(cached) if len(cached) > 0 else 0.0
    return {
        "recall": float(recall),
        "fp_per_img": float(fp_per_img),
        "preds_per_img": float(preds_per_img),
        "total_gt": int(total_gt),
        "total_matches": int(total_matches),
        "total_preds": int(total_preds),
    }

# Cachear VALID (una vez)
cached_valid = cache_valid_outputs(
    model, valid_dl, device,
    force_score_thresh=0.0,
    force_nms_thresh=1.0,
    force_det_per_img=1500,
)

print(f"Cached VALID images: {len(cached_valid)}")

# 2) Grid search operating point. Target: box-recall >= 0.98, minimizar FP/img
TARGET_RECALL = 0.98
IOU_THRESH = 0.5

score_grid = [0.01, 0.02, 0.03, 0.05, 0.08, 0.10, 0.15, 0.20, 0.30, 0.50]
nms_grid   = [0.30, 0.40, 0.50, 0.60, 0.70]
det_grid   = [50, 100, 200, 400]

results = []
for s in score_grid:
    for n in nms_grid:
        for d in det_grid:
            r = eval_box_recall_fp(cached_valid, s, n, d, iou_thresh=IOU_THRESH)
            r.update({"score_thresh": s, "nms_thresh": n, "det_per_img": d})
            results.append(r)

# Filtrar por recall objetivo
feasible = [r for r in results if r["recall"] >= TARGET_RECALL]

if not feasible:
    best = sorted(results, key=lambda x: (-x["recall"], x["fp_per_img"], x["preds_per_img"]))[0]
    print("\nNo hubo combinaciones con recall >= target.")
    print("Mejor alternativa (max recall, luego min FP/img):")
else:
    best = sorted(feasible, key=lambda x: (x["fp_per_img"], x["preds_per_img"], -x["recall"]))[0]
    print("\nMejor combinación cumpliendo recall >= target:")

print(best)

# Top-10 para mirar trade-off
top10 = sorted(
    feasible if feasible else results,
    key=lambda x: (x["fp_per_img"], x["preds_per_img"], -x["recall"])
)[:10]

print("\nTop 10 (ordenadas por menor FP/img):")
for r in top10:
    print(f"s={r['score_thresh']:.2f} nms={r['nms_thresh']:.2f} d={r['det_per_img']:4d} | "
          f"rec={r['recall']:.3f} fp/img={r['fp_per_img']:.2f} preds/img={r['preds_per_img']:.2f}")

# 3) Setear el modelo con el operating point elegido
model.roi_heads.score_thresh = float(best["score_thresh"])
model.roi_heads.nms_thresh = float(best["nms_thresh"])
model.roi_heads.detections_per_img = int(best["det_per_img"])

print("\nModel ROI heads set:")
print("  score_thresh      =", model.roi_heads.score_thresh)
print("  nms_thresh        =", model.roi_heads.nms_thresh)
print("  detections_per_img=", model.roi_heads.detections_per_img)
# Out:
# Cached VALID images: 1766
#
# Mejor combinación cumpliendo recall >= target:
# {'recall': 0.9801812004530012, 'fp_per_img': 5.5436013590033975, 'preds_per_img': 6.523782559456398, 'total_gt': 1766, 'total_matches': 1731, 'total_preds': 11521, 'score_thresh': 0.05, 'nms_thresh': 0.7, 'det_per_img': 50}
#
# Top 10 (ordenadas por menor FP/img):
# s=0.05 nms=0.70 d=  50 | rec=0.980 fp/img=5.54 preds/img=6.52
# s=0.05 nms=0.70 d= 100 | rec=0.980 fp/img=5.54 preds/img=6.52
# s=0.05 nms=0.70 d= 200 | rec=0.980 fp/img=5.54 preds/img=6.52
# s=0.05 nms=0.70 d= 400 | rec=0.980 fp/img=5.54 preds/img=6.52
# s=0.02 nms=0.60 d=  50 | rec=0.981 fp/img=5.70 preds/img=6.69
# s=0.02 nms=0.60 d= 100 | rec=0.981 fp/img=5.70 preds/img=6.69
# s=0.02 nms=0.60 d= 200 | rec=0.981 fp/img=5.70 preds/img=6.69
# s=0.02 nms=0.60 d= 400 | rec=0.981 fp/img=5.70 preds/img=6.69
# s=0.03 nms=0.70 d=  50 | rec=0.982 fp/img=8.23 preds/img=9.22
# s=0.03 nms=0.70 d= 100 | rec=0.982 fp/img=8.23 preds/img=9.22
#
# Model ROI heads set:
#   score_thresh      = 0.05
#   nms_thresh        = 0.7
#   detections_per_img= 50

# %%
print(f"Tiempo calibración operating point: {datetime.datetime.now() - INICIO_STEP}")
INICIO_STEP = datetime.datetime.now()
# Out:
# Tiempo calibración operating point: 1:47:48.599839

# %%
# ---------------------------------------
# 9) Graficar métricas por epoch
# ---------------------------------------

def _get(h, *keys, default=np.nan):
    cur = h
    for k in keys:
        if cur is None or not isinstance(cur, dict) or k not in cur:
            return default
        cur = cur[k]
    return cur if cur is not None else default

epochs = [h["epoch"] for h in history]

# Series base (loss + LR)
train_loss = [_get(h, "train", "loss_total") for h in history]
val_loss   = [_get(h, "valid", "loss_total") for h in history]

train_cls  = [_get(h, "train", "loss_classifier") for h in history]
train_box  = [_get(h, "train", "loss_box_reg") for h in history]
train_obj  = [_get(h, "train", "loss_objectness") for h in history]
train_rpn  = [_get(h, "train", "loss_rpn_box_reg") for h in history]

val_cls    = [_get(h, "valid", "loss_classifier") for h in history]
val_box    = [_get(h, "valid", "loss_box_reg") for h in history]
val_obj    = [_get(h, "valid", "loss_objectness") for h in history]
val_rpn    = [_get(h, "valid", "loss_rpn_box_reg") for h in history]

lr_series  = [_get(h, "lr") for h in history]

# Series de métricas (macro)
val_prec = [_get(h, "valid_macro", "precision") for h in history]
val_rec  = [_get(h, "valid_macro", "recall") for h in history]
val_f1   = [_get(h, "valid_macro", "f1") for h in history]
val_f2   = [_get(h, "valid_macro", "f2") for h in history]

# mAP (si existe)
map50 = [_get(h, "valid_map", "map_50") for h in history]
map95 = [_get(h, "valid_map", "map") for h in history]
has_map = np.any(np.isfinite(map50)) or np.any(np.isfinite(map95))

# Loss total: train vs val
plt.figure()
plt.plot(epochs, train_loss, marker="o", label="train loss_total")
plt.plot(epochs, val_loss,   marker="o", label="val loss_total")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss total (train vs val)")
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()

# Breakdown de losses (train vs val)
plt.figure()
plt.plot(epochs, train_cls, marker="o", label="train loss_classifier")
plt.plot(epochs, val_cls,   marker="o", label="val loss_classifier")
plt.xlabel("Epoch"); plt.ylabel("Loss"); plt.title("Loss: classifier"); plt.grid(True, alpha=0.3); plt.legend(); plt.show()

plt.figure()
plt.plot(epochs, train_box, marker="o", label="train loss_box_reg")
plt.plot(epochs, val_box,   marker="o", label="val loss_box_reg")
plt.xlabel("Epoch"); plt.ylabel("Loss"); plt.title("Loss: box_reg"); plt.grid(True, alpha=0.3); plt.legend(); plt.show()

plt.figure()
plt.plot(epochs, train_obj, marker="o", label="train loss_objectness")
plt.plot(epochs, val_obj,   marker="o", label="val loss_objectness")
plt.xlabel("Epoch"); plt.ylabel("Loss"); plt.title("Loss: objectness"); plt.grid(True, alpha=0.3); plt.legend(); plt.show()

plt.figure()
plt.plot(epochs, train_rpn, marker="o", label="train loss_rpn_box_reg")
plt.plot(epochs, val_rpn,   marker="o", label="val loss_rpn_box_reg")
plt.xlabel("Epoch"); plt.ylabel("Loss"); plt.title("Loss: rpn_box_reg"); plt.grid(True, alpha=0.3); plt.legend(); plt.show()

# 3) Métricas macro en VALID (precision/recall/F1/F2)
plt.figure()
plt.plot(epochs, val_prec, marker="o", label="val macro precision")
plt.plot(epochs, val_rec,  marker="o", label="val macro recall")
plt.plot(epochs, val_f1,   marker="o", label="val macro F1")
plt.plot(epochs, val_f2,   marker="o", label="val macro F2")
plt.xlabel("Epoch")
plt.ylabel("Score")
plt.ylim(0, 1.0)
plt.title("VALID macro metrics @ score_thresh / IoU")
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()

# mAP en VALID
if has_map:
    plt.figure()
    plt.plot(epochs, map50, marker="o", label="val mAP@0.5 (map_50)")
    plt.plot(epochs, map95, marker="o", label="val mAP@[0.5:0.95] (map)")
    plt.xlabel("Epoch")
    plt.ylabel("mAP")
    plt.ylim(0, 1.0)
    plt.title("VALID mAP (torchmetrics)")
    plt.grid(True, alpha=0.3)
    plt.legend()
    plt.show()
else:
    print("mAP no aparece en history.")

# Learning rate
plt.figure()
plt.plot(epochs, lr_series, marker="o")
plt.xlabel("Epoch")
plt.ylabel("LR")
plt.title("Learning Rate per epoch")
plt.grid(True, alpha=0.3)
plt.show()

# %%
print(f"Tiempo entrenamiento: {datetime.datetime.now() - INICIO_STEP}")
INICIO_STEP = datetime.datetime.now()
# Out:
# Tiempo entrenamiento: 0:00:01.174187

# %%
# ---------------------------------------
# 10) Guardado del modelo (pesos y checkpoint)
# ---------------------------------------

stamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
OUT_DIR = os.path.join(OUT_BASE_DIR, f"artifacts_{stamp}")
os.makedirs(OUT_DIR, exist_ok=True)

weights_path    = os.path.join(OUT_DIR, f"weights.pth")
checkpoint_path = os.path.join(OUT_DIR, f"frcnn_checkpoint.pth")
meta_path       = os.path.join(OUT_DIR, f"meta.json")

torch.save(model.state_dict(), weights_path)
print(f"[OK] Pesos guardados en: {weights_path}")

ckpt = {
    "model_state": model.state_dict(),
    "optimizer_state": optimizer.state_dict(),
    "epoch": EPOCHS,
    "num_classes": NUM_CLASSES,
    "class_names": CLASS_NAMES,
    "img_size": (416, 416),
    "lr": LR,
}
torch.save(ckpt, checkpoint_path)
print(f"[OK] Checkpoint guardado en: {checkpoint_path}")

meta = {
    "saved_at": stamp,
    "framework": "torchvision Faster R-CNN ResNet50-FPN",
    "device": str(device),
    "num_classes_with_bg": NUM_CLASSES_WITH_BG,
    "class_names": CLASS_NAMES,
    "train_imgs": len(train_ds),
    "valid_imgs": len(valid_ds),
    "test_imgs": len(test_ds),
    # "eval_valid_macro": eval_valid.get("macro", {}) if 'eval_valid' in locals() else {}
}
with open(meta_path, "w", encoding="utf-8") as f:
    json.dump(meta, f, indent=2, ensure_ascii=False)
print(f"[OK] Metadatos guardados en: {meta_path}")
# Out:
# [OK] Pesos guardados en: /content/drive/MyDrive/UBA/CEIA/Materias/Visión por Computadora II/google_colab_data/FasterR-CNN-ResNet50_notebook/artifacts_20251201_045126/weights.pth
# [OK] Checkpoint guardado en: /content/drive/MyDrive/UBA/CEIA/Materias/Visión por Computadora II/google_colab_data/FasterR-CNN-ResNet50_notebook/artifacts_20251201_045126/frcnn_checkpoint.pth
# [OK] Metadatos guardados en: /content/drive/MyDrive/UBA/CEIA/Materias/Visión por Computadora II/google_colab_data/FasterR-CNN-ResNet50_notebook/artifacts_20251201_045126/meta.json

# %%
print(f"Tiempo guardado modelo: {datetime.datetime.now() - INICIO_STEP}")
INICIO_STEP = datetime.datetime.now()
# Out:
# Tiempo guardado modelo: 0:00:01.191080

# %%
# ---------------------------------------
# 11) Matriz de confusión (valid y test)
# ---------------------------------------

def _greedy_match_iou_class_first(pred_boxes, gt_boxes, pred_labels, gt_labels, iou_thresh=0.5):
    if len(pred_boxes) == 0 or len(gt_boxes) == 0:
        return []

    ious = box_iou(pred_boxes, gt_boxes).cpu().numpy()
    matches = []
    used_pred, used_gt = set(), set()

    def _run(flat_pairs):
        nonlocal matches, used_pred, used_gt
        for i, j, v in flat_pairs:
            if v < iou_thresh:
                break
            if (i not in used_pred) and (j not in used_gt):
                used_pred.add(i); used_gt.add(j)
                matches.append((i, j))

    # Construir pares (i, j, iou)
    flat_same = []
    flat_diff = []
    for i in range(ious.shape[0]):
        for j in range(ious.shape[1]):
            v = ious[i, j]
            if pred_labels[i] == gt_labels[j]:
                flat_same.append((i, j, v))
            else:
                flat_diff.append((i, j, v))

    flat_same.sort(key=lambda x: x[2], reverse=True)
    flat_diff.sort(key=lambda x: x[2], reverse=True)

    _run(flat_same)  # etapa 1: aciertos
    _run(flat_diff)  # etapa 2: confusiones

    return matches


def confusion_matrix_detection(model, loader, class_names, score_thresh=0.5, iou_thresh=0.5, normalize=True, title="Confusion Matrix"):
    model.eval()
    K = len(class_names)
    C = np.zeros((K+1, K+1), dtype=np.int64)  # filas=pred, cols=true ; ultimo índice = background
    bg = K  # índice background

    with torch.no_grad():
        for imgs, targets in loader:
            imgs = [img.to(device) for img in imgs]
            outs = model(imgs)

            for out, tgt in zip(outs, targets):
                # Filtrar por score
                keep = out["scores"].cpu().numpy() >= score_thresh
                p_boxes = out["boxes"][keep].cpu()
                p_labels = out["labels"][keep].cpu().numpy()  # en 1..K

                g_boxes  = tgt["boxes"].cpu()
                g_labels = tgt["labels"].cpu().numpy()        # en 1..K

                # Emparejar por IoU (class-agnostic) para poder medir confusiones entre clases. Pasar labels a 0..K-1 para el matching
                p_labels0 = (p_labels.astype(int) - 1)
                g_labels0 = (g_labels.astype(int) - 1)

                matches = _greedy_match_iou_class_first(p_boxes, g_boxes, p_labels0, g_labels0, iou_thresh=iou_thresh)

                matched_pred = set(i for i, _ in matches)
                matched_gt   = set(j for _, j in matches)

                # Contar matches (pueden ser aciertos o confusiones de clase)
                for i, j in matches:
                  pred_c = int(p_labels0[i])
                  true_c = int(g_labels0[j])
                  C[pred_c, true_c] += 1

                # Predicciones no emparejadas -> true = background
                for i in range(len(p_boxes)):
                    if i not in matched_pred:
                        pred_c = int(p_labels[i]) - 1
                        C[pred_c, bg] += 1

                # GT no emparejadas -> pred = background
                for j in range(len(g_boxes)):
                    if j not in matched_gt:
                        true_c = int(g_labels[j]) - 1
                        C[bg, true_c] += 1

    # Normalización por columna
    Cn = C.astype(float)
    if normalize:
        col_sums = Cn.sum(axis=0, keepdims=True)
        col_sums[col_sums == 0] = 1.0
        Cn = Cn / col_sums

    # Plot
    labels_plot = class_names + ["background"]
    fig, ax = plt.subplots(figsize=(8, 6))
    im = ax.imshow(Cn, interpolation='nearest', aspect='auto')
    ax.set_title(title)
    ax.set_xlabel("True")
    ax.set_ylabel("Predicted")
    ax.set_xticks(range(len(labels_plot)))
    ax.set_yticks(range(len(labels_plot)))
    ax.set_xticklabels(labels_plot, rotation=45, ha='right')
    ax.set_yticklabels(labels_plot)

    # Anotar valores
    for i in range(Cn.shape[0]):
        for j in range(Cn.shape[1]):
            val = Cn[i, j]
            txt = f"{val:.2f}" if normalize else str(C[i, j])
            ax.text(j, i, txt, ha='center', va='center', color='white' if val > 0.5 else 'black', fontsize=8)

    fig.colorbar(im, ax=ax, fraction=0.046, pad=0.04)
    plt.tight_layout()
    plt.show()

    return {"raw": C, "norm": Cn, "labels": labels_plot}

# Una matriz absoluta y normalizada para VALID y otra para TEST
confusion_matrix_detection(model, valid_dl, CLASS_NAMES, score_thresh=model.roi_heads.score_thresh, iou_thresh=0.5,
                           normalize=False, title=f"Matriz de confusión (Absoluta, VALID, IoU=0.5, score≥{model.roi_heads.score_thresh})")
confusion_matrix_detection(model, valid_dl, CLASS_NAMES, score_thresh=model.roi_heads.score_thresh, iou_thresh=0.5,
                           normalize=True, title=f"Matriz de confusión (Normalizada, VALID, IoU=0.5, score≥{model.roi_heads.score_thresh})")
confusion_matrix_detection(model, test_dl,  CLASS_NAMES, score_thresh=model.roi_heads.score_thresh, iou_thresh=0.5,
                           normalize=False, title=f"Matriz de confusión (Absoluta, TEST, IoU=0.5, score≥{model.roi_heads.score_thresh})")
confusion_matrix_detection(model, test_dl,  CLASS_NAMES, score_thresh=model.roi_heads.score_thresh, iou_thresh=0.5,
                           normalize=True, title=f"Matriz de confusión (Normalizada, TEST, IoU=0.5, score≥{model.roi_heads.score_thresh})")
# Out:
# {'raw': array([[ 164,    0,    0,    0,    0,  584],
#         [   0,  190,    0,    0,    0, 1026],
#         [   0,    1,  110,    0,    1, 1070],
#         [   1,    0,    3,  196,    1, 1423],
#         [   0,    0,    0,    0,  199,  956],
#         [   1,    2,    5,    7,    2,    0]]),
#  'norm': array([[0.98795181, 0.        , 0.        , 0.        , 0.        ,
#          0.11543783],
#         [0.        , 0.98445596, 0.        , 0.        , 0.        ,
#          0.20280688],
#         [0.        , 0.00518135, 0.93220339, 0.        , 0.00492611,
#          0.21150425],
#         [0.0060241 , 0.        , 0.02542373, 0.96551724, 0.00492611,
#          0.28128089],
#         [0.        , 0.        , 0.        , 0.        , 0.98029557,
#          0.18897015],
#         [0.0060241 , 0.01036269, 0.04237288, 0.03448276, 0.00985222,
#          0.        ]]),
#  'labels': ['Tijera',
#   'Navaja',
#   'Cuchillo',
#   'Cutter',
#   'Navaja multiuso',
#   'background']}

# %%
print(f"Tiempo matrices confusión: {datetime.datetime.now() - INICIO_STEP}")
INICIO_STEP = datetime.datetime.now()
# Out:
# Tiempo matrices confusión: 0:01:54.256563

# %%
# ---------------------------------------
# 12) Recolectar métricas y guardar en JSON
# ---------------------------------------

if 'train_loss_history' not in globals():
    train_loss_history = []

def summarize_eval(eval_dict, split_name):
    """Convierte la salida de evaluate_prf1(...) al esquema JSON estandar."""
    if eval_dict is None:
        return None
    per_class = []
    for (name, tp, fp, fn, prec, rec, f1) in eval_dict["per_class"]:
        per_class.append({
            "class": name,
            "tp": int(tp),
            "fp": int(fp),
            "fn": int(fn),
            "precision": float(prec),
            "recall": float(rec),
            "f1": float(f1),
        })
    # totales (sin background)
    TP = int(eval_dict["raw"]["TP"][1:].sum())
    FP = int(eval_dict["raw"]["FP"][1:].sum())
    FN = int(eval_dict["raw"]["FN"][1:].sum())
    return {
        "split": split_name,
        "macro": {
            "precision": float(eval_dict["macro"]["precision"]),
            "recall":    float(eval_dict["macro"]["recall"]),
            "f1":        float(eval_dict["macro"]["f1"]),
        },
        "totals": {"TP": TP, "FP": FP, "FN": FN},
        "per_class": per_class,
        "thresholds": {"iou": 0.5, "score": 0.5}
    }

def is_backbone_frozen(m):
    try:
        return all((not p.requires_grad) for p in m.backbone.parameters())
    except Exception:
        return None

# Información del optimizador/scheduler
opt_name = optimizer.__class__.__name__ if 'optimizer' in globals() else None
sch_name = lr_sched.__class__.__name__ if 'lr_sched' in globals() else None

# Build del JSON
stamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
payload = {
    "saved_at": stamp,
    "notebook": "CEIA_VpC2_TP_Opcion2.ipynb",
    "framework": "torchvision Faster R-CNN ResNet50-FPN",
    "device": str(device),
    "classes": CLASS_NAMES,
    "num_classes": len(CLASS_NAMES),
    "data": {
        "train_images": len(train_ds) if 'train_ds' in globals() else None,
        "valid_images": len(valid_ds) if 'valid_ds' in globals() else None,
        "test_images":  len(test_ds)  if 'test_ds'  in globals() else None
    },
    "training": {
        "epochs": EPOCHS if 'EPOCHS' in globals() else None,
        "batch_size": BATCH_SIZE if 'BATCH_SIZE' in globals() else None,
        "lr": LR if 'LR' in globals() else None,
        "optimizer": opt_name,
        "scheduler": sch_name,
        "backbone_frozen": is_backbone_frozen(model),
        "loss_history": train_loss_history,
    },
}

path_metrics_full = os.path.join(OUT_DIR, "metrics_full.json")

with open(path_metrics_full, "w", encoding="utf-8") as f:
    json.dump(payload, f, indent=2, ensure_ascii=False)

print(f"[OK] Métricas guardadas:\n  - {path_metrics_full}")
# Out:
# [OK] Métricas guardadas:
#   - /content/drive/MyDrive/UBA/CEIA/Materias/Visión por Computadora II/google_colab_data/FasterR-CNN-ResNet50_notebook/artifacts_20251201_045126/metrics_full.json

# %%
print(f"Tiempo recolección métricas: {datetime.datetime.now() - INICIO_STEP}")
INICIO_STEP = datetime.datetime.now()
# Out:
# Tiempo recolección métricas: 0:00:00.020801

# %%
# ---------------------------------------
# 13) Curvas P-R por clase y mAP (mAP@0.5 y mAP@[0.5:0.95])
# ---------------------------------------


@torch.no_grad()
def _collect_predictions_and_gts(model, loader, device, num_classes, score_min=0.0):
    model.eval()
    preds_by_cls = {c: [] for c in range(1, num_classes+1)}
    gts_by_cls   = {c: [] for c in range(1, num_classes+1)}

    img_index = 0
    for imgs, targets in loader:
        imgs = [img.to(device) for img in imgs]
        outs = model(imgs)

        for out, tgt in zip(outs, targets):
            # GT
            gt_boxes  = tgt["boxes"].cpu().numpy()
            gt_labels = tgt["labels"].cpu().numpy()  # 1..K
            for b, lab in zip(gt_boxes, gt_labels):
                gts_by_cls[int(lab)].append((b[0], b[1], b[2], b[3], img_index))

            # Preds
            scores = out["scores"].cpu().numpy()
            keep = scores >= score_min
            p_boxes  = out["boxes"][keep].cpu().numpy()
            p_labels = out["labels"][keep].cpu().numpy()  # 1..K
            p_scores = scores[keep]

            for b, lab, sc in zip(p_boxes, p_labels, p_scores):
                preds_by_cls[int(lab)].append((float(sc), b[0], b[1], b[2], b[3], img_index))

            img_index += 1
    return preds_by_cls, gts_by_cls

def _ap_from_pr(precision, recall):
    if len(precision) == 0:
        return 0.0
    # Ordenar por recall ascendente
    order = np.argsort(recall)
    r = np.array(recall)[order]
    p = np.array(precision)[order]

    # Precision envelope: p[i] = max_{j>=i} p[j]
    for i in range(len(p)-2, -1, -1):
        p[i] = max(p[i], p[i+1])

    # Muestreamos 101 puntos de recall
    recall_grid = np.linspace(0, 1, 101)
    p_interp = np.zeros_like(recall_grid)
    for i, rg in enumerate(recall_grid):
        idx = np.where(r >= rg)[0]
        p_interp[i] = 0.0 if len(idx) == 0 else np.max(p[idx])
    return float(np.mean(p_interp))

def _pr_curve_for_class(preds_cls, gts_cls, iou_thresh=0.5):
    # Índice de GTs por imagen para acelerar matching
    gt_by_img = {}
    for (x1, y1, x2, y2, img_id) in gts_cls:
        gt_by_img.setdefault(img_id, []).append([x1, y1, x2, y2, False])  # False = no emparejada todavía

    # Ordenar predicciones por score descendente
    preds_cls = sorted(preds_cls, key=lambda x: x[0], reverse=True)

    tp = np.zeros(len(preds_cls), dtype=np.float32)
    fp = np.zeros(len(preds_cls), dtype=np.float32)
    total_gts = len(gts_cls)

    for i, (score, x1, y1, x2, y2, img_id) in enumerate(preds_cls):
        pred_box = np.array([[x1, y1, x2, y2]], dtype=np.float32)
        gts_list = gt_by_img.get(img_id, [])

        if len(gts_list) == 0:
            fp[i] = 1.0
            continue

        # IoU con todas las GTs de esta imagen para esta clase
        gt_boxes = np.array([g[:4] for g in gts_list], dtype=np.float32)
        ious = box_iou(torch.tensor(pred_box), torch.tensor(gt_boxes)).numpy()[0]

        # Mejor IoU
        best_idx = int(np.argmax(ious))
        best_iou = float(ious[best_idx])

        if best_iou >= iou_thresh and (not gts_list[best_idx][4]):  # no emparejada
            tp[i] = 1.0
            gts_list[best_idx][4] = True  # marcar como usada
        else:
            fp[i] = 1.0

    # Cálculo de precisión y recall acumulados
    cum_tp = np.cumsum(tp)
    cum_fp = np.cumsum(fp)
    precision = cum_tp / np.maximum(cum_tp + cum_fp, 1e-9)
    recall = cum_tp / max(total_gts, 1e-9)

    ap = _ap_from_pr(precision, recall)
    return precision, recall, ap, int(cum_tp[-1]) if len(cum_tp) else 0, int(cum_fp[-1]) if len(cum_fp) else 0, total_gts

def compute_map(model, loader, class_names, device, iou_list=(0.5,), score_min=0.0, plot_pr=True, title_prefix="VALID"):
    K = len(class_names)
    preds_by_cls, gts_by_cls = _collect_predictions_and_gts(model, loader, device, K, score_min=score_min)

    aps_per_iou = []
    pr_cache = {}  # para el primer IoU (plot)

    for iou in iou_list:
        ap_classes = []
        for cls_id in range(1, K+1):
            precision, recall, ap, tps, fps, total_gts = _pr_curve_for_class(preds_by_cls[cls_id], gts_by_cls[cls_id], iou_thresh=iou)
            ap_classes.append(ap)
            if iou == iou_list[0]:  # cachear para plot
                pr_cache[cls_id] = (precision, recall, ap, tps, fps, total_gts)

        mAP = float(np.mean(ap_classes)) if len(ap_classes) else 0.0
        aps_per_iou.append((iou, ap_classes, mAP))

    # Plot P-R (solo para el primer IoU)
    if plot_pr:
        cols = 2
        rows = int(np.ceil(K / cols))
        fig, axes = plt.subplots(rows, cols, figsize=(10, 4*rows), squeeze=False)
        i = 0
        for r in range(rows):
            for c in range(cols):
                ax = axes[r][c]
                i += 1
                if i <= K:
                    P, R, APc, TPc, FPc, GTc = pr_cache[i]
                    ax.plot(R, P)
                    ax.set_title(f"{class_names[i-1]} | AP@{iou_list[0]:.2f}={APc:.3f} | TP={TPc} FP={FPc} GT={GTc}")
                    ax.set_xlabel("Recall")
                    ax.set_ylabel("Precision")
                    ax.set_xlim(0, 1)
                    ax.set_ylim(0, 1)
                else:
                    ax.axis("off")
        plt.suptitle(f"Precision-Recall por clase ({title_prefix}, IoU={iou_list[0]:.2f})")
        plt.tight_layout()
        plt.show()

    # Reporte numérico
    for iou, ap_classes, mAP in aps_per_iou:
        print(f"\n=== Resultados AP/mAP @ IoU={iou:.2f} ({title_prefix}) ===")
        for ci, ap in enumerate(ap_classes, start=1):
            print(f"  {class_names[ci-1]:20s}: AP={ap:.3f}")
        print(f"  mAP@{iou:.2f}: {mAP:.3f}")

    return aps_per_iou  # lista de (iou, [AP_cls], mAP)

# Ejecutar en VALID
# mAP@0.5
aps_valid_05 = compute_map(model, valid_dl, CLASS_NAMES, device, iou_list=(0.5,), score_min=0.0, plot_pr=True, title_prefix="VALID")
# mAP@[0.5:0.95] (COCO)
iou_grid = tuple(np.round(np.arange(0.5, 0.96, 0.05), 2))
aps_valid_COCO = compute_map(model, valid_dl, CLASS_NAMES, device, iou_list=iou_grid, score_min=0.0, plot_pr=False, title_prefix="VALID")

# Ejecutar en TEST
aps_test_05 = compute_map(model, test_dl, CLASS_NAMES, device, iou_list=(0.5,), score_min=0.0, plot_pr=True, title_prefix="TEST")
aps_test_COCO = compute_map(model, test_dl, CLASS_NAMES, device, iou_list=iou_grid, score_min=0.0, plot_pr=False, title_prefix="TEST")
# Out:
# === Resultados AP/mAP @ IoU=0.50 (VALID) ===
#   Tijera              : AP=0.968
#   Navaja              : AP=0.922
#   Cuchillo            : AP=0.651
#   Cutter              : AP=0.811
#   Navaja multiuso     : AP=0.930
#   mAP@0.50: 0.856
#
# === Resultados AP/mAP @ IoU=0.50 (VALID) ===
#   Tijera              : AP=0.968
#   Navaja              : AP=0.922
#   Cuchillo            : AP=0.651
#   Cutter              : AP=0.811
#   Navaja multiuso     : AP=0.930
#   mAP@0.50: 0.856
#
# === Resultados AP/mAP @ IoU=0.55 (VALID) ===
#   Tijera              : AP=0.965
#   Navaja              : AP=0.856
#   Cuchillo            : AP=0.586
#   Cutter              : AP=0.780
#   Navaja multiuso     : AP=0.876
#   mAP@0.55: 0.812
#
# === Resultados AP/mAP @ IoU=0.60 (VALID) ===
#   Tijera              : AP=0.927
#   Navaja              : AP=0.786
#   Cuchillo            : AP=0.489
#   Cutter              : AP=0.719
#   Navaja multiuso     : AP=0.805
#   mAP@0.60: 0.745
#
# === Resultados AP/mAP @ IoU=0.65 (VALID) ===
#   Tijera              : AP=0.823
#   Navaja              : AP=0.672
#   Cuchillo            : AP=0.375
#   Cutter              : AP=0.632
#   Navaja multiuso     : AP=0.658
#   mAP@0.65: 0.632
#
# === Resultados AP/mAP @ IoU=0.70 (VALID) ===
#   Tijera              : AP=0.659
#   Navaja              : AP=0.520
#   Cuchillo            : AP=0.232
#   Cutter              : AP=0.458
#   Navaja multiuso     : AP=0.473
#   mAP@0.70: 0.468
#
# === Resultados AP/mAP @ IoU=0.75 (VALID) ===
#   Tijera              : AP=0.423
#   Navaja              : AP=0.287
#   Cuchillo            : AP=0.089
#   Cutter              : AP=0.298
#   Navaja multiuso     : AP=0.290
#   mAP@0.75: 0.277
#
# === Resultados AP/mAP @ IoU=0.80 (VALID) ===
#   Tijera              : AP=0.222
#   Navaja              : AP=0.098
#   Cuchillo            : AP=0.024
#   Cutter              : AP=0.145
#   Navaja multiuso     : AP=0.086
#   mAP@0.80: 0.115
#
# === Resultados AP/mAP @ IoU=0.85 (VALID) ===
#   Tijera              : AP=0.051
#   Navaja              : AP=0.019
#   Cuchillo            : AP=0.003
#   Cutter              : AP=0.026
#   Navaja multiuso     : AP=0.015
#   mAP@0.85: 0.023
#
# === Resultados AP/mAP @ IoU=0.90 (VALID) ===
#   Tijera              : AP=0.007
#   Navaja              : AP=0.001
#   Cuchillo            : AP=0.001
#   Cutter              : AP=0.007
#   Navaja multiuso     : AP=0.002
#   mAP@0.90: 0.004
#
# === Resultados AP/mAP @ IoU=0.95 (VALID) ===
#   Tijera              : AP=0.000
#   Navaja              : AP=0.000
#   Cuchillo            : AP=0.000
#   Cutter              : AP=0.000
#   Navaja multiuso     : AP=0.000
#   mAP@0.95: 0.000
# === Resultados AP/mAP @ IoU=0.50 (TEST) ===
#   Tijera              : AP=0.973
#   Navaja              : AP=0.903
#   Cuchillo            : AP=0.788
#   Cutter              : AP=0.881
#   Navaja multiuso     : AP=0.928
#   mAP@0.50: 0.895
#
# === Resultados AP/mAP @ IoU=0.50 (TEST) ===
#   Tijera              : AP=0.973
#   Navaja              : AP=0.903
#   Cuchillo            : AP=0.788
#   Cutter              : AP=0.881
#   Navaja multiuso     : AP=0.928
#   mAP@0.50: 0.895
#
# === Resultados AP/mAP @ IoU=0.55 (TEST) ===
#   Tijera              : AP=0.958
#   Navaja              : AP=0.869
#   Cuchillo            : AP=0.752
#   Cutter              : AP=0.827
#   Navaja multiuso     : AP=0.864
#   mAP@0.55: 0.854
#
# === Resultados AP/mAP @ IoU=0.60 (TEST) ===
#   Tijera              : AP=0.919
#   Navaja              : AP=0.808
#   Cuchillo            : AP=0.683
#   Cutter              : AP=0.798
#   Navaja multiuso     : AP=0.831
#   mAP@0.60: 0.808
#
# === Resultados AP/mAP @ IoU=0.65 (TEST) ===
#   Tijera              : AP=0.847
#   Navaja              : AP=0.734
#   Cuchillo            : AP=0.564
#   Cutter              : AP=0.687
#   Navaja multiuso     : AP=0.758
#   mAP@0.65: 0.718
#
# === Resultados AP/mAP @ IoU=0.70 (TEST) ===
#   Tijera              : AP=0.693
#   Navaja              : AP=0.547
#   Cuchillo            : AP=0.419
#   Cutter              : AP=0.547
#   Navaja multiuso     : AP=0.568
#   mAP@0.70: 0.555
#
# === Resultados AP/mAP @ IoU=0.75 (TEST) ===
#   Tijera              : AP=0.454
#   Navaja              : AP=0.292
#   Cuchillo            : AP=0.210
#   Cutter              : AP=0.277
#   Navaja multiuso     : AP=0.343
#   mAP@0.75: 0.315
#
# === Resultados AP/mAP @ IoU=0.80 (TEST) ===
#   Tijera              : AP=0.211
#   Navaja              : AP=0.146
#   Cuchillo            : AP=0.049
#   Cutter              : AP=0.120
#   Navaja multiuso     : AP=0.141
#   mAP@0.80: 0.134
#
# === Resultados AP/mAP @ IoU=0.85 (TEST) ===
#   Tijera              : AP=0.064
#   Navaja              : AP=0.027
#   Cuchillo            : AP=0.017
#   Cutter              : AP=0.025
#   Navaja multiuso     : AP=0.037
#   mAP@0.85: 0.034
#
# === Resultados AP/mAP @ IoU=0.90 (TEST) ===
#   Tijera              : AP=0.009
#   Navaja              : AP=0.006
#   Cuchillo            : AP=0.002
#   Cutter              : AP=0.005
#   Navaja multiuso     : AP=0.001
#   mAP@0.90: 0.005
#
# === Resultados AP/mAP @ IoU=0.95 (TEST) ===
#   Tijera              : AP=0.002
#   Navaja              : AP=0.005
#   Cuchillo            : AP=0.000
#   Cutter              : AP=0.000
#   Navaja multiuso     : AP=0.000
#   mAP@0.95: 0.001

# %%
print(f"Tiempo preparación curvas: {datetime.datetime.now() - INICIO_STEP}")
INICIO_STEP = datetime.datetime.now()
# Out:
# Tiempo preparación curvas: 0:02:18.661088

# %%
# ---------------------------------------
# 14) Barrido de umbral de score → Macro-F1 vs. score (en VALID)
# ---------------------------------------

@torch.no_grad()
def evaluate_prf1(model, loader, device, class_names, score_thresh=0.5, iou_thresh=0.5):
    model.eval()
    K = len(class_names)
    TP = np.zeros(K+1, dtype=np.int64)
    FP = np.zeros(K+1, dtype=np.int64)
    FN = np.zeros(K+1, dtype=np.int64)

    for imgs, targets in loader:
        imgs = [img.to(device) for img in imgs]
        outs = model(imgs)

        for out, tgt in zip(outs, targets):
            gt_boxes = tgt["boxes"].cpu()
            gt_labels = tgt["labels"].cpu()  # 1..K

            keep = out["scores"].cpu() >= score_thresh
            pred_boxes = out["boxes"][keep].cpu()
            pred_labels = out["labels"][keep].cpu()  # 1..K
            pred_scores = out["scores"][keep].cpu()

            if len(gt_boxes) == 0 and len(pred_boxes) == 0:
                continue

            ious = box_iou(pred_boxes, gt_boxes) if (len(pred_boxes)>0 and len(gt_boxes)>0) else torch.zeros((len(pred_boxes), len(gt_boxes)))

            matched_gt = set()
            matched_pred = set()

            # greedy por score desc, y match por clase + IoU
            order = torch.argsort(pred_scores, descending=True).cpu().numpy()
            for pi in order:
                best_j, best_iou = -1, 0.0
                for gj in range(len(gt_boxes)):
                    if gj in matched_gt:
                        continue
                    if pred_labels[pi].item() != gt_labels[gj].item():
                        continue
                    iou_val = float(ious[pi, gj].item())
                    if iou_val >= iou_thresh and iou_val > best_iou:
                        best_iou, best_j = iou_val, gj
                if best_j >= 0:
                    cls = int(pred_labels[pi].item())
                    TP[cls] += 1
                    matched_pred.add(pi)
                    matched_gt.add(best_j)

            for pi in range(len(pred_boxes)):
                if pi not in matched_pred:
                    cls = int(pred_labels[pi].item())
                    FP[cls] += 1

            for gj in range(len(gt_boxes)):
                if gj not in matched_gt:
                    cls = int(gt_labels[gj].item())
                    FN[cls] += 1

    results = []
    for cls in range(1, K+1):
        tp, fp, fn = TP[cls], FP[cls], FN[cls]
        prec = tp/(tp+fp) if (tp+fp)>0 else 0.0
        rec  = tp/(tp+fn) if (tp+fn)>0 else 0.0
        f1   = 2*prec*rec/(prec+rec) if (prec+rec)>0 else 0.0
        results.append((class_names[cls-1], tp, fp, fn, prec, rec, f1))

    macro_prec = float(np.mean([r[4] for r in results])) if results else 0.0
    macro_rec  = float(np.mean([r[5] for r in results])) if results else 0.0
    macro_f1   = float(np.mean([r[6] for r in results])) if results else 0.0

    return {"per_class": results, "macro": {"precision": macro_prec, "recall": macro_rec, "f1": macro_f1}}


def sweep_threshold_macro_f1(model, loader, device, class_names,
                             iou_thresh=0.5,
                             scores=np.linspace(0.05, 0.95, 19)):
    model.eval()
    macro_f1 = []
    for s in scores:
        out = evaluate_prf1(model, loader, device, class_names,
                            score_thresh=float(s), iou_thresh=float(iou_thresh))
        macro_f1.append(out["macro"]["f1"])
    macro_f1 = np.array(macro_f1, dtype=float)

    # Mejor umbral
    best_idx = int(np.argmax(macro_f1))
    best_score = float(scores[best_idx])
    best_macro_f1 = float(macro_f1[best_idx])

    # Print detallado
    print(f"\n=== Barrido de umbral (VALID, IoU={iou_thresh:.2f}) ===")
    for s, f in zip(scores, macro_f1):
        print(f"  score={s:>4.2f}  →  Macro-F1={f:0.3f}")
    print(f"\nMejor umbral: score={best_score:.2f}  →  Macro-F1={best_macro_f1:.3f}")

    # Plot
    plt.figure(figsize=(6,4))
    plt.plot(scores, macro_f1, marker='o')
    plt.title(f"VALID | Macro-F1 vs. score (IoU={iou_thresh:.2f})")
    plt.xlabel("score threshold")
    plt.ylabel("Macro-F1")
    plt.grid(True, linestyle="--", alpha=0.4)
    plt.tight_layout()
    plt.show()

    return {
        "scores": scores.tolist(),
        "macro_f1": macro_f1.tolist(),
        "best_score": best_score,
        "best_macro_f1": best_macro_f1
    }

# Ejecutar barrido en VALID
score_sweep_valid = sweep_threshold_macro_f1(model, valid_dl, device, CLASS_NAMES, iou_thresh=0.5)

if 'payload' in globals():
    payload.setdefault("results", {}).setdefault("valid", {})
    payload["results"]["valid"]["score_sweep"] = {
        "scores": score_sweep_valid["scores"],
        "macro_f1": score_sweep_valid["macro_f1"],
        "best_score": score_sweep_valid["best_score"],
        "best_macro_f1": score_sweep_valid["best_macro_f1"],
        "iou": 0.5
    }
    print("[OK] Barrido de umbral agregado al payload de métricas (VALID).")

# Usar el mejor umbral para inferencia/validación rápida:
BEST_SCORE_FOR_INFERENCE = score_sweep_valid["best_score"]
print(f"BEST_SCORE_FOR_INFERENCE = {BEST_SCORE_FOR_INFERENCE:.2f}")
# Out:
# === Barrido de umbral (VALID, IoU=0.50) ===
#   score=0.05  →  Macro-F1=0.264
#   score=0.10  →  Macro-F1=0.375
#   score=0.15  →  Macro-F1=0.447
#   score=0.20  →  Macro-F1=0.506
#   score=0.25  →  Macro-F1=0.554
#   score=0.30  →  Macro-F1=0.588
#   score=0.35  →  Macro-F1=0.619
#   score=0.40  →  Macro-F1=0.644
#   score=0.45  →  Macro-F1=0.669
#   score=0.50  →  Macro-F1=0.690
#   score=0.55  →  Macro-F1=0.713
#   score=0.60  →  Macro-F1=0.735
#   score=0.65  →  Macro-F1=0.752
#   score=0.70  →  Macro-F1=0.767
#   score=0.75  →  Macro-F1=0.783
#   score=0.80  →  Macro-F1=0.804
#   score=0.85  →  Macro-F1=0.817
#   score=0.90  →  Macro-F1=0.826
#   score=0.95  →  Macro-F1=0.801
#
# Mejor umbral: score=0.90  →  Macro-F1=0.826
# [OK] Barrido de umbral agregado al payload de métricas (VALID).
# BEST_SCORE_FOR_INFERENCE = 0.90

# %%
print(f"Tiempo preparación barrido umbral: {datetime.datetime.now() - INICIO_STEP}")
INICIO_STEP = datetime.datetime.now()
# Out:
# Tiempo preparación barrido umbral: 0:11:53.547834

# %%
print(f"Tiempo total ejecución: {datetime.datetime.now() - INICIO_EJECUCION}")
# Out:
# Tiempo total ejecución: 2:03:58.401749

# %% [markdown]
# ---

# %% [markdown]
# TODO:JA Summary de los resultados. Inetrpretacion de los resultados. Comparación con los resultados de la corrida anterior.

# %% [markdown]
# ---
