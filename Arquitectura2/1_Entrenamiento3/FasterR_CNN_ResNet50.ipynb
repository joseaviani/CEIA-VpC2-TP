# %% [markdown]
# ### Faster R-CNN (ResNet50-FPN) ###
#
# Notebook diseñada para ejecutarse en Google Colab con aceleración GPU.

# %% [markdown]
# ---

# %% [markdown]
# TODO:JA Descripción de los parámetros y caracteristicas del modelo de esta corrida. Comparar con la corrida anterior

# %% [markdown]
# ---

# %%
# Montamos un google drive para guardar los resultados y el modelo entrenado.
from google.colab import drive
drive.mount('/content/drive')

OUT_BASE_DIR = "/content/drive/MyDrive/UBA/CEIA/Materias/Visión por Computadora II/google_colab_data/FasterR-CNN-ResNet50_notebook" # Setear el path Google Drive deseado
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %pip install gdown --quiet
# %pip install torch --quiet
# %pip install torchvision --quiet
# %pip install matplotlib --quiet
# %pip install pandas --quiet
# %pip install pillow --quiet
# %pip install numpy --quiet
# %pip install matplotlib --quiet
# %pip install torchmetrics --quiet

# %%
import os
import zipfile
import gdown
import shutil
import glob
import torch
import torchvision
import numpy as np
from collections import Counter
from PIL import Image
import random
import matplotlib.pyplot as plt
from torchvision.ops import box_convert
import matplotlib.patches as patches
import pandas as pd
from torch.utils.data import WeightedRandomSampler
import time
import math
from typing import List, Dict, Tuple, Any
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision
from torchvision.ops import box_iou
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
import torchvision.transforms as T
import datetime
import json
from torchmetrics.detection.mean_ap import MeanAveragePrecision
from torchvision.ops import batched_nms
from torchvision.transforms import v2 as Tv2
from torchvision.tv_tensors import BoundingBoxes

# %%
# Reproducibilidad
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

# %%
INICIO_EJECUCION = datetime.datetime.now()
INICIO_STEP = datetime.datetime.now()

# %%
# ---------------------------------------
# 1) Descargar dataset
# ---------------------------------------

DATA_DIR = "/content/data"

def descargar_dataset(data_dir):

  # Verificar si exsite la carpeta
  if not os.path.exists(data_dir):

    try:
      # Nombre del archivo ZIP que se va a guardar
      ZIP_NAME = "kaggle-xray_baggage_scanner_anomaly_detection.zip"
      zip_path = os.path.join(data_dir, ZIP_NAME)

      # Crear carpeta data
      os.makedirs(data_dir, exist_ok=True)

      # Descargar el ZIP
      print("Descargando archivo zip ...")
      # Lo tomamos de Google Drive porque Kaggle requeire autenticación
      gdown.download(id="1IqPblTm7nmKFpHXtl4beopE_SajTBoI0", output=zip_path, quiet=False)
      print("Archivo zip descargado.")

      # Descomprimir el ZIP
      print("Descomprimiendo archivo ...")
      with zipfile.ZipFile(zip_path, "r") as zf:
          zf.extractall(data_dir)
      print("Archivo descomprimido.")
    except:
      # En caso de error, eliminar la carpeta creada
      shutil.rmtree(data_dir, ignore_errors=True)
      print("Ocurrió un error al descargar el dataset.")

  print(f"Dataset descargado en: '{data_dir}'")


# Descargar el dataset (solo si no existe la carpeta data)
descargar_dataset(DATA_DIR)
# Out:
# Dataset descargado en: '/content/data'

# %%
print(f"Tiempo descarga dataset: {datetime.datetime.now() - INICIO_STEP}")
INICIO_STEP = datetime.datetime.now()
# Out:
# Tiempo descarga dataset: 0:00:00.010022

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")
# Out:
# Device: cuda

# %%
# ---------------------------------------
# 2) Configuración de rutas y clases
# ---------------------------------------

CLASS_NAMES = ["Tijera", "Navaja", "Cuchillo", "Cutter", "Navaja multiuso"]
NUM_CLASSES = len(CLASS_NAMES)  # 5
NUM_CLASSES_WITH_BG = NUM_CLASSES + 1  # +1 background para Faster R-CNN

# Paths estándar de YOLO
SPLITS = {
    "train": {"images": os.path.join(DATA_DIR, "train", "images"),
              "labels": os.path.join(DATA_DIR, "train", "labels")},
    "valid": {"images": os.path.join(DATA_DIR, "valid", "images"),
              "labels": os.path.join(DATA_DIR, "valid", "labels")},
    "test":  {"images": os.path.join(DATA_DIR, "test",  "images"),
              "labels": os.path.join(DATA_DIR, "test",  "labels")},
}

# %%
# ---------------------------------------
# 3) Dataset: De YOLO a torchvision detection
# ---------------------------------------

class YoloDetectionDataset(Dataset):
    def __init__(self, images_dir, labels_dir, transforms=None):
        self.images = sorted(glob.glob(os.path.join(images_dir, "*")))
        self.labels_dir = labels_dir
        self.transforms = transforms

    def __len__(self):
        return len(self.images)

    def _read_yolo_txt(self, label_path):
        boxes_cxcywh = []
        labels = []
        if not os.path.exists(label_path):
            return torch.zeros((0, 4), dtype=torch.float32), torch.zeros((0,), dtype=torch.int64)

        with open(label_path, "r") as f:
            lines = [ln.strip() for ln in f.readlines() if ln.strip()]

        if not lines:
            return torch.zeros((0, 4), dtype=torch.float32), torch.zeros((0,), dtype=torch.int64)

        for ln in lines:
            parts = ln.split()
            if len(parts) != 5:
                continue
            c, cx, cy, w, h = parts
            labels.append(int(c))
            boxes_cxcywh.append([float(cx), float(cy), float(w), float(h)])

        if len(boxes_cxcywh) == 0:
            return torch.zeros((0, 4), dtype=torch.float32), torch.zeros((0,), dtype=torch.int64)

        return torch.tensor(boxes_cxcywh, dtype=torch.float32), torch.tensor(labels, dtype=torch.int64)

    def __getitem__(self, idx):
        img_path = self.images[idx]
        img = Image.open(img_path).convert("RGB")
        W, H = img.size  # PIL: (W,H)

        base = os.path.splitext(os.path.basename(img_path))[0]
        lbl_path = os.path.join(self.labels_dir, base + ".txt")
        boxes_cxcywh_norm, labels0 = self._read_yolo_txt(lbl_path)

        # Desnormalizar y convertir a XYXY en píxeles
        if boxes_cxcywh_norm.numel() > 0:
            scale = torch.tensor([W, H, W, H], dtype=torch.float32)
            boxes_cxcywh_px = boxes_cxcywh_norm * scale
            boxes_xyxy = box_convert(boxes_cxcywh_px, in_fmt="cxcywh", out_fmt="xyxy")
            boxes_xyxy[:, [0, 2]] = boxes_xyxy[:, [0, 2]].clamp(0, W)
            boxes_xyxy[:, [1, 3]] = boxes_xyxy[:, [1, 3]].clamp(0, H)
        else:
            boxes_xyxy = torch.zeros((0, 4), dtype=torch.float32)

        # labels YOLO: 0..K-1 -> torchvision: 1..K
        labels = (labels0 + 1) if labels0.numel() > 0 else torch.zeros((0,), dtype=torch.int64)

        target = {
            "boxes": boxes_xyxy,
            "labels": labels,
            "image_id": torch.tensor([idx]),
            "iscrowd": torch.zeros((len(labels),), dtype=torch.int64),
        }
        # area (si no hay boxes, tensor vacío)
        if boxes_xyxy.numel() > 0:
            target["area"] = (boxes_xyxy[:, 2] - boxes_xyxy[:, 0]) * (boxes_xyxy[:, 3] - boxes_xyxy[:, 1])
        else:
            target["area"] = torch.zeros((0,), dtype=torch.float32)

        # Tv2 transforms con boxes
        if self.transforms is not None:
            # Convertir boxes a tv_tensors para que Tv2 actualice coordenadas
            target = dict(target)
            target["boxes"] = BoundingBoxes(target["boxes"], format="XYXY", canvas_size=(H, W))

            img, target = self.transforms(img, target)

            # Volver a Tensor estándar (torchvision detection espera Tensor)
            target["boxes"] = target["boxes"].as_subclass(torch.Tensor)

        return img, target


def collate_fn(batch):
    imgs, targets = list(zip(*batch))
    return list(imgs), list(targets)

# %%
# ---------------------------------------
# 4) Transforms y DataLoaders
# ---------------------------------------

# Transforms
class RandomGammaDual(torch.nn.Module):
    def __init__(self, gamma_range=(0.85, 1.15), p=0.5):
        super().__init__()
        self.g0, self.g1 = gamma_range
        self.p = p

    def forward(self, img, target):
        if torch.rand(()) > self.p:
            return img, target
        g = torch.empty((), dtype=torch.float32).uniform_(self.g0, self.g1).item()
        img = torch.clamp(img, 0.0, 1.0) ** g
        return img, target

train_tfms = Tv2.Compose([
    Tv2.ToImage(),
    Tv2.ToDtype(torch.float32, scale=True),

    Tv2.RandomApply([Tv2.ColorJitter(brightness=0.15, contrast=0.20, saturation=0.0, hue=0.0)], p=0.8),
    RandomGammaDual((0.85, 1.15), p=0.5),

    # ruido gaussiano
    Tv2.RandomApply([Tv2.GaussianNoise(sigma=0.02)], p=0.5),

    Tv2.RandomAffine(degrees=3, translate=(0.02, 0.02), scale=(0.95, 1.05), shear=0, fill=0),
    Tv2.SanitizeBoundingBoxes(),
])

eval_tfms = Tv2.Compose([
    Tv2.ToImage(),
    Tv2.ToDtype(torch.float32, scale=True),
    Tv2.SanitizeBoundingBoxes(),
])

# Datasets
train_ds = YoloDetectionDataset(SPLITS["train"]["images"], SPLITS["train"]["labels"], transforms=train_tfms)
valid_ds = YoloDetectionDataset(SPLITS["valid"]["images"], SPLITS["valid"]["labels"], transforms=eval_tfms)
test_ds  = YoloDetectionDataset(SPLITS["test"]["images"],  SPLITS["test"]["labels"],  transforms=eval_tfms)

# DataLoaders
BATCH_SIZE = 4   # Ajustar según VRAM
NUM_WORKERS = 2

train_dl = DataLoader(
    train_ds, batch_size=BATCH_SIZE, shuffle=True,
    num_workers=NUM_WORKERS, collate_fn=collate_fn,
    pin_memory=True, persistent_workers=(NUM_WORKERS > 0), prefetch_factor=2
)
valid_dl = DataLoader(
    valid_ds, batch_size=BATCH_SIZE, shuffle=False,
    num_workers=NUM_WORKERS, collate_fn=collate_fn,
    pin_memory=True, persistent_workers=(NUM_WORKERS > 0), prefetch_factor=2
)
test_dl = DataLoader(
    test_ds, batch_size=BATCH_SIZE, shuffle=False,
    num_workers=NUM_WORKERS, collate_fn=collate_fn,
    pin_memory=True, persistent_workers=(NUM_WORKERS > 0), prefetch_factor=2
)

print(f"train: {len(train_ds)} imgs | valid: {len(valid_ds)} | test: {len(test_ds)}")
# Out:
# train: 6181 imgs | valid: 1766 | test: 883

# %%
print(f"Tiempo preparación dataset y dataloaders: {datetime.datetime.now() - INICIO_STEP}")
INICIO_STEP = datetime.datetime.now()
# Out:
# Tiempo preparación dataset y dataloaders: 0:00:00.088837

# %%
# ---------------------------------------
# 5) Modelo: Faster R-CNN (ResNet50-FPN preentrenado COCO)
# ---------------------------------------
def get_fasterrcnn_model(num_classes_with_bg: int):
    model = torchvision.models.detection.fasterrcnn_resnet50_fpn(weights="DEFAULT")  # COCO-pretrained
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes_with_bg)
    return model

model = get_fasterrcnn_model(NUM_CLASSES_WITH_BG).to(device)

# %%
# ---------------------------------------
# 6) Optimizador y scheduler
# ---------------------------------------
params = [p for p in model.parameters() if p.requires_grad]
LR = 5e-3
optimizer = optim.SGD(params, lr=LR, momentum=0.9, weight_decay=5e-4)
lr_sched = optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.1)

# %%
print(f"Tiempo preparación modelo, optimizor y scheduler: {datetime.datetime.now() - INICIO_STEP}")
INICIO_STEP = datetime.datetime.now()
# Out:
# Tiempo preparación modelo, optimizor y scheduler: 0:00:00.822246

# %%
EPOCHS = 12 # Setear epochs según corresponda

# ---------------------------------------
# 7) Entrenar y evaluar el modelo
# ---------------------------------------

def _loss_dict_to_scalars(loss_dict: Dict[str, torch.Tensor]) -> Dict[str, float]:
    # torchvision devuelve tensores escalares
    out = {
        "loss_classifier": float(loss_dict.get("loss_classifier", torch.tensor(0.0)).item()),
        "loss_box_reg": float(loss_dict.get("loss_box_reg", torch.tensor(0.0)).item()),
        "loss_objectness": float(loss_dict.get("loss_objectness", torch.tensor(0.0)).item()),
        "loss_rpn_box_reg": float(loss_dict.get("loss_rpn_box_reg", torch.tensor(0.0)).item()),
    }
    out["loss_total"] = out["loss_classifier"] + out["loss_box_reg"] + out["loss_objectness"] + out["loss_rpn_box_reg"]
    return out


def _avg_dicts(dicts: List[Dict[str, float]]) -> Dict[str, float]:
    if not dicts:
        return {}
    keys = dicts[0].keys()
    return {k: float(np.mean([d[k] for d in dicts])) for k in keys}


def fbeta(prec: float, rec: float, beta: float = 2.0) -> float:
    if prec + rec == 0:
        return 0.0
    b2 = beta * beta
    return (1 + b2) * (prec * rec) / (b2 * prec + rec)


def train_one_epoch(
    model,
    loader,
    optimizer,
    device,
    log_every: int = 50,
) -> Dict[str, float]:
    model.train()

    batch_losses = []
    batch_times = []
    start_t = time.time()

    for bi, (imgs, targets) in enumerate(loader, start=1):
        imgs = [img.to(device) for img in imgs]
        tgts = [{k: v.to(device) for k, v in t.items()} for t in targets]

        loss_dict = model(imgs, tgts)
        loss = sum(v for v in loss_dict.values())

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # timing/log
        bt = time.time() - start_t
        batch_times.append(bt)
        start_t = time.time()

        loss_scalars = _loss_dict_to_scalars(loss_dict)
        batch_losses.append(loss_scalars)

        if (bi % log_every == 0) or (bi == len(loader)):
            avg_loss_running = float(np.mean([d["loss_total"] for d in batch_losses[-50:]]))
            avg_bt = float(np.mean(batch_times[-50:])) if batch_times else 0.0
            eta_sec = max(0.0, (len(loader) - bi) * avg_bt)
            cur_lr = optimizer.param_groups[0]["lr"]

            imgs_per_sec = (len(imgs) / bt) if bt > 0 else 0.0
            gpu_mem = None
            if torch.cuda.is_available():
                torch.cuda.synchronize()
                gpu_mem = torch.cuda.max_memory_allocated() / (1024**2)  # MiB

            msg = (f"[batch {bi:4d}/{len(loader)}] "
                   f"loss(b)={loss_scalars['loss_total']:.4f} | loss(µ50)={avg_loss_running:.4f} | "
                   f"lr={cur_lr:.3g} | {imgs_per_sec:.1f} img/s | "
                   f"ETA~{int(eta_sec//60)}m{int(eta_sec%60)}s")
            if gpu_mem is not None:
                msg += f" | GPU~{gpu_mem:.0f} MiB"
            print(msg)

    return _avg_dicts(batch_losses)

EVAL_LOG_EVERY = 50

SCORE_THRESH = 0.5
IOU_THRESH   = 0.5

@torch.no_grad()
def compute_losses_no_grad(model, loader, device, log_every: int = 50):
    was_training = model.training
    model.train()

    batch_losses = []
    t0 = time.time()
    for bi, (imgs, targets) in enumerate(loader, start=1):
        imgs = [img.to(device) for img in imgs]
        tgts = [{k: v.to(device) for k, v in t.items()} for t in targets]

        loss_dict = model(imgs, tgts)
        loss_scalars = _loss_dict_to_scalars(loss_dict)
        batch_losses.append(loss_scalars)

        if bi % log_every == 0 or bi == len(loader):
            dt = time.time() - t0
            print(f"[val_loss {bi:4d}/{len(loader)}] loss={loss_scalars['loss_total']:.4f} | {bi/dt:.2f} it/s")

    if not was_training:
        model.eval()
    return _avg_dicts(batch_losses)


@torch.no_grad()
def evaluate_prf1_f2(model, loader, device, class_names, score_thresh=0.5, iou_thresh=0.5, log_every: int = 50):
    model.eval()

    K = len(class_names)
    TP = np.zeros(K + 1, dtype=np.int64)
    FP = np.zeros(K + 1, dtype=np.int64)
    FN = np.zeros(K + 1, dtype=np.int64)

    t0 = time.time()
    for bi, (imgs, targets) in enumerate(loader, start=1):
        imgs = [img.to(device) for img in imgs]
        outputs = model(imgs)

        for out, tgt in zip(outputs, targets):
            gt_boxes = tgt["boxes"].cpu()
            gt_labels = tgt["labels"].cpu()

            keep = out["scores"].cpu() >= score_thresh
            pred_boxes = out["boxes"].cpu()[keep]
            pred_labels = out["labels"].cpu()[keep]
            pred_scores = out["scores"].cpu()[keep]

            if len(gt_boxes) == 0 and len(pred_boxes) == 0:
                continue

            ious = box_iou(pred_boxes, gt_boxes) if (len(pred_boxes) > 0 and len(gt_boxes) > 0) else torch.zeros((len(pred_boxes), len(gt_boxes)))
            matched_gt, matched_pred = set(), set()

            order = torch.argsort(pred_scores, descending=True).cpu().numpy()
            for pi in order:
                best_j, best_iou = -1, 0.0
                for gj in range(len(gt_boxes)):
                    if gj in matched_gt:
                        continue
                    if pred_labels[pi].item() != gt_labels[gj].item():
                        continue
                    iou_val = float(ious[pi, gj].item())
                    if iou_val >= iou_thresh and iou_val > best_iou:
                        best_iou, best_j = iou_val, gj
                if best_j >= 0:
                    cls = int(pred_labels[pi].item())
                    TP[cls] += 1
                    matched_pred.add(pi)
                    matched_gt.add(best_j)

            for pi in range(len(pred_boxes)):
                if pi not in matched_pred:
                    cls = int(pred_labels[pi].item())
                    FP[cls] += 1

            for gj in range(len(gt_boxes)):
                if gj not in matched_gt:
                    cls = int(gt_labels[gj].item())
                    FN[cls] += 1

        if bi % log_every == 0 or bi == len(loader):
            dt = time.time() - t0
            print(f"[val_prf  {bi:4d}/{len(loader)}] {bi/dt:.2f} it/s | TP={TP.sum()} FP={FP.sum()} FN={FN.sum()}")

    per_class = []
    for cls in range(1, K + 1):
        tp, fp, fn = int(TP[cls]), int(FP[cls]), int(FN[cls])
        prec = tp / (tp + fp) if (tp + fp) > 0 else 0.0
        rec  = tp / (tp + fn) if (tp + fn) > 0 else 0.0
        f1   = 2 * prec * rec / (prec + rec) if (prec + rec) > 0 else 0.0
        f2   = fbeta(prec, rec, beta=2.0)
        per_class.append((class_names[cls - 1], tp, fp, fn, prec, rec, f1, f2))

    macro_prec = float(np.mean([r[4] for r in per_class])) if per_class else 0.0
    macro_rec  = float(np.mean([r[5] for r in per_class])) if per_class else 0.0
    macro_f1   = float(np.mean([r[6] for r in per_class])) if per_class else 0.0
    macro_f2   = float(np.mean([r[7] for r in per_class])) if per_class else 0.0

    return {
        "per_class": per_class,
        "macro": {"precision": macro_prec, "recall": macro_rec, "f1": macro_f1, "f2": macro_f2},
        "raw": {"TP": TP, "FP": FP, "FN": FN},
        "settings": {"score_thresh": score_thresh, "iou_thresh": iou_thresh},
    }



@torch.no_grad()
def evaluate_map_torchmetrics(model, loader, device, include_per_class: bool = True):

    model.eval()
    metric = MeanAveragePrecision(iou_type="bbox", class_metrics=include_per_class)

    for imgs, targets in loader:
        imgs = [img.to(device) for img in imgs]
        outputs = model(imgs)

        preds, gts = [], []
        for out, tgt in zip(outputs, targets):
            preds.append({
                "boxes": out["boxes"].detach().cpu(),
                "scores": out["scores"].detach().cpu(),
                "labels": out["labels"].detach().cpu(),
            })
            gts.append({
                "boxes": tgt["boxes"].detach().cpu(),
                "labels": tgt["labels"].detach().cpu(),
            })
        metric.update(preds, gts)

    res = metric.compute()

    out = {}
    for k, v in res.items():
        if isinstance(v, torch.Tensor):
            if v.ndim == 0:
                out[k] = float(v.item())
            elif include_per_class:
                out[k] = v.detach().cpu().tolist()

    return out


# Loop principal
history = []

for epoch in range(1, EPOCHS + 1):
    print("\n" + "=" * 80)
    print(f"INICIO ÉPOCA {epoch}/{EPOCHS}  |  train_batches: {len(train_dl)}  |  batch_size: {BATCH_SIZE}")
    if torch.cuda.is_available():
        print(f"GPU: {torch.cuda.get_device_name(0)}  |  VRAM total: {torch.cuda.get_device_properties(0).total_memory/(1024**3):.1f} GB")
        torch.cuda.reset_peak_memory_stats()
    print("=" * 80)

    t0 = time.time()

    # Train
    train_losses = train_one_epoch(model, train_dl, optimizer, device, log_every=50)
    print("FIN TRAIN ")

    # Valid
    valid_losses = None
    valid_pr = None
    valid_map = None

    print(f"INICIO val_loss (batches={len(valid_dl)}) ...")
    tv = time.time()
    valid_losses = compute_losses_no_grad(model, valid_dl, device, log_every=EVAL_LOG_EVERY)
    print(f"FIN val_loss  ({(time.time()-tv)/60:.1f} min)")

    print(f"INICIO val_prf (batches={len(valid_dl)}) ...")
    tv = time.time()
    valid_pr = evaluate_prf1_f2(model, valid_dl, device, CLASS_NAMES, score_thresh=SCORE_THRESH, iou_thresh=IOU_THRESH, log_every=EVAL_LOG_EVERY)
    print(f"FIN val_prf  ({(time.time()-tv)/60:.1f} min)")

    print(f"INICIO val_mAP (batches={len(valid_dl)}) ...")
    tv = time.time()
    valid_map = evaluate_map_torchmetrics(model, valid_dl, device)
    print(f"FIN val_mAP  ({(time.time()-tv)/60:.1f} min)")

    # Scheduler
    lr_sched.step()
    cur_lr = optimizer.param_groups[0]["lr"]

    dt = time.time() - t0
    msg = f"[RESUMEN ÉPOCA {epoch:02d}] lr→{cur_lr:.3g} | dur={dt/60:.1f} min | train_loss={train_losses['loss_total']:.4f}"
    if valid_losses is not None:
        msg += f" | val_loss={valid_losses['loss_total']:.4f}"
    if valid_pr is not None:
        msg += f" | val_rec={valid_pr['macro']['recall']:.3f} | val_f2={valid_pr['macro']['f2']:.3f}"
    if valid_map is not None:
        msg += f" | val_mAP50={valid_map['map_50']:.3f} | val_mAP={valid_map['map']:.3f}"
    print(msg)

    history.append({
        "epoch": epoch,
        "lr": float(cur_lr),
        "train": train_losses,
        "valid": valid_losses,
        "valid_macro": None if valid_pr is None else valid_pr["macro"],
        "valid_per_class": None if valid_pr is None else valid_pr["per_class"],
        "valid_map": valid_map,
        "settings": {"score_thresh": SCORE_THRESH, "iou_thresh": IOU_THRESH},
        "duration_sec": float(dt),
    })
# Out:
# ================================================================================
# INICIO ÉPOCA 1/12  |  train_batches: 1546  |  batch_size: 4
# GPU: NVIDIA A100-SXM4-40GB  |  VRAM total: 39.6 GB
# ================================================================================
# [batch   50/1546] loss(b)=0.1814 | loss(µ50)=0.3159 | lr=0.005 | 33.6 img/s | ETA~3m36s | GPU~2823 MiB
# [batch  100/1546] loss(b)=0.2402 | loss(µ50)=0.2398 | lr=0.005 | 31.3 img/s | ETA~2m56s | GPU~2823 MiB
# [batch  150/1546] loss(b)=0.2246 | loss(µ50)=0.2379 | lr=0.005 | 30.2 img/s | ETA~2m52s | GPU~2823 MiB
# [batch  200/1546] loss(b)=0.2170 | loss(µ50)=0.2232 | lr=0.005 | 33.0 img/s | ETA~2m44s | GPU~2823 MiB
# [batch  250/1546] loss(b)=0.1750 | loss(µ50)=0.2158 | lr=0.005 | 33.0 img/s | ETA~2m37s | GPU~2823 MiB
# [batch  300/1546] loss(b)=0.1922 | loss(µ50)=0.2233 | lr=0.005 | 33.2 img/s | ETA~2m30s | GPU~2823 MiB
# [batch  350/1546] loss(b)=0.2295 | loss(µ50)=0.2089 | lr=0.005 | 33.0 img/s | ETA~2m24s | GPU~2823 MiB
# [batch  400/1546] loss(b)=0.1532 | loss(µ50)=0.2010 | lr=0.005 | 31.8 img/s | ETA~2m18s | GPU~2823 MiB
# [batch  450/1546] loss(b)=0.2139 | loss(µ50)=0.2107 | lr=0.005 | 29.8 img/s | ETA~2m13s | GPU~2823 MiB
# [batch  500/1546] loss(b)=0.1720 | loss(µ50)=0.1929 | lr=0.005 | 32.6 img/s | ETA~2m7s | GPU~2823 MiB
# [batch  550/1546] loss(b)=0.1852 | loss(µ50)=0.1883 | lr=0.005 | 34.0 img/s | ETA~2m0s | GPU~2823 MiB
# [batch  600/1546] loss(b)=0.1911 | loss(µ50)=0.1896 | lr=0.005 | 32.4 img/s | ETA~1m54s | GPU~2823 MiB
# [batch  650/1546] loss(b)=0.2147 | loss(µ50)=0.1918 | lr=0.005 | 33.7 img/s | ETA~1m47s | GPU~2823 MiB
# [batch  700/1546] loss(b)=0.2135 | loss(µ50)=0.1937 | lr=0.005 | 30.9 img/s | ETA~1m42s | GPU~2823 MiB
# [batch  750/1546] loss(b)=0.1638 | loss(µ50)=0.1953 | lr=0.005 | 33.3 img/s | ETA~1m36s | GPU~2823 MiB
# [batch  800/1546] loss(b)=0.1993 | loss(µ50)=0.1755 | lr=0.005 | 34.3 img/s | ETA~1m30s | GPU~2823 MiB
# [batch  850/1546] loss(b)=0.2019 | loss(µ50)=0.1704 | lr=0.005 | 32.4 img/s | ETA~1m24s | GPU~2823 MiB
# [batch  900/1546] loss(b)=0.1977 | loss(µ50)=0.1728 | lr=0.005 | 32.0 img/s | ETA~1m17s | GPU~2823 MiB
# [batch  950/1546] loss(b)=0.2019 | loss(µ50)=0.1818 | lr=0.005 | 33.2 img/s | ETA~1m11s | GPU~2823 MiB
# [batch 1000/1546] loss(b)=0.1721 | loss(µ50)=0.1771 | lr=0.005 | 31.5 img/s | ETA~1m6s | GPU~2823 MiB
# [batch 1050/1546] loss(b)=0.1593 | loss(µ50)=0.1706 | lr=0.005 | 34.9 img/s | ETA~1m0s | GPU~2823 MiB
# [batch 1100/1546] loss(b)=0.1414 | loss(µ50)=0.1752 | lr=0.005 | 31.9 img/s | ETA~0m53s | GPU~2823 MiB
# [batch 1150/1546] loss(b)=0.1709 | loss(µ50)=0.1732 | lr=0.005 | 33.3 img/s | ETA~0m47s | GPU~2823 MiB
# [batch 1200/1546] loss(b)=0.1576 | loss(µ50)=0.1713 | lr=0.005 | 32.9 img/s | ETA~0m41s | GPU~2823 MiB
# [batch 1250/1546] loss(b)=0.1670 | loss(µ50)=0.1671 | lr=0.005 | 33.3 img/s | ETA~0m36s | GPU~2823 MiB
# [batch 1300/1546] loss(b)=0.1781 | loss(µ50)=0.1665 | lr=0.005 | 33.2 img/s | ETA~0m30s | GPU~2823 MiB
# [batch 1350/1546] loss(b)=0.2023 | loss(µ50)=0.1622 | lr=0.005 | 32.8 img/s | ETA~0m24s | GPU~2823 MiB
# [batch 1400/1546] loss(b)=0.1857 | loss(µ50)=0.1561 | lr=0.005 | 32.7 img/s | ETA~0m17s | GPU~2823 MiB
# [batch 1450/1546] loss(b)=0.1821 | loss(µ50)=0.1611 | lr=0.005 | 33.5 img/s | ETA~0m11s | GPU~2823 MiB
# [batch 1500/1546] loss(b)=0.1851 | loss(µ50)=0.1695 | lr=0.005 | 34.0 img/s | ETA~0m5s | GPU~2823 MiB
# [batch 1546/1546] loss(b)=0.1413 | loss(µ50)=0.1593 | lr=0.005 | 4.6 img/s | ETA~0m0s | GPU~2823 MiB
# FIN TRAIN
# INICIO val_loss (batches=442) ...
# [val_loss   50/442] loss=0.2069 | 13.99 it/s
# [val_loss  100/442] loss=0.1437 | 14.32 it/s
# [val_loss  150/442] loss=0.1174 | 14.44 it/s
# [val_loss  200/442] loss=0.1797 | 14.50 it/s
# [val_loss  250/442] loss=0.1202 | 14.54 it/s
# [val_loss  300/442] loss=0.1780 | 14.58 it/s
# [val_loss  350/442] loss=0.1423 | 14.59 it/s
# [val_loss  400/442] loss=0.1928 | 14.62 it/s
# [val_loss  442/442] loss=0.0897 | 14.62 it/s
# FIN val_loss  (0.5 min)
# INICIO val_prf (batches=442) ...
# [val_prf    50/442] 16.04 it/s | TP=1 FP=130 FN=199
# [val_prf   100/442] 16.16 it/s | TP=169 FP=183 FN=231
# [val_prf   150/442] 16.23 it/s | TP=356 FP=238 FN=244
# [val_prf   200/442] 16.29 it/s | TP=519 FP=316 FN=281
# [val_prf   250/442] 16.34 it/s | TP=693 FP=399 FN=307
# [val_prf   300/442] 16.36 it/s | TP=858 FP=487 FN=342
# [val_prf   350/442] 16.40 it/s | TP=1019 FP=568 FN=381
# [val_prf   400/442] 16.42 it/s | TP=1178 FP=638 FN=422
# [val_prf   442/442] 16.45 it/s | TP=1305 FP=708 FN=461
# FIN val_prf  (0.4 min)
# INICIO val_mAP (batches=442) ...
# FIN val_mAP  (0.5 min)
# [RESUMEN ÉPOCA 01] lr→0.005 | dur=4.6 min | train_loss=0.1916 | val_loss=0.1575 | val_rec=0.676 | val_f2=0.640 | val_mAP50=0.709 | val_mAP=0.290
#
# ================================================================================
# INICIO ÉPOCA 2/12  |  train_batches: 1546  |  batch_size: 4
# GPU: NVIDIA A100-SXM4-40GB  |  VRAM total: 39.6 GB
# ================================================================================
# [batch   50/1546] loss(b)=0.1883 | loss(µ50)=0.1490 | lr=0.005 | 33.3 img/s | ETA~3m3s | GPU~2821 MiB
# [batch  100/1546] loss(b)=0.1098 | loss(µ50)=0.1487 | lr=0.005 | 33.5 img/s | ETA~2m55s | GPU~2821 MiB
# [batch  150/1546] loss(b)=0.1480 | loss(µ50)=0.1505 | lr=0.005 | 31.6 img/s | ETA~2m49s | GPU~2821 MiB
# [batch  200/1546] loss(b)=0.1802 | loss(µ50)=0.1646 | lr=0.005 | 29.5 img/s | ETA~2m45s | GPU~2821 MiB
# [batch  250/1546] loss(b)=0.1413 | loss(µ50)=0.1594 | lr=0.005 | 31.2 img/s | ETA~2m38s | GPU~2821 MiB
# [batch  300/1546] loss(b)=0.0983 | loss(µ50)=0.1535 | lr=0.005 | 31.3 img/s | ETA~2m31s | GPU~2821 MiB
# [batch  350/1546] loss(b)=0.1455 | loss(µ50)=0.1449 | lr=0.005 | 33.1 img/s | ETA~2m25s | GPU~2821 MiB
# [batch  400/1546] loss(b)=0.1716 | loss(µ50)=0.1422 | lr=0.005 | 33.6 img/s | ETA~2m19s | GPU~2821 MiB
# [batch  450/1546] loss(b)=0.1160 | loss(µ50)=0.1462 | lr=0.005 | 33.9 img/s | ETA~2m13s | GPU~2821 MiB
# [batch  500/1546] loss(b)=0.1155 | loss(µ50)=0.1423 | lr=0.005 | 32.4 img/s | ETA~2m7s | GPU~2821 MiB
# [batch  550/1546] loss(b)=0.0982 | loss(µ50)=0.1421 | lr=0.005 | 32.4 img/s | ETA~2m0s | GPU~2821 MiB
# [batch  600/1546] loss(b)=0.1400 | loss(µ50)=0.1459 | lr=0.005 | 33.3 img/s | ETA~1m54s | GPU~2821 MiB
# [batch  650/1546] loss(b)=0.1206 | loss(µ50)=0.1542 | lr=0.005 | 31.8 img/s | ETA~1m48s | GPU~2821 MiB
# [batch  700/1546] loss(b)=0.1757 | loss(µ50)=0.1487 | lr=0.005 | 33.2 img/s | ETA~1m42s | GPU~2821 MiB
# [batch  750/1546] loss(b)=0.1561 | loss(µ50)=0.1423 | lr=0.005 | 31.8 img/s | ETA~1m36s | GPU~2821 MiB
# [batch  800/1546] loss(b)=0.1950 | loss(µ50)=0.1452 | lr=0.005 | 30.6 img/s | ETA~1m30s | GPU~2821 MiB
# [batch  850/1546] loss(b)=0.1415 | loss(µ50)=0.1461 | lr=0.005 | 31.9 img/s | ETA~1m25s | GPU~2821 MiB
# [batch  900/1546] loss(b)=0.1542 | loss(µ50)=0.1456 | lr=0.005 | 33.2 img/s | ETA~1m19s | GPU~2821 MiB
# [batch  950/1546] loss(b)=0.1868 | loss(µ50)=0.1382 | lr=0.005 | 33.7 img/s | ETA~1m12s | GPU~2821 MiB
# [batch 1000/1546] loss(b)=0.1390 | loss(µ50)=0.1386 | lr=0.005 | 32.7 img/s | ETA~1m6s | GPU~2821 MiB
# [batch 1050/1546] loss(b)=0.1428 | loss(µ50)=0.1388 | lr=0.005 | 33.4 img/s | ETA~1m0s | GPU~2821 MiB
# [batch 1100/1546] loss(b)=0.1956 | loss(µ50)=0.1385 | lr=0.005 | 32.9 img/s | ETA~0m54s | GPU~2821 MiB
# [batch 1150/1546] loss(b)=0.2024 | loss(µ50)=0.1460 | lr=0.005 | 33.1 img/s | ETA~0m48s | GPU~2821 MiB
# [batch 1200/1546] loss(b)=0.1533 | loss(µ50)=0.1345 | lr=0.005 | 32.2 img/s | ETA~0m42s | GPU~2821 MiB
# [batch 1250/1546] loss(b)=0.1709 | loss(µ50)=0.1352 | lr=0.005 | 31.8 img/s | ETA~0m36s | GPU~2821 MiB
# [batch 1300/1546] loss(b)=0.1277 | loss(µ50)=0.1322 | lr=0.005 | 33.2 img/s | ETA~0m29s | GPU~2821 MiB
# [batch 1350/1546] loss(b)=0.1013 | loss(µ50)=0.1289 | lr=0.005 | 31.6 img/s | ETA~0m23s | GPU~2821 MiB
# [batch 1400/1546] loss(b)=0.2306 | loss(µ50)=0.1364 | lr=0.005 | 32.9 img/s | ETA~0m17s | GPU~2821 MiB
# [batch 1450/1546] loss(b)=0.1300 | loss(µ50)=0.1315 | lr=0.005 | 32.6 img/s | ETA~0m11s | GPU~2821 MiB
# [batch 1500/1546] loss(b)=0.1401 | loss(µ50)=0.1340 | lr=0.005 | 33.1 img/s | ETA~0m5s | GPU~2821 MiB
# [batch 1546/1546] loss(b)=0.0533 | loss(µ50)=0.1321 | lr=0.005 | 11.5 img/s | ETA~0m0s | GPU~2821 MiB
# FIN TRAIN
# INICIO val_loss (batches=442) ...
# [val_loss   50/442] loss=0.1862 | 14.47 it/s
# [val_loss  100/442] loss=0.1409 | 14.49 it/s
# [val_loss  150/442] loss=0.1079 | 14.53 it/s
# [val_loss  200/442] loss=0.1789 | 14.57 it/s
# [val_loss  250/442] loss=0.1161 | 14.60 it/s
# [val_loss  300/442] loss=0.1666 | 14.58 it/s
# [val_loss  350/442] loss=0.1092 | 14.59 it/s
# [val_loss  400/442] loss=0.1260 | 14.59 it/s
# [val_loss  442/442] loss=0.1181 | 14.60 it/s
# FIN val_loss  (0.5 min)
# INICIO val_prf (batches=442) ...
# [val_prf    50/442] 16.17 it/s | TP=63 FP=116 FN=137
# [val_prf   100/442] 16.31 it/s | TP=240 FP=176 FN=160
# [val_prf   150/442] 16.38 it/s | TP=427 FP=234 FN=173
# [val_prf   200/442] 16.42 it/s | TP=591 FP=316 FN=209
# [val_prf   250/442] 16.42 it/s | TP=760 FP=389 FN=240
# [val_prf   300/442] 16.44 it/s | TP=918 FP=475 FN=282
# [val_prf   350/442] 16.46 it/s | TP=1067 FP=570 FN=333
# [val_prf   400/442] 16.47 it/s | TP=1213 FP=659 FN=387
# [val_prf   442/442] 16.48 it/s | TP=1342 FP=733 FN=424
# FIN val_prf  (0.4 min)
# INICIO val_mAP (batches=442) ...
# FIN val_mAP  (0.5 min)
# [RESUMEN ÉPOCA 02] lr→0.005 | dur=4.6 min | train_loss=0.1431 | val_loss=0.1403 | val_rec=0.722 | val_f2=0.700 | val_mAP50=0.738 | val_mAP=0.297
#
# ================================================================================
# INICIO ÉPOCA 3/12  |  train_batches: 1546  |  batch_size: 4
# GPU: NVIDIA A100-SXM4-40GB  |  VRAM total: 39.6 GB
# ================================================================================
# [batch   50/1546] loss(b)=0.1071 | loss(µ50)=0.1192 | lr=0.005 | 33.1 img/s | ETA~3m7s | GPU~2820 MiB
# [batch  100/1546] loss(b)=0.1224 | loss(µ50)=0.1319 | lr=0.005 | 34.6 img/s | ETA~2m56s | GPU~2820 MiB
# [batch  150/1546] loss(b)=0.1125 | loss(µ50)=0.1316 | lr=0.005 | 30.8 img/s | ETA~2m49s | GPU~2820 MiB
# [batch  200/1546] loss(b)=0.1086 | loss(µ50)=0.1340 | lr=0.005 | 33.9 img/s | ETA~2m43s | GPU~2820 MiB
# [batch  250/1546] loss(b)=0.1209 | loss(µ50)=0.1380 | lr=0.005 | 33.8 img/s | ETA~2m37s | GPU~2820 MiB
# [batch  300/1546] loss(b)=0.1502 | loss(µ50)=0.1291 | lr=0.005 | 34.1 img/s | ETA~2m32s | GPU~2820 MiB
# [batch  350/1546] loss(b)=0.1842 | loss(µ50)=0.1306 | lr=0.005 | 33.3 img/s | ETA~2m25s | GPU~2820 MiB
# [batch  400/1546] loss(b)=0.1224 | loss(µ50)=0.1271 | lr=0.005 | 31.5 img/s | ETA~2m19s | GPU~2821 MiB
# [batch  450/1546] loss(b)=0.1301 | loss(µ50)=0.1239 | lr=0.005 | 32.3 img/s | ETA~2m13s | GPU~2821 MiB
# [batch  500/1546] loss(b)=0.1165 | loss(µ50)=0.1276 | lr=0.005 | 33.5 img/s | ETA~2m7s | GPU~2821 MiB
# [batch  550/1546] loss(b)=0.1015 | loss(µ50)=0.1295 | lr=0.005 | 35.1 img/s | ETA~2m1s | GPU~2822 MiB
# [batch  600/1546] loss(b)=0.0987 | loss(µ50)=0.1304 | lr=0.005 | 30.7 img/s | ETA~1m55s | GPU~2822 MiB
# [batch  650/1546] loss(b)=0.1350 | loss(µ50)=0.1304 | lr=0.005 | 32.1 img/s | ETA~1m48s | GPU~2822 MiB
# [batch  700/1546] loss(b)=0.1125 | loss(µ50)=0.1298 | lr=0.005 | 31.6 img/s | ETA~1m43s | GPU~2822 MiB
# [batch  750/1546] loss(b)=0.1053 | loss(µ50)=0.1328 | lr=0.005 | 32.7 img/s | ETA~1m37s | GPU~2822 MiB
# [batch  800/1546] loss(b)=0.1124 | loss(µ50)=0.1358 | lr=0.005 | 32.7 img/s | ETA~1m30s | GPU~2822 MiB
# [batch  850/1546] loss(b)=0.1321 | loss(µ50)=0.1384 | lr=0.005 | 31.5 img/s | ETA~1m24s | GPU~2822 MiB
# [batch  900/1546] loss(b)=0.2127 | loss(µ50)=0.1343 | lr=0.005 | 32.7 img/s | ETA~1m18s | GPU~2822 MiB
# [batch  950/1546] loss(b)=0.1535 | loss(µ50)=0.1344 | lr=0.005 | 32.6 img/s | ETA~1m12s | GPU~2822 MiB
# [batch 1000/1546] loss(b)=0.1515 | loss(µ50)=0.1300 | lr=0.005 | 33.8 img/s | ETA~1m6s | GPU~2822 MiB
# [batch 1050/1546] loss(b)=0.1530 | loss(µ50)=0.1395 | lr=0.005 | 33.8 img/s | ETA~1m0s | GPU~2822 MiB
# [batch 1100/1546] loss(b)=0.1174 | loss(µ50)=0.1233 | lr=0.005 | 31.1 img/s | ETA~0m54s | GPU~2822 MiB
# [batch 1150/1546] loss(b)=0.1508 | loss(µ50)=0.1266 | lr=0.005 | 33.1 img/s | ETA~0m48s | GPU~2822 MiB
# [batch 1200/1546] loss(b)=0.0798 | loss(µ50)=0.1425 | lr=0.005 | 35.2 img/s | ETA~0m42s | GPU~2822 MiB
# [batch 1250/1546] loss(b)=0.1076 | loss(µ50)=0.1273 | lr=0.005 | 34.1 img/s | ETA~0m35s | GPU~2822 MiB
# [batch 1300/1546] loss(b)=0.1407 | loss(µ50)=0.1305 | lr=0.005 | 31.5 img/s | ETA~0m29s | GPU~2822 MiB
# [batch 1350/1546] loss(b)=0.1374 | loss(µ50)=0.1352 | lr=0.005 | 32.8 img/s | ETA~0m23s | GPU~2822 MiB
# [batch 1400/1546] loss(b)=0.1126 | loss(µ50)=0.1267 | lr=0.005 | 33.3 img/s | ETA~0m17s | GPU~2822 MiB
# [batch 1450/1546] loss(b)=0.1287 | loss(µ50)=0.1295 | lr=0.005 | 30.7 img/s | ETA~0m11s | GPU~2822 MiB
# [batch 1500/1546] loss(b)=0.1152 | loss(µ50)=0.1308 | lr=0.005 | 32.7 img/s | ETA~0m5s | GPU~2822 MiB
# [batch 1546/1546] loss(b)=0.1544 | loss(µ50)=0.1300 | lr=0.005 | 12.1 img/s | ETA~0m0s | GPU~2822 MiB
# FIN TRAIN
# INICIO val_loss (batches=442) ...
# [val_loss   50/442] loss=0.1781 | 14.28 it/s
# [val_loss  100/442] loss=0.1217 | 14.41 it/s
# [val_loss  150/442] loss=0.1318 | 14.48 it/s
# [val_loss  200/442] loss=0.1875 | 14.53 it/s
# [val_loss  250/442] loss=0.0998 | 14.52 it/s
# [val_loss  300/442] loss=0.1753 | 14.53 it/s
# [val_loss  350/442] loss=0.1013 | 14.55 it/s
# [val_loss  400/442] loss=0.1606 | 14.57 it/s
# [val_loss  442/442] loss=0.1317 | 14.59 it/s
# FIN val_loss  (0.5 min)
# INICIO val_prf (batches=442) ...
# [val_prf    50/442] 16.37 it/s | TP=73 FP=101 FN=127
# [val_prf   100/442] 16.51 it/s | TP=253 FP=143 FN=147
# [val_prf   150/442] 16.58 it/s | TP=443 FP=181 FN=157
# [val_prf   200/442] 16.56 it/s | TP=619 FP=231 FN=181
# [val_prf   250/442] 16.55 it/s | TP=802 FP=280 FN=198
# [val_prf   300/442] 16.55 it/s | TP=978 FP=318 FN=222
# [val_prf   350/442] 16.56 it/s | TP=1150 FP=361 FN=250
# [val_prf   400/442] 16.56 it/s | TP=1318 FP=412 FN=282
# [val_prf   442/442] 16.58 it/s | TP=1457 FP=447 FN=309
# FIN val_prf  (0.4 min)
# INICIO val_mAP (batches=442) ...
# FIN val_mAP  (0.5 min)
# [RESUMEN ÉPOCA 03] lr→0.005 | dur=4.6 min | train_loss=0.1310 | val_loss=0.1343 | val_rec=0.785 | val_f2=0.771 | val_mAP50=0.801 | val_mAP=0.328
#
# ================================================================================
# INICIO ÉPOCA 4/12  |  train_batches: 1546  |  batch_size: 4
# GPU: NVIDIA A100-SXM4-40GB  |  VRAM total: 39.6 GB
# ================================================================================
# [batch   50/1546] loss(b)=0.1612 | loss(µ50)=0.1226 | lr=0.005 | 33.1 img/s | ETA~3m5s | GPU~2821 MiB
# [batch  100/1546] loss(b)=0.0993 | loss(µ50)=0.1239 | lr=0.005 | 35.6 img/s | ETA~2m56s | GPU~2821 MiB
# [batch  150/1546] loss(b)=0.1034 | loss(µ50)=0.1184 | lr=0.005 | 31.5 img/s | ETA~2m50s | GPU~2821 MiB
# [batch  200/1546] loss(b)=0.1173 | loss(µ50)=0.1166 | lr=0.005 | 33.1 img/s | ETA~2m44s | GPU~2821 MiB
# [batch  250/1546] loss(b)=0.1464 | loss(µ50)=0.1252 | lr=0.005 | 31.6 img/s | ETA~2m37s | GPU~2821 MiB
# [batch  300/1546] loss(b)=0.0955 | loss(µ50)=0.1179 | lr=0.005 | 32.7 img/s | ETA~2m31s | GPU~2821 MiB
# [batch  350/1546] loss(b)=0.1107 | loss(µ50)=0.1235 | lr=0.005 | 32.5 img/s | ETA~2m25s | GPU~2821 MiB
# [batch  400/1546] loss(b)=0.0757 | loss(µ50)=0.1187 | lr=0.005 | 32.6 img/s | ETA~2m19s | GPU~2821 MiB
# [batch  450/1546] loss(b)=0.0884 | loss(µ50)=0.1198 | lr=0.005 | 31.6 img/s | ETA~2m13s | GPU~2821 MiB
# [batch  500/1546] loss(b)=0.1217 | loss(µ50)=0.1224 | lr=0.005 | 35.9 img/s | ETA~2m8s | GPU~2821 MiB
# [batch  550/1546] loss(b)=0.0988 | loss(µ50)=0.1272 | lr=0.005 | 32.4 img/s | ETA~2m1s | GPU~2821 MiB
# [batch  600/1546] loss(b)=0.1642 | loss(µ50)=0.1255 | lr=0.005 | 31.7 img/s | ETA~1m56s | GPU~2821 MiB
# [batch  650/1546] loss(b)=0.1270 | loss(µ50)=0.1194 | lr=0.005 | 33.1 img/s | ETA~1m48s | GPU~2821 MiB
# [batch  700/1546] loss(b)=0.1218 | loss(µ50)=0.1207 | lr=0.005 | 33.9 img/s | ETA~1m43s | GPU~2821 MiB
# [batch  750/1546] loss(b)=0.1130 | loss(µ50)=0.1201 | lr=0.005 | 32.2 img/s | ETA~1m36s | GPU~2821 MiB
# [batch  800/1546] loss(b)=0.1643 | loss(µ50)=0.1248 | lr=0.005 | 31.4 img/s | ETA~1m30s | GPU~2821 MiB
# [batch  850/1546] loss(b)=0.2201 | loss(µ50)=0.1297 | lr=0.005 | 33.8 img/s | ETA~1m24s | GPU~2821 MiB
# [batch  900/1546] loss(b)=0.1389 | loss(µ50)=0.1292 | lr=0.005 | 32.8 img/s | ETA~1m18s | GPU~2821 MiB
# [batch  950/1546] loss(b)=0.1068 | loss(µ50)=0.1297 | lr=0.005 | 34.2 img/s | ETA~1m12s | GPU~2821 MiB
# [batch 1000/1546] loss(b)=0.1133 | loss(µ50)=0.1241 | lr=0.005 | 33.1 img/s | ETA~1m6s | GPU~2821 MiB
# [batch 1050/1546] loss(b)=0.1440 | loss(µ50)=0.1258 | lr=0.005 | 33.0 img/s | ETA~1m0s | GPU~2821 MiB
# [batch 1100/1546] loss(b)=0.0907 | loss(µ50)=0.1190 | lr=0.005 | 32.9 img/s | ETA~0m54s | GPU~2821 MiB
# [batch 1150/1546] loss(b)=0.1253 | loss(µ50)=0.1192 | lr=0.005 | 31.4 img/s | ETA~0m48s | GPU~2821 MiB
# [batch 1200/1546] loss(b)=0.1672 | loss(µ50)=0.1291 | lr=0.005 | 32.7 img/s | ETA~0m42s | GPU~2821 MiB
# [batch 1250/1546] loss(b)=0.0849 | loss(µ50)=0.1343 | lr=0.005 | 31.9 img/s | ETA~0m35s | GPU~2821 MiB
# [batch 1300/1546] loss(b)=0.1204 | loss(µ50)=0.1230 | lr=0.005 | 33.1 img/s | ETA~0m30s | GPU~2821 MiB
# [batch 1350/1546] loss(b)=0.1310 | loss(µ50)=0.1312 | lr=0.005 | 32.6 img/s | ETA~0m23s | GPU~2821 MiB
# [batch 1400/1546] loss(b)=0.1601 | loss(µ50)=0.1237 | lr=0.005 | 33.2 img/s | ETA~0m17s | GPU~2821 MiB
# [batch 1450/1546] loss(b)=0.1059 | loss(µ50)=0.1329 | lr=0.005 | 32.8 img/s | ETA~0m11s | GPU~2821 MiB
# [batch 1500/1546] loss(b)=0.1154 | loss(µ50)=0.1249 | lr=0.005 | 32.9 img/s | ETA~0m5s | GPU~2821 MiB
# [batch 1546/1546] loss(b)=0.1055 | loss(µ50)=0.1211 | lr=0.005 | 11.9 img/s | ETA~0m0s | GPU~2821 MiB
# FIN TRAIN
# INICIO val_loss (batches=442) ...
# [val_loss   50/442] loss=0.1511 | 14.38 it/s
# [val_loss  100/442] loss=0.1286 | 14.50 it/s
# [val_loss  150/442] loss=0.1389 | 14.60 it/s
# [val_loss  200/442] loss=0.1507 | 14.64 it/s
# [val_loss  250/442] loss=0.0844 | 14.68 it/s
# [val_loss  300/442] loss=0.1559 | 14.72 it/s
# [val_loss  350/442] loss=0.1160 | 14.74 it/s
# [val_loss  400/442] loss=0.1089 | 14.76 it/s
# [val_loss  442/442] loss=0.1081 | 14.77 it/s
# FIN val_loss  (0.5 min)
# INICIO val_prf (batches=442) ...
# [val_prf    50/442] 16.15 it/s | TP=126 FP=120 FN=74
# [val_prf   100/442] 16.18 it/s | TP=310 FP=181 FN=90
# [val_prf   150/442] 16.20 it/s | TP=501 FP=233 FN=99
# [val_prf   200/442] 16.17 it/s | TP=682 FP=312 FN=118
# [val_prf   250/442] 16.15 it/s | TP=872 FP=374 FN=128
# [val_prf   300/442] 16.16 it/s | TP=1052 FP=438 FN=148
# [val_prf   350/442] 16.20 it/s | TP=1230 FP=510 FN=170
# [val_prf   400/442] 16.21 it/s | TP=1409 FP=585 FN=191
# [val_prf   442/442] 16.24 it/s | TP=1559 FP=658 FN=207
# FIN val_prf  (0.5 min)
# INICIO val_mAP (batches=442) ...
# FIN val_mAP  (0.5 min)
# [RESUMEN ÉPOCA 04] lr→0.005 | dur=4.6 min | train_loss=0.1241 | val_loss=0.1275 | val_rec=0.860 | val_f2=0.820 | val_mAP50=0.825 | val_mAP=0.337
#
# ================================================================================
# INICIO ÉPOCA 5/12  |  train_batches: 1546  |  batch_size: 4
# GPU: NVIDIA A100-SXM4-40GB  |  VRAM total: 39.6 GB
# ================================================================================
# [batch   50/1546] loss(b)=0.1171 | loss(µ50)=0.1185 | lr=0.005 | 33.6 img/s | ETA~3m7s | GPU~2821 MiB
# [batch  100/1546] loss(b)=0.1189 | loss(µ50)=0.1136 | lr=0.005 | 31.9 img/s | ETA~2m56s | GPU~2821 MiB
# [batch  150/1546] loss(b)=0.1075 | loss(µ50)=0.1231 | lr=0.005 | 32.3 img/s | ETA~2m51s | GPU~2821 MiB
# [batch  200/1546] loss(b)=0.1112 | loss(µ50)=0.1256 | lr=0.005 | 32.7 img/s | ETA~2m44s | GPU~2821 MiB
# [batch  250/1546] loss(b)=0.1257 | loss(µ50)=0.1240 | lr=0.005 | 31.9 img/s | ETA~2m38s | GPU~2821 MiB
# [batch  300/1546] loss(b)=0.0972 | loss(µ50)=0.1170 | lr=0.005 | 32.7 img/s | ETA~2m31s | GPU~2821 MiB
# [batch  350/1546] loss(b)=0.1109 | loss(µ50)=0.1268 | lr=0.005 | 32.8 img/s | ETA~2m25s | GPU~2821 MiB
# [batch  400/1546] loss(b)=0.0933 | loss(µ50)=0.1242 | lr=0.005 | 32.7 img/s | ETA~2m20s | GPU~2821 MiB
# [batch  450/1546] loss(b)=0.1261 | loss(µ50)=0.1270 | lr=0.005 | 33.3 img/s | ETA~2m15s | GPU~2821 MiB
# [batch  500/1546] loss(b)=0.1383 | loss(µ50)=0.1229 | lr=0.005 | 32.4 img/s | ETA~2m9s | GPU~2821 MiB
# [batch  550/1546] loss(b)=0.1277 | loss(µ50)=0.1242 | lr=0.005 | 31.2 img/s | ETA~2m2s | GPU~2821 MiB
# [batch  600/1546] loss(b)=0.1031 | loss(µ50)=0.1279 | lr=0.005 | 32.9 img/s | ETA~1m55s | GPU~2821 MiB
# [batch  650/1546] loss(b)=0.1244 | loss(µ50)=0.1237 | lr=0.005 | 32.9 img/s | ETA~1m49s | GPU~2821 MiB
# [batch  700/1546] loss(b)=0.1192 | loss(µ50)=0.1194 | lr=0.005 | 32.7 img/s | ETA~1m43s | GPU~2821 MiB
# [batch  750/1546] loss(b)=0.1147 | loss(µ50)=0.1197 | lr=0.005 | 31.8 img/s | ETA~1m38s | GPU~2821 MiB
# [batch  800/1546] loss(b)=0.1176 | loss(µ50)=0.1149 | lr=0.005 | 33.1 img/s | ETA~1m31s | GPU~2821 MiB
# [batch  850/1546] loss(b)=0.1401 | loss(µ50)=0.1171 | lr=0.005 | 32.7 img/s | ETA~1m25s | GPU~2821 MiB
# [batch  900/1546] loss(b)=0.1604 | loss(µ50)=0.1273 | lr=0.005 | 32.8 img/s | ETA~1m18s | GPU~2821 MiB
# [batch  950/1546] loss(b)=0.1343 | loss(µ50)=0.1240 | lr=0.005 | 32.3 img/s | ETA~1m13s | GPU~2821 MiB
# [batch 1000/1546] loss(b)=0.1521 | loss(µ50)=0.1245 | lr=0.005 | 32.1 img/s | ETA~1m6s | GPU~2821 MiB
# [batch 1050/1546] loss(b)=0.0734 | loss(µ50)=0.1154 | lr=0.005 | 32.0 img/s | ETA~1m1s | GPU~2821 MiB
# [batch 1100/1546] loss(b)=0.1297 | loss(µ50)=0.1243 | lr=0.005 | 31.4 img/s | ETA~0m54s | GPU~2821 MiB
# [batch 1150/1546] loss(b)=0.1465 | loss(µ50)=0.1310 | lr=0.005 | 33.0 img/s | ETA~0m48s | GPU~2821 MiB
# [batch 1200/1546] loss(b)=0.1797 | loss(µ50)=0.1204 | lr=0.005 | 32.8 img/s | ETA~0m42s | GPU~2821 MiB
# [batch 1250/1546] loss(b)=0.1552 | loss(µ50)=0.1251 | lr=0.005 | 33.1 img/s | ETA~0m36s | GPU~2821 MiB
# [batch 1300/1546] loss(b)=0.1420 | loss(µ50)=0.1163 | lr=0.005 | 31.4 img/s | ETA~0m30s | GPU~2821 MiB
# [batch 1350/1546] loss(b)=0.1290 | loss(µ50)=0.1199 | lr=0.005 | 32.3 img/s | ETA~0m23s | GPU~2821 MiB
# [batch 1400/1546] loss(b)=0.1168 | loss(µ50)=0.1213 | lr=0.005 | 32.5 img/s | ETA~0m17s | GPU~2821 MiB
# [batch 1450/1546] loss(b)=0.0988 | loss(µ50)=0.1201 | lr=0.005 | 32.5 img/s | ETA~0m11s | GPU~2821 MiB
# [batch 1500/1546] loss(b)=0.0946 | loss(µ50)=0.1217 | lr=0.005 | 32.9 img/s | ETA~0m5s | GPU~2821 MiB
# [batch 1546/1546] loss(b)=0.0841 | loss(µ50)=0.1149 | lr=0.005 | 12.0 img/s | ETA~0m0s | GPU~2821 MiB
# FIN TRAIN
# INICIO val_loss (batches=442) ...
# [val_loss   50/442] loss=0.1678 | 14.26 it/s
# [val_loss  100/442] loss=0.1361 | 14.38 it/s
# [val_loss  150/442] loss=0.1554 | 14.43 it/s
# [val_loss  200/442] loss=0.1235 | 14.44 it/s
# [val_loss  250/442] loss=0.1122 | 14.45 it/s
# [val_loss  300/442] loss=0.1471 | 14.47 it/s
# [val_loss  350/442] loss=0.0944 | 14.48 it/s
# [val_loss  400/442] loss=0.1279 | 14.48 it/s
# [val_loss  442/442] loss=0.1138 | 14.50 it/s
# FIN val_loss  (0.5 min)
# INICIO val_prf (batches=442) ...
# [val_prf    50/442] 16.04 it/s | TP=133 FP=117 FN=67
# [val_prf   100/442] 16.16 it/s | TP=319 FP=174 FN=81
# [val_prf   150/442] 16.20 it/s | TP=514 FP=237 FN=86
# [val_prf   200/442] 16.24 it/s | TP=694 FP=306 FN=106
# [val_prf   250/442] 16.26 it/s | TP=881 FP=383 FN=119
# [val_prf   300/442] 16.29 it/s | TP=1060 FP=458 FN=140
# [val_prf   350/442] 16.26 it/s | TP=1237 FP=533 FN=163
# [val_prf   400/442] 16.28 it/s | TP=1415 FP=601 FN=185
# [val_prf   442/442] 16.30 it/s | TP=1568 FP=671 FN=198
# FIN val_prf  (0.5 min)
# INICIO val_mAP (batches=442) ...
# FIN val_mAP  (0.5 min)
# [RESUMEN ÉPOCA 05] lr→0.0005 | dur=4.6 min | train_loss=0.1218 | val_loss=0.1301 | val_rec=0.867 | val_f2=0.823 | val_mAP50=0.830 | val_mAP=0.336
#
# ================================================================================
# INICIO ÉPOCA 6/12  |  train_batches: 1546  |  batch_size: 4
# GPU: NVIDIA A100-SXM4-40GB  |  VRAM total: 39.6 GB
# ================================================================================
# [batch   50/1546] loss(b)=0.0999 | loss(µ50)=0.1172 | lr=0.0005 | 33.0 img/s | ETA~3m7s | GPU~2821 MiB
# [batch  100/1546] loss(b)=0.1112 | loss(µ50)=0.1096 | lr=0.0005 | 32.3 img/s | ETA~2m57s | GPU~2821 MiB
# [batch  150/1546] loss(b)=0.1016 | loss(µ50)=0.1099 | lr=0.0005 | 32.9 img/s | ETA~2m50s | GPU~2821 MiB
# [batch  200/1546] loss(b)=0.1073 | loss(µ50)=0.1100 | lr=0.0005 | 33.2 img/s | ETA~2m45s | GPU~2821 MiB
# [batch  250/1546] loss(b)=0.1518 | loss(µ50)=0.1087 | lr=0.0005 | 32.9 img/s | ETA~2m38s | GPU~2821 MiB
# [batch  300/1546] loss(b)=0.1072 | loss(µ50)=0.1144 | lr=0.0005 | 33.2 img/s | ETA~2m32s | GPU~2821 MiB
# [batch  350/1546] loss(b)=0.1013 | loss(µ50)=0.1108 | lr=0.0005 | 32.4 img/s | ETA~2m26s | GPU~2821 MiB
# [batch  400/1546] loss(b)=0.1457 | loss(µ50)=0.1134 | lr=0.0005 | 32.9 img/s | ETA~2m20s | GPU~2821 MiB
# [batch  450/1546] loss(b)=0.1029 | loss(µ50)=0.1133 | lr=0.0005 | 33.3 img/s | ETA~2m14s | GPU~2821 MiB
# [batch  500/1546] loss(b)=0.0592 | loss(µ50)=0.1069 | lr=0.0005 | 31.8 img/s | ETA~2m7s | GPU~2821 MiB
# [batch  550/1546] loss(b)=0.1138 | loss(µ50)=0.1112 | lr=0.0005 | 32.9 img/s | ETA~2m1s | GPU~2821 MiB
# [batch  600/1546] loss(b)=0.1386 | loss(µ50)=0.1104 | lr=0.0005 | 32.1 img/s | ETA~1m56s | GPU~2821 MiB
# [batch  650/1546] loss(b)=0.1235 | loss(µ50)=0.1086 | lr=0.0005 | 32.6 img/s | ETA~1m50s | GPU~2821 MiB
# [batch  700/1546] loss(b)=0.1207 | loss(µ50)=0.1162 | lr=0.0005 | 31.4 img/s | ETA~1m44s | GPU~2821 MiB
# [batch  750/1546] loss(b)=0.1089 | loss(µ50)=0.1095 | lr=0.0005 | 32.7 img/s | ETA~1m38s | GPU~2821 MiB
# [batch  800/1546] loss(b)=0.0848 | loss(µ50)=0.1109 | lr=0.0005 | 32.9 img/s | ETA~1m31s | GPU~2821 MiB
# [batch  850/1546] loss(b)=0.1136 | loss(µ50)=0.1086 | lr=0.0005 | 32.9 img/s | ETA~1m26s | GPU~2821 MiB
# [batch  900/1546] loss(b)=0.1071 | loss(µ50)=0.1064 | lr=0.0005 | 32.6 img/s | ETA~1m19s | GPU~2821 MiB
# [batch  950/1546] loss(b)=0.0877 | loss(µ50)=0.1056 | lr=0.0005 | 31.0 img/s | ETA~1m14s | GPU~2821 MiB
# [batch 1000/1546] loss(b)=0.1455 | loss(µ50)=0.1081 | lr=0.0005 | 32.4 img/s | ETA~1m7s | GPU~2821 MiB
# [batch 1050/1546] loss(b)=0.1255 | loss(µ50)=0.1115 | lr=0.0005 | 32.4 img/s | ETA~1m1s | GPU~2821 MiB
# [batch 1100/1546] loss(b)=0.1425 | loss(µ50)=0.1066 | lr=0.0005 | 31.4 img/s | ETA~0m55s | GPU~2821 MiB
# [batch 1150/1546] loss(b)=0.0807 | loss(µ50)=0.1091 | lr=0.0005 | 32.8 img/s | ETA~0m49s | GPU~2821 MiB
# [batch 1200/1546] loss(b)=0.0966 | loss(µ50)=0.1099 | lr=0.0005 | 31.6 img/s | ETA~0m42s | GPU~2821 MiB
# [batch 1250/1546] loss(b)=0.1669 | loss(µ50)=0.1160 | lr=0.0005 | 34.0 img/s | ETA~0m36s | GPU~2821 MiB
# [batch 1300/1546] loss(b)=0.1051 | loss(µ50)=0.1025 | lr=0.0005 | 32.3 img/s | ETA~0m30s | GPU~2821 MiB
# [batch 1350/1546] loss(b)=0.0896 | loss(µ50)=0.1102 | lr=0.0005 | 31.9 img/s | ETA~0m24s | GPU~2821 MiB
# [batch 1400/1546] loss(b)=0.1329 | loss(µ50)=0.1192 | lr=0.0005 | 32.4 img/s | ETA~0m17s | GPU~2821 MiB
# [batch 1450/1546] loss(b)=0.1116 | loss(µ50)=0.1074 | lr=0.0005 | 31.0 img/s | ETA~0m11s | GPU~2821 MiB
# [batch 1500/1546] loss(b)=0.0737 | loss(µ50)=0.1132 | lr=0.0005 | 33.0 img/s | ETA~0m5s | GPU~2821 MiB
# [batch 1546/1546] loss(b)=0.1672 | loss(µ50)=0.1128 | lr=0.0005 | 12.2 img/s | ETA~0m0s | GPU~2821 MiB
# FIN TRAIN
# INICIO val_loss (batches=442) ...
# [val_loss   50/442] loss=0.1390 | 14.10 it/s
# [val_loss  100/442] loss=0.1030 | 14.27 it/s
# [val_loss  150/442] loss=0.1146 | 14.32 it/s
# [val_loss  200/442] loss=0.1331 | 14.38 it/s
# [val_loss  250/442] loss=0.0919 | 14.41 it/s
# [val_loss  300/442] loss=0.1772 | 14.42 it/s
# [val_loss  350/442] loss=0.0866 | 14.42 it/s
# [val_loss  400/442] loss=0.0943 | 14.42 it/s
# [val_loss  442/442] loss=0.1137 | 14.44 it/s
# FIN val_loss  (0.5 min)
# INICIO val_prf (batches=442) ...
# [val_prf    50/442] 15.93 it/s | TP=144 FP=67 FN=56
# [val_prf   100/442] 16.13 it/s | TP=332 FP=99 FN=68
# [val_prf   150/442] 16.21 it/s | TP=526 FP=124 FN=74
# [val_prf   200/442] 16.25 it/s | TP=711 FP=159 FN=89
# [val_prf   250/442] 16.26 it/s | TP=899 FP=194 FN=101
# [val_prf   300/442] 16.27 it/s | TP=1080 FP=222 FN=120
# [val_prf   350/442] 16.30 it/s | TP=1258 FP=262 FN=142
# [val_prf   400/442] 16.31 it/s | TP=1440 FP=290 FN=160
# [val_prf   442/442] 16.33 it/s | TP=1591 FP=324 FN=175
# FIN val_prf  (0.5 min)
# INICIO val_mAP (batches=442) ...
# FIN val_mAP  (0.5 min)
# [RESUMEN ÉPOCA 06] lr→0.0005 | dur=4.6 min | train_loss=0.1106 | val_loss=0.1216 | val_rec=0.884 | val_f2=0.869 | val_mAP50=0.874 | val_mAP=0.372
#
# ================================================================================
# INICIO ÉPOCA 7/12  |  train_batches: 1546  |  batch_size: 4
# GPU: NVIDIA A100-SXM4-40GB  |  VRAM total: 39.6 GB
# ================================================================================
# [batch   50/1546] loss(b)=0.1209 | loss(µ50)=0.1108 | lr=0.0005 | 31.6 img/s | ETA~3m6s | GPU~2821 MiB
# [batch  100/1546] loss(b)=0.1610 | loss(µ50)=0.1075 | lr=0.0005 | 33.1 img/s | ETA~2m57s | GPU~2821 MiB
# [batch  150/1546] loss(b)=0.1155 | loss(µ50)=0.1098 | lr=0.0005 | 32.6 img/s | ETA~2m50s | GPU~2821 MiB
# [batch  200/1546] loss(b)=0.1154 | loss(µ50)=0.1136 | lr=0.0005 | 32.9 img/s | ETA~2m45s | GPU~2821 MiB
# [batch  250/1546] loss(b)=0.0750 | loss(µ50)=0.1052 | lr=0.0005 | 33.1 img/s | ETA~2m38s | GPU~2822 MiB
# [batch  300/1546] loss(b)=0.1120 | loss(µ50)=0.1150 | lr=0.0005 | 32.9 img/s | ETA~2m32s | GPU~2822 MiB
# [batch  350/1546] loss(b)=0.0580 | loss(µ50)=0.1142 | lr=0.0005 | 32.8 img/s | ETA~2m26s | GPU~2822 MiB
# [batch  400/1546] loss(b)=0.0719 | loss(µ50)=0.1159 | lr=0.0005 | 29.6 img/s | ETA~2m21s | GPU~2822 MiB
# [batch  450/1546] loss(b)=0.1348 | loss(µ50)=0.1102 | lr=0.0005 | 32.0 img/s | ETA~2m15s | GPU~2822 MiB
# [batch  500/1546] loss(b)=0.1139 | loss(µ50)=0.1014 | lr=0.0005 | 32.5 img/s | ETA~2m8s | GPU~2822 MiB
# [batch  550/1546] loss(b)=0.0759 | loss(µ50)=0.1066 | lr=0.0005 | 32.9 img/s | ETA~2m2s | GPU~2822 MiB
# [batch  600/1546] loss(b)=0.1283 | loss(µ50)=0.1107 | lr=0.0005 | 31.7 img/s | ETA~1m57s | GPU~2822 MiB
# [batch  650/1546] loss(b)=0.1063 | loss(µ50)=0.1106 | lr=0.0005 | 32.9 img/s | ETA~1m49s | GPU~2822 MiB
# [batch  700/1546] loss(b)=0.1536 | loss(µ50)=0.1080 | lr=0.0005 | 32.7 img/s | ETA~1m44s | GPU~2822 MiB
# [batch  750/1546] loss(b)=0.0961 | loss(µ50)=0.1031 | lr=0.0005 | 32.6 img/s | ETA~1m37s | GPU~2822 MiB
# [batch  800/1546] loss(b)=0.1252 | loss(µ50)=0.1041 | lr=0.0005 | 33.1 img/s | ETA~1m31s | GPU~2822 MiB
# [batch  850/1546] loss(b)=0.1287 | loss(µ50)=0.1105 | lr=0.0005 | 33.5 img/s | ETA~1m24s | GPU~2822 MiB
# [batch  900/1546] loss(b)=0.1084 | loss(µ50)=0.1101 | lr=0.0005 | 32.4 img/s | ETA~1m19s | GPU~2822 MiB
# [batch  950/1546] loss(b)=0.0971 | loss(µ50)=0.1066 | lr=0.0005 | 31.8 img/s | ETA~1m13s | GPU~2822 MiB
# [batch 1000/1546] loss(b)=0.1071 | loss(µ50)=0.1090 | lr=0.0005 | 33.5 img/s | ETA~1m7s | GPU~2822 MiB
# [batch 1050/1546] loss(b)=0.0880 | loss(µ50)=0.1107 | lr=0.0005 | 32.1 img/s | ETA~1m0s | GPU~2822 MiB
# [batch 1100/1546] loss(b)=0.0830 | loss(µ50)=0.1132 | lr=0.0005 | 33.2 img/s | ETA~0m54s | GPU~2822 MiB
# [batch 1150/1546] loss(b)=0.1617 | loss(µ50)=0.1005 | lr=0.0005 | 33.3 img/s | ETA~0m48s | GPU~2822 MiB
# [batch 1200/1546] loss(b)=0.1082 | loss(µ50)=0.1163 | lr=0.0005 | 29.5 img/s | ETA~0m42s | GPU~2822 MiB
# [batch 1250/1546] loss(b)=0.1036 | loss(µ50)=0.1053 | lr=0.0005 | 32.6 img/s | ETA~0m36s | GPU~2822 MiB
# [batch 1300/1546] loss(b)=0.1210 | loss(µ50)=0.1107 | lr=0.0005 | 32.6 img/s | ETA~0m30s | GPU~2822 MiB
# [batch 1350/1546] loss(b)=0.1127 | loss(µ50)=0.1082 | lr=0.0005 | 33.3 img/s | ETA~0m24s | GPU~2822 MiB
# [batch 1400/1546] loss(b)=0.0905 | loss(µ50)=0.1092 | lr=0.0005 | 32.8 img/s | ETA~0m18s | GPU~2822 MiB
# [batch 1450/1546] loss(b)=0.1205 | loss(µ50)=0.1118 | lr=0.0005 | 31.5 img/s | ETA~0m11s | GPU~2822 MiB
# [batch 1500/1546] loss(b)=0.1051 | loss(µ50)=0.1077 | lr=0.0005 | 32.9 img/s | ETA~0m5s | GPU~2822 MiB
# [batch 1546/1546] loss(b)=0.1485 | loss(µ50)=0.1069 | lr=0.0005 | 12.1 img/s | ETA~0m0s | GPU~2822 MiB
# FIN TRAIN
# INICIO val_loss (batches=442) ...
# [val_loss   50/442] loss=0.1344 | 14.24 it/s
# [val_loss  100/442] loss=0.1008 | 14.31 it/s
# [val_loss  150/442] loss=0.1273 | 14.37 it/s
# [val_loss  200/442] loss=0.1555 | 14.41 it/s
# [val_loss  250/442] loss=0.0891 | 14.41 it/s
# [val_loss  300/442] loss=0.1563 | 14.41 it/s
# [val_loss  350/442] loss=0.0862 | 14.42 it/s
# [val_loss  400/442] loss=0.1102 | 14.43 it/s
# [val_loss  442/442] loss=0.1092 | 14.45 it/s
# FIN val_loss  (0.5 min)
# INICIO val_prf (batches=442) ...
# [val_prf    50/442] 15.90 it/s | TP=142 FP=67 FN=58
# [val_prf   100/442] 16.12 it/s | TP=330 FP=99 FN=70
# [val_prf   150/442] 16.24 it/s | TP=525 FP=118 FN=75
# [val_prf   200/442] 16.26 it/s | TP=705 FP=150 FN=95
# [val_prf   250/442] 16.25 it/s | TP=895 FP=185 FN=105
# [val_prf   300/442] 16.28 it/s | TP=1076 FP=217 FN=124
# [val_prf   350/442] 16.30 it/s | TP=1255 FP=250 FN=145
# [val_prf   400/442] 16.31 it/s | TP=1439 FP=274 FN=161
# [val_prf   442/442] 16.33 it/s | TP=1588 FP=306 FN=178
# FIN val_prf  (0.5 min)
# INICIO val_mAP (batches=442) ...
# FIN val_mAP  (0.5 min)
# [RESUMEN ÉPOCA 07] lr→0.0005 | dur=4.6 min | train_loss=0.1091 | val_loss=0.1221 | val_rec=0.881 | val_f2=0.870 | val_mAP50=0.872 | val_mAP=0.378
#
# ================================================================================
# INICIO ÉPOCA 8/12  |  train_batches: 1546  |  batch_size: 4
# GPU: NVIDIA A100-SXM4-40GB  |  VRAM total: 39.6 GB
# ================================================================================
# [batch   50/1546] loss(b)=0.0982 | loss(µ50)=0.1125 | lr=0.0005 | 33.0 img/s | ETA~3m7s | GPU~2821 MiB
# [batch  100/1546] loss(b)=0.0683 | loss(µ50)=0.1084 | lr=0.0005 | 33.1 img/s | ETA~2m57s | GPU~2821 MiB
# [batch  150/1546] loss(b)=0.1217 | loss(µ50)=0.1131 | lr=0.0005 | 32.0 img/s | ETA~2m51s | GPU~2821 MiB
# [batch  200/1546] loss(b)=0.0978 | loss(µ50)=0.1039 | lr=0.0005 | 32.9 img/s | ETA~2m46s | GPU~2821 MiB
# [batch  250/1546] loss(b)=0.1125 | loss(µ50)=0.1090 | lr=0.0005 | 34.2 img/s | ETA~2m38s | GPU~2821 MiB
# [batch  300/1546] loss(b)=0.1009 | loss(µ50)=0.1069 | lr=0.0005 | 33.6 img/s | ETA~2m33s | GPU~2821 MiB
# [batch  350/1546] loss(b)=0.1154 | loss(µ50)=0.1096 | lr=0.0005 | 33.1 img/s | ETA~2m27s | GPU~2821 MiB
# [batch  400/1546] loss(b)=0.0971 | loss(µ50)=0.1122 | lr=0.0005 | 32.5 img/s | ETA~2m21s | GPU~2821 MiB
# [batch  450/1546] loss(b)=0.0905 | loss(µ50)=0.1121 | lr=0.0005 | 31.8 img/s | ETA~2m13s | GPU~2821 MiB
# [batch  500/1546] loss(b)=0.1820 | loss(µ50)=0.1070 | lr=0.0005 | 34.4 img/s | ETA~2m8s | GPU~2821 MiB
# [batch  550/1546] loss(b)=0.0960 | loss(µ50)=0.1104 | lr=0.0005 | 32.8 img/s | ETA~2m2s | GPU~2821 MiB
# [batch  600/1546] loss(b)=0.1179 | loss(µ50)=0.1061 | lr=0.0005 | 30.8 img/s | ETA~1m55s | GPU~2821 MiB
# [batch  650/1546] loss(b)=0.0956 | loss(µ50)=0.1067 | lr=0.0005 | 32.4 img/s | ETA~1m50s | GPU~2821 MiB
# [batch  700/1546] loss(b)=0.1233 | loss(µ50)=0.1050 | lr=0.0005 | 31.5 img/s | ETA~1m44s | GPU~2821 MiB
# [batch  750/1546] loss(b)=0.1159 | loss(µ50)=0.1116 | lr=0.0005 | 33.0 img/s | ETA~1m37s | GPU~2821 MiB
# [batch  800/1546] loss(b)=0.0832 | loss(µ50)=0.1051 | lr=0.0005 | 33.1 img/s | ETA~1m31s | GPU~2821 MiB
# [batch  850/1546] loss(b)=0.1371 | loss(µ50)=0.1098 | lr=0.0005 | 33.1 img/s | ETA~1m25s | GPU~2821 MiB
# [batch  900/1546] loss(b)=0.1112 | loss(µ50)=0.1144 | lr=0.0005 | 32.8 img/s | ETA~1m19s | GPU~2821 MiB
# [batch  950/1546] loss(b)=0.0947 | loss(µ50)=0.1118 | lr=0.0005 | 31.1 img/s | ETA~1m13s | GPU~2821 MiB
# [batch 1000/1546] loss(b)=0.1250 | loss(µ50)=0.1088 | lr=0.0005 | 33.4 img/s | ETA~1m6s | GPU~2821 MiB
# [batch 1050/1546] loss(b)=0.1332 | loss(µ50)=0.1065 | lr=0.0005 | 34.5 img/s | ETA~1m0s | GPU~2821 MiB
# [batch 1100/1546] loss(b)=0.0783 | loss(µ50)=0.1034 | lr=0.0005 | 32.5 img/s | ETA~0m55s | GPU~2821 MiB
# [batch 1150/1546] loss(b)=0.1478 | loss(µ50)=0.1065 | lr=0.0005 | 32.0 img/s | ETA~0m48s | GPU~2821 MiB
# [batch 1200/1546] loss(b)=0.1397 | loss(µ50)=0.1114 | lr=0.0005 | 31.0 img/s | ETA~0m42s | GPU~2821 MiB
# [batch 1250/1546] loss(b)=0.1616 | loss(µ50)=0.1056 | lr=0.0005 | 32.9 img/s | ETA~0m36s | GPU~2821 MiB
# [batch 1300/1546] loss(b)=0.0958 | loss(µ50)=0.1064 | lr=0.0005 | 32.1 img/s | ETA~0m30s | GPU~2821 MiB
# [batch 1350/1546] loss(b)=0.0918 | loss(µ50)=0.1134 | lr=0.0005 | 31.5 img/s | ETA~0m24s | GPU~2821 MiB
# [batch 1400/1546] loss(b)=0.1059 | loss(µ50)=0.1058 | lr=0.0005 | 32.5 img/s | ETA~0m17s | GPU~2821 MiB
# [batch 1450/1546] loss(b)=0.1167 | loss(µ50)=0.1077 | lr=0.0005 | 30.7 img/s | ETA~0m11s | GPU~2821 MiB
# [batch 1500/1546] loss(b)=0.1014 | loss(µ50)=0.1023 | lr=0.0005 | 32.9 img/s | ETA~0m5s | GPU~2821 MiB
# [batch 1546/1546] loss(b)=0.1058 | loss(µ50)=0.1061 | lr=0.0005 | 12.2 img/s | ETA~0m0s | GPU~2821 MiB
# FIN TRAIN
# INICIO val_loss (batches=442) ...
# [val_loss   50/442] loss=0.1459 | 14.22 it/s
# [val_loss  100/442] loss=0.1096 | 14.35 it/s
# [val_loss  150/442] loss=0.1390 | 14.38 it/s
# [val_loss  200/442] loss=0.1451 | 14.39 it/s
# [val_loss  250/442] loss=0.0862 | 14.38 it/s
# [val_loss  300/442] loss=0.1600 | 14.41 it/s
# [val_loss  350/442] loss=0.0901 | 14.42 it/s
# [val_loss  400/442] loss=0.1028 | 14.41 it/s
# [val_loss  442/442] loss=0.1049 | 14.44 it/s
# FIN val_loss  (0.5 min)
# INICIO val_prf (batches=442) ...
# [val_prf    50/442] 16.32 it/s | TP=143 FP=68 FN=57
# [val_prf   100/442] 16.47 it/s | TP=333 FP=100 FN=67
# [val_prf   150/442] 16.45 it/s | TP=528 FP=122 FN=72
# [val_prf   200/442] 16.47 it/s | TP=709 FP=153 FN=91
# [val_prf   250/442] 16.47 it/s | TP=898 FP=188 FN=102
# [val_prf   300/442] 16.49 it/s | TP=1079 FP=216 FN=121
# [val_prf   350/442] 16.51 it/s | TP=1255 FP=254 FN=145
# [val_prf   400/442] 16.51 it/s | TP=1432 FP=282 FN=168
# [val_prf   442/442] 16.53 it/s | TP=1581 FP=317 FN=185
# FIN val_prf  (0.4 min)
# INICIO val_mAP (batches=442) ...
# FIN val_mAP  (0.5 min)
# [RESUMEN ÉPOCA 08] lr→0.0005 | dur=4.6 min | train_loss=0.1084 | val_loss=0.1237 | val_rec=0.879 | val_f2=0.867 | val_mAP50=0.869 | val_mAP=0.378
#
# ================================================================================
# INICIO ÉPOCA 9/12  |  train_batches: 1546  |  batch_size: 4
# GPU: NVIDIA A100-SXM4-40GB  |  VRAM total: 39.6 GB
# ================================================================================
# [batch   50/1546] loss(b)=0.0999 | loss(µ50)=0.1086 | lr=0.0005 | 33.8 img/s | ETA~3m9s | GPU~2822 MiB
# [batch  100/1546] loss(b)=0.1258 | loss(µ50)=0.1111 | lr=0.0005 | 32.6 img/s | ETA~2m58s | GPU~2823 MiB
# [batch  150/1546] loss(b)=0.0837 | loss(µ50)=0.1060 | lr=0.0005 | 32.4 img/s | ETA~2m52s | GPU~2823 MiB
# [batch  200/1546] loss(b)=0.0972 | loss(µ50)=0.1033 | lr=0.0005 | 32.3 img/s | ETA~2m46s | GPU~2823 MiB
# [batch  250/1546] loss(b)=0.1167 | loss(µ50)=0.1096 | lr=0.0005 | 31.9 img/s | ETA~2m40s | GPU~2823 MiB
# [batch  300/1546] loss(b)=0.1050 | loss(µ50)=0.1084 | lr=0.0005 | 33.5 img/s | ETA~2m33s | GPU~2823 MiB
# [batch  350/1546] loss(b)=0.1188 | loss(µ50)=0.1074 | lr=0.0005 | 32.8 img/s | ETA~2m27s | GPU~2823 MiB
# [batch  400/1546] loss(b)=0.0899 | loss(µ50)=0.1078 | lr=0.0005 | 32.7 img/s | ETA~2m20s | GPU~2823 MiB
# [batch  450/1546] loss(b)=0.1041 | loss(µ50)=0.1086 | lr=0.0005 | 33.2 img/s | ETA~2m15s | GPU~2823 MiB
# [batch  500/1546] loss(b)=0.1029 | loss(µ50)=0.1077 | lr=0.0005 | 32.2 img/s | ETA~2m8s | GPU~2823 MiB
# [batch  550/1546] loss(b)=0.1040 | loss(µ50)=0.1031 | lr=0.0005 | 32.6 img/s | ETA~2m2s | GPU~2823 MiB
# [batch  600/1546] loss(b)=0.0760 | loss(µ50)=0.1061 | lr=0.0005 | 33.8 img/s | ETA~1m56s | GPU~2823 MiB
# [batch  650/1546] loss(b)=0.0863 | loss(µ50)=0.1156 | lr=0.0005 | 32.9 img/s | ETA~1m50s | GPU~2823 MiB
# [batch  700/1546] loss(b)=0.0944 | loss(µ50)=0.1056 | lr=0.0005 | 32.8 img/s | ETA~1m43s | GPU~2823 MiB
# [batch  750/1546] loss(b)=0.0934 | loss(µ50)=0.1094 | lr=0.0005 | 34.1 img/s | ETA~1m37s | GPU~2823 MiB
# [batch  800/1546] loss(b)=0.1043 | loss(µ50)=0.1047 | lr=0.0005 | 32.9 img/s | ETA~1m31s | GPU~2823 MiB
# [batch  850/1546] loss(b)=0.1303 | loss(µ50)=0.1074 | lr=0.0005 | 31.8 img/s | ETA~1m27s | GPU~2823 MiB
# [batch  900/1546] loss(b)=0.0975 | loss(µ50)=0.1044 | lr=0.0005 | 32.6 img/s | ETA~1m20s | GPU~2823 MiB
# [batch  950/1546] loss(b)=0.1142 | loss(µ50)=0.1106 | lr=0.0005 | 29.6 img/s | ETA~1m13s | GPU~2823 MiB
# [batch 1000/1546] loss(b)=0.1433 | loss(µ50)=0.1127 | lr=0.0005 | 32.2 img/s | ETA~1m7s | GPU~2823 MiB
# [batch 1050/1546] loss(b)=0.1478 | loss(µ50)=0.1078 | lr=0.0005 | 32.7 img/s | ETA~1m0s | GPU~2823 MiB
# [batch 1100/1546] loss(b)=0.0749 | loss(µ50)=0.1024 | lr=0.0005 | 32.6 img/s | ETA~0m54s | GPU~2823 MiB
# [batch 1150/1546] loss(b)=0.1223 | loss(µ50)=0.1080 | lr=0.0005 | 33.1 img/s | ETA~0m48s | GPU~2823 MiB
# [batch 1200/1546] loss(b)=0.0574 | loss(µ50)=0.1042 | lr=0.0005 | 33.4 img/s | ETA~0m42s | GPU~2823 MiB
# [batch 1250/1546] loss(b)=0.1322 | loss(µ50)=0.1025 | lr=0.0005 | 32.9 img/s | ETA~0m36s | GPU~2823 MiB
# [batch 1300/1546] loss(b)=0.1136 | loss(µ50)=0.1042 | lr=0.0005 | 30.7 img/s | ETA~0m30s | GPU~2823 MiB
# [batch 1350/1546] loss(b)=0.1649 | loss(µ50)=0.1021 | lr=0.0005 | 32.1 img/s | ETA~0m24s | GPU~2823 MiB
# [batch 1400/1546] loss(b)=0.1168 | loss(µ50)=0.1160 | lr=0.0005 | 32.5 img/s | ETA~0m17s | GPU~2823 MiB
# [batch 1450/1546] loss(b)=0.0877 | loss(µ50)=0.1100 | lr=0.0005 | 34.5 img/s | ETA~0m11s | GPU~2823 MiB
# [batch 1500/1546] loss(b)=0.1618 | loss(µ50)=0.1079 | lr=0.0005 | 33.3 img/s | ETA~0m5s | GPU~2823 MiB
# [batch 1546/1546] loss(b)=0.1125 | loss(µ50)=0.1058 | lr=0.0005 | 12.2 img/s | ETA~0m0s | GPU~2823 MiB
# FIN TRAIN
# INICIO val_loss (batches=442) ...
# [val_loss   50/442] loss=0.1449 | 14.27 it/s
# [val_loss  100/442] loss=0.1139 | 14.39 it/s
# [val_loss  150/442] loss=0.1320 | 14.41 it/s
# [val_loss  200/442] loss=0.1335 | 14.29 it/s
# [val_loss  250/442] loss=0.0858 | 14.25 it/s
# [val_loss  300/442] loss=0.1613 | 14.23 it/s
# [val_loss  350/442] loss=0.0850 | 14.28 it/s
# [val_loss  400/442] loss=0.1125 | 14.31 it/s
# [val_loss  442/442] loss=0.1084 | 14.35 it/s
# FIN val_loss  (0.5 min)
# INICIO val_prf (batches=442) ...
# [val_prf    50/442] 16.08 it/s | TP=150 FP=66 FN=50
# [val_prf   100/442] 16.15 it/s | TP=340 FP=93 FN=60
# [val_prf   150/442] 16.20 it/s | TP=534 FP=117 FN=66
# [val_prf   200/442] 16.21 it/s | TP=715 FP=151 FN=85
# [val_prf   250/442] 16.24 it/s | TP=905 FP=188 FN=95
# [val_prf   300/442] 16.26 it/s | TP=1086 FP=221 FN=114
# [val_prf   350/442] 16.28 it/s | TP=1263 FP=261 FN=137
# [val_prf   400/442] 16.30 it/s | TP=1444 FP=288 FN=156
# [val_prf   442/442] 16.33 it/s | TP=1594 FP=318 FN=172
# FIN val_prf  (0.5 min)
# INICIO val_mAP (batches=442) ...
# FIN val_mAP  (0.5 min)
# [RESUMEN ÉPOCA 09] lr→0.0005 | dur=4.6 min | train_loss=0.1074 | val_loss=0.1224 | val_rec=0.888 | val_f2=0.874 | val_mAP50=0.873 | val_mAP=0.380
#
# ================================================================================
# INICIO ÉPOCA 10/12  |  train_batches: 1546  |  batch_size: 4
# GPU: NVIDIA A100-SXM4-40GB  |  VRAM total: 39.6 GB
# ================================================================================
# [batch   50/1546] loss(b)=0.0941 | loss(µ50)=0.1103 | lr=0.0005 | 32.7 img/s | ETA~3m8s | GPU~2822 MiB
# [batch  100/1546] loss(b)=0.1123 | loss(µ50)=0.1049 | lr=0.0005 | 31.5 img/s | ETA~2m58s | GPU~2823 MiB
# [batch  150/1546] loss(b)=0.1398 | loss(µ50)=0.1048 | lr=0.0005 | 32.9 img/s | ETA~2m50s | GPU~2823 MiB
# [batch  200/1546] loss(b)=0.0647 | loss(µ50)=0.1082 | lr=0.0005 | 32.5 img/s | ETA~2m45s | GPU~2823 MiB
# [batch  250/1546] loss(b)=0.1362 | loss(µ50)=0.1095 | lr=0.0005 | 33.2 img/s | ETA~2m39s | GPU~2823 MiB
# [batch  300/1546] loss(b)=0.1574 | loss(µ50)=0.1105 | lr=0.0005 | 32.2 img/s | ETA~2m33s | GPU~2823 MiB
# [batch  350/1546] loss(b)=0.0924 | loss(µ50)=0.1071 | lr=0.0005 | 33.5 img/s | ETA~2m27s | GPU~2823 MiB
# [batch  400/1546] loss(b)=0.1281 | loss(µ50)=0.1094 | lr=0.0005 | 34.8 img/s | ETA~2m20s | GPU~2823 MiB
# [batch  450/1546] loss(b)=0.1191 | loss(µ50)=0.1050 | lr=0.0005 | 32.9 img/s | ETA~2m14s | GPU~2823 MiB
# [batch  500/1546] loss(b)=0.1510 | loss(µ50)=0.1112 | lr=0.0005 | 32.3 img/s | ETA~2m8s | GPU~2823 MiB
# [batch  550/1546] loss(b)=0.1147 | loss(µ50)=0.1065 | lr=0.0005 | 33.8 img/s | ETA~2m2s | GPU~2823 MiB
# [batch  600/1546] loss(b)=0.1423 | loss(µ50)=0.1090 | lr=0.0005 | 33.6 img/s | ETA~1m56s | GPU~2823 MiB
# [batch  650/1546] loss(b)=0.1042 | loss(µ50)=0.1034 | lr=0.0005 | 32.0 img/s | ETA~1m50s | GPU~2823 MiB
# [batch  700/1546] loss(b)=0.0930 | loss(µ50)=0.1070 | lr=0.0005 | 33.0 img/s | ETA~1m43s | GPU~2823 MiB
# [batch  750/1546] loss(b)=0.1100 | loss(µ50)=0.1081 | lr=0.0005 | 32.9 img/s | ETA~1m37s | GPU~2823 MiB
# [batch  800/1546] loss(b)=0.1327 | loss(µ50)=0.1059 | lr=0.0005 | 32.7 img/s | ETA~1m31s | GPU~2823 MiB
# [batch  850/1546] loss(b)=0.0751 | loss(µ50)=0.1050 | lr=0.0005 | 32.4 img/s | ETA~1m25s | GPU~2823 MiB
# [batch  900/1546] loss(b)=0.0939 | loss(µ50)=0.1097 | lr=0.0005 | 32.9 img/s | ETA~1m19s | GPU~2823 MiB
# [batch  950/1546] loss(b)=0.0961 | loss(µ50)=0.1080 | lr=0.0005 | 32.5 img/s | ETA~1m13s | GPU~2823 MiB
# [batch 1000/1546] loss(b)=0.1038 | loss(µ50)=0.1078 | lr=0.0005 | 32.5 img/s | ETA~1m7s | GPU~2823 MiB
# [batch 1050/1546] loss(b)=0.1261 | loss(µ50)=0.0993 | lr=0.0005 | 32.3 img/s | ETA~1m0s | GPU~2823 MiB
# [batch 1100/1546] loss(b)=0.1058 | loss(µ50)=0.0999 | lr=0.0005 | 35.4 img/s | ETA~0m54s | GPU~2823 MiB
# [batch 1150/1546] loss(b)=0.1165 | loss(µ50)=0.1068 | lr=0.0005 | 31.6 img/s | ETA~0m48s | GPU~2823 MiB
# [batch 1200/1546] loss(b)=0.1604 | loss(µ50)=0.1024 | lr=0.0005 | 32.7 img/s | ETA~0m42s | GPU~2823 MiB
# [batch 1250/1546] loss(b)=0.0979 | loss(µ50)=0.1056 | lr=0.0005 | 33.2 img/s | ETA~0m36s | GPU~2823 MiB
# [batch 1300/1546] loss(b)=0.1148 | loss(µ50)=0.1113 | lr=0.0005 | 33.4 img/s | ETA~0m30s | GPU~2823 MiB
# [batch 1350/1546] loss(b)=0.1271 | loss(µ50)=0.1044 | lr=0.0005 | 33.4 img/s | ETA~0m24s | GPU~2823 MiB
# [batch 1400/1546] loss(b)=0.0895 | loss(µ50)=0.1090 | lr=0.0005 | 33.8 img/s | ETA~0m18s | GPU~2823 MiB
# [batch 1450/1546] loss(b)=0.0849 | loss(µ50)=0.1042 | lr=0.0005 | 34.1 img/s | ETA~0m11s | GPU~2823 MiB
# [batch 1500/1546] loss(b)=0.1387 | loss(µ50)=0.1119 | lr=0.0005 | 33.0 img/s | ETA~0m5s | GPU~2823 MiB
# [batch 1546/1546] loss(b)=0.0893 | loss(µ50)=0.1126 | lr=0.0005 | 12.1 img/s | ETA~0m0s | GPU~2823 MiB
# FIN TRAIN
# INICIO val_loss (batches=442) ...
# [val_loss   50/442] loss=0.1297 | 13.91 it/s
# [val_loss  100/442] loss=0.1128 | 14.13 it/s
# [val_loss  150/442] loss=0.1388 | 14.19 it/s
# [val_loss  200/442] loss=0.1348 | 14.25 it/s
# [val_loss  250/442] loss=0.0885 | 14.27 it/s
# [val_loss  300/442] loss=0.1464 | 14.28 it/s
# [val_loss  350/442] loss=0.0816 | 14.30 it/s
# [val_loss  400/442] loss=0.1045 | 14.31 it/s
# [val_loss  442/442] loss=0.0940 | 14.34 it/s
# FIN val_loss  (0.5 min)
# INICIO val_prf (batches=442) ...
# [val_prf    50/442] 15.92 it/s | TP=146 FP=63 FN=54
# [val_prf   100/442] 16.03 it/s | TP=335 FP=85 FN=65
# [val_prf   150/442] 16.03 it/s | TP=529 FP=105 FN=71
# [val_prf   200/442] 16.12 it/s | TP=708 FP=135 FN=92
# [val_prf   250/442] 16.16 it/s | TP=896 FP=172 FN=104
# [val_prf   300/442] 16.19 it/s | TP=1075 FP=202 FN=125
# [val_prf   350/442] 16.23 it/s | TP=1254 FP=237 FN=146
# [val_prf   400/442] 16.25 it/s | TP=1430 FP=264 FN=170
# [val_prf   442/442] 16.28 it/s | TP=1578 FP=293 FN=188
# FIN val_prf  (0.5 min)
# INICIO val_mAP (batches=442) ...
# FIN val_mAP  (0.5 min)
# [RESUMEN ÉPOCA 10] lr→5e-05 | dur=4.6 min | train_loss=0.1070 | val_loss=0.1229 | val_rec=0.879 | val_f2=0.868 | val_mAP50=0.872 | val_mAP=0.382
#
# ================================================================================
# INICIO ÉPOCA 11/12  |  train_batches: 1546  |  batch_size: 4
# GPU: NVIDIA A100-SXM4-40GB  |  VRAM total: 39.6 GB
# ================================================================================
# [batch   50/1546] loss(b)=0.1062 | loss(µ50)=0.1055 | lr=5e-05 | 33.0 img/s | ETA~3m8s | GPU~2822 MiB
# [batch  100/1546] loss(b)=0.0713 | loss(µ50)=0.1049 | lr=5e-05 | 30.7 img/s | ETA~2m59s | GPU~2822 MiB
# [batch  150/1546] loss(b)=0.1089 | loss(µ50)=0.1061 | lr=5e-05 | 31.6 img/s | ETA~2m54s | GPU~2822 MiB
# [batch  200/1546] loss(b)=0.1068 | loss(µ50)=0.1042 | lr=5e-05 | 32.5 img/s | ETA~2m46s | GPU~2822 MiB
# [batch  250/1546] loss(b)=0.0793 | loss(µ50)=0.1113 | lr=5e-05 | 31.3 img/s | ETA~2m39s | GPU~2822 MiB
# [batch  300/1546] loss(b)=0.0949 | loss(µ50)=0.1073 | lr=5e-05 | 31.7 img/s | ETA~2m33s | GPU~2822 MiB
# [batch  350/1546] loss(b)=0.0912 | loss(µ50)=0.1081 | lr=5e-05 | 30.6 img/s | ETA~2m26s | GPU~2822 MiB
# [batch  400/1546] loss(b)=0.1153 | loss(µ50)=0.1041 | lr=5e-05 | 33.0 img/s | ETA~2m20s | GPU~2822 MiB
# [batch  450/1546] loss(b)=0.1066 | loss(µ50)=0.1075 | lr=5e-05 | 33.4 img/s | ETA~2m14s | GPU~2822 MiB
# [batch  500/1546] loss(b)=0.0992 | loss(µ50)=0.1074 | lr=5e-05 | 32.9 img/s | ETA~2m8s | GPU~2822 MiB
# [batch  550/1546] loss(b)=0.1041 | loss(µ50)=0.1038 | lr=5e-05 | 32.8 img/s | ETA~2m2s | GPU~2822 MiB
# [batch  600/1546] loss(b)=0.1652 | loss(µ50)=0.1108 | lr=5e-05 | 33.9 img/s | ETA~1m56s | GPU~2822 MiB
# [batch  650/1546] loss(b)=0.1269 | loss(µ50)=0.1011 | lr=5e-05 | 29.6 img/s | ETA~1m51s | GPU~2822 MiB
# [batch  700/1546] loss(b)=0.0517 | loss(µ50)=0.1057 | lr=5e-05 | 33.0 img/s | ETA~1m45s | GPU~2822 MiB
# [batch  750/1546] loss(b)=0.1034 | loss(µ50)=0.1007 | lr=5e-05 | 32.9 img/s | ETA~1m37s | GPU~2822 MiB
# [batch  800/1546] loss(b)=0.0743 | loss(µ50)=0.1018 | lr=5e-05 | 33.1 img/s | ETA~1m31s | GPU~2822 MiB
# [batch  850/1546] loss(b)=0.0914 | loss(µ50)=0.1061 | lr=5e-05 | 32.2 img/s | ETA~1m25s | GPU~2822 MiB
# [batch  900/1546] loss(b)=0.0814 | loss(µ50)=0.1021 | lr=5e-05 | 31.9 img/s | ETA~1m19s | GPU~2822 MiB
# [batch  950/1546] loss(b)=0.1283 | loss(µ50)=0.1039 | lr=5e-05 | 32.8 img/s | ETA~1m12s | GPU~2822 MiB
# [batch 1000/1546] loss(b)=0.1131 | loss(µ50)=0.0994 | lr=5e-05 | 32.1 img/s | ETA~1m7s | GPU~2822 MiB
# [batch 1050/1546] loss(b)=0.0877 | loss(µ50)=0.1100 | lr=5e-05 | 33.1 img/s | ETA~1m1s | GPU~2822 MiB
# [batch 1100/1546] loss(b)=0.1227 | loss(µ50)=0.1058 | lr=5e-05 | 32.8 img/s | ETA~0m54s | GPU~2822 MiB
# [batch 1150/1546] loss(b)=0.1000 | loss(µ50)=0.1072 | lr=5e-05 | 33.5 img/s | ETA~0m48s | GPU~2822 MiB
# [batch 1200/1546] loss(b)=0.1868 | loss(µ50)=0.1130 | lr=5e-05 | 32.8 img/s | ETA~0m42s | GPU~2822 MiB
# [batch 1250/1546] loss(b)=0.0993 | loss(µ50)=0.1046 | lr=5e-05 | 30.8 img/s | ETA~0m36s | GPU~2822 MiB
# [batch 1300/1546] loss(b)=0.0587 | loss(µ50)=0.1053 | lr=5e-05 | 32.7 img/s | ETA~0m30s | GPU~2822 MiB
# [batch 1350/1546] loss(b)=0.1207 | loss(µ50)=0.1015 | lr=5e-05 | 32.8 img/s | ETA~0m24s | GPU~2822 MiB
# [batch 1400/1546] loss(b)=0.0871 | loss(µ50)=0.0978 | lr=5e-05 | 30.9 img/s | ETA~0m18s | GPU~2822 MiB
# [batch 1450/1546] loss(b)=0.1037 | loss(µ50)=0.1034 | lr=5e-05 | 32.8 img/s | ETA~0m11s | GPU~2822 MiB
# [batch 1500/1546] loss(b)=0.1436 | loss(µ50)=0.0997 | lr=5e-05 | 32.8 img/s | ETA~0m5s | GPU~2822 MiB
# [batch 1546/1546] loss(b)=0.1358 | loss(µ50)=0.1043 | lr=5e-05 | 12.1 img/s | ETA~0m0s | GPU~2822 MiB
# FIN TRAIN
# INICIO val_loss (batches=442) ...
# [val_loss   50/442] loss=0.1351 | 14.21 it/s
# [val_loss  100/442] loss=0.1093 | 14.29 it/s
# [val_loss  150/442] loss=0.1358 | 14.36 it/s
# [val_loss  200/442] loss=0.1331 | 14.38 it/s
# [val_loss  250/442] loss=0.0839 | 14.39 it/s
# [val_loss  300/442] loss=0.1552 | 14.40 it/s
# [val_loss  350/442] loss=0.0895 | 14.42 it/s
# [val_loss  400/442] loss=0.1077 | 14.43 it/s
# [val_loss  442/442] loss=0.1001 | 14.42 it/s
# FIN val_loss  (0.5 min)
# INICIO val_prf (batches=442) ...
# [val_prf    50/442] 16.03 it/s | TP=144 FP=58 FN=56
# [val_prf   100/442] 16.25 it/s | TP=332 FP=80 FN=68
# [val_prf   150/442] 16.30 it/s | TP=525 FP=97 FN=75
# [val_prf   200/442] 16.26 it/s | TP=706 FP=126 FN=94
# [val_prf   250/442] 16.29 it/s | TP=897 FP=161 FN=103
# [val_prf   300/442] 16.33 it/s | TP=1078 FP=188 FN=122
# [val_prf   350/442] 16.35 it/s | TP=1258 FP=219 FN=142
# [val_prf   400/442] 16.33 it/s | TP=1436 FP=243 FN=164
# [val_prf   442/442] 16.36 it/s | TP=1584 FP=272 FN=182
# FIN val_prf  (0.5 min)
# INICIO val_mAP (batches=442) ...
# FIN val_mAP  (0.5 min)
# [RESUMEN ÉPOCA 11] lr→5e-05 | dur=4.6 min | train_loss=0.1050 | val_loss=0.1223 | val_rec=0.881 | val_f2=0.873 | val_mAP50=0.877 | val_mAP=0.386
#
# ================================================================================
# INICIO ÉPOCA 12/12  |  train_batches: 1546  |  batch_size: 4
# GPU: NVIDIA A100-SXM4-40GB  |  VRAM total: 39.6 GB
# ================================================================================
# [batch   50/1546] loss(b)=0.1221 | loss(µ50)=0.1097 | lr=5e-05 | 33.0 img/s | ETA~3m9s | GPU~2821 MiB
# [batch  100/1546] loss(b)=0.1276 | loss(µ50)=0.1038 | lr=5e-05 | 32.5 img/s | ETA~2m58s | GPU~2821 MiB
# [batch  150/1546] loss(b)=0.1527 | loss(µ50)=0.1090 | lr=5e-05 | 32.6 img/s | ETA~2m52s | GPU~2821 MiB
# [batch  200/1546] loss(b)=0.0758 | loss(µ50)=0.1052 | lr=5e-05 | 32.4 img/s | ETA~2m46s | GPU~2821 MiB
# [batch  250/1546] loss(b)=0.1130 | loss(µ50)=0.1045 | lr=5e-05 | 32.8 img/s | ETA~2m40s | GPU~2821 MiB
# [batch  300/1546] loss(b)=0.1062 | loss(µ50)=0.1018 | lr=5e-05 | 32.4 img/s | ETA~2m34s | GPU~2821 MiB
# [batch  350/1546] loss(b)=0.0915 | loss(µ50)=0.1102 | lr=5e-05 | 31.6 img/s | ETA~2m28s | GPU~2821 MiB
# [batch  400/1546] loss(b)=0.1034 | loss(µ50)=0.1078 | lr=5e-05 | 33.3 img/s | ETA~2m20s | GPU~2821 MiB
# [batch  450/1546] loss(b)=0.1165 | loss(µ50)=0.1036 | lr=5e-05 | 32.6 img/s | ETA~2m15s | GPU~2821 MiB
# [batch  500/1546] loss(b)=0.0741 | loss(µ50)=0.1020 | lr=5e-05 | 33.1 img/s | ETA~2m8s | GPU~2821 MiB
# [batch  550/1546] loss(b)=0.1173 | loss(µ50)=0.1043 | lr=5e-05 | 32.8 img/s | ETA~2m3s | GPU~2821 MiB
# [batch  600/1546] loss(b)=0.1042 | loss(µ50)=0.1018 | lr=5e-05 | 32.4 img/s | ETA~1m56s | GPU~2821 MiB
# [batch  650/1546] loss(b)=0.1061 | loss(µ50)=0.1065 | lr=5e-05 | 31.8 img/s | ETA~1m50s | GPU~2821 MiB
# [batch  700/1546] loss(b)=0.0768 | loss(µ50)=0.1029 | lr=5e-05 | 32.5 img/s | ETA~1m44s | GPU~2821 MiB
# [batch  750/1546] loss(b)=0.1361 | loss(µ50)=0.1039 | lr=5e-05 | 33.8 img/s | ETA~1m38s | GPU~2821 MiB
# [batch  800/1546] loss(b)=0.1085 | loss(µ50)=0.1031 | lr=5e-05 | 30.7 img/s | ETA~1m32s | GPU~2821 MiB
# [batch  850/1546] loss(b)=0.1256 | loss(µ50)=0.1039 | lr=5e-05 | 31.8 img/s | ETA~1m26s | GPU~2821 MiB
# [batch  900/1546] loss(b)=0.1433 | loss(µ50)=0.1075 | lr=5e-05 | 32.7 img/s | ETA~1m19s | GPU~2821 MiB
# [batch  950/1546] loss(b)=0.1317 | loss(µ50)=0.1053 | lr=5e-05 | 31.7 img/s | ETA~1m13s | GPU~2821 MiB
# [batch 1000/1546] loss(b)=0.1571 | loss(µ50)=0.1057 | lr=5e-05 | 32.8 img/s | ETA~1m7s | GPU~2821 MiB
# [batch 1050/1546] loss(b)=0.1217 | loss(µ50)=0.1067 | lr=5e-05 | 30.8 img/s | ETA~1m1s | GPU~2821 MiB
# [batch 1100/1546] loss(b)=0.0954 | loss(µ50)=0.1078 | lr=5e-05 | 30.4 img/s | ETA~0m55s | GPU~2821 MiB
# [batch 1150/1546] loss(b)=0.0809 | loss(µ50)=0.1032 | lr=5e-05 | 32.7 img/s | ETA~0m49s | GPU~2821 MiB
# [batch 1200/1546] loss(b)=0.1047 | loss(µ50)=0.1023 | lr=5e-05 | 32.9 img/s | ETA~0m42s | GPU~2821 MiB
# [batch 1250/1546] loss(b)=0.0863 | loss(µ50)=0.1056 | lr=5e-05 | 31.4 img/s | ETA~0m36s | GPU~2821 MiB
# [batch 1300/1546] loss(b)=0.1290 | loss(µ50)=0.1047 | lr=5e-05 | 32.6 img/s | ETA~0m30s | GPU~2821 MiB
# [batch 1350/1546] loss(b)=0.0699 | loss(µ50)=0.1033 | lr=5e-05 | 31.6 img/s | ETA~0m24s | GPU~2821 MiB
# [batch 1400/1546] loss(b)=0.0705 | loss(µ50)=0.1087 | lr=5e-05 | 33.4 img/s | ETA~0m18s | GPU~2821 MiB
# [batch 1450/1546] loss(b)=0.1097 | loss(µ50)=0.1013 | lr=5e-05 | 32.3 img/s | ETA~0m11s | GPU~2821 MiB
# [batch 1500/1546] loss(b)=0.0823 | loss(µ50)=0.1056 | lr=5e-05 | 32.5 img/s | ETA~0m5s | GPU~2821 MiB
# [batch 1546/1546] loss(b)=0.0876 | loss(µ50)=0.1065 | lr=5e-05 | 11.8 img/s | ETA~0m0s | GPU~2821 MiB
# FIN TRAIN
# INICIO val_loss (batches=442) ...
# [val_loss   50/442] loss=0.1360 | 14.19 it/s
# [val_loss  100/442] loss=0.1105 | 14.31 it/s
# [val_loss  150/442] loss=0.1347 | 14.36 it/s
# [val_loss  200/442] loss=0.1298 | 14.36 it/s
# [val_loss  250/442] loss=0.0881 | 14.38 it/s
# [val_loss  300/442] loss=0.1471 | 14.39 it/s
# [val_loss  350/442] loss=0.0867 | 14.40 it/s
# [val_loss  400/442] loss=0.1081 | 14.39 it/s
# [val_loss  442/442] loss=0.1083 | 14.41 it/s
# FIN val_loss  (0.5 min)
# INICIO val_prf (batches=442) ...
# [val_prf    50/442] 16.35 it/s | TP=144 FP=61 FN=56
# [val_prf   100/442] 16.41 it/s | TP=334 FP=82 FN=66
# [val_prf   150/442] 16.33 it/s | TP=528 FP=98 FN=72
# [val_prf   200/442] 16.31 it/s | TP=707 FP=130 FN=93
# [val_prf   250/442] 16.31 it/s | TP=896 FP=165 FN=104
# [val_prf   300/442] 16.27 it/s | TP=1078 FP=190 FN=122
# [val_prf   350/442] 16.30 it/s | TP=1252 FP=225 FN=148
# [val_prf   400/442] 16.33 it/s | TP=1429 FP=251 FN=171
# [val_prf   442/442] 16.37 it/s | TP=1577 FP=284 FN=189
# FIN val_prf  (0.5 min)
# INICIO val_mAP (batches=442) ...
# FIN val_mAP  (0.5 min)
# [RESUMEN ÉPOCA 12] lr→5e-05 | dur=4.6 min | train_loss=0.1051 | val_loss=0.1224 | val_rec=0.877 | val_f2=0.869 | val_mAP50=0.873 | val_mAP=0.384

# %%
# -----------------------------
# 8) Calibración del operating point (score_thresh, nms_thresh, detections_per_img) en VALID
# -----------------------------

# Greedy match (class-agnostic)
def greedy_match_iou(pred_boxes: torch.Tensor, gt_boxes: torch.Tensor, iou_thresh: float = 0.5) -> int:
    if pred_boxes.numel() == 0 or gt_boxes.numel() == 0:
        return 0
    ious = box_iou(pred_boxes, gt_boxes)  # [P,G]
    P, G = ious.shape

    flat = []
    # construir lista de pares (p,g,iou)
    ious_np = ious.cpu().numpy()
    for i in range(P):
        for j in range(G):
            v = float(ious_np[i, j])
            if v >= iou_thresh:
                flat.append((i, j, v))
    if not flat:
        return 0

    flat.sort(key=lambda x: x[2], reverse=True)
    used_p, used_g = set(), set()
    matches = 0
    for i, j, v in flat:
        if i in used_p or j in used_g:
            continue
        used_p.add(i); used_g.add(j)
        matches += 1
    return matches

# Cache outputs
@torch.no_grad()
def cache_valid_outputs(model, loader, device, force_score_thresh=0.0, force_nms_thresh=1.0, force_det_per_img=1000):
    model.eval()

    # backup params
    roi = model.roi_heads
    b_score = getattr(roi, "score_thresh", None)
    b_nms   = getattr(roi, "nms_thresh", None)
    b_det   = getattr(roi, "detections_per_img", None)

    roi.score_thresh = float(force_score_thresh)
    roi.nms_thresh = float(force_nms_thresh)
    roi.detections_per_img = int(force_det_per_img)

    cached = []
    for imgs, targets in loader:
        imgs = [img.to(device) for img in imgs]
        outs = model(imgs)
        for out, tgt in zip(outs, targets):
            cached.append({
                "p_boxes":  out["boxes"].detach().cpu(),
                "p_scores": out["scores"].detach().cpu(),
                "p_labels": out["labels"].detach().cpu(),  # 1..K
                "g_boxes":  tgt["boxes"].detach().cpu(),
            })

    # Restore
    if b_score is not None: roi.score_thresh = b_score
    if b_nms is not None:   roi.nms_thresh = b_nms
    if b_det is not None:   roi.detections_per_img = b_det

    return cached

# Aplicar operating point offline (score + NMS + topK)
def apply_operating_point(p_boxes, p_scores, p_labels, score_thresh, nms_thresh, det_per_img):
    keep = p_scores >= score_thresh
    boxes = p_boxes[keep]
    scores = p_scores[keep]
    labels = p_labels[keep]

    if boxes.numel() == 0:
        return boxes, scores, labels

    # NMS por clase (como torchvision)
    if nms_thresh < 1.0:
        keep_idx = batched_nms(boxes, scores, labels, iou_threshold=float(nms_thresh))
        boxes, scores, labels = boxes[keep_idx], scores[keep_idx], labels[keep_idx]

    # top-k detections
    if det_per_img is not None and len(scores) > det_per_img:
        topk = torch.topk(scores, k=int(det_per_img)).indices
        boxes, scores, labels = boxes[topk], scores[topk], labels[topk]

    return boxes, scores, labels

# Evaluar (box-recall y FP/img)
def eval_box_recall_fp(cached, score_thresh, nms_thresh, det_per_img, iou_thresh=0.5):
    total_gt = 0
    total_matches = 0
    total_preds = 0

    for item in cached:
        g = item["g_boxes"]
        pb, ps, pl = apply_operating_point(
            item["p_boxes"], item["p_scores"], item["p_labels"],
            score_thresh=score_thresh, nms_thresh=nms_thresh, det_per_img=det_per_img
        )

        m = greedy_match_iou(pb, g, iou_thresh=iou_thresh)

        total_gt += int(len(g))
        total_matches += int(m)
        total_preds += int(len(pb))

    recall = total_matches / total_gt if total_gt > 0 else 0.0
    fp = total_preds - total_matches
    fp_per_img = fp / len(cached) if len(cached) > 0 else 0.0
    preds_per_img = total_preds / len(cached) if len(cached) > 0 else 0.0
    return {
        "recall": float(recall),
        "fp_per_img": float(fp_per_img),
        "preds_per_img": float(preds_per_img),
        "total_gt": int(total_gt),
        "total_matches": int(total_matches),
        "total_preds": int(total_preds),
    }

# Cachear VALID (una vez)
cached_valid = cache_valid_outputs(
    model, valid_dl, device,
    force_score_thresh=0.0,
    force_nms_thresh=1.0,
    force_det_per_img=1500,
)

print(f"Cached VALID images: {len(cached_valid)}")

# 2) Grid search operating point. Target: box-recall >= 0.98, minimizar FP/img
TARGET_RECALL = 0.98
IOU_THRESH = 0.5

score_grid = [0.01, 0.02, 0.03, 0.05, 0.08, 0.10, 0.15, 0.20, 0.30, 0.50]
nms_grid   = [0.30, 0.40, 0.50, 0.60, 0.70]
det_grid   = [50, 100, 200, 400]

results = []
for s in score_grid:
    for n in nms_grid:
        for d in det_grid:
            r = eval_box_recall_fp(cached_valid, s, n, d, iou_thresh=IOU_THRESH)
            r.update({"score_thresh": s, "nms_thresh": n, "det_per_img": d})
            results.append(r)

# Filtrar por recall objetivo
feasible = [r for r in results if r["recall"] >= TARGET_RECALL]

if not feasible:
    best = sorted(results, key=lambda x: (-x["recall"], x["fp_per_img"], x["preds_per_img"]))[0]
    print("\nNo hubo combinaciones con recall >= target.")
    print("Mejor alternativa (max recall, luego min FP/img):")
else:
    best = sorted(feasible, key=lambda x: (x["fp_per_img"], x["preds_per_img"], -x["recall"]))[0]
    print("\nMejor combinación cumpliendo recall >= target:")

print(best)

# Top-10 para mirar trade-off
top10 = sorted(
    feasible if feasible else results,
    key=lambda x: (x["fp_per_img"], x["preds_per_img"], -x["recall"])
)[:10]

print("\nTop 10 (ordenadas por menor FP/img):")
for r in top10:
    print(f"s={r['score_thresh']:.2f} nms={r['nms_thresh']:.2f} d={r['det_per_img']:4d} | "
          f"rec={r['recall']:.3f} fp/img={r['fp_per_img']:.2f} preds/img={r['preds_per_img']:.2f}")

# 3) Setear el modelo con el operating point elegido
model.roi_heads.score_thresh = float(best["score_thresh"])
model.roi_heads.nms_thresh = float(best["nms_thresh"])
model.roi_heads.detections_per_img = int(best["det_per_img"])

print("\nModel ROI heads set:")
print("  score_thresh      =", model.roi_heads.score_thresh)
print("  nms_thresh        =", model.roi_heads.nms_thresh)
print("  detections_per_img=", model.roi_heads.detections_per_img)
# Out:
# Cached VALID images: 1766
#
# Mejor combinación cumpliendo recall >= target:
# {'recall': 0.9847112117780294, 'fp_per_img': 5.375424688561721, 'preds_per_img': 6.360135900339751, 'total_gt': 1766, 'total_matches': 1739, 'total_preds': 11232, 'score_thresh': 0.01, 'nms_thresh': 0.6, 'det_per_img': 50}
#
# Top 10 (ordenadas por menor FP/img):
# s=0.01 nms=0.60 d=  50 | rec=0.985 fp/img=5.38 preds/img=6.36
# s=0.01 nms=0.60 d= 100 | rec=0.985 fp/img=5.38 preds/img=6.36
# s=0.01 nms=0.60 d= 200 | rec=0.985 fp/img=5.38 preds/img=6.36
# s=0.01 nms=0.60 d= 400 | rec=0.985 fp/img=5.38 preds/img=6.36
# s=0.02 nms=0.70 d=  50 | rec=0.981 fp/img=7.05 preds/img=8.03
# s=0.02 nms=0.70 d= 100 | rec=0.981 fp/img=7.05 preds/img=8.03
# s=0.02 nms=0.70 d= 200 | rec=0.981 fp/img=7.05 preds/img=8.03
# s=0.02 nms=0.70 d= 400 | rec=0.981 fp/img=7.05 preds/img=8.03
# s=0.01 nms=0.70 d=  50 | rec=0.987 fp/img=10.93 preds/img=11.92
# s=0.01 nms=0.70 d= 100 | rec=0.987 fp/img=10.94 preds/img=11.92
#
# Model ROI heads set:
#   score_thresh      = 0.01
#   nms_thresh        = 0.6
#   detections_per_img= 50

# %%
print(f"Tiempo calibración operating point: {datetime.datetime.now() - INICIO_STEP}")
INICIO_STEP = datetime.datetime.now()
# Out:
# Tiempo calibración operating point: 0:58:10.263642

# %%
# ---------------------------------------
# 9) Graficar métricas por epoch
# ---------------------------------------

def _get(h, *keys, default=np.nan):
    cur = h
    for k in keys:
        if cur is None or not isinstance(cur, dict) or k not in cur:
            return default
        cur = cur[k]
    return cur if cur is not None else default

epochs = [h["epoch"] for h in history]

# Series base (loss + LR)
train_loss = [_get(h, "train", "loss_total") for h in history]
val_loss   = [_get(h, "valid", "loss_total") for h in history]

train_cls  = [_get(h, "train", "loss_classifier") for h in history]
train_box  = [_get(h, "train", "loss_box_reg") for h in history]
train_obj  = [_get(h, "train", "loss_objectness") for h in history]
train_rpn  = [_get(h, "train", "loss_rpn_box_reg") for h in history]

val_cls    = [_get(h, "valid", "loss_classifier") for h in history]
val_box    = [_get(h, "valid", "loss_box_reg") for h in history]
val_obj    = [_get(h, "valid", "loss_objectness") for h in history]
val_rpn    = [_get(h, "valid", "loss_rpn_box_reg") for h in history]

lr_series  = [_get(h, "lr") for h in history]

# Series de métricas (macro)
val_prec = [_get(h, "valid_macro", "precision") for h in history]
val_rec  = [_get(h, "valid_macro", "recall") for h in history]
val_f1   = [_get(h, "valid_macro", "f1") for h in history]
val_f2   = [_get(h, "valid_macro", "f2") for h in history]

# mAP (si existe)
map50 = [_get(h, "valid_map", "map_50") for h in history]
map95 = [_get(h, "valid_map", "map") for h in history]
has_map = np.any(np.isfinite(map50)) or np.any(np.isfinite(map95))

# Loss total: train vs val
plt.figure()
plt.plot(epochs, train_loss, marker="o", label="train loss_total")
plt.plot(epochs, val_loss,   marker="o", label="val loss_total")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss total (train vs val)")
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()

# Breakdown de losses (train vs val)
plt.figure()
plt.plot(epochs, train_cls, marker="o", label="train loss_classifier")
plt.plot(epochs, val_cls,   marker="o", label="val loss_classifier")
plt.xlabel("Epoch"); plt.ylabel("Loss"); plt.title("Loss: classifier"); plt.grid(True, alpha=0.3); plt.legend(); plt.show()

plt.figure()
plt.plot(epochs, train_box, marker="o", label="train loss_box_reg")
plt.plot(epochs, val_box,   marker="o", label="val loss_box_reg")
plt.xlabel("Epoch"); plt.ylabel("Loss"); plt.title("Loss: box_reg"); plt.grid(True, alpha=0.3); plt.legend(); plt.show()

plt.figure()
plt.plot(epochs, train_obj, marker="o", label="train loss_objectness")
plt.plot(epochs, val_obj,   marker="o", label="val loss_objectness")
plt.xlabel("Epoch"); plt.ylabel("Loss"); plt.title("Loss: objectness"); plt.grid(True, alpha=0.3); plt.legend(); plt.show()

plt.figure()
plt.plot(epochs, train_rpn, marker="o", label="train loss_rpn_box_reg")
plt.plot(epochs, val_rpn,   marker="o", label="val loss_rpn_box_reg")
plt.xlabel("Epoch"); plt.ylabel("Loss"); plt.title("Loss: rpn_box_reg"); plt.grid(True, alpha=0.3); plt.legend(); plt.show()

# 3) Métricas macro en VALID (precision/recall/F1/F2)
plt.figure()
plt.plot(epochs, val_prec, marker="o", label="val macro precision")
plt.plot(epochs, val_rec,  marker="o", label="val macro recall")
plt.plot(epochs, val_f1,   marker="o", label="val macro F1")
plt.plot(epochs, val_f2,   marker="o", label="val macro F2")
plt.xlabel("Epoch")
plt.ylabel("Score")
plt.ylim(0, 1.0)
plt.title("VALID macro metrics @ score_thresh / IoU")
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()

# mAP en VALID
if has_map:
    plt.figure()
    plt.plot(epochs, map50, marker="o", label="val mAP@0.5 (map_50)")
    plt.plot(epochs, map95, marker="o", label="val mAP@[0.5:0.95] (map)")
    plt.xlabel("Epoch")
    plt.ylabel("mAP")
    plt.ylim(0, 1.0)
    plt.title("VALID mAP (torchmetrics)")
    plt.grid(True, alpha=0.3)
    plt.legend()
    plt.show()
else:
    print("mAP no aparece en history.")

# Learning rate
plt.figure()
plt.plot(epochs, lr_series, marker="o")
plt.xlabel("Epoch")
plt.ylabel("LR")
plt.title("Learning Rate per epoch")
plt.grid(True, alpha=0.3)
plt.show()

# %%
print(f"Tiempo entrenamiento: {datetime.datetime.now() - INICIO_STEP}")
INICIO_STEP = datetime.datetime.now()
# Out:
# Tiempo entrenamiento: 0:00:01.093993

# %%
# ---------------------------------------
# 10) Guardado del modelo (pesos y checkpoint)
# ---------------------------------------

stamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
OUT_DIR = os.path.join(OUT_BASE_DIR, f"artifacts_{stamp}")
os.makedirs(OUT_DIR, exist_ok=True)

weights_path    = os.path.join(OUT_DIR, f"weights.pth")
checkpoint_path = os.path.join(OUT_DIR, f"frcnn_checkpoint.pth")
meta_path       = os.path.join(OUT_DIR, f"meta.json")

torch.save(model.state_dict(), weights_path)
print(f"[OK] Pesos guardados en: {weights_path}")

ckpt = {
    "model_state": model.state_dict(),
    "optimizer_state": optimizer.state_dict(),
    "epoch": EPOCHS,
    "num_classes": NUM_CLASSES,
    "class_names": CLASS_NAMES,
    "img_size": (416, 416),
    "lr": LR,
}
torch.save(ckpt, checkpoint_path)
print(f"[OK] Checkpoint guardado en: {checkpoint_path}")

meta = {
    "saved_at": stamp,
    "framework": "torchvision Faster R-CNN ResNet50-FPN",
    "device": str(device),
    "num_classes_with_bg": NUM_CLASSES_WITH_BG,
    "class_names": CLASS_NAMES,
    "train_imgs": len(train_ds),
    "valid_imgs": len(valid_ds),
    "test_imgs": len(test_ds),
    # "eval_valid_macro": eval_valid.get("macro", {}) if 'eval_valid' in locals() else {}
}
with open(meta_path, "w", encoding="utf-8") as f:
    json.dump(meta, f, indent=2, ensure_ascii=False)
print(f"[OK] Metadatos guardados en: {meta_path}")
# Out:
# [OK] Pesos guardados en: /content/drive/MyDrive/UBA/CEIA/Materias/Visión por Computadora II/google_colab_data/FasterR-CNN-ResNet50_notebook/artifacts_20251201_013759/weights.pth
# [OK] Checkpoint guardado en: /content/drive/MyDrive/UBA/CEIA/Materias/Visión por Computadora II/google_colab_data/FasterR-CNN-ResNet50_notebook/artifacts_20251201_013759/frcnn_checkpoint.pth
# [OK] Metadatos guardados en: /content/drive/MyDrive/UBA/CEIA/Materias/Visión por Computadora II/google_colab_data/FasterR-CNN-ResNet50_notebook/artifacts_20251201_013759/meta.json

# %%
print(f"Tiempo guardado modelo: {datetime.datetime.now() - INICIO_STEP}")
INICIO_STEP = datetime.datetime.now()
# Out:
# Tiempo guardado modelo: 0:00:01.269973

# %%
# ---------------------------------------
# 11) Matriz de confusión (valid y test)
# ---------------------------------------

def _greedy_match_iou_class_first(pred_boxes, gt_boxes, pred_labels, gt_labels, iou_thresh=0.5):
    if len(pred_boxes) == 0 or len(gt_boxes) == 0:
        return []

    ious = box_iou(pred_boxes, gt_boxes).cpu().numpy()
    matches = []
    used_pred, used_gt = set(), set()

    def _run(flat_pairs):
        nonlocal matches, used_pred, used_gt
        for i, j, v in flat_pairs:
            if v < iou_thresh:
                break
            if (i not in used_pred) and (j not in used_gt):
                used_pred.add(i); used_gt.add(j)
                matches.append((i, j))

    # Construir pares (i, j, iou)
    flat_same = []
    flat_diff = []
    for i in range(ious.shape[0]):
        for j in range(ious.shape[1]):
            v = ious[i, j]
            if pred_labels[i] == gt_labels[j]:
                flat_same.append((i, j, v))
            else:
                flat_diff.append((i, j, v))

    flat_same.sort(key=lambda x: x[2], reverse=True)
    flat_diff.sort(key=lambda x: x[2], reverse=True)

    _run(flat_same)  # etapa 1: aciertos
    _run(flat_diff)  # etapa 2: confusiones

    return matches


def confusion_matrix_detection(model, loader, class_names, score_thresh=0.5, iou_thresh=0.5, normalize=True, title="Confusion Matrix"):
    model.eval()
    K = len(class_names)
    C = np.zeros((K+1, K+1), dtype=np.int64)  # filas=pred, cols=true ; ultimo índice = background
    bg = K  # índice background

    with torch.no_grad():
        for imgs, targets in loader:
            imgs = [img.to(device) for img in imgs]
            outs = model(imgs)

            for out, tgt in zip(outs, targets):
                # Filtrar por score
                keep = out["scores"].cpu().numpy() >= score_thresh
                p_boxes = out["boxes"][keep].cpu()
                p_labels = out["labels"][keep].cpu().numpy()  # en 1..K

                g_boxes  = tgt["boxes"].cpu()
                g_labels = tgt["labels"].cpu().numpy()        # en 1..K

                # Emparejar por IoU (class-agnostic) para poder medir confusiones entre clases. Pasar labels a 0..K-1 para el matching
                p_labels0 = (p_labels.astype(int) - 1)
                g_labels0 = (g_labels.astype(int) - 1)

                matches = _greedy_match_iou_class_first(p_boxes, g_boxes, p_labels0, g_labels0, iou_thresh=iou_thresh)

                matched_pred = set(i for i, _ in matches)
                matched_gt   = set(j for _, j in matches)

                # Contar matches (pueden ser aciertos o confusiones de clase)
                for i, j in matches:
                  pred_c = int(p_labels0[i])
                  true_c = int(g_labels0[j])
                  C[pred_c, true_c] += 1

                # Predicciones no emparejadas -> true = background
                for i in range(len(p_boxes)):
                    if i not in matched_pred:
                        pred_c = int(p_labels[i]) - 1
                        C[pred_c, bg] += 1

                # GT no emparejadas -> pred = background
                for j in range(len(g_boxes)):
                    if j not in matched_gt:
                        true_c = int(g_labels[j]) - 1
                        C[bg, true_c] += 1

    # Normalización por columna
    Cn = C.astype(float)
    if normalize:
        col_sums = Cn.sum(axis=0, keepdims=True)
        col_sums[col_sums == 0] = 1.0
        Cn = Cn / col_sums

    # Plot
    labels_plot = class_names + ["background"]
    fig, ax = plt.subplots(figsize=(8, 6))
    im = ax.imshow(Cn, interpolation='nearest', aspect='auto')
    ax.set_title(title)
    ax.set_xlabel("True")
    ax.set_ylabel("Predicted")
    ax.set_xticks(range(len(labels_plot)))
    ax.set_yticks(range(len(labels_plot)))
    ax.set_xticklabels(labels_plot, rotation=45, ha='right')
    ax.set_yticklabels(labels_plot)

    # Anotar valores
    for i in range(Cn.shape[0]):
        for j in range(Cn.shape[1]):
            val = Cn[i, j]
            txt = f"{val:.2f}" if normalize else str(C[i, j])
            ax.text(j, i, txt, ha='center', va='center', color='white' if val > 0.5 else 'black', fontsize=8)

    fig.colorbar(im, ax=ax, fraction=0.046, pad=0.04)
    plt.tight_layout()
    plt.show()

    return {"raw": C, "norm": Cn, "labels": labels_plot}

# Una matriz absoluta y normalizada para VALID y otra para TEST
confusion_matrix_detection(model, valid_dl, CLASS_NAMES, score_thresh=model.roi_heads.score_thresh, iou_thresh=0.5,
                           normalize=False, title=f"Matriz de confusión (Absoluta, VALID, IoU=0.5, score≥{model.roi_heads.score_thresh})")
confusion_matrix_detection(model, valid_dl, CLASS_NAMES, score_thresh=model.roi_heads.score_thresh, iou_thresh=0.5,
                           normalize=True, title=f"Matriz de confusión (Normalizada, VALID, IoU=0.5, score≥{model.roi_heads.score_thresh})")
confusion_matrix_detection(model, test_dl,  CLASS_NAMES, score_thresh=model.roi_heads.score_thresh, iou_thresh=0.5,
                           normalize=False, title=f"Matriz de confusión (Absoluta, TEST, IoU=0.5, score≥{model.roi_heads.score_thresh})")
confusion_matrix_detection(model, test_dl,  CLASS_NAMES, score_thresh=model.roi_heads.score_thresh, iou_thresh=0.5,
                           normalize=True, title=f"Matriz de confusión (Normalizada, TEST, IoU=0.5, score≥{model.roi_heads.score_thresh})")
# Out:
# {'raw': array([[ 164,    0,    0,    0,    0,  370],
#         [   0,  189,    0,    0,    0,  937],
#         [   0,    2,  112,    0,    1, 1283],
#         [   1,    0,    2,  195,    0, 1437],
#         [   0,    0,    0,    0,  199,  784],
#         [   1,    2,    4,    8,    3,    0]]),
#  'norm': array([[0.98795181, 0.        , 0.        , 0.        , 0.        ,
#          0.07690709],
#         [0.        , 0.97927461, 0.        , 0.        , 0.        ,
#          0.194762  ],
#         [0.        , 0.01036269, 0.94915254, 0.        , 0.00492611,
#          0.26668052],
#         [0.0060241 , 0.        , 0.01694915, 0.96059113, 0.        ,
#          0.2986905 ],
#         [0.        , 0.        , 0.        , 0.        , 0.98029557,
#          0.16295988],
#         [0.0060241 , 0.01036269, 0.03389831, 0.03940887, 0.01477833,
#          0.        ]]),
#  'labels': ['Tijera',
#   'Navaja',
#   'Cuchillo',
#   'Cutter',
#   'Navaja multiuso',
#   'background']}

# %%
print(f"Tiempo matrices confusión: {datetime.datetime.now() - INICIO_STEP}")
INICIO_STEP = datetime.datetime.now()
# Out:
# Tiempo matrices confusión: 0:01:23.459023

# %%
# ---------------------------------------
# 12) Recolectar métricas y guardar en JSON
# ---------------------------------------

if 'train_loss_history' not in globals():
    train_loss_history = []

def summarize_eval(eval_dict, split_name):
    """Convierte la salida de evaluate_prf1(...) al esquema JSON estandar."""
    if eval_dict is None:
        return None
    per_class = []
    for (name, tp, fp, fn, prec, rec, f1) in eval_dict["per_class"]:
        per_class.append({
            "class": name,
            "tp": int(tp),
            "fp": int(fp),
            "fn": int(fn),
            "precision": float(prec),
            "recall": float(rec),
            "f1": float(f1),
        })
    # totales (sin background)
    TP = int(eval_dict["raw"]["TP"][1:].sum())
    FP = int(eval_dict["raw"]["FP"][1:].sum())
    FN = int(eval_dict["raw"]["FN"][1:].sum())
    return {
        "split": split_name,
        "macro": {
            "precision": float(eval_dict["macro"]["precision"]),
            "recall":    float(eval_dict["macro"]["recall"]),
            "f1":        float(eval_dict["macro"]["f1"]),
        },
        "totals": {"TP": TP, "FP": FP, "FN": FN},
        "per_class": per_class,
        "thresholds": {"iou": 0.5, "score": 0.5}
    }

def is_backbone_frozen(m):
    try:
        return all((not p.requires_grad) for p in m.backbone.parameters())
    except Exception:
        return None

# Información del optimizador/scheduler
opt_name = optimizer.__class__.__name__ if 'optimizer' in globals() else None
sch_name = lr_sched.__class__.__name__ if 'lr_sched' in globals() else None

# Build del JSON
stamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
payload = {
    "saved_at": stamp,
    "notebook": "CEIA_VpC2_TP_Opcion2.ipynb",
    "framework": "torchvision Faster R-CNN ResNet50-FPN",
    "device": str(device),
    "classes": CLASS_NAMES,
    "num_classes": len(CLASS_NAMES),
    "data": {
        "train_images": len(train_ds) if 'train_ds' in globals() else None,
        "valid_images": len(valid_ds) if 'valid_ds' in globals() else None,
        "test_images":  len(test_ds)  if 'test_ds'  in globals() else None
    },
    "training": {
        "epochs": EPOCHS if 'EPOCHS' in globals() else None,
        "batch_size": BATCH_SIZE if 'BATCH_SIZE' in globals() else None,
        "lr": LR if 'LR' in globals() else None,
        "optimizer": opt_name,
        "scheduler": sch_name,
        "backbone_frozen": is_backbone_frozen(model),
        "loss_history": train_loss_history,
    },
}

path_metrics_full = os.path.join(OUT_DIR, "metrics_full.json")

with open(path_metrics_full, "w", encoding="utf-8") as f:
    json.dump(payload, f, indent=2, ensure_ascii=False)

print(f"[OK] Métricas guardadas:\n  - {path_metrics_full}")
# Out:
# [OK] Métricas guardadas:
#   - /content/drive/MyDrive/UBA/CEIA/Materias/Visión por Computadora II/google_colab_data/FasterR-CNN-ResNet50_notebook/artifacts_20251201_013759/metrics_full.json

# %%
print(f"Tiempo recolección métricas: {datetime.datetime.now() - INICIO_STEP}")
INICIO_STEP = datetime.datetime.now()
# Out:
# Tiempo recolección métricas: 0:00:00.023931

# %%
# ---------------------------------------
# 13) Curvas P-R por clase y mAP (mAP@0.5 y mAP@[0.5:0.95])
# ---------------------------------------


@torch.no_grad()
def _collect_predictions_and_gts(model, loader, device, num_classes, score_min=0.0):
    model.eval()
    preds_by_cls = {c: [] for c in range(1, num_classes+1)}
    gts_by_cls   = {c: [] for c in range(1, num_classes+1)}

    img_index = 0
    for imgs, targets in loader:
        imgs = [img.to(device) for img in imgs]
        outs = model(imgs)

        for out, tgt in zip(outs, targets):
            # GT
            gt_boxes  = tgt["boxes"].cpu().numpy()
            gt_labels = tgt["labels"].cpu().numpy()  # 1..K
            for b, lab in zip(gt_boxes, gt_labels):
                gts_by_cls[int(lab)].append((b[0], b[1], b[2], b[3], img_index))

            # Preds
            scores = out["scores"].cpu().numpy()
            keep = scores >= score_min
            p_boxes  = out["boxes"][keep].cpu().numpy()
            p_labels = out["labels"][keep].cpu().numpy()  # 1..K
            p_scores = scores[keep]

            for b, lab, sc in zip(p_boxes, p_labels, p_scores):
                preds_by_cls[int(lab)].append((float(sc), b[0], b[1], b[2], b[3], img_index))

            img_index += 1
    return preds_by_cls, gts_by_cls

def _ap_from_pr(precision, recall):
    if len(precision) == 0:
        return 0.0
    # Ordenar por recall ascendente
    order = np.argsort(recall)
    r = np.array(recall)[order]
    p = np.array(precision)[order]

    # Precision envelope: p[i] = max_{j>=i} p[j]
    for i in range(len(p)-2, -1, -1):
        p[i] = max(p[i], p[i+1])

    # Muestreamos 101 puntos de recall
    recall_grid = np.linspace(0, 1, 101)
    p_interp = np.zeros_like(recall_grid)
    for i, rg in enumerate(recall_grid):
        idx = np.where(r >= rg)[0]
        p_interp[i] = 0.0 if len(idx) == 0 else np.max(p[idx])
    return float(np.mean(p_interp))

def _pr_curve_for_class(preds_cls, gts_cls, iou_thresh=0.5):
    # Índice de GTs por imagen para acelerar matching
    gt_by_img = {}
    for (x1, y1, x2, y2, img_id) in gts_cls:
        gt_by_img.setdefault(img_id, []).append([x1, y1, x2, y2, False])  # False = no emparejada todavía

    # Ordenar predicciones por score descendente
    preds_cls = sorted(preds_cls, key=lambda x: x[0], reverse=True)

    tp = np.zeros(len(preds_cls), dtype=np.float32)
    fp = np.zeros(len(preds_cls), dtype=np.float32)
    total_gts = len(gts_cls)

    for i, (score, x1, y1, x2, y2, img_id) in enumerate(preds_cls):
        pred_box = np.array([[x1, y1, x2, y2]], dtype=np.float32)
        gts_list = gt_by_img.get(img_id, [])

        if len(gts_list) == 0:
            fp[i] = 1.0
            continue

        # IoU con todas las GTs de esta imagen para esta clase
        gt_boxes = np.array([g[:4] for g in gts_list], dtype=np.float32)
        ious = box_iou(torch.tensor(pred_box), torch.tensor(gt_boxes)).numpy()[0]

        # Mejor IoU
        best_idx = int(np.argmax(ious))
        best_iou = float(ious[best_idx])

        if best_iou >= iou_thresh and (not gts_list[best_idx][4]):  # no emparejada
            tp[i] = 1.0
            gts_list[best_idx][4] = True  # marcar como usada
        else:
            fp[i] = 1.0

    # Cálculo de precisión y recall acumulados
    cum_tp = np.cumsum(tp)
    cum_fp = np.cumsum(fp)
    precision = cum_tp / np.maximum(cum_tp + cum_fp, 1e-9)
    recall = cum_tp / max(total_gts, 1e-9)

    ap = _ap_from_pr(precision, recall)
    return precision, recall, ap, int(cum_tp[-1]) if len(cum_tp) else 0, int(cum_fp[-1]) if len(cum_fp) else 0, total_gts

def compute_map(model, loader, class_names, device, iou_list=(0.5,), score_min=0.0, plot_pr=True, title_prefix="VALID"):
    K = len(class_names)
    preds_by_cls, gts_by_cls = _collect_predictions_and_gts(model, loader, device, K, score_min=score_min)

    aps_per_iou = []
    pr_cache = {}  # para el primer IoU (plot)

    for iou in iou_list:
        ap_classes = []
        for cls_id in range(1, K+1):
            precision, recall, ap, tps, fps, total_gts = _pr_curve_for_class(preds_by_cls[cls_id], gts_by_cls[cls_id], iou_thresh=iou)
            ap_classes.append(ap)
            if iou == iou_list[0]:  # cachear para plot
                pr_cache[cls_id] = (precision, recall, ap, tps, fps, total_gts)

        mAP = float(np.mean(ap_classes)) if len(ap_classes) else 0.0
        aps_per_iou.append((iou, ap_classes, mAP))

    # Plot P-R (solo para el primer IoU)
    if plot_pr:
        cols = 2
        rows = int(np.ceil(K / cols))
        fig, axes = plt.subplots(rows, cols, figsize=(10, 4*rows), squeeze=False)
        i = 0
        for r in range(rows):
            for c in range(cols):
                ax = axes[r][c]
                i += 1
                if i <= K:
                    P, R, APc, TPc, FPc, GTc = pr_cache[i]
                    ax.plot(R, P)
                    ax.set_title(f"{class_names[i-1]} | AP@{iou_list[0]:.2f}={APc:.3f} | TP={TPc} FP={FPc} GT={GTc}")
                    ax.set_xlabel("Recall")
                    ax.set_ylabel("Precision")
                    ax.set_xlim(0, 1)
                    ax.set_ylim(0, 1)
                else:
                    ax.axis("off")
        plt.suptitle(f"Precision-Recall por clase ({title_prefix}, IoU={iou_list[0]:.2f})")
        plt.tight_layout()
        plt.show()

    # Reporte numérico
    for iou, ap_classes, mAP in aps_per_iou:
        print(f"\n=== Resultados AP/mAP @ IoU={iou:.2f} ({title_prefix}) ===")
        for ci, ap in enumerate(ap_classes, start=1):
            print(f"  {class_names[ci-1]:20s}: AP={ap:.3f}")
        print(f"  mAP@{iou:.2f}: {mAP:.3f}")

    return aps_per_iou  # lista de (iou, [AP_cls], mAP)

# Ejecutar en VALID
# mAP@0.5
aps_valid_05 = compute_map(model, valid_dl, CLASS_NAMES, device, iou_list=(0.5,), score_min=0.0, plot_pr=True, title_prefix="VALID")
# mAP@[0.5:0.95] (COCO)
iou_grid = tuple(np.round(np.arange(0.5, 0.96, 0.05), 2))
aps_valid_COCO = compute_map(model, valid_dl, CLASS_NAMES, device, iou_list=iou_grid, score_min=0.0, plot_pr=False, title_prefix="VALID")

# Ejecutar en TEST
aps_test_05 = compute_map(model, test_dl, CLASS_NAMES, device, iou_list=(0.5,), score_min=0.0, plot_pr=True, title_prefix="TEST")
aps_test_COCO = compute_map(model, test_dl, CLASS_NAMES, device, iou_list=iou_grid, score_min=0.0, plot_pr=False, title_prefix="TEST")
# Out:
# === Resultados AP/mAP @ IoU=0.50 (VALID) ===
#   Tijera              : AP=0.973
#   Navaja              : AP=0.913
#   Cuchillo            : AP=0.747
#   Cutter              : AP=0.827
#   Navaja multiuso     : AP=0.944
#   mAP@0.50: 0.881
#
# === Resultados AP/mAP @ IoU=0.50 (VALID) ===
#   Tijera              : AP=0.973
#   Navaja              : AP=0.913
#   Cuchillo            : AP=0.747
#   Cutter              : AP=0.827
#   Navaja multiuso     : AP=0.944
#   mAP@0.50: 0.881
#
# === Resultados AP/mAP @ IoU=0.55 (VALID) ===
#   Tijera              : AP=0.949
#   Navaja              : AP=0.860
#   Cuchillo            : AP=0.669
#   Cutter              : AP=0.797
#   Navaja multiuso     : AP=0.903
#   mAP@0.55: 0.836
#
# === Resultados AP/mAP @ IoU=0.60 (VALID) ===
#   Tijera              : AP=0.904
#   Navaja              : AP=0.799
#   Cuchillo            : AP=0.510
#   Cutter              : AP=0.745
#   Navaja multiuso     : AP=0.824
#   mAP@0.60: 0.756
#
# === Resultados AP/mAP @ IoU=0.65 (VALID) ===
#   Tijera              : AP=0.809
#   Navaja              : AP=0.681
#   Cuchillo            : AP=0.417
#   Cutter              : AP=0.651
#   Navaja multiuso     : AP=0.675
#   mAP@0.65: 0.647
#
# === Resultados AP/mAP @ IoU=0.70 (VALID) ===
#   Tijera              : AP=0.666
#   Navaja              : AP=0.507
#   Cuchillo            : AP=0.268
#   Cutter              : AP=0.482
#   Navaja multiuso     : AP=0.482
#   mAP@0.70: 0.481
#
# === Resultados AP/mAP @ IoU=0.75 (VALID) ===
#   Tijera              : AP=0.440
#   Navaja              : AP=0.255
#   Cuchillo            : AP=0.104
#   Cutter              : AP=0.305
#   Navaja multiuso     : AP=0.258
#   mAP@0.75: 0.272
#
# === Resultados AP/mAP @ IoU=0.80 (VALID) ===
#   Tijera              : AP=0.184
#   Navaja              : AP=0.105
#   Cuchillo            : AP=0.020
#   Cutter              : AP=0.143
#   Navaja multiuso     : AP=0.089
#   mAP@0.80: 0.108
#
# === Resultados AP/mAP @ IoU=0.85 (VALID) ===
#   Tijera              : AP=0.050
#   Navaja              : AP=0.018
#   Cuchillo            : AP=0.004
#   Cutter              : AP=0.029
#   Navaja multiuso     : AP=0.020
#   mAP@0.85: 0.024
#
# === Resultados AP/mAP @ IoU=0.90 (VALID) ===
#   Tijera              : AP=0.003
#   Navaja              : AP=0.001
#   Cuchillo            : AP=0.000
#   Cutter              : AP=0.005
#   Navaja multiuso     : AP=0.001
#   mAP@0.90: 0.002
#
# === Resultados AP/mAP @ IoU=0.95 (VALID) ===
#   Tijera              : AP=0.000
#   Navaja              : AP=0.000
#   Cuchillo            : AP=0.000
#   Cutter              : AP=0.000
#   Navaja multiuso     : AP=0.000
#   mAP@0.95: 0.000
# === Resultados AP/mAP @ IoU=0.50 (TEST) ===
#   Tijera              : AP=0.973
#   Navaja              : AP=0.887
#   Cuchillo            : AP=0.818
#   Cutter              : AP=0.870
#   Navaja multiuso     : AP=0.929
#   mAP@0.50: 0.895
#
# === Resultados AP/mAP @ IoU=0.50 (TEST) ===
#   Tijera              : AP=0.973
#   Navaja              : AP=0.887
#   Cuchillo            : AP=0.818
#   Cutter              : AP=0.870
#   Navaja multiuso     : AP=0.929
#   mAP@0.50: 0.895
#
# === Resultados AP/mAP @ IoU=0.55 (TEST) ===
#   Tijera              : AP=0.953
#   Navaja              : AP=0.879
#   Cuchillo            : AP=0.779
#   Cutter              : AP=0.824
#   Navaja multiuso     : AP=0.887
#   mAP@0.55: 0.864
#
# === Resultados AP/mAP @ IoU=0.60 (TEST) ===
#   Tijera              : AP=0.937
#   Navaja              : AP=0.821
#   Cuchillo            : AP=0.705
#   Cutter              : AP=0.766
#   Navaja multiuso     : AP=0.839
#   mAP@0.60: 0.814
#
# === Resultados AP/mAP @ IoU=0.65 (TEST) ===
#   Tijera              : AP=0.836
#   Navaja              : AP=0.747
#   Cuchillo            : AP=0.552
#   Cutter              : AP=0.660
#   Navaja multiuso     : AP=0.784
#   mAP@0.65: 0.716
#
# === Resultados AP/mAP @ IoU=0.70 (TEST) ===
#   Tijera              : AP=0.674
#   Navaja              : AP=0.554
#   Cuchillo            : AP=0.385
#   Cutter              : AP=0.514
#   Navaja multiuso     : AP=0.580
#   mAP@0.70: 0.541
#
# === Resultados AP/mAP @ IoU=0.75 (TEST) ===
#   Tijera              : AP=0.494
#   Navaja              : AP=0.290
#   Cuchillo            : AP=0.181
#   Cutter              : AP=0.309
#   Navaja multiuso     : AP=0.329
#   mAP@0.75: 0.321
#
# === Resultados AP/mAP @ IoU=0.80 (TEST) ===
#   Tijera              : AP=0.200
#   Navaja              : AP=0.082
#   Cuchillo            : AP=0.063
#   Cutter              : AP=0.117
#   Navaja multiuso     : AP=0.108
#   mAP@0.80: 0.114
#
# === Resultados AP/mAP @ IoU=0.85 (TEST) ===
#   Tijera              : AP=0.055
#   Navaja              : AP=0.019
#   Cuchillo            : AP=0.006
#   Cutter              : AP=0.032
#   Navaja multiuso     : AP=0.022
#   mAP@0.85: 0.027
#
# === Resultados AP/mAP @ IoU=0.90 (TEST) ===
#   Tijera              : AP=0.006
#   Navaja              : AP=0.004
#   Cuchillo            : AP=0.001
#   Cutter              : AP=0.003
#   Navaja multiuso     : AP=0.002
#   mAP@0.90: 0.003
#
# === Resultados AP/mAP @ IoU=0.95 (TEST) ===
#   Tijera              : AP=0.000
#   Navaja              : AP=0.000
#   Cuchillo            : AP=0.000
#   Cutter              : AP=0.001
#   Navaja multiuso     : AP=0.000
#   mAP@0.95: 0.000

# %%
print(f"Tiempo preparación curvas: {datetime.datetime.now() - INICIO_STEP}")
INICIO_STEP = datetime.datetime.now()
# Out:
# Tiempo preparación curvas: 0:01:43.048836

# %%
# ---------------------------------------
# 14) Barrido de umbral de score → Macro-F1 vs. score (en VALID)
# ---------------------------------------

@torch.no_grad()
def evaluate_prf1(model, loader, device, class_names, score_thresh=0.5, iou_thresh=0.5):
    model.eval()
    K = len(class_names)
    TP = np.zeros(K+1, dtype=np.int64)
    FP = np.zeros(K+1, dtype=np.int64)
    FN = np.zeros(K+1, dtype=np.int64)

    for imgs, targets in loader:
        imgs = [img.to(device) for img in imgs]
        outs = model(imgs)

        for out, tgt in zip(outs, targets):
            gt_boxes = tgt["boxes"].cpu()
            gt_labels = tgt["labels"].cpu()  # 1..K

            keep = out["scores"].cpu() >= score_thresh
            pred_boxes = out["boxes"][keep].cpu()
            pred_labels = out["labels"][keep].cpu()  # 1..K
            pred_scores = out["scores"][keep].cpu()

            if len(gt_boxes) == 0 and len(pred_boxes) == 0:
                continue

            ious = box_iou(pred_boxes, gt_boxes) if (len(pred_boxes)>0 and len(gt_boxes)>0) else torch.zeros((len(pred_boxes), len(gt_boxes)))

            matched_gt = set()
            matched_pred = set()

            # greedy por score desc, y match por clase + IoU
            order = torch.argsort(pred_scores, descending=True).cpu().numpy()
            for pi in order:
                best_j, best_iou = -1, 0.0
                for gj in range(len(gt_boxes)):
                    if gj in matched_gt:
                        continue
                    if pred_labels[pi].item() != gt_labels[gj].item():
                        continue
                    iou_val = float(ious[pi, gj].item())
                    if iou_val >= iou_thresh and iou_val > best_iou:
                        best_iou, best_j = iou_val, gj
                if best_j >= 0:
                    cls = int(pred_labels[pi].item())
                    TP[cls] += 1
                    matched_pred.add(pi)
                    matched_gt.add(best_j)

            for pi in range(len(pred_boxes)):
                if pi not in matched_pred:
                    cls = int(pred_labels[pi].item())
                    FP[cls] += 1

            for gj in range(len(gt_boxes)):
                if gj not in matched_gt:
                    cls = int(gt_labels[gj].item())
                    FN[cls] += 1

    results = []
    for cls in range(1, K+1):
        tp, fp, fn = TP[cls], FP[cls], FN[cls]
        prec = tp/(tp+fp) if (tp+fp)>0 else 0.0
        rec  = tp/(tp+fn) if (tp+fn)>0 else 0.0
        f1   = 2*prec*rec/(prec+rec) if (prec+rec)>0 else 0.0
        results.append((class_names[cls-1], tp, fp, fn, prec, rec, f1))

    macro_prec = float(np.mean([r[4] for r in results])) if results else 0.0
    macro_rec  = float(np.mean([r[5] for r in results])) if results else 0.0
    macro_f1   = float(np.mean([r[6] for r in results])) if results else 0.0

    return {"per_class": results, "macro": {"precision": macro_prec, "recall": macro_rec, "f1": macro_f1}}


def sweep_threshold_macro_f1(model, loader, device, class_names,
                             iou_thresh=0.5,
                             scores=np.linspace(0.05, 0.95, 19)):
    model.eval()
    macro_f1 = []
    for s in scores:
        out = evaluate_prf1(model, loader, device, class_names,
                            score_thresh=float(s), iou_thresh=float(iou_thresh))
        macro_f1.append(out["macro"]["f1"])
    macro_f1 = np.array(macro_f1, dtype=float)

    # Mejor umbral
    best_idx = int(np.argmax(macro_f1))
    best_score = float(scores[best_idx])
    best_macro_f1 = float(macro_f1[best_idx])

    # Print detallado
    print(f"\n=== Barrido de umbral (VALID, IoU={iou_thresh:.2f}) ===")
    for s, f in zip(scores, macro_f1):
        print(f"  score={s:>4.2f}  →  Macro-F1={f:0.3f}")
    print(f"\nMejor umbral: score={best_score:.2f}  →  Macro-F1={best_macro_f1:.3f}")

    # Plot
    plt.figure(figsize=(6,4))
    plt.plot(scores, macro_f1, marker='o')
    plt.title(f"VALID | Macro-F1 vs. score (IoU={iou_thresh:.2f})")
    plt.xlabel("score threshold")
    plt.ylabel("Macro-F1")
    plt.grid(True, linestyle="--", alpha=0.4)
    plt.tight_layout()
    plt.show()

    return {
        "scores": scores.tolist(),
        "macro_f1": macro_f1.tolist(),
        "best_score": best_score,
        "best_macro_f1": best_macro_f1
    }

# Ejecutar barrido en VALID
score_sweep_valid = sweep_threshold_macro_f1(model, valid_dl, device, CLASS_NAMES, iou_thresh=0.5)

if 'payload' in globals():
    payload.setdefault("results", {}).setdefault("valid", {})
    payload["results"]["valid"]["score_sweep"] = {
        "scores": score_sweep_valid["scores"],
        "macro_f1": score_sweep_valid["macro_f1"],
        "best_score": score_sweep_valid["best_score"],
        "best_macro_f1": score_sweep_valid["best_macro_f1"],
        "iou": 0.5
    }
    print("[OK] Barrido de umbral agregado al payload de métricas (VALID).")

# Usar el mejor umbral para inferencia/validación rápida:
BEST_SCORE_FOR_INFERENCE = score_sweep_valid["best_score"]
print(f"BEST_SCORE_FOR_INFERENCE = {BEST_SCORE_FOR_INFERENCE:.2f}")
# Out:
# === Barrido de umbral (VALID, IoU=0.50) ===
#   score=0.05  →  Macro-F1=0.503
#   score=0.10  →  Macro-F1=0.603
#   score=0.15  →  Macro-F1=0.669
#   score=0.20  →  Macro-F1=0.712
#   score=0.25  →  Macro-F1=0.744
#   score=0.30  →  Macro-F1=0.768
#   score=0.35  →  Macro-F1=0.783
#   score=0.40  →  Macro-F1=0.798
#   score=0.45  →  Macro-F1=0.811
#   score=0.50  →  Macro-F1=0.822
#   score=0.55  →  Macro-F1=0.829
#   score=0.60  →  Macro-F1=0.836
#   score=0.65  →  Macro-F1=0.842
#   score=0.70  →  Macro-F1=0.842
#   score=0.75  →  Macro-F1=0.845
#   score=0.80  →  Macro-F1=0.847
#   score=0.85  →  Macro-F1=0.846
#   score=0.90  →  Macro-F1=0.840
#   score=0.95  →  Macro-F1=0.812
#
# Mejor umbral: score=0.80  →  Macro-F1=0.847
# [OK] Barrido de umbral agregado al payload de métricas (VALID).
# BEST_SCORE_FOR_INFERENCE = 0.80

# %%
print(f"Tiempo preparación barrido umbral: {datetime.datetime.now() - INICIO_STEP}")
INICIO_STEP = datetime.datetime.now()
# Out:
# Tiempo preparación barrido umbral: 0:10:19.778947

# %%
print(f"Tiempo total ejecución: {datetime.datetime.now() - INICIO_EJECUCION}")
# Out:
# Tiempo total ejecución: 1:11:42.081860

# %% [markdown]
# ---

# %% [markdown]
# TODO:JA Summary de los resultados. Inetrpretacion de los resultados. Comparación con los resultados de la corrida anterior.

# %% [markdown]
# ---
