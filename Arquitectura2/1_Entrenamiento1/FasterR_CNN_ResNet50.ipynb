# %% [markdown]
# ### Faster R-CNN (ResNet50-FPN) ###
#
# Notebook diseñada para ejecutarse en Google Colab con aceleración GPU.

# %% [markdown]
# ---

# %% [markdown]
# TODO:JA Descripción de los parámetros y caracteristicas del modelo de esta corrida. Comparar con la corrida anterior

# %% [markdown]
# ---

# %%
# Montamos un google drive para guardar los resultados y el modelo entrenado.
from google.colab import drive
drive.mount('/content/drive')

BASE_DIR = "/content/drive/MyDrive/UBA/CEIA/Materias/Visión por Computadora II/google_colab_data/FasterR-CNN-ResNet50_notebook" # Setear el path Google Drive deseado
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %pip install gdown --quiet
# %pip install torch --quiet
# %pip install torchvision --quiet
# %pip install matplotlib --quiet
# %pip install pandas --quiet
# %pip install pillow --quiet
# %pip install numpy --quiet
# %pip install matplotlib --quiet
# %pip install torchmetrics --quiet

# %%
import os
import zipfile
import gdown
import shutil
import glob
import torch
import torchvision
import numpy as np
from collections import Counter
from PIL import Image
import random
import matplotlib.pyplot as plt
from torchvision.ops import box_convert
import matplotlib.patches as patches
import pandas as pd
from torch.utils.data import WeightedRandomSampler
import time
import math
from typing import List, Dict, Tuple, Any
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision
from torchvision.ops import box_iou
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
import torchvision.transforms as T
import datetime
import json
from torchmetrics.detection.mean_ap import MeanAveragePrecision

# %%
# Reproducibilidad
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

# %%
INICIO_EJECUCION = datetime.datetime.now()
INICIO_STEP = datetime.datetime.now()

# %%
# ---------------------------------------
# 1) Descargar dataset
# ---------------------------------------

DATA_DIR = os.path.join(BASE_DIR, "data")

def descargar_dataset(data_dir):

  # Verificar si exsite la carpeta
  if not os.path.exists(data_dir):

    try:
      # Nombre del archivo ZIP que se va a guardar
      ZIP_NAME = "kaggle-xray_baggage_scanner_anomaly_detection.zip"
      zip_path = os.path.join(data_dir, ZIP_NAME)

      # Crear carpeta data
      os.makedirs(data_dir, exist_ok=True)

      # Descargar el ZIP
      print("Descargando archivo zip ...")
      # Lo tomamos de Google Drive porque Kaggle requeire autenticación
      gdown.download(id="1IqPblTm7nmKFpHXtl4beopE_SajTBoI0", output=zip_path, quiet=False)
      print("Archivo zip descargado.")

      # Descomprimir el ZIP
      print("Descomprimiendo archivo ...")
      with zipfile.ZipFile(zip_path, "r") as zf:
          zf.extractall(data_dir)
      print("Archivo descomprimido.")
    except:
      # En caso de error, eliminar la carpeta creada
      shutil.rmtree(data_dir, ignore_errors=True)
      print("Ocurrió un error al descargar el dataset.")

  print(f"Dataset descargado en: '{data_dir}'")


# Descargar el dataset (solo si no existe la carpeta data)
descargar_dataset(DATA_DIR)
# Out:
# Dataset descargado en: '/content/drive/MyDrive/UBA/CEIA/Materias/Visión por Computadora II/google_colab_data/FasterR-CNN-ResNet50_notebook/data'

# %%
print(f"Tiempo descarga dataset: {datetime.datetime.now() - INICIO_STEP}")
INICIO_STEP = datetime.datetime.now()
# Out:
# Tiempo descarga dataset: 0:00:00.012243

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")
# Out:
# Device: cuda

# %%
# ---------------------------------------
# 2) Configuración de rutas y clases
# ---------------------------------------

CLASS_NAMES = ["Tijera", "Navaja", "Cuchillo", "Cutter", "Navaja multiuso"]
NUM_CLASSES = len(CLASS_NAMES)
NUM_CLASSES_WITH_BG = NUM_CLASSES + 1  # +1 background para Faster R-CNN

# Paths estándar de YOLO
SPLITS = {
    "train": {"images": os.path.join(DATA_DIR, "train", "images"),
              "labels": os.path.join(DATA_DIR, "train", "labels")},
    "valid": {"images": os.path.join(DATA_DIR, "valid", "images"),
              "labels": os.path.join(DATA_DIR, "valid", "labels")},
    "test":  {"images": os.path.join(DATA_DIR, "test",  "images"),
              "labels": os.path.join(DATA_DIR, "test",  "labels")},
}

# %%
# ---------------------------------------
# 3) Dataset: De YOLO a torchvision detection
# ---------------------------------------
class YoloDetectionDataset(Dataset):
    def __init__(self, images_dir, labels_dir, transforms=None):
        self.images = sorted(glob.glob(os.path.join(images_dir, "*")))
        self.labels_dir = labels_dir
        self.transforms = transforms

    def __len__(self):
        return len(self.images)

    def _read_yolo_txt(self, label_path):
        boxes_cxcywh = []
        labels = []
        if not os.path.exists(label_path):
            # Si no existe el .txt, interpretamos como imagen sin objetos
            return torch.zeros((0,4), dtype=torch.float32), torch.zeros((0,), dtype=torch.int64)
        with open(label_path, "r") as f:
            lines = [ln.strip() for ln in f.readlines() if ln.strip()]
        if not lines:
            return torch.zeros((0,4), dtype=torch.float32), torch.zeros((0,), dtype=torch.int64)
        for ln in lines:
            parts = ln.split()
            if len(parts) != 5:
                # Línea malformada -> ignorarmos
                continue
            c, cx, cy, w, h = parts
            labels.append(int(c))
            boxes_cxcywh.append([float(cx), float(cy), float(w), float(h)])
        if len(boxes_cxcywh) == 0:
            return torch.zeros((0,4), dtype=torch.float32), torch.zeros((0,), dtype=torch.int64)
        return torch.tensor(boxes_cxcywh, dtype=torch.float32), torch.tensor(labels, dtype=torch.int64)

    def __getitem__(self, idx):
        img_path = self.images[idx]
        img = Image.open(img_path).convert("RGB")
        W, H = img.size

        base = os.path.splitext(os.path.basename(img_path))[0]
        lbl_path = os.path.join(self.labels_dir, base + ".txt")
        boxes_cxcywh_norm, labels0 = self._read_yolo_txt(lbl_path)

        # Desnormalizar y convertir a xyxy en píxeles
        if boxes_cxcywh_norm.numel() > 0:
            scale = torch.tensor([W, H, W, H], dtype=torch.float32)
            boxes_cxcywh_px = boxes_cxcywh_norm * scale
            boxes_xyxy = box_convert(boxes_cxcywh_px, in_fmt="cxcywh", out_fmt="xyxy")
            # clamp por seguridad
            boxes_xyxy[:, [0,2]] = boxes_xyxy[:, [0,2]].clamp(0, W)
            boxes_xyxy[:, [1,3]] = boxes_xyxy[:, [1,3]].clamp(0, H)
        else:
            boxes_xyxy = torch.zeros((0,4), dtype=torch.float32)

        labels = labels0 + 1 if labels0.numel() > 0 else torch.zeros((0,), dtype=torch.int64)

        target = {
            "boxes": boxes_xyxy,
            "labels": labels,
            "image_id": torch.tensor([idx]),
            "area": ((boxes_xyxy[:,2]-boxes_xyxy[:,0]) * (boxes_xyxy[:,3]-boxes_xyxy[:,1])) if boxes_xyxy.numel() else torch.tensor([], dtype=torch.float32),
            "iscrowd": torch.zeros((len(labels),), dtype=torch.int64),
        }

        if self.transforms:
            img = self.transforms(img)

        return img, target

def collate_fn(batch):
    imgs, targets = list(zip(*batch))
    return list(imgs), list(targets)

# %%
# ---------------------------------------
# 4) Transforms y DataLoaders
# ---------------------------------------
train_tfms = T.Compose([T.ToTensor()])
test_tfms  = T.Compose([T.ToTensor()])

train_ds = YoloDetectionDataset(SPLITS["train"]["images"], SPLITS["train"]["labels"], transforms=train_tfms)
valid_ds = YoloDetectionDataset(SPLITS["valid"]["images"], SPLITS["valid"]["labels"], transforms=test_tfms)
test_ds  = YoloDetectionDataset(SPLITS["test"]["images"],  SPLITS["test"]["labels"],  transforms=test_tfms)

BATCH_SIZE = 4  # Ajustar según VRAM
NUM_WORKERS = 2

train_dl = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True,  num_workers=NUM_WORKERS, collate_fn=collate_fn)
valid_dl = DataLoader(valid_ds, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS, collate_fn=collate_fn)
test_dl  = DataLoader(test_ds,  batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS, collate_fn=collate_fn)

print(f"train: {len(train_ds)} imgs | valid: {len(valid_ds)} | test: {len(test_ds)}")
# Out:
# train: 6181 imgs | valid: 1766 | test: 883

# %%
print(f"Tiempo preparación dataset y dataloaders: {datetime.datetime.now() - INICIO_STEP}")
INICIO_STEP = datetime.datetime.now()
# Out:
# Tiempo preparación dataset y dataloaders: 0:00:00.284996

# %%
# ---------------------------------------
# 5) Modelo: Faster R-CNN (ResNet50-FPN preentrenado COCO)
# ---------------------------------------
def get_fasterrcnn_model(num_classes_with_bg: int):
    model = torchvision.models.detection.fasterrcnn_resnet50_fpn(weights="DEFAULT")  # COCO-pretrained
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes_with_bg)
    return model

model = get_fasterrcnn_model(NUM_CLASSES_WITH_BG).to(device)

# %%
# ---------------------------------------
# 6) Optimizador y scheduler
# ---------------------------------------
params = [p for p in model.parameters() if p.requires_grad]
LR = 5e-3
optimizer = optim.SGD(params, lr=LR, momentum=0.9, weight_decay=5e-4)
lr_sched = optim.lr_scheduler.StepLR(optimizer, step_size=5, gamma=0.1)

# %%
print(f"Tiempo preparación modelo, optimizor y scheduler: {datetime.datetime.now() - INICIO_STEP}")
INICIO_STEP = datetime.datetime.now()
# Out:
# Tiempo preparación modelo, optimizor y scheduler: 0:00:00.846252

# %%
EPOCHS = 20 # Setear epochs según corresponda

# ---------------------------------------
# 7) Entrenar y evaluar el modelo
# ---------------------------------------

def _loss_dict_to_scalars(loss_dict: Dict[str, torch.Tensor]) -> Dict[str, float]:
    # torchvision devuelve tensores escalares
    out = {
        "loss_classifier": float(loss_dict.get("loss_classifier", torch.tensor(0.0)).item()),
        "loss_box_reg": float(loss_dict.get("loss_box_reg", torch.tensor(0.0)).item()),
        "loss_objectness": float(loss_dict.get("loss_objectness", torch.tensor(0.0)).item()),
        "loss_rpn_box_reg": float(loss_dict.get("loss_rpn_box_reg", torch.tensor(0.0)).item()),
    }
    out["loss_total"] = out["loss_classifier"] + out["loss_box_reg"] + out["loss_objectness"] + out["loss_rpn_box_reg"]
    return out


def _avg_dicts(dicts: List[Dict[str, float]]) -> Dict[str, float]:
    if not dicts:
        return {}
    keys = dicts[0].keys()
    return {k: float(np.mean([d[k] for d in dicts])) for k in keys}


def fbeta(prec: float, rec: float, beta: float = 2.0) -> float:
    if prec + rec == 0:
        return 0.0
    b2 = beta * beta
    return (1 + b2) * (prec * rec) / (b2 * prec + rec)


def train_one_epoch(
    model,
    loader,
    optimizer,
    device,
    log_every: int = 50,
) -> Dict[str, float]:
    model.train()

    batch_losses = []
    batch_times = []
    start_t = time.time()

    for bi, (imgs, targets) in enumerate(loader, start=1):
        imgs = [img.to(device) for img in imgs]
        tgts = [{k: v.to(device) for k, v in t.items()} for t in targets]

        loss_dict = model(imgs, tgts)
        loss = sum(v for v in loss_dict.values())

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # timing/log
        bt = time.time() - start_t
        batch_times.append(bt)
        start_t = time.time()

        loss_scalars = _loss_dict_to_scalars(loss_dict)
        batch_losses.append(loss_scalars)

        if (bi % log_every == 0) or (bi == len(loader)):
            avg_loss_running = float(np.mean([d["loss_total"] for d in batch_losses[-50:]]))
            avg_bt = float(np.mean(batch_times[-50:])) if batch_times else 0.0
            eta_sec = max(0.0, (len(loader) - bi) * avg_bt)
            cur_lr = optimizer.param_groups[0]["lr"]

            imgs_per_sec = (len(imgs) / bt) if bt > 0 else 0.0
            gpu_mem = None
            if torch.cuda.is_available():
                torch.cuda.synchronize()
                gpu_mem = torch.cuda.max_memory_allocated() / (1024**2)  # MiB

            msg = (f"[batch {bi:4d}/{len(loader)}] "
                   f"loss(b)={loss_scalars['loss_total']:.4f} | loss(µ50)={avg_loss_running:.4f} | "
                   f"lr={cur_lr:.3g} | {imgs_per_sec:.1f} img/s | "
                   f"ETA~{int(eta_sec//60)}m{int(eta_sec%60)}s")
            if gpu_mem is not None:
                msg += f" | GPU~{gpu_mem:.0f} MiB"
            print(msg)

    return _avg_dicts(batch_losses)


EVAL_LOG_EVERY = 50
SCORE_THRESH = 0.5
IOU_THRESH   = 0.5


@torch.no_grad()
def compute_losses_no_grad(model, loader, device, log_every: int = 50):
    was_training = model.training
    model.train()

    batch_losses = []
    t0 = time.time()
    for bi, (imgs, targets) in enumerate(loader, start=1):
        imgs = [img.to(device) for img in imgs]
        tgts = [{k: v.to(device) for k, v in t.items()} for t in targets]

        loss_dict = model(imgs, tgts)
        loss_scalars = _loss_dict_to_scalars(loss_dict)
        batch_losses.append(loss_scalars)

        if bi % log_every == 0 or bi == len(loader):
            dt = time.time() - t0
            print(f"[val_loss {bi:4d}/{len(loader)}] loss={loss_scalars['loss_total']:.4f} | {bi/dt:.2f} it/s")

    if not was_training:
        model.eval()
    return _avg_dicts(batch_losses)


@torch.no_grad()
def evaluate_prf1_f2(model, loader, device, class_names, score_thresh=0.5, iou_thresh=0.5, log_every: int = 50):
    model.eval()

    K = len(class_names)
    TP = np.zeros(K + 1, dtype=np.int64)
    FP = np.zeros(K + 1, dtype=np.int64)
    FN = np.zeros(K + 1, dtype=np.int64)

    t0 = time.time()
    for bi, (imgs, targets) in enumerate(loader, start=1):
        imgs = [img.to(device) for img in imgs]
        outputs = model(imgs)

        for out, tgt in zip(outputs, targets):
            gt_boxes = tgt["boxes"].cpu()
            gt_labels = tgt["labels"].cpu()

            keep = out["scores"].cpu() >= score_thresh
            pred_boxes = out["boxes"].cpu()[keep]
            pred_labels = out["labels"].cpu()[keep]
            pred_scores = out["scores"].cpu()[keep]

            if len(gt_boxes) == 0 and len(pred_boxes) == 0:
                continue

            ious = box_iou(pred_boxes, gt_boxes) if (len(pred_boxes) > 0 and len(gt_boxes) > 0) else torch.zeros((len(pred_boxes), len(gt_boxes)))
            matched_gt, matched_pred = set(), set()

            order = torch.argsort(pred_scores, descending=True).cpu().numpy()
            for pi in order:
                best_j, best_iou = -1, 0.0
                for gj in range(len(gt_boxes)):
                    if gj in matched_gt:
                        continue
                    if pred_labels[pi].item() != gt_labels[gj].item():
                        continue
                    iou_val = float(ious[pi, gj].item())
                    if iou_val >= iou_thresh and iou_val > best_iou:
                        best_iou, best_j = iou_val, gj
                if best_j >= 0:
                    cls = int(pred_labels[pi].item())
                    TP[cls] += 1
                    matched_pred.add(pi)
                    matched_gt.add(best_j)

            for pi in range(len(pred_boxes)):
                if pi not in matched_pred:
                    cls = int(pred_labels[pi].item())
                    FP[cls] += 1

            for gj in range(len(gt_boxes)):
                if gj not in matched_gt:
                    cls = int(gt_labels[gj].item())
                    FN[cls] += 1

        if bi % log_every == 0 or bi == len(loader):
            dt = time.time() - t0
            print(f"[val_prf  {bi:4d}/{len(loader)}] {bi/dt:.2f} it/s | TP={TP.sum()} FP={FP.sum()} FN={FN.sum()}")

    per_class = []
    for cls in range(1, K + 1):
        tp, fp, fn = int(TP[cls]), int(FP[cls]), int(FN[cls])
        prec = tp / (tp + fp) if (tp + fp) > 0 else 0.0
        rec  = tp / (tp + fn) if (tp + fn) > 0 else 0.0
        f1   = 2 * prec * rec / (prec + rec) if (prec + rec) > 0 else 0.0
        f2   = fbeta(prec, rec, beta=2.0)
        per_class.append((class_names[cls - 1], tp, fp, fn, prec, rec, f1, f2))

    macro_prec = float(np.mean([r[4] for r in per_class])) if per_class else 0.0
    macro_rec  = float(np.mean([r[5] for r in per_class])) if per_class else 0.0
    macro_f1   = float(np.mean([r[6] for r in per_class])) if per_class else 0.0
    macro_f2   = float(np.mean([r[7] for r in per_class])) if per_class else 0.0

    return {
        "per_class": per_class,
        "macro": {"precision": macro_prec, "recall": macro_rec, "f1": macro_f1, "f2": macro_f2},
        "raw": {"TP": TP, "FP": FP, "FN": FN},
        "settings": {"score_thresh": score_thresh, "iou_thresh": iou_thresh},
    }



@torch.no_grad()
def evaluate_map_torchmetrics(model, loader, device, include_per_class: bool = True):

    model.eval()
    metric = MeanAveragePrecision(iou_type="bbox", class_metrics=include_per_class)

    for imgs, targets in loader:
        imgs = [img.to(device) for img in imgs]
        outputs = model(imgs)

        preds, gts = [], []
        for out, tgt in zip(outputs, targets):
            preds.append({
                "boxes": out["boxes"].detach().cpu(),
                "scores": out["scores"].detach().cpu(),
                "labels": out["labels"].detach().cpu(),
            })
            gts.append({
                "boxes": tgt["boxes"].detach().cpu(),
                "labels": tgt["labels"].detach().cpu(),
            })
        metric.update(preds, gts)

    res = metric.compute()

    out = {}
    for k, v in res.items():
        if isinstance(v, torch.Tensor):
            if v.ndim == 0:
                out[k] = float(v.item())
            elif include_per_class:
                out[k] = v.detach().cpu().tolist()

    return out

# Loop principal
history = []

for epoch in range(1, EPOCHS + 1):
    print("\n" + "=" * 80)
    print(f"INICIO ÉPOCA {epoch}/{EPOCHS}  |  train_batches: {len(train_dl)}  |  batch_size: {BATCH_SIZE}")
    if torch.cuda.is_available():
        print(f"GPU: {torch.cuda.get_device_name(0)}  |  VRAM total: {torch.cuda.get_device_properties(0).total_memory/(1024**3):.1f} GB")
        torch.cuda.reset_peak_memory_stats()
    print("=" * 80)

    t0 = time.time()

    # Train
    train_losses = train_one_epoch(model, train_dl, optimizer, device, log_every=50)
    print("FIN TRAIN ")

    # Valid
    valid_losses = None
    valid_pr = None
    valid_map = None

    print(f"INICIO val_loss (batches={len(valid_dl)}) ...")
    tv = time.time()
    valid_losses = compute_losses_no_grad(model, valid_dl, device, log_every=EVAL_LOG_EVERY)
    print(f"FIN val_loss  ({(time.time()-tv)/60:.1f} min)")

    print(f"INICIO val_prf (batches={len(valid_dl)}) ...")
    tv = time.time()
    valid_pr = evaluate_prf1_f2(model, valid_dl, device, CLASS_NAMES, score_thresh=SCORE_THRESH, iou_thresh=IOU_THRESH, log_every=EVAL_LOG_EVERY)
    print(f"FIN val_prf  ({(time.time()-tv)/60:.1f} min)")

    print(f"INICIO val_mAP (batches={len(valid_dl)}) ...")
    tv = time.time()
    valid_map = evaluate_map_torchmetrics(model, valid_dl, device)
    print(f"FIN val_mAP  ({(time.time()-tv)/60:.1f} min)")

    # Scheduler
    lr_sched.step()
    cur_lr = optimizer.param_groups[0]["lr"]

    dt = time.time() - t0
    msg = f"[RESUMEN ÉPOCA {epoch:02d}] lr→{cur_lr:.3g} | dur={dt/60:.1f} min | train_loss={train_losses['loss_total']:.4f}"
    if valid_losses is not None:
        msg += f" | val_loss={valid_losses['loss_total']:.4f}"
    if valid_pr is not None:
        msg += f" | val_rec={valid_pr['macro']['recall']:.3f} | val_f2={valid_pr['macro']['f2']:.3f}"
    if valid_map is not None:
        msg += f" | val_mAP50={valid_map['map_50']:.3f} | val_mAP={valid_map['map']:.3f}"
    print(msg)

    history.append({
        "epoch": epoch,
        "lr": float(cur_lr),
        "train": train_losses,
        "valid": valid_losses,
        "valid_macro": None if valid_pr is None else valid_pr["macro"],
        "valid_per_class": None if valid_pr is None else valid_pr["per_class"],
        "valid_map": valid_map,
        "settings": {"score_thresh": SCORE_THRESH, "iou_thresh": IOU_THRESH},
        "duration_sec": float(dt),
    })
# Out:
# ================================================================================
# INICIO ÉPOCA 1/20  |  train_batches: 1546  |  batch_size: 4
# GPU: NVIDIA A100-SXM4-40GB  |  VRAM total: 39.6 GB
# ================================================================================
# [batch   50/1546] loss(b)=0.2384 | loss(µ50)=0.3167 | lr=0.005 | 30.8 img/s | ETA~24m17s | GPU~2823 MiB
# [batch  100/1546] loss(b)=0.2437 | loss(µ50)=0.2348 | lr=0.005 | 30.5 img/s | ETA~3m9s | GPU~2823 MiB
# [batch  150/1546] loss(b)=0.2458 | loss(µ50)=0.2415 | lr=0.005 | 30.6 img/s | ETA~3m2s | GPU~2823 MiB
# [batch  200/1546] loss(b)=0.2362 | loss(µ50)=0.2376 | lr=0.005 | 31.4 img/s | ETA~2m57s | GPU~2824 MiB
# [batch  250/1546] loss(b)=0.1567 | loss(µ50)=0.2306 | lr=0.005 | 30.5 img/s | ETA~2m48s | GPU~2824 MiB
# [batch  300/1546] loss(b)=0.1965 | loss(µ50)=0.2108 | lr=0.005 | 30.5 img/s | ETA~2m44s | GPU~2824 MiB
# [batch  350/1546] loss(b)=0.2390 | loss(µ50)=0.2054 | lr=0.005 | 29.7 img/s | ETA~2m37s | GPU~2824 MiB
# [batch  400/1546] loss(b)=0.1424 | loss(µ50)=0.1941 | lr=0.005 | 30.8 img/s | ETA~2m30s | GPU~2824 MiB
# [batch  450/1546] loss(b)=0.1675 | loss(µ50)=0.1903 | lr=0.005 | 30.5 img/s | ETA~2m24s | GPU~2824 MiB
# [batch  500/1546] loss(b)=0.1782 | loss(µ50)=0.1805 | lr=0.005 | 31.0 img/s | ETA~2m16s | GPU~2824 MiB
# [batch  550/1546] loss(b)=0.1698 | loss(µ50)=0.1771 | lr=0.005 | 30.3 img/s | ETA~2m11s | GPU~2824 MiB
# [batch  600/1546] loss(b)=0.2069 | loss(µ50)=0.1810 | lr=0.005 | 31.0 img/s | ETA~2m4s | GPU~2824 MiB
# [batch  650/1546] loss(b)=0.2124 | loss(µ50)=0.1978 | lr=0.005 | 30.6 img/s | ETA~1m57s | GPU~2824 MiB
# [batch  700/1546] loss(b)=0.2124 | loss(µ50)=0.1885 | lr=0.005 | 30.0 img/s | ETA~1m50s | GPU~2824 MiB
# [batch  750/1546] loss(b)=0.1529 | loss(µ50)=0.1890 | lr=0.005 | 29.4 img/s | ETA~1m44s | GPU~2824 MiB
# [batch  800/1546] loss(b)=0.2334 | loss(µ50)=0.1653 | lr=0.005 | 30.8 img/s | ETA~1m37s | GPU~2824 MiB
# [batch  850/1546] loss(b)=0.1670 | loss(µ50)=0.1566 | lr=0.005 | 30.9 img/s | ETA~1m30s | GPU~2824 MiB
# [batch  900/1546] loss(b)=0.1617 | loss(µ50)=0.1608 | lr=0.005 | 30.8 img/s | ETA~1m23s | GPU~2824 MiB
# [batch  950/1546] loss(b)=0.1756 | loss(µ50)=0.1644 | lr=0.005 | 30.9 img/s | ETA~1m18s | GPU~2824 MiB
# [batch 1000/1546] loss(b)=0.1298 | loss(µ50)=0.1561 | lr=0.005 | 30.7 img/s | ETA~1m11s | GPU~2824 MiB
# [batch 1050/1546] loss(b)=0.1293 | loss(µ50)=0.1641 | lr=0.005 | 30.6 img/s | ETA~1m5s | GPU~2824 MiB
# [batch 1100/1546] loss(b)=0.1466 | loss(µ50)=0.1613 | lr=0.005 | 28.5 img/s | ETA~0m59s | GPU~2824 MiB
# [batch 1150/1546] loss(b)=0.1662 | loss(µ50)=0.1625 | lr=0.005 | 29.3 img/s | ETA~0m52s | GPU~2824 MiB
# [batch 1200/1546] loss(b)=0.1488 | loss(µ50)=0.1655 | lr=0.005 | 29.8 img/s | ETA~0m45s | GPU~2824 MiB
# [batch 1250/1546] loss(b)=0.1907 | loss(µ50)=0.1558 | lr=0.005 | 30.9 img/s | ETA~0m38s | GPU~2824 MiB
# [batch 1300/1546] loss(b)=0.1209 | loss(µ50)=0.1518 | lr=0.005 | 30.2 img/s | ETA~0m32s | GPU~2824 MiB
# [batch 1350/1546] loss(b)=0.1381 | loss(µ50)=0.1519 | lr=0.005 | 30.9 img/s | ETA~0m25s | GPU~2824 MiB
# [batch 1400/1546] loss(b)=0.2112 | loss(µ50)=0.1294 | lr=0.005 | 30.4 img/s | ETA~0m19s | GPU~2824 MiB
# [batch 1450/1546] loss(b)=0.1745 | loss(µ50)=0.1406 | lr=0.005 | 30.5 img/s | ETA~0m12s | GPU~2824 MiB
# [batch 1500/1546] loss(b)=0.1219 | loss(µ50)=0.1505 | lr=0.005 | 30.6 img/s | ETA~0m6s | GPU~2824 MiB
# [batch 1546/1546] loss(b)=0.0917 | loss(µ50)=0.1460 | lr=0.005 | 4.5 img/s | ETA~0m0s | GPU~2824 MiB
# FIN TRAIN
# INICIO val_loss (batches=442) ...
# [val_loss   50/442] loss=0.1680 | 12.08 it/s
# [val_loss  100/442] loss=0.1453 | 12.40 it/s
# [val_loss  150/442] loss=0.1226 | 12.46 it/s
# [val_loss  200/442] loss=0.1481 | 12.46 it/s
# [val_loss  250/442] loss=0.1124 | 12.51 it/s
# [val_loss  300/442] loss=0.1566 | 12.55 it/s
# [val_loss  350/442] loss=0.1307 | 12.56 it/s
# [val_loss  400/442] loss=0.1539 | 12.56 it/s
# [val_loss  442/442] loss=0.1063 | 12.57 it/s
# FIN val_loss  (0.6 min)
# INICIO val_prf (batches=442) ...
# [val_prf    50/442] 13.63 it/s | TP=13 FP=101 FN=187
# [val_prf   100/442] 13.80 it/s | TP=180 FP=148 FN=220
# [val_prf   150/442] 13.91 it/s | TP=363 FP=189 FN=237
# [val_prf   200/442] 13.95 it/s | TP=536 FP=237 FN=264
# [val_prf   250/442] 13.91 it/s | TP=705 FP=304 FN=295
# [val_prf   300/442] 13.93 it/s | TP=869 FP=359 FN=331
# [val_prf   350/442] 13.94 it/s | TP=1024 FP=408 FN=376
# [val_prf   400/442] 13.94 it/s | TP=1180 FP=466 FN=420
# [val_prf   442/442] 13.96 it/s | TP=1308 FP=525 FN=458
# FIN val_prf  (0.5 min)
# INICIO val_mAP (batches=442) ...
# FIN val_mAP  (0.6 min)
# [RESUMEN ÉPOCA 01] lr→0.005 | dur=5.8 min | train_loss=0.1826 | val_loss=0.1492 | val_rec=0.682 | val_f2=0.663 | val_mAP50=0.718 | val_mAP=0.288
#
# ================================================================================
# INICIO ÉPOCA 2/20  |  train_batches: 1546  |  batch_size: 4
# GPU: NVIDIA A100-SXM4-40GB  |  VRAM total: 39.6 GB
# ================================================================================
# [batch   50/1546] loss(b)=0.1386 | loss(µ50)=0.1345 | lr=0.005 | 30.6 img/s | ETA~3m20s | GPU~2821 MiB
# [batch  100/1546] loss(b)=0.1348 | loss(µ50)=0.1341 | lr=0.005 | 30.2 img/s | ETA~3m10s | GPU~2821 MiB
# [batch  150/1546] loss(b)=0.0990 | loss(µ50)=0.1279 | lr=0.005 | 30.7 img/s | ETA~3m5s | GPU~2821 MiB
# [batch  200/1546] loss(b)=0.1044 | loss(µ50)=0.1261 | lr=0.005 | 30.7 img/s | ETA~2m57s | GPU~2821 MiB
# [batch  250/1546] loss(b)=0.1049 | loss(µ50)=0.1290 | lr=0.005 | 30.8 img/s | ETA~2m50s | GPU~2821 MiB
# [batch  300/1546] loss(b)=0.1485 | loss(µ50)=0.1410 | lr=0.005 | 30.7 img/s | ETA~2m44s | GPU~2822 MiB
# [batch  350/1546] loss(b)=0.1125 | loss(µ50)=0.1442 | lr=0.005 | 30.8 img/s | ETA~2m35s | GPU~2822 MiB
# [batch  400/1546] loss(b)=0.1437 | loss(µ50)=0.1375 | lr=0.005 | 30.4 img/s | ETA~2m32s | GPU~2822 MiB
# [batch  450/1546] loss(b)=0.1355 | loss(µ50)=0.1340 | lr=0.005 | 30.7 img/s | ETA~2m23s | GPU~2822 MiB
# [batch  500/1546] loss(b)=0.1184 | loss(µ50)=0.1394 | lr=0.005 | 30.3 img/s | ETA~2m19s | GPU~2822 MiB
# [batch  550/1546] loss(b)=0.1688 | loss(µ50)=0.1263 | lr=0.005 | 30.7 img/s | ETA~2m10s | GPU~2822 MiB
# [batch  600/1546] loss(b)=0.1209 | loss(µ50)=0.1373 | lr=0.005 | 30.4 img/s | ETA~2m5s | GPU~2822 MiB
# [batch  650/1546] loss(b)=0.1380 | loss(µ50)=0.1369 | lr=0.005 | 30.7 img/s | ETA~1m57s | GPU~2822 MiB
# [batch  700/1546] loss(b)=0.0775 | loss(µ50)=0.1251 | lr=0.005 | 29.9 img/s | ETA~1m51s | GPU~2822 MiB
# [batch  750/1546] loss(b)=0.1726 | loss(µ50)=0.1292 | lr=0.005 | 29.7 img/s | ETA~1m44s | GPU~2822 MiB
# [batch  800/1546] loss(b)=0.1384 | loss(µ50)=0.1351 | lr=0.005 | 30.7 img/s | ETA~1m37s | GPU~2822 MiB
# [batch  850/1546] loss(b)=0.1957 | loss(µ50)=0.1366 | lr=0.005 | 29.4 img/s | ETA~1m31s | GPU~2822 MiB
# [batch  900/1546] loss(b)=0.1411 | loss(µ50)=0.1276 | lr=0.005 | 30.7 img/s | ETA~1m25s | GPU~2822 MiB
# [batch  950/1546] loss(b)=0.1201 | loss(µ50)=0.1347 | lr=0.005 | 30.2 img/s | ETA~1m20s | GPU~2822 MiB
# [batch 1000/1546] loss(b)=0.1079 | loss(µ50)=0.1372 | lr=0.005 | 31.2 img/s | ETA~1m11s | GPU~2822 MiB
# [batch 1050/1546] loss(b)=0.1115 | loss(µ50)=0.1288 | lr=0.005 | 30.7 img/s | ETA~1m4s | GPU~2822 MiB
# [batch 1100/1546] loss(b)=0.1121 | loss(µ50)=0.1225 | lr=0.005 | 30.7 img/s | ETA~0m58s | GPU~2822 MiB
# [batch 1150/1546] loss(b)=0.0975 | loss(µ50)=0.1307 | lr=0.005 | 30.7 img/s | ETA~0m52s | GPU~2822 MiB
# [batch 1200/1546] loss(b)=0.1317 | loss(µ50)=0.1324 | lr=0.005 | 30.2 img/s | ETA~0m45s | GPU~2822 MiB
# [batch 1250/1546] loss(b)=0.1787 | loss(µ50)=0.1272 | lr=0.005 | 30.6 img/s | ETA~0m38s | GPU~2822 MiB
# [batch 1300/1546] loss(b)=0.1142 | loss(µ50)=0.1228 | lr=0.005 | 30.7 img/s | ETA~0m32s | GPU~2822 MiB
# [batch 1350/1546] loss(b)=0.1291 | loss(µ50)=0.1219 | lr=0.005 | 30.8 img/s | ETA~0m25s | GPU~2822 MiB
# [batch 1400/1546] loss(b)=0.1038 | loss(µ50)=0.1266 | lr=0.005 | 29.4 img/s | ETA~0m19s | GPU~2822 MiB
# [batch 1450/1546] loss(b)=0.1252 | loss(µ50)=0.1272 | lr=0.005 | 30.8 img/s | ETA~0m12s | GPU~2822 MiB
# [batch 1500/1546] loss(b)=0.1211 | loss(µ50)=0.1236 | lr=0.005 | 30.3 img/s | ETA~0m6s | GPU~2822 MiB
# [batch 1546/1546] loss(b)=0.1117 | loss(µ50)=0.1210 | lr=0.005 | 11.1 img/s | ETA~0m0s | GPU~2822 MiB
# FIN TRAIN
# INICIO val_loss (batches=442) ...
# [val_loss   50/442] loss=0.1670 | 12.09 it/s
# [val_loss  100/442] loss=0.1050 | 12.28 it/s
# [val_loss  150/442] loss=0.1259 | 12.38 it/s
# [val_loss  200/442] loss=0.1550 | 12.40 it/s
# [val_loss  250/442] loss=0.1120 | 12.40 it/s
# [val_loss  300/442] loss=0.1396 | 12.43 it/s
# [val_loss  350/442] loss=0.1066 | 12.46 it/s
# [val_loss  400/442] loss=0.1295 | 12.46 it/s
# [val_loss  442/442] loss=0.0851 | 12.47 it/s
# FIN val_loss  (0.6 min)
# INICIO val_prf (batches=442) ...
# [val_prf    50/442] 13.52 it/s | TP=71 FP=86 FN=129
# [val_prf   100/442] 13.66 it/s | TP=247 FP=129 FN=153
# [val_prf   150/442] 13.71 it/s | TP=437 FP=181 FN=163
# [val_prf   200/442] 13.75 it/s | TP=610 FP=222 FN=190
# [val_prf   250/442] 13.79 it/s | TP=790 FP=273 FN=210
# [val_prf   300/442] 13.80 it/s | TP=960 FP=330 FN=240
# [val_prf   350/442] 13.83 it/s | TP=1124 FP=384 FN=276
# [val_prf   400/442] 13.86 it/s | TP=1298 FP=430 FN=302
# [val_prf   442/442] 13.87 it/s | TP=1436 FP=487 FN=330
# FIN val_prf  (0.5 min)
# INICIO val_mAP (batches=442) ...
# FIN val_mAP  (0.6 min)
# [RESUMEN ÉPOCA 02] lr→0.005 | dur=5.1 min | train_loss=0.1309 | val_loss=0.1356 | val_rec=0.773 | val_f2=0.758 | val_mAP50=0.774 | val_mAP=0.311
#
# ================================================================================
# INICIO ÉPOCA 3/20  |  train_batches: 1546  |  batch_size: 4
# GPU: NVIDIA A100-SXM4-40GB  |  VRAM total: 39.6 GB
# ================================================================================
# [batch   50/1546] loss(b)=0.0957 | loss(µ50)=0.1218 | lr=0.005 | 31.0 img/s | ETA~3m22s | GPU~2821 MiB
# [batch  100/1546] loss(b)=0.1366 | loss(µ50)=0.1200 | lr=0.005 | 30.5 img/s | ETA~3m11s | GPU~2822 MiB
# [batch  150/1546] loss(b)=0.1072 | loss(µ50)=0.1152 | lr=0.005 | 30.5 img/s | ETA~3m3s | GPU~2822 MiB
# [batch  200/1546] loss(b)=0.1061 | loss(µ50)=0.1118 | lr=0.005 | 30.4 img/s | ETA~2m56s | GPU~2822 MiB
# [batch  250/1546] loss(b)=0.0608 | loss(µ50)=0.1139 | lr=0.005 | 30.3 img/s | ETA~2m49s | GPU~2822 MiB
# [batch  300/1546] loss(b)=0.1199 | loss(µ50)=0.1179 | lr=0.005 | 30.7 img/s | ETA~2m43s | GPU~2822 MiB
# [batch  350/1546] loss(b)=0.1122 | loss(µ50)=0.1077 | lr=0.005 | 30.8 img/s | ETA~2m36s | GPU~2822 MiB
# [batch  400/1546] loss(b)=0.1037 | loss(µ50)=0.1202 | lr=0.005 | 30.8 img/s | ETA~2m30s | GPU~2822 MiB
# [batch  450/1546] loss(b)=0.1390 | loss(µ50)=0.1166 | lr=0.005 | 30.1 img/s | ETA~2m23s | GPU~2822 MiB
# [batch  500/1546] loss(b)=0.1537 | loss(µ50)=0.1130 | lr=0.005 | 30.8 img/s | ETA~2m16s | GPU~2822 MiB
# [batch  550/1546] loss(b)=0.1069 | loss(µ50)=0.1126 | lr=0.005 | 30.8 img/s | ETA~2m10s | GPU~2822 MiB
# [batch  600/1546] loss(b)=0.1156 | loss(µ50)=0.1138 | lr=0.005 | 30.4 img/s | ETA~2m4s | GPU~2822 MiB
# [batch  650/1546] loss(b)=0.1446 | loss(µ50)=0.1162 | lr=0.005 | 28.9 img/s | ETA~1m58s | GPU~2822 MiB
# [batch  700/1546] loss(b)=0.0929 | loss(µ50)=0.1211 | lr=0.005 | 30.7 img/s | ETA~1m51s | GPU~2822 MiB
# [batch  750/1546] loss(b)=0.1150 | loss(µ50)=0.1155 | lr=0.005 | 29.4 img/s | ETA~1m44s | GPU~2822 MiB
# [batch  800/1546] loss(b)=0.1409 | loss(µ50)=0.1188 | lr=0.005 | 30.5 img/s | ETA~1m39s | GPU~2822 MiB
# [batch  850/1546] loss(b)=0.1070 | loss(µ50)=0.1223 | lr=0.005 | 30.2 img/s | ETA~1m31s | GPU~2822 MiB
# [batch  900/1546] loss(b)=0.1274 | loss(µ50)=0.1214 | lr=0.005 | 29.7 img/s | ETA~1m24s | GPU~2822 MiB
# [batch  950/1546] loss(b)=0.1396 | loss(µ50)=0.1180 | lr=0.005 | 30.2 img/s | ETA~1m18s | GPU~2822 MiB
# [batch 1000/1546] loss(b)=0.0993 | loss(µ50)=0.1176 | lr=0.005 | 30.7 img/s | ETA~1m11s | GPU~2822 MiB
# [batch 1050/1546] loss(b)=0.1248 | loss(µ50)=0.1099 | lr=0.005 | 30.5 img/s | ETA~1m5s | GPU~2822 MiB
# [batch 1100/1546] loss(b)=0.0950 | loss(µ50)=0.1208 | lr=0.005 | 30.2 img/s | ETA~0m58s | GPU~2822 MiB
# [batch 1150/1546] loss(b)=0.1462 | loss(µ50)=0.1170 | lr=0.005 | 30.0 img/s | ETA~0m52s | GPU~2822 MiB
# [batch 1200/1546] loss(b)=0.1091 | loss(µ50)=0.1162 | lr=0.005 | 30.1 img/s | ETA~0m45s | GPU~2822 MiB
# [batch 1250/1546] loss(b)=0.1702 | loss(µ50)=0.1245 | lr=0.005 | 30.1 img/s | ETA~0m39s | GPU~2822 MiB
# [batch 1300/1546] loss(b)=0.1563 | loss(µ50)=0.1282 | lr=0.005 | 30.4 img/s | ETA~0m32s | GPU~2822 MiB
# [batch 1350/1546] loss(b)=0.1348 | loss(µ50)=0.1196 | lr=0.005 | 31.0 img/s | ETA~0m25s | GPU~2822 MiB
# [batch 1400/1546] loss(b)=0.1170 | loss(µ50)=0.1272 | lr=0.005 | 30.3 img/s | ETA~0m19s | GPU~2822 MiB
# [batch 1450/1546] loss(b)=0.1101 | loss(µ50)=0.1150 | lr=0.005 | 30.3 img/s | ETA~0m12s | GPU~2822 MiB
# [batch 1500/1546] loss(b)=0.1270 | loss(µ50)=0.1141 | lr=0.005 | 30.7 img/s | ETA~0m6s | GPU~2822 MiB
# [batch 1546/1546] loss(b)=0.1294 | loss(µ50)=0.1221 | lr=0.005 | 11.3 img/s | ETA~0m0s | GPU~2822 MiB
# FIN TRAIN
# INICIO val_loss (batches=442) ...
# [val_loss   50/442] loss=0.1454 | 12.13 it/s
# [val_loss  100/442] loss=0.1136 | 12.25 it/s
# [val_loss  150/442] loss=0.1343 | 12.30 it/s
# [val_loss  200/442] loss=0.1405 | 12.36 it/s
# [val_loss  250/442] loss=0.0968 | 12.38 it/s
# [val_loss  300/442] loss=0.1599 | 12.42 it/s
# [val_loss  350/442] loss=0.0974 | 12.29 it/s
# [val_loss  400/442] loss=0.1330 | 12.24 it/s
# [val_loss  442/442] loss=0.0754 | 12.30 it/s
# FIN val_loss  (0.6 min)
# INICIO val_prf (batches=442) ...
# [val_prf    50/442] 13.33 it/s | TP=110 FP=69 FN=90
# [val_prf   100/442] 13.63 it/s | TP=297 FP=102 FN=103
# [val_prf   150/442] 13.76 it/s | TP=487 FP=137 FN=113
# [val_prf   200/442] 13.87 it/s | TP=662 FP=182 FN=138
# [val_prf   250/442] 13.92 it/s | TP=839 FP=228 FN=161
# [val_prf   300/442] 13.94 it/s | TP=1011 FP=265 FN=189
# [val_prf   350/442] 13.93 it/s | TP=1182 FP=310 FN=218
# [val_prf   400/442] 13.94 it/s | TP=1360 FP=354 FN=240
# [val_prf   442/442] 13.95 it/s | TP=1496 FP=388 FN=270
# FIN val_prf  (0.5 min)
# INICIO val_mAP (batches=442) ...
# FIN val_mAP  (0.6 min)
# [RESUMEN ÉPOCA 03] lr→0.005 | dur=5.1 min | train_loss=0.1177 | val_loss=0.1304 | val_rec=0.821 | val_f2=0.812 | val_mAP50=0.833 | val_mAP=0.344
#
# ================================================================================
# INICIO ÉPOCA 4/20  |  train_batches: 1546  |  batch_size: 4
# GPU: NVIDIA A100-SXM4-40GB  |  VRAM total: 39.6 GB
# ================================================================================
# [batch   50/1546] loss(b)=0.0807 | loss(µ50)=0.1107 | lr=0.005 | 30.3 img/s | ETA~3m21s | GPU~2822 MiB
# [batch  100/1546] loss(b)=0.0868 | loss(µ50)=0.1039 | lr=0.005 | 29.9 img/s | ETA~3m10s | GPU~2822 MiB
# [batch  150/1546] loss(b)=0.1183 | loss(µ50)=0.1029 | lr=0.005 | 28.9 img/s | ETA~3m4s | GPU~2822 MiB
# [batch  200/1546] loss(b)=0.1415 | loss(µ50)=0.1159 | lr=0.005 | 31.2 img/s | ETA~2m57s | GPU~2822 MiB
# [batch  250/1546] loss(b)=0.1317 | loss(µ50)=0.1046 | lr=0.005 | 30.8 img/s | ETA~2m50s | GPU~2822 MiB
# [batch  300/1546] loss(b)=0.1112 | loss(µ50)=0.1108 | lr=0.005 | 30.1 img/s | ETA~2m43s | GPU~2822 MiB
# [batch  350/1546] loss(b)=0.0919 | loss(µ50)=0.1035 | lr=0.005 | 30.8 img/s | ETA~2m36s | GPU~2822 MiB
# [batch  400/1546] loss(b)=0.0825 | loss(µ50)=0.1125 | lr=0.005 | 30.7 img/s | ETA~2m30s | GPU~2822 MiB
# [batch  450/1546] loss(b)=0.0993 | loss(µ50)=0.1063 | lr=0.005 | 29.7 img/s | ETA~2m24s | GPU~2822 MiB
# [batch  500/1546] loss(b)=0.1246 | loss(µ50)=0.1085 | lr=0.005 | 30.5 img/s | ETA~2m19s | GPU~2822 MiB
# [batch  550/1546] loss(b)=0.1118 | loss(µ50)=0.1064 | lr=0.005 | 30.5 img/s | ETA~2m10s | GPU~2822 MiB
# [batch  600/1546] loss(b)=0.1248 | loss(µ50)=0.1148 | lr=0.005 | 30.7 img/s | ETA~2m4s | GPU~2822 MiB
# [batch  650/1546] loss(b)=0.0860 | loss(µ50)=0.1082 | lr=0.005 | 30.3 img/s | ETA~1m57s | GPU~2822 MiB
# [batch  700/1546] loss(b)=0.0891 | loss(µ50)=0.1053 | lr=0.005 | 30.4 img/s | ETA~1m51s | GPU~2822 MiB
# [batch  750/1546] loss(b)=0.1435 | loss(µ50)=0.1120 | lr=0.005 | 30.7 img/s | ETA~1m44s | GPU~2822 MiB
# [batch  800/1546] loss(b)=0.0885 | loss(µ50)=0.1084 | lr=0.005 | 30.7 img/s | ETA~1m38s | GPU~2822 MiB
# [batch  850/1546] loss(b)=0.1495 | loss(µ50)=0.1100 | lr=0.005 | 30.5 img/s | ETA~1m32s | GPU~2822 MiB
# [batch  900/1546] loss(b)=0.0777 | loss(µ50)=0.1040 | lr=0.005 | 30.2 img/s | ETA~1m24s | GPU~2822 MiB
# [batch  950/1546] loss(b)=0.1369 | loss(µ50)=0.1087 | lr=0.005 | 29.0 img/s | ETA~1m18s | GPU~2822 MiB
# [batch 1000/1546] loss(b)=0.0800 | loss(µ50)=0.1055 | lr=0.005 | 30.5 img/s | ETA~1m12s | GPU~2822 MiB
# [batch 1050/1546] loss(b)=0.1365 | loss(µ50)=0.1132 | lr=0.005 | 30.5 img/s | ETA~1m5s | GPU~2822 MiB
# [batch 1100/1546] loss(b)=0.0871 | loss(µ50)=0.1085 | lr=0.005 | 30.5 img/s | ETA~0m58s | GPU~2822 MiB
# [batch 1150/1546] loss(b)=0.0927 | loss(µ50)=0.1145 | lr=0.005 | 28.7 img/s | ETA~0m52s | GPU~2822 MiB
# [batch 1200/1546] loss(b)=0.1471 | loss(µ50)=0.1099 | lr=0.005 | 29.6 img/s | ETA~0m46s | GPU~2822 MiB
# [batch 1250/1546] loss(b)=0.0778 | loss(µ50)=0.1146 | lr=0.005 | 30.6 img/s | ETA~0m39s | GPU~2822 MiB
# [batch 1300/1546] loss(b)=0.1328 | loss(µ50)=0.1119 | lr=0.005 | 29.5 img/s | ETA~0m32s | GPU~2822 MiB
# [batch 1350/1546] loss(b)=0.1364 | loss(µ50)=0.1141 | lr=0.005 | 30.4 img/s | ETA~0m25s | GPU~2822 MiB
# [batch 1400/1546] loss(b)=0.1668 | loss(µ50)=0.1103 | lr=0.005 | 30.5 img/s | ETA~0m19s | GPU~2822 MiB
# [batch 1450/1546] loss(b)=0.0986 | loss(µ50)=0.1046 | lr=0.005 | 29.8 img/s | ETA~0m12s | GPU~2822 MiB
# [batch 1500/1546] loss(b)=0.1161 | loss(µ50)=0.1114 | lr=0.005 | 29.9 img/s | ETA~0m6s | GPU~2822 MiB
# [batch 1546/1546] loss(b)=0.1044 | loss(µ50)=0.1129 | lr=0.005 | 11.1 img/s | ETA~0m0s | GPU~2822 MiB
# FIN TRAIN
# INICIO val_loss (batches=442) ...
# [val_loss   50/442] loss=0.1378 | 12.10 it/s
# [val_loss  100/442] loss=0.1052 | 12.23 it/s
# [val_loss  150/442] loss=0.1382 | 12.35 it/s
# [val_loss  200/442] loss=0.1722 | 12.39 it/s
# [val_loss  250/442] loss=0.0846 | 12.42 it/s
# [val_loss  300/442] loss=0.1448 | 12.29 it/s
# [val_loss  350/442] loss=0.0896 | 12.34 it/s
# [val_loss  400/442] loss=0.1403 | 12.37 it/s
# [val_loss  442/442] loss=0.0881 | 12.40 it/s
# FIN val_loss  (0.6 min)
# INICIO val_prf (batches=442) ...
# [val_prf    50/442] 13.38 it/s | TP=96 FP=51 FN=104
# [val_prf   100/442] 13.52 it/s | TP=282 FP=68 FN=118
# [val_prf   150/442] 13.64 it/s | TP=473 FP=84 FN=127
# [val_prf   200/442] 13.74 it/s | TP=646 FP=114 FN=154
# [val_prf   250/442] 13.80 it/s | TP=832 FP=140 FN=168
# [val_prf   300/442] 13.79 it/s | TP=1004 FP=164 FN=196
# [val_prf   350/442] 13.81 it/s | TP=1164 FP=197 FN=236
# [val_prf   400/442] 13.82 it/s | TP=1336 FP=221 FN=264
# [val_prf   442/442] 13.83 it/s | TP=1478 FP=243 FN=288
# FIN val_prf  (0.5 min)
# INICIO val_mAP (batches=442) ...
# FIN val_mAP  (0.6 min)
# [RESUMEN ÉPOCA 04] lr→0.005 | dur=5.1 min | train_loss=0.1093 | val_loss=0.1322 | val_rec=0.806 | val_f2=0.811 | val_mAP50=0.829 | val_mAP=0.347
#
# ================================================================================
# INICIO ÉPOCA 5/20  |  train_batches: 1546  |  batch_size: 4
# GPU: NVIDIA A100-SXM4-40GB  |  VRAM total: 39.6 GB
# ================================================================================
# [batch   50/1546] loss(b)=0.1386 | loss(µ50)=0.1069 | lr=0.005 | 30.6 img/s | ETA~3m21s | GPU~2822 MiB
# [batch  100/1546] loss(b)=0.1141 | loss(µ50)=0.1018 | lr=0.005 | 30.7 img/s | ETA~3m10s | GPU~2822 MiB
# [batch  150/1546] loss(b)=0.0889 | loss(µ50)=0.1018 | lr=0.005 | 30.5 img/s | ETA~3m3s | GPU~2822 MiB
# [batch  200/1546] loss(b)=0.1011 | loss(µ50)=0.1003 | lr=0.005 | 30.1 img/s | ETA~2m57s | GPU~2822 MiB
# [batch  250/1546] loss(b)=0.1193 | loss(µ50)=0.0995 | lr=0.005 | 30.6 img/s | ETA~2m50s | GPU~2822 MiB
# [batch  300/1546] loss(b)=0.0885 | loss(µ50)=0.1003 | lr=0.005 | 30.5 img/s | ETA~2m44s | GPU~2822 MiB
# [batch  350/1546] loss(b)=0.0894 | loss(µ50)=0.1077 | lr=0.005 | 30.7 img/s | ETA~2m37s | GPU~2822 MiB
# [batch  400/1546] loss(b)=0.0808 | loss(µ50)=0.1053 | lr=0.005 | 29.7 img/s | ETA~2m31s | GPU~2822 MiB
# [batch  450/1546] loss(b)=0.0900 | loss(µ50)=0.1063 | lr=0.005 | 30.3 img/s | ETA~2m24s | GPU~2822 MiB
# [batch  500/1546] loss(b)=0.1203 | loss(µ50)=0.1014 | lr=0.005 | 29.9 img/s | ETA~2m19s | GPU~2822 MiB
# [batch  550/1546] loss(b)=0.0921 | loss(µ50)=0.1052 | lr=0.005 | 30.0 img/s | ETA~2m12s | GPU~2822 MiB
# [batch  600/1546] loss(b)=0.0807 | loss(µ50)=0.1042 | lr=0.005 | 30.1 img/s | ETA~2m6s | GPU~2822 MiB
# [batch  650/1546] loss(b)=0.1355 | loss(µ50)=0.1027 | lr=0.005 | 30.1 img/s | ETA~1m59s | GPU~2822 MiB
# [batch  700/1546] loss(b)=0.1146 | loss(µ50)=0.1052 | lr=0.005 | 29.5 img/s | ETA~1m53s | GPU~2822 MiB
# [batch  750/1546] loss(b)=0.0870 | loss(µ50)=0.1028 | lr=0.005 | 29.7 img/s | ETA~1m46s | GPU~2822 MiB
# [batch  800/1546] loss(b)=0.1104 | loss(µ50)=0.0996 | lr=0.005 | 30.0 img/s | ETA~1m41s | GPU~2822 MiB
# [batch  850/1546] loss(b)=0.0771 | loss(µ50)=0.1086 | lr=0.005 | 29.6 img/s | ETA~1m33s | GPU~2822 MiB
# [batch  900/1546] loss(b)=0.1573 | loss(µ50)=0.1009 | lr=0.005 | 30.5 img/s | ETA~1m26s | GPU~2822 MiB
# [batch  950/1546] loss(b)=0.1106 | loss(µ50)=0.1054 | lr=0.005 | 29.0 img/s | ETA~1m19s | GPU~2822 MiB
# [batch 1000/1546] loss(b)=0.1464 | loss(µ50)=0.1124 | lr=0.005 | 30.4 img/s | ETA~1m12s | GPU~2822 MiB
# [batch 1050/1546] loss(b)=0.1006 | loss(µ50)=0.1032 | lr=0.005 | 29.8 img/s | ETA~1m6s | GPU~2822 MiB
# [batch 1100/1546] loss(b)=0.0749 | loss(µ50)=0.1100 | lr=0.005 | 29.5 img/s | ETA~0m59s | GPU~2822 MiB
# [batch 1150/1546] loss(b)=0.1189 | loss(µ50)=0.1075 | lr=0.005 | 29.7 img/s | ETA~0m53s | GPU~2822 MiB
# [batch 1200/1546] loss(b)=0.1014 | loss(µ50)=0.1083 | lr=0.005 | 29.9 img/s | ETA~0m46s | GPU~2822 MiB
# [batch 1250/1546] loss(b)=0.0826 | loss(µ50)=0.1098 | lr=0.005 | 29.3 img/s | ETA~0m39s | GPU~2822 MiB
# [batch 1300/1546] loss(b)=0.0997 | loss(µ50)=0.1080 | lr=0.005 | 30.1 img/s | ETA~0m32s | GPU~2822 MiB
# [batch 1350/1546] loss(b)=0.1201 | loss(µ50)=0.1105 | lr=0.005 | 29.9 img/s | ETA~0m26s | GPU~2822 MiB
# [batch 1400/1546] loss(b)=0.0915 | loss(µ50)=0.1062 | lr=0.005 | 29.9 img/s | ETA~0m19s | GPU~2822 MiB
# [batch 1450/1546] loss(b)=0.0916 | loss(µ50)=0.1073 | lr=0.005 | 28.2 img/s | ETA~0m13s | GPU~2822 MiB
# [batch 1500/1546] loss(b)=0.0746 | loss(µ50)=0.1078 | lr=0.005 | 29.9 img/s | ETA~0m6s | GPU~2822 MiB
# [batch 1546/1546] loss(b)=0.1298 | loss(µ50)=0.1086 | lr=0.005 | 11.1 img/s | ETA~0m0s | GPU~2822 MiB
# FIN TRAIN
# INICIO val_loss (batches=442) ...
# [val_loss   50/442] loss=0.1341 | 11.79 it/s
# [val_loss  100/442] loss=0.1049 | 11.93 it/s
# [val_loss  150/442] loss=0.1554 | 12.00 it/s
# [val_loss  200/442] loss=0.1903 | 12.00 it/s
# [val_loss  250/442] loss=0.0868 | 12.02 it/s
# [val_loss  300/442] loss=0.1406 | 12.05 it/s
# [val_loss  350/442] loss=0.0858 | 12.08 it/s
# [val_loss  400/442] loss=0.1549 | 12.07 it/s
# [val_loss  442/442] loss=0.0751 | 12.09 it/s
# FIN val_loss  (0.6 min)
# INICIO val_prf (batches=442) ...
# [val_prf    50/442] 13.35 it/s | TP=122 FP=68 FN=78
# [val_prf   100/442] 13.50 it/s | TP=309 FP=91 FN=91
# [val_prf   150/442] 13.59 it/s | TP=502 FP=112 FN=98
# [val_prf   200/442] 13.64 it/s | TP=680 FP=141 FN=120
# [val_prf   250/442] 13.44 it/s | TP=865 FP=177 FN=135
# [val_prf   300/442] 13.52 it/s | TP=1038 FP=227 FN=162
# [val_prf   350/442] 13.58 it/s | TP=1205 FP=265 FN=195
# [val_prf   400/442] 13.53 it/s | TP=1382 FP=296 FN=218
# [val_prf   442/442] 13.52 it/s | TP=1527 FP=325 FN=239
# FIN val_prf  (0.5 min)
# INICIO val_mAP (batches=442) ...
# FIN val_mAP  (0.6 min)
# [RESUMEN ÉPOCA 05] lr→0.0005 | dur=5.2 min | train_loss=0.1053 | val_loss=0.1304 | val_rec=0.843 | val_f2=0.835 | val_mAP50=0.848 | val_mAP=0.342
#
# ================================================================================
# INICIO ÉPOCA 6/20  |  train_batches: 1546  |  batch_size: 4
# GPU: NVIDIA A100-SXM4-40GB  |  VRAM total: 39.6 GB
# ================================================================================
# [batch   50/1546] loss(b)=0.0766 | loss(µ50)=0.0977 | lr=0.0005 | 30.4 img/s | ETA~3m22s | GPU~2820 MiB
# [batch  100/1546] loss(b)=0.1080 | loss(µ50)=0.0890 | lr=0.0005 | 30.7 img/s | ETA~3m11s | GPU~2820 MiB
# [batch  150/1546] loss(b)=0.0706 | loss(µ50)=0.0895 | lr=0.0005 | 29.8 img/s | ETA~3m5s | GPU~2821 MiB
# [batch  200/1546] loss(b)=0.0816 | loss(µ50)=0.0918 | lr=0.0005 | 30.0 img/s | ETA~3m1s | GPU~2821 MiB
# [batch  250/1546] loss(b)=0.0853 | loss(µ50)=0.0896 | lr=0.0005 | 29.0 img/s | ETA~2m54s | GPU~2821 MiB
# [batch  300/1546] loss(b)=0.0621 | loss(µ50)=0.0870 | lr=0.0005 | 29.7 img/s | ETA~2m47s | GPU~2821 MiB
# [batch  350/1546] loss(b)=0.0914 | loss(µ50)=0.0894 | lr=0.0005 | 30.0 img/s | ETA~2m40s | GPU~2821 MiB
# [batch  400/1546] loss(b)=0.0892 | loss(µ50)=0.0858 | lr=0.0005 | 29.6 img/s | ETA~2m34s | GPU~2821 MiB
# [batch  450/1546] loss(b)=0.0640 | loss(µ50)=0.0876 | lr=0.0005 | 30.2 img/s | ETA~2m26s | GPU~2821 MiB
# [batch  500/1546] loss(b)=0.0874 | loss(µ50)=0.0925 | lr=0.0005 | 30.0 img/s | ETA~2m21s | GPU~2821 MiB
# [batch  550/1546] loss(b)=0.0948 | loss(µ50)=0.0903 | lr=0.0005 | 30.0 img/s | ETA~2m13s | GPU~2821 MiB
# [batch  600/1546] loss(b)=0.1148 | loss(µ50)=0.0935 | lr=0.0005 | 29.9 img/s | ETA~2m6s | GPU~2821 MiB
# [batch  650/1546] loss(b)=0.1065 | loss(µ50)=0.0929 | lr=0.0005 | 29.0 img/s | ETA~2m1s | GPU~2821 MiB
# [batch  700/1546] loss(b)=0.1287 | loss(µ50)=0.0912 | lr=0.0005 | 29.3 img/s | ETA~1m54s | GPU~2821 MiB
# [batch  750/1546] loss(b)=0.1489 | loss(µ50)=0.0862 | lr=0.0005 | 29.4 img/s | ETA~1m47s | GPU~2821 MiB
# [batch  800/1546] loss(b)=0.1077 | loss(µ50)=0.0895 | lr=0.0005 | 29.6 img/s | ETA~1m40s | GPU~2821 MiB
# [batch  850/1546] loss(b)=0.0740 | loss(µ50)=0.0913 | lr=0.0005 | 30.3 img/s | ETA~1m33s | GPU~2821 MiB
# [batch  900/1546] loss(b)=0.0782 | loss(µ50)=0.0873 | lr=0.0005 | 30.4 img/s | ETA~1m25s | GPU~2821 MiB
# [batch  950/1546] loss(b)=0.0777 | loss(µ50)=0.0904 | lr=0.0005 | 30.3 img/s | ETA~1m19s | GPU~2821 MiB
# [batch 1000/1546] loss(b)=0.1145 | loss(µ50)=0.0880 | lr=0.0005 | 29.7 img/s | ETA~1m12s | GPU~2821 MiB
# [batch 1050/1546] loss(b)=0.0440 | loss(µ50)=0.0911 | lr=0.0005 | 29.9 img/s | ETA~1m6s | GPU~2821 MiB
# [batch 1100/1546] loss(b)=0.0753 | loss(µ50)=0.0885 | lr=0.0005 | 29.3 img/s | ETA~1m0s | GPU~2821 MiB
# [batch 1150/1546] loss(b)=0.1101 | loss(µ50)=0.0857 | lr=0.0005 | 30.4 img/s | ETA~0m53s | GPU~2821 MiB
# [batch 1200/1546] loss(b)=0.1057 | loss(µ50)=0.0898 | lr=0.0005 | 30.0 img/s | ETA~0m46s | GPU~2821 MiB
# [batch 1250/1546] loss(b)=0.0930 | loss(µ50)=0.0883 | lr=0.0005 | 30.5 img/s | ETA~0m39s | GPU~2821 MiB
# [batch 1300/1546] loss(b)=0.0759 | loss(µ50)=0.0862 | lr=0.0005 | 29.8 img/s | ETA~0m32s | GPU~2821 MiB
# [batch 1350/1546] loss(b)=0.1029 | loss(µ50)=0.0857 | lr=0.0005 | 30.5 img/s | ETA~0m26s | GPU~2821 MiB
# [batch 1400/1546] loss(b)=0.0771 | loss(µ50)=0.0857 | lr=0.0005 | 29.4 img/s | ETA~0m19s | GPU~2821 MiB
# [batch 1450/1546] loss(b)=0.0521 | loss(µ50)=0.0882 | lr=0.0005 | 30.4 img/s | ETA~0m12s | GPU~2821 MiB
# [batch 1500/1546] loss(b)=0.0552 | loss(µ50)=0.0923 | lr=0.0005 | 30.0 img/s | ETA~0m6s | GPU~2821 MiB
# [batch 1546/1546] loss(b)=0.0977 | loss(µ50)=0.0841 | lr=0.0005 | 10.8 img/s | ETA~0m0s | GPU~2821 MiB
# FIN TRAIN
# INICIO val_loss (batches=442) ...
# [val_loss   50/442] loss=0.1431 | 11.61 it/s
# [val_loss  100/442] loss=0.1121 | 11.95 it/s
# [val_loss  150/442] loss=0.1388 | 12.14 it/s
# [val_loss  200/442] loss=0.1834 | 12.19 it/s
# [val_loss  250/442] loss=0.0803 | 12.21 it/s
# [val_loss  300/442] loss=0.1432 | 12.22 it/s
# [val_loss  350/442] loss=0.0783 | 12.18 it/s
# [val_loss  400/442] loss=0.1284 | 12.17 it/s
# [val_loss  442/442] loss=0.1064 | 12.17 it/s
# FIN val_loss  (0.6 min)
# INICIO val_prf (batches=442) ...
# [val_prf    50/442] 12.68 it/s | TP=126 FP=51 FN=74
# [val_prf   100/442] 13.03 it/s | TP=314 FP=73 FN=86
# [val_prf   150/442] 13.28 it/s | TP=506 FP=92 FN=94
# [val_prf   200/442] 13.41 it/s | TP=687 FP=115 FN=113
# [val_prf   250/442] 13.51 it/s | TP=873 FP=142 FN=127
# [val_prf   300/442] 13.44 it/s | TP=1048 FP=168 FN=152
# [val_prf   350/442] 13.49 it/s | TP=1217 FP=193 FN=183
# [val_prf   400/442] 13.53 it/s | TP=1393 FP=211 FN=207
# [val_prf   442/442] 13.58 it/s | TP=1537 FP=235 FN=229
# FIN val_prf  (0.5 min)
# INICIO val_mAP (batches=442) ...
# FIN val_mAP  (0.6 min)
# [RESUMEN ÉPOCA 06] lr→0.0005 | dur=5.2 min | train_loss=0.0893 | val_loss=0.1266 | val_rec=0.849 | val_f2=0.849 | val_mAP50=0.856 | val_mAP=0.367
#
# ================================================================================
# INICIO ÉPOCA 7/20  |  train_batches: 1546  |  batch_size: 4
# GPU: NVIDIA A100-SXM4-40GB  |  VRAM total: 39.6 GB
# ================================================================================
# [batch   50/1546] loss(b)=0.1306 | loss(µ50)=0.0884 | lr=0.0005 | 29.9 img/s | ETA~3m24s | GPU~2821 MiB
# [batch  100/1546] loss(b)=0.0875 | loss(µ50)=0.0844 | lr=0.0005 | 30.6 img/s | ETA~3m14s | GPU~2821 MiB
# [batch  150/1546] loss(b)=0.0921 | loss(µ50)=0.0845 | lr=0.0005 | 29.1 img/s | ETA~3m6s | GPU~2821 MiB
# [batch  200/1546] loss(b)=0.0998 | loss(µ50)=0.0850 | lr=0.0005 | 29.9 img/s | ETA~3m1s | GPU~2821 MiB
# [batch  250/1546] loss(b)=0.0803 | loss(µ50)=0.0869 | lr=0.0005 | 29.1 img/s | ETA~2m55s | GPU~2821 MiB
# [batch  300/1546] loss(b)=0.0827 | loss(µ50)=0.0853 | lr=0.0005 | 29.6 img/s | ETA~2m45s | GPU~2821 MiB
# [batch  350/1546] loss(b)=0.0584 | loss(µ50)=0.0876 | lr=0.0005 | 30.2 img/s | ETA~2m39s | GPU~2821 MiB
# [batch  400/1546] loss(b)=0.1316 | loss(µ50)=0.0844 | lr=0.0005 | 29.7 img/s | ETA~2m32s | GPU~2821 MiB
# [batch  450/1546] loss(b)=0.0624 | loss(µ50)=0.0835 | lr=0.0005 | 29.3 img/s | ETA~2m27s | GPU~2821 MiB
# [batch  500/1546] loss(b)=0.0733 | loss(µ50)=0.0823 | lr=0.0005 | 30.3 img/s | ETA~2m19s | GPU~2821 MiB
# [batch  550/1546] loss(b)=0.0728 | loss(µ50)=0.0829 | lr=0.0005 | 30.0 img/s | ETA~2m13s | GPU~2821 MiB
# [batch  600/1546] loss(b)=0.0917 | loss(µ50)=0.0803 | lr=0.0005 | 29.8 img/s | ETA~2m6s | GPU~2821 MiB
# [batch  650/1546] loss(b)=0.0948 | loss(µ50)=0.0857 | lr=0.0005 | 29.6 img/s | ETA~2m1s | GPU~2821 MiB
# [batch  700/1546] loss(b)=0.0954 | loss(µ50)=0.0851 | lr=0.0005 | 29.2 img/s | ETA~1m54s | GPU~2821 MiB
# [batch  750/1546] loss(b)=0.0627 | loss(µ50)=0.0846 | lr=0.0005 | 30.2 img/s | ETA~1m47s | GPU~2821 MiB
# [batch  800/1546] loss(b)=0.1021 | loss(µ50)=0.0857 | lr=0.0005 | 29.1 img/s | ETA~1m40s | GPU~2821 MiB
# [batch  850/1546] loss(b)=0.0645 | loss(µ50)=0.0850 | lr=0.0005 | 29.7 img/s | ETA~1m33s | GPU~2821 MiB
# [batch  900/1546] loss(b)=0.1302 | loss(µ50)=0.0845 | lr=0.0005 | 29.8 img/s | ETA~1m26s | GPU~2821 MiB
# [batch  950/1546] loss(b)=0.1088 | loss(µ50)=0.0877 | lr=0.0005 | 30.4 img/s | ETA~1m19s | GPU~2821 MiB
# [batch 1000/1546] loss(b)=0.0882 | loss(µ50)=0.0838 | lr=0.0005 | 30.0 img/s | ETA~1m12s | GPU~2821 MiB
# [batch 1050/1546] loss(b)=0.0970 | loss(µ50)=0.0852 | lr=0.0005 | 30.5 img/s | ETA~1m5s | GPU~2821 MiB
# [batch 1100/1546] loss(b)=0.0836 | loss(µ50)=0.0829 | lr=0.0005 | 29.3 img/s | ETA~0m59s | GPU~2821 MiB
# [batch 1150/1546] loss(b)=0.1023 | loss(µ50)=0.0832 | lr=0.0005 | 30.1 img/s | ETA~0m53s | GPU~2821 MiB
# [batch 1200/1546] loss(b)=0.0714 | loss(µ50)=0.0878 | lr=0.0005 | 30.3 img/s | ETA~0m47s | GPU~2821 MiB
# [batch 1250/1546] loss(b)=0.0883 | loss(µ50)=0.0848 | lr=0.0005 | 30.4 img/s | ETA~0m40s | GPU~2821 MiB
# [batch 1300/1546] loss(b)=0.1049 | loss(µ50)=0.0877 | lr=0.0005 | 30.0 img/s | ETA~0m32s | GPU~2821 MiB
# [batch 1350/1546] loss(b)=0.1234 | loss(µ50)=0.0878 | lr=0.0005 | 29.6 img/s | ETA~0m26s | GPU~2821 MiB
# [batch 1400/1546] loss(b)=0.0890 | loss(µ50)=0.0891 | lr=0.0005 | 29.7 img/s | ETA~0m19s | GPU~2821 MiB
# [batch 1450/1546] loss(b)=0.0636 | loss(µ50)=0.0837 | lr=0.0005 | 30.3 img/s | ETA~0m13s | GPU~2821 MiB
# [batch 1500/1546] loss(b)=0.0806 | loss(µ50)=0.0872 | lr=0.0005 | 30.3 img/s | ETA~0m6s | GPU~2821 MiB
# [batch 1546/1546] loss(b)=0.0664 | loss(µ50)=0.0854 | lr=0.0005 | 11.1 img/s | ETA~0m0s | GPU~2821 MiB
# FIN TRAIN
# INICIO val_loss (batches=442) ...
# [val_loss   50/442] loss=0.1373 | 11.82 it/s
# [val_loss  100/442] loss=0.1069 | 12.09 it/s
# [val_loss  150/442] loss=0.1427 | 12.19 it/s
# [val_loss  200/442] loss=0.1996 | 12.22 it/s
# [val_loss  250/442] loss=0.0791 | 12.22 it/s
# [val_loss  300/442] loss=0.1465 | 12.15 it/s
# [val_loss  350/442] loss=0.0799 | 12.12 it/s
# [val_loss  400/442] loss=0.1443 | 12.12 it/s
# [val_loss  442/442] loss=0.1090 | 12.14 it/s
# FIN val_loss  (0.6 min)
# INICIO val_prf (batches=442) ...
# [val_prf    50/442] 13.06 it/s | TP=126 FP=53 FN=74
# [val_prf   100/442] 13.39 it/s | TP=313 FP=70 FN=87
# [val_prf   150/442] 13.48 it/s | TP=504 FP=88 FN=96
# [val_prf   200/442] 13.22 it/s | TP=685 FP=108 FN=115
# [val_prf   250/442] 13.34 it/s | TP=871 FP=132 FN=129
# [val_prf   300/442] 13.40 it/s | TP=1047 FP=155 FN=153
# [val_prf   350/442] 13.43 it/s | TP=1211 FP=184 FN=189
# [val_prf   400/442] 13.46 it/s | TP=1389 FP=200 FN=211
# [val_prf   442/442] 13.49 it/s | TP=1529 FP=222 FN=237
# FIN val_prf  (0.5 min)
# INICIO val_mAP (batches=442) ...
# FIN val_mAP  (0.6 min)
# [RESUMEN ÉPOCA 07] lr→0.0005 | dur=5.2 min | train_loss=0.0852 | val_loss=0.1299 | val_rec=0.845 | val_f2=0.847 | val_mAP50=0.848 | val_mAP=0.366
#
# ================================================================================
# INICIO ÉPOCA 8/20  |  train_batches: 1546  |  batch_size: 4
# GPU: NVIDIA A100-SXM4-40GB  |  VRAM total: 39.6 GB
# ================================================================================
# [batch   50/1546] loss(b)=0.0785 | loss(µ50)=0.0791 | lr=0.0005 | 30.2 img/s | ETA~3m24s | GPU~2821 MiB
# [batch  100/1546] loss(b)=0.1235 | loss(µ50)=0.0828 | lr=0.0005 | 29.7 img/s | ETA~3m11s | GPU~2822 MiB
# [batch  150/1546] loss(b)=0.1167 | loss(µ50)=0.0836 | lr=0.0005 | 30.9 img/s | ETA~3m5s | GPU~2822 MiB
# [batch  200/1546] loss(b)=0.0884 | loss(µ50)=0.0814 | lr=0.0005 | 30.2 img/s | ETA~2m57s | GPU~2822 MiB
# [batch  250/1546] loss(b)=0.0813 | loss(µ50)=0.0795 | lr=0.0005 | 30.7 img/s | ETA~2m53s | GPU~2822 MiB
# [batch  300/1546] loss(b)=0.1105 | loss(µ50)=0.0821 | lr=0.0005 | 30.1 img/s | ETA~2m47s | GPU~2822 MiB
# [batch  350/1546] loss(b)=0.0773 | loss(µ50)=0.0813 | lr=0.0005 | 28.8 img/s | ETA~2m41s | GPU~2822 MiB
# [batch  400/1546] loss(b)=0.0957 | loss(µ50)=0.0881 | lr=0.0005 | 30.2 img/s | ETA~2m33s | GPU~2822 MiB
# [batch  450/1546] loss(b)=0.0898 | loss(µ50)=0.0815 | lr=0.0005 | 29.8 img/s | ETA~2m27s | GPU~2822 MiB
# [batch  500/1546] loss(b)=0.0590 | loss(µ50)=0.0792 | lr=0.0005 | 29.6 img/s | ETA~2m22s | GPU~2822 MiB
# [batch  550/1546] loss(b)=0.0860 | loss(µ50)=0.0850 | lr=0.0005 | 29.1 img/s | ETA~2m14s | GPU~2822 MiB
# [batch  600/1546] loss(b)=0.0692 | loss(µ50)=0.0851 | lr=0.0005 | 29.8 img/s | ETA~2m8s | GPU~2822 MiB
# [batch  650/1546] loss(b)=0.0918 | loss(µ50)=0.0834 | lr=0.0005 | 30.5 img/s | ETA~2m0s | GPU~2822 MiB
# [batch  700/1546] loss(b)=0.0879 | loss(µ50)=0.0820 | lr=0.0005 | 30.4 img/s | ETA~1m54s | GPU~2822 MiB
# [batch  750/1546] loss(b)=0.1298 | loss(µ50)=0.0861 | lr=0.0005 | 30.4 img/s | ETA~1m46s | GPU~2822 MiB
# [batch  800/1546] loss(b)=0.0772 | loss(µ50)=0.0809 | lr=0.0005 | 30.3 img/s | ETA~1m40s | GPU~2822 MiB
# [batch  850/1546] loss(b)=0.0725 | loss(µ50)=0.0821 | lr=0.0005 | 29.2 img/s | ETA~1m33s | GPU~2822 MiB
# [batch  900/1546] loss(b)=0.0772 | loss(µ50)=0.0821 | lr=0.0005 | 29.6 img/s | ETA~1m27s | GPU~2822 MiB
# [batch  950/1546] loss(b)=0.1054 | loss(µ50)=0.0869 | lr=0.0005 | 29.2 img/s | ETA~1m20s | GPU~2822 MiB
# [batch 1000/1546] loss(b)=0.0738 | loss(µ50)=0.0860 | lr=0.0005 | 29.4 img/s | ETA~1m13s | GPU~2822 MiB
# [batch 1050/1546] loss(b)=0.0777 | loss(µ50)=0.0830 | lr=0.0005 | 29.9 img/s | ETA~1m6s | GPU~2822 MiB
# [batch 1100/1546] loss(b)=0.0911 | loss(µ50)=0.0852 | lr=0.0005 | 28.8 img/s | ETA~1m0s | GPU~2822 MiB
# [batch 1150/1546] loss(b)=0.0690 | loss(µ50)=0.0823 | lr=0.0005 | 29.2 img/s | ETA~0m54s | GPU~2822 MiB
# [batch 1200/1546] loss(b)=0.0910 | loss(µ50)=0.0813 | lr=0.0005 | 30.5 img/s | ETA~0m45s | GPU~2822 MiB
# [batch 1250/1546] loss(b)=0.0952 | loss(µ50)=0.0821 | lr=0.0005 | 30.5 img/s | ETA~0m39s | GPU~2822 MiB
# [batch 1300/1546] loss(b)=0.0842 | loss(µ50)=0.0820 | lr=0.0005 | 29.8 img/s | ETA~0m32s | GPU~2822 MiB
# [batch 1350/1546] loss(b)=0.0973 | loss(µ50)=0.0873 | lr=0.0005 | 29.9 img/s | ETA~0m26s | GPU~2822 MiB
# [batch 1400/1546] loss(b)=0.0566 | loss(µ50)=0.0839 | lr=0.0005 | 30.4 img/s | ETA~0m19s | GPU~2822 MiB
# [batch 1450/1546] loss(b)=0.0942 | loss(µ50)=0.0841 | lr=0.0005 | 30.1 img/s | ETA~0m12s | GPU~2822 MiB
# [batch 1500/1546] loss(b)=0.0737 | loss(µ50)=0.0824 | lr=0.0005 | 29.6 img/s | ETA~0m6s | GPU~2822 MiB
# [batch 1546/1546] loss(b)=0.0774 | loss(µ50)=0.0805 | lr=0.0005 | 10.3 img/s | ETA~0m0s | GPU~2822 MiB
# FIN TRAIN
# INICIO val_loss (batches=442) ...
# [val_loss   50/442] loss=0.1273 | 11.59 it/s
# [val_loss  100/442] loss=0.1031 | 11.80 it/s
# [val_loss  150/442] loss=0.1493 | 11.92 it/s
# [val_loss  200/442] loss=0.1768 | 11.97 it/s
# [val_loss  250/442] loss=0.0836 | 11.97 it/s
# [val_loss  300/442] loss=0.1510 | 11.99 it/s
# [val_loss  350/442] loss=0.0802 | 12.00 it/s
# [val_loss  400/442] loss=0.1474 | 12.02 it/s
# [val_loss  442/442] loss=0.1173 | 12.06 it/s
# FIN val_loss  (0.6 min)
# INICIO val_prf (batches=442) ...
# [val_prf    50/442] 12.85 it/s | TP=130 FP=48 FN=70
# [val_prf   100/442] 12.02 it/s | TP=315 FP=65 FN=85
# [val_prf   150/442] 12.60 it/s | TP=507 FP=82 FN=93
# [val_prf   200/442] 12.90 it/s | TP=688 FP=98 FN=112
# [val_prf   250/442] 13.06 it/s | TP=874 FP=121 FN=126
# [val_prf   300/442] 13.15 it/s | TP=1049 FP=143 FN=151
# [val_prf   350/442] 13.22 it/s | TP=1216 FP=169 FN=184
# [val_prf   400/442] 13.26 it/s | TP=1397 FP=182 FN=203
# [val_prf   442/442] 13.30 it/s | TP=1540 FP=202 FN=226
# FIN val_prf  (0.6 min)
# INICIO val_mAP (batches=442) ...
# FIN val_mAP  (0.6 min)
# [RESUMEN ÉPOCA 08] lr→0.0005 | dur=5.2 min | train_loss=0.0830 | val_loss=0.1311 | val_rec=0.852 | val_f2=0.855 | val_mAP50=0.851 | val_mAP=0.365
#
# ================================================================================
# INICIO ÉPOCA 9/20  |  train_batches: 1546  |  batch_size: 4
# GPU: NVIDIA A100-SXM4-40GB  |  VRAM total: 39.6 GB
# ================================================================================
# [batch   50/1546] loss(b)=0.0813 | loss(µ50)=0.0753 | lr=0.0005 | 29.8 img/s | ETA~3m26s | GPU~2821 MiB
# [batch  100/1546] loss(b)=0.0642 | loss(µ50)=0.0770 | lr=0.0005 | 29.1 img/s | ETA~3m16s | GPU~2822 MiB
# [batch  150/1546] loss(b)=0.0833 | loss(µ50)=0.0793 | lr=0.0005 | 30.2 img/s | ETA~3m8s | GPU~2822 MiB
# [batch  200/1546] loss(b)=0.0985 | loss(µ50)=0.0835 | lr=0.0005 | 29.5 img/s | ETA~3m3s | GPU~2822 MiB
# [batch  250/1546] loss(b)=0.0817 | loss(µ50)=0.0798 | lr=0.0005 | 29.6 img/s | ETA~2m54s | GPU~2822 MiB
# [batch  300/1546] loss(b)=0.0765 | loss(µ50)=0.0827 | lr=0.0005 | 29.3 img/s | ETA~2m50s | GPU~2822 MiB
# [batch  350/1546] loss(b)=0.1083 | loss(µ50)=0.0774 | lr=0.0005 | 30.1 img/s | ETA~2m43s | GPU~2822 MiB
# [batch  400/1546] loss(b)=0.0912 | loss(µ50)=0.0785 | lr=0.0005 | 29.1 img/s | ETA~2m36s | GPU~2822 MiB
# [batch  450/1546] loss(b)=0.0688 | loss(µ50)=0.0797 | lr=0.0005 | 29.4 img/s | ETA~2m30s | GPU~2822 MiB
# [batch  500/1546] loss(b)=0.0716 | loss(µ50)=0.0855 | lr=0.0005 | 29.5 img/s | ETA~2m21s | GPU~2822 MiB
# [batch  550/1546] loss(b)=0.0622 | loss(µ50)=0.0821 | lr=0.0005 | 29.8 img/s | ETA~2m14s | GPU~2822 MiB
# [batch  600/1546] loss(b)=0.0913 | loss(µ50)=0.0787 | lr=0.0005 | 29.9 img/s | ETA~2m8s | GPU~2822 MiB
# [batch  650/1546] loss(b)=0.0930 | loss(µ50)=0.0832 | lr=0.0005 | 30.0 img/s | ETA~2m0s | GPU~2822 MiB
# [batch  700/1546] loss(b)=0.0767 | loss(µ50)=0.0812 | lr=0.0005 | 29.8 img/s | ETA~1m53s | GPU~2822 MiB
# [batch  750/1546] loss(b)=0.0615 | loss(µ50)=0.0779 | lr=0.0005 | 28.4 img/s | ETA~1m47s | GPU~2822 MiB
# [batch  800/1546] loss(b)=0.0867 | loss(µ50)=0.0807 | lr=0.0005 | 29.3 img/s | ETA~1m40s | GPU~2822 MiB
# [batch  850/1546] loss(b)=0.1005 | loss(µ50)=0.0819 | lr=0.0005 | 29.9 img/s | ETA~1m33s | GPU~2822 MiB
# [batch  900/1546] loss(b)=0.0597 | loss(µ50)=0.0835 | lr=0.0005 | 30.3 img/s | ETA~1m26s | GPU~2822 MiB
# [batch  950/1546] loss(b)=0.0638 | loss(µ50)=0.0825 | lr=0.0005 | 30.2 img/s | ETA~1m19s | GPU~2822 MiB
# [batch 1000/1546] loss(b)=0.0663 | loss(µ50)=0.0814 | lr=0.0005 | 30.4 img/s | ETA~1m13s | GPU~2822 MiB
# [batch 1050/1546] loss(b)=0.0483 | loss(µ50)=0.0821 | lr=0.0005 | 30.1 img/s | ETA~1m6s | GPU~2822 MiB
# [batch 1100/1546] loss(b)=0.0988 | loss(µ50)=0.0807 | lr=0.0005 | 29.7 img/s | ETA~1m0s | GPU~2822 MiB
# [batch 1150/1546] loss(b)=0.0774 | loss(µ50)=0.0793 | lr=0.0005 | 30.0 img/s | ETA~0m52s | GPU~2822 MiB
# [batch 1200/1546] loss(b)=0.0806 | loss(µ50)=0.0821 | lr=0.0005 | 30.4 img/s | ETA~0m46s | GPU~2822 MiB
# [batch 1250/1546] loss(b)=0.0915 | loss(µ50)=0.0810 | lr=0.0005 | 29.8 img/s | ETA~0m39s | GPU~2822 MiB
# [batch 1300/1546] loss(b)=0.0923 | loss(µ50)=0.0803 | lr=0.0005 | 29.8 img/s | ETA~0m33s | GPU~2822 MiB
# [batch 1350/1546] loss(b)=0.0839 | loss(µ50)=0.0845 | lr=0.0005 | 29.8 img/s | ETA~0m26s | GPU~2822 MiB
# [batch 1400/1546] loss(b)=0.1121 | loss(µ50)=0.0817 | lr=0.0005 | 30.0 img/s | ETA~0m19s | GPU~2822 MiB
# [batch 1450/1546] loss(b)=0.0863 | loss(µ50)=0.0792 | lr=0.0005 | 29.3 img/s | ETA~0m12s | GPU~2822 MiB
# [batch 1500/1546] loss(b)=0.1028 | loss(µ50)=0.0807 | lr=0.0005 | 30.4 img/s | ETA~0m6s | GPU~2822 MiB
# [batch 1546/1546] loss(b)=0.0737 | loss(µ50)=0.0811 | lr=0.0005 | 10.7 img/s | ETA~0m0s | GPU~2822 MiB
# FIN TRAIN
# INICIO val_loss (batches=442) ...
# [val_loss   50/442] loss=0.1229 | 11.66 it/s
# [val_loss  100/442] loss=0.1088 | 11.88 it/s
# [val_loss  150/442] loss=0.1429 | 12.01 it/s
# [val_loss  200/442] loss=0.1845 | 12.00 it/s
# [val_loss  250/442] loss=0.0853 | 11.95 it/s
# [val_loss  300/442] loss=0.1519 | 11.95 it/s
# [val_loss  350/442] loss=0.0966 | 11.97 it/s
# [val_loss  400/442] loss=0.1432 | 12.01 it/s
# [val_loss  442/442] loss=0.1054 | 12.05 it/s
# FIN val_loss  (0.6 min)
# INICIO val_prf (batches=442) ...
# [val_prf    50/442] 13.14 it/s | TP=132 FP=49 FN=68
# [val_prf   100/442] 13.34 it/s | TP=317 FP=67 FN=83
# [val_prf   150/442] 13.38 it/s | TP=509 FP=87 FN=91
# [val_prf   200/442] 13.38 it/s | TP=687 FP=107 FN=113
# [val_prf   250/442] 13.43 it/s | TP=870 FP=132 FN=130
# [val_prf   300/442] 13.46 it/s | TP=1040 FP=154 FN=160
# [val_prf   350/442] 13.50 it/s | TP=1207 FP=184 FN=193
# [val_prf   400/442] 13.40 it/s | TP=1388 FP=196 FN=212
# [val_prf   442/442] 13.48 it/s | TP=1530 FP=215 FN=236
# FIN val_prf  (0.5 min)
# INICIO val_mAP (batches=442) ...
# FIN val_mAP  (0.6 min)
# [RESUMEN ÉPOCA 09] lr→0.0005 | dur=5.2 min | train_loss=0.0807 | val_loss=0.1337 | val_rec=0.847 | val_f2=0.850 | val_mAP50=0.843 | val_mAP=0.360
#
# ================================================================================
# INICIO ÉPOCA 10/20  |  train_batches: 1546  |  batch_size: 4
# GPU: NVIDIA A100-SXM4-40GB  |  VRAM total: 39.6 GB
# ================================================================================
# [batch   50/1546] loss(b)=0.0679 | loss(µ50)=0.0843 | lr=0.0005 | 29.8 img/s | ETA~3m27s | GPU~2821 MiB
# [batch  100/1546] loss(b)=0.0924 | loss(µ50)=0.0778 | lr=0.0005 | 29.8 img/s | ETA~3m14s | GPU~2821 MiB
# [batch  150/1546] loss(b)=0.0963 | loss(µ50)=0.0802 | lr=0.0005 | 29.6 img/s | ETA~3m8s | GPU~2821 MiB
# [batch  200/1546] loss(b)=0.0741 | loss(µ50)=0.0746 | lr=0.0005 | 30.1 img/s | ETA~3m0s | GPU~2821 MiB
# [batch  250/1546] loss(b)=0.0778 | loss(µ50)=0.0826 | lr=0.0005 | 30.4 img/s | ETA~2m52s | GPU~2821 MiB
# [batch  300/1546] loss(b)=0.0668 | loss(µ50)=0.0798 | lr=0.0005 | 29.5 img/s | ETA~2m46s | GPU~2821 MiB
# [batch  350/1546] loss(b)=0.1002 | loss(µ50)=0.0770 | lr=0.0005 | 30.2 img/s | ETA~2m39s | GPU~2821 MiB
# [batch  400/1546] loss(b)=0.0608 | loss(µ50)=0.0743 | lr=0.0005 | 29.7 img/s | ETA~2m32s | GPU~2821 MiB
# [batch  450/1546] loss(b)=0.0664 | loss(µ50)=0.0781 | lr=0.0005 | 29.2 img/s | ETA~2m28s | GPU~2821 MiB
# [batch  500/1546] loss(b)=0.0763 | loss(µ50)=0.0773 | lr=0.0005 | 29.8 img/s | ETA~2m20s | GPU~2821 MiB
# [batch  550/1546] loss(b)=0.0713 | loss(µ50)=0.0791 | lr=0.0005 | 29.2 img/s | ETA~2m15s | GPU~2821 MiB
# [batch  600/1546] loss(b)=0.0829 | loss(µ50)=0.0752 | lr=0.0005 | 30.6 img/s | ETA~2m7s | GPU~2821 MiB
# [batch  650/1546] loss(b)=0.0630 | loss(µ50)=0.0731 | lr=0.0005 | 29.0 img/s | ETA~2m1s | GPU~2821 MiB
# [batch  700/1546] loss(b)=0.0744 | loss(µ50)=0.0788 | lr=0.0005 | 29.8 img/s | ETA~1m53s | GPU~2822 MiB
# [batch  750/1546] loss(b)=0.0919 | loss(µ50)=0.0766 | lr=0.0005 | 29.5 img/s | ETA~1m47s | GPU~2822 MiB
# [batch  800/1546] loss(b)=0.0624 | loss(µ50)=0.0743 | lr=0.0005 | 28.8 img/s | ETA~1m42s | GPU~2822 MiB
# [batch  850/1546] loss(b)=0.0993 | loss(µ50)=0.0828 | lr=0.0005 | 29.8 img/s | ETA~1m34s | GPU~2822 MiB
# [batch  900/1546] loss(b)=0.0873 | loss(µ50)=0.0799 | lr=0.0005 | 28.9 img/s | ETA~1m27s | GPU~2822 MiB
# [batch  950/1546] loss(b)=0.0955 | loss(µ50)=0.0798 | lr=0.0005 | 30.9 img/s | ETA~1m20s | GPU~2822 MiB
# [batch 1000/1546] loss(b)=0.1030 | loss(µ50)=0.0799 | lr=0.0005 | 31.4 img/s | ETA~1m13s | GPU~2822 MiB
# [batch 1050/1546] loss(b)=0.0914 | loss(µ50)=0.0794 | lr=0.0005 | 28.5 img/s | ETA~1m7s | GPU~2822 MiB
# [batch 1100/1546] loss(b)=0.0669 | loss(µ50)=0.0791 | lr=0.0005 | 30.3 img/s | ETA~1m1s | GPU~2822 MiB
# [batch 1150/1546] loss(b)=0.0960 | loss(µ50)=0.0794 | lr=0.0005 | 29.7 img/s | ETA~0m53s | GPU~2822 MiB
# [batch 1200/1546] loss(b)=0.1153 | loss(µ50)=0.0760 | lr=0.0005 | 30.1 img/s | ETA~0m46s | GPU~2822 MiB
# [batch 1250/1546] loss(b)=0.0708 | loss(µ50)=0.0787 | lr=0.0005 | 29.9 img/s | ETA~0m39s | GPU~2822 MiB
# [batch 1300/1546] loss(b)=0.0886 | loss(µ50)=0.0793 | lr=0.0005 | 30.4 img/s | ETA~0m32s | GPU~2822 MiB
# [batch 1350/1546] loss(b)=0.0963 | loss(µ50)=0.0770 | lr=0.0005 | 30.0 img/s | ETA~0m26s | GPU~2822 MiB
# [batch 1400/1546] loss(b)=0.0938 | loss(µ50)=0.0768 | lr=0.0005 | 30.6 img/s | ETA~0m19s | GPU~2822 MiB
# [batch 1450/1546] loss(b)=0.0822 | loss(µ50)=0.0787 | lr=0.0005 | 29.3 img/s | ETA~0m13s | GPU~2822 MiB
# [batch 1500/1546] loss(b)=0.0622 | loss(µ50)=0.0822 | lr=0.0005 | 29.7 img/s | ETA~0m6s | GPU~2822 MiB
# [batch 1546/1546] loss(b)=0.0542 | loss(µ50)=0.0775 | lr=0.0005 | 10.8 img/s | ETA~0m0s | GPU~2822 MiB
# FIN TRAIN
# INICIO val_loss (batches=442) ...
# [val_loss   50/442] loss=0.1325 | 11.40 it/s
# [val_loss  100/442] loss=0.1050 | 11.76 it/s
# [val_loss  150/442] loss=0.1575 | 11.85 it/s
# [val_loss  200/442] loss=0.1854 | 11.87 it/s
# [val_loss  250/442] loss=0.0808 | 11.88 it/s
# [val_loss  300/442] loss=0.1502 | 11.91 it/s
# [val_loss  350/442] loss=0.0857 | 11.93 it/s
# [val_loss  400/442] loss=0.1449 | 11.94 it/s
# [val_loss  442/442] loss=0.1208 | 11.97 it/s
# FIN val_loss  (0.6 min)
# INICIO val_prf (batches=442) ...
# [val_prf    50/442] 13.04 it/s | TP=125 FP=44 FN=75
# [val_prf   100/442] 13.20 it/s | TP=309 FP=63 FN=91
# [val_prf   150/442] 12.94 it/s | TP=502 FP=80 FN=98
# [val_prf   200/442] 13.10 it/s | TP=681 FP=98 FN=119
# [val_prf   250/442] 13.18 it/s | TP=866 FP=120 FN=134
# [val_prf   300/442] 13.13 it/s | TP=1039 FP=145 FN=161
# [val_prf   350/442] 13.20 it/s | TP=1206 FP=174 FN=194
# [val_prf   400/442] 13.25 it/s | TP=1385 FP=187 FN=215
# [val_prf   442/442] 13.30 it/s | TP=1528 FP=206 FN=238
# FIN val_prf  (0.6 min)
# INICIO val_mAP (batches=442) ...
# FIN val_mAP  (0.6 min)
# [RESUMEN ÉPOCA 10] lr→5e-05 | dur=5.2 min | train_loss=0.0784 | val_loss=0.1345 | val_rec=0.843 | val_f2=0.847 | val_mAP50=0.841 | val_mAP=0.363
#
# ================================================================================
# INICIO ÉPOCA 11/20  |  train_batches: 1546  |  batch_size: 4
# GPU: NVIDIA A100-SXM4-40GB  |  VRAM total: 39.6 GB
# ================================================================================
# [batch   50/1546] loss(b)=0.0615 | loss(µ50)=0.0749 | lr=5e-05 | 30.1 img/s | ETA~3m25s | GPU~2822 MiB
# [batch  100/1546] loss(b)=0.0536 | loss(µ50)=0.0709 | lr=5e-05 | 28.5 img/s | ETA~3m17s | GPU~2822 MiB
# [batch  150/1546] loss(b)=0.0788 | loss(µ50)=0.0796 | lr=5e-05 | 30.1 img/s | ETA~3m8s | GPU~2822 MiB
# [batch  200/1546] loss(b)=0.0480 | loss(µ50)=0.0693 | lr=5e-05 | 30.0 img/s | ETA~2m59s | GPU~2822 MiB
# [batch  250/1546] loss(b)=0.0687 | loss(µ50)=0.0745 | lr=5e-05 | 29.6 img/s | ETA~2m53s | GPU~2822 MiB
# [batch  300/1546] loss(b)=0.0936 | loss(µ50)=0.0679 | lr=5e-05 | 29.8 img/s | ETA~2m46s | GPU~2822 MiB
# [batch  350/1546] loss(b)=0.0668 | loss(µ50)=0.0750 | lr=5e-05 | 30.2 img/s | ETA~2m40s | GPU~2822 MiB
# ...
# [batch 1250/1546] loss(b)=0.0514 | loss(µ50)=0.0724 | lr=5e-06 | 29.2 img/s | ETA~0m39s | GPU~2823 MiB
# [batch 1300/1546] loss(b)=0.0545 | loss(µ50)=0.0725 | lr=5e-06 | 29.3 img/s | ETA~0m33s | GPU~2823 MiB
# [batch 1350/1546] loss(b)=0.0691 | loss(µ50)=0.0758 | lr=5e-06 | 29.5 img/s | ETA~0m26s | GPU~2823 MiB
# [batch 1400/1546] loss(b)=0.0686 | loss(µ50)=0.0757 | lr=5e-06 | 29.9 img/s | ETA~0m19s | GPU~2823 MiB
# [batch 1450/1546] loss(b)=0.0838 | loss(µ50)=0.0708 | lr=5e-06 | 29.5 img/s | ETA~0m12s | GPU~2823 MiB
# [batch 1500/1546] loss(b)=0.0853 | loss(µ50)=0.0714 | lr=5e-06 | 29.8 img/s | ETA~0m6s | GPU~2823 MiB
# [batch 1546/1546] loss(b)=0.0807 | loss(µ50)=0.0705 | lr=5e-06 | 10.8 img/s | ETA~0m0s | GPU~2823 MiB
# FIN TRAIN
# INICIO val_loss (batches=442) ...
# [val_loss   50/442] loss=0.1263 | 11.61 it/s
# [val_loss  100/442] loss=0.1056 | 11.66 it/s
# [val_loss  150/442] loss=0.1556 | 11.74 it/s
# [val_loss  200/442] loss=0.1870 | 11.81 it/s
# [val_loss  250/442] loss=0.0856 | 11.78 it/s
# [val_loss  300/442] loss=0.1466 | 11.82 it/s
# [val_loss  350/442] loss=0.0867 | 11.87 it/s
# [val_loss  400/442] loss=0.1449 | 11.87 it/s
# [val_loss  442/442] loss=0.1356 | 11.87 it/s
# FIN val_loss  (0.6 min)
# INICIO val_prf (batches=442) ...
# [val_prf    50/442] 12.94 it/s | TP=124 FP=48 FN=76
# [val_prf   100/442] 13.06 it/s | TP=308 FP=68 FN=92
# [val_prf   150/442] 13.08 it/s | TP=500 FP=86 FN=100
# [val_prf   200/442] 13.17 it/s | TP=680 FP=103 FN=120
# [val_prf   250/442] 13.17 it/s | TP=865 FP=127 FN=135
# [val_prf   300/442] 13.18 it/s | TP=1039 FP=151 FN=161
# [val_prf   350/442] 13.22 it/s | TP=1203 FP=178 FN=197
# [val_prf   400/442] 13.25 it/s | TP=1384 FP=190 FN=216
# [val_prf   442/442] 13.27 it/s | TP=1528 FP=209 FN=238
# FIN val_prf  (0.6 min)
# INICIO val_mAP (batches=442) ...
# FIN val_mAP  (0.6 min)
# [RESUMEN ÉPOCA 17] lr→5e-06 | dur=5.2 min | train_loss=0.0718 | val_loss=0.1370 | val_rec=0.843 | val_f2=0.846 | val_mAP50=0.833 | val_mAP=0.356
#
# ================================================================================
# INICIO ÉPOCA 18/20  |  train_batches: 1546  |  batch_size: 4
# GPU: NVIDIA A100-SXM4-40GB  |  VRAM total: 39.6 GB
# ================================================================================
# [batch   50/1546] loss(b)=0.0863 | loss(µ50)=0.0683 | lr=5e-06 | 29.9 img/s | ETA~3m25s | GPU~2821 MiB
# [batch  100/1546] loss(b)=0.0411 | loss(µ50)=0.0666 | lr=5e-06 | 28.4 img/s | ETA~3m14s | GPU~2822 MiB
# [batch  150/1546] loss(b)=0.0868 | loss(µ50)=0.0717 | lr=5e-06 | 29.8 img/s | ETA~3m7s | GPU~2822 MiB
# [batch  200/1546] loss(b)=0.1087 | loss(µ50)=0.0755 | lr=5e-06 | 30.2 img/s | ETA~3m0s | GPU~2822 MiB
# [batch  250/1546] loss(b)=0.0600 | loss(µ50)=0.0727 | lr=5e-06 | 30.4 img/s | ETA~2m52s | GPU~2822 MiB
# [batch  300/1546] loss(b)=0.0764 | loss(µ50)=0.0717 | lr=5e-06 | 29.8 img/s | ETA~2m46s | GPU~2822 MiB
# [batch  350/1546] loss(b)=0.0752 | loss(µ50)=0.0720 | lr=5e-06 | 30.0 img/s | ETA~2m40s | GPU~2822 MiB
# [batch  400/1546] loss(b)=0.0743 | loss(µ50)=0.0718 | lr=5e-06 | 29.6 img/s | ETA~2m34s | GPU~2822 MiB
# [batch  450/1546] loss(b)=0.0968 | loss(µ50)=0.0721 | lr=5e-06 | 29.9 img/s | ETA~2m27s | GPU~2822 MiB
# [batch  500/1546] loss(b)=0.0781 | loss(µ50)=0.0707 | lr=5e-06 | 30.1 img/s | ETA~2m20s | GPU~2822 MiB
# [batch  550/1546] loss(b)=0.0772 | loss(µ50)=0.0770 | lr=5e-06 | 28.2 img/s | ETA~2m13s | GPU~2822 MiB
# [batch  600/1546] loss(b)=0.1071 | loss(µ50)=0.0706 | lr=5e-06 | 29.8 img/s | ETA~2m6s | GPU~2822 MiB
# [batch  650/1546] loss(b)=0.1075 | loss(µ50)=0.0763 | lr=5e-06 | 29.8 img/s | ETA~2m0s | GPU~2822 MiB
# [batch  700/1546] loss(b)=0.0799 | loss(µ50)=0.0693 | lr=5e-06 | 29.9 img/s | ETA~1m52s | GPU~2822 MiB
# [batch  750/1546] loss(b)=0.0668 | loss(µ50)=0.0674 | lr=5e-06 | 30.1 img/s | ETA~1m47s | GPU~2822 MiB
# [batch  800/1546] loss(b)=0.0769 | loss(µ50)=0.0723 | lr=5e-06 | 29.7 img/s | ETA~1m40s | GPU~2822 MiB
# [batch  850/1546] loss(b)=0.0576 | loss(µ50)=0.0670 | lr=5e-06 | 29.3 img/s | ETA~1m34s | GPU~2822 MiB
# [batch  900/1546] loss(b)=0.0898 | loss(µ50)=0.0696 | lr=5e-06 | 29.9 img/s | ETA~1m26s | GPU~2822 MiB
# [batch  950/1546] loss(b)=0.0614 | loss(µ50)=0.0737 | lr=5e-06 | 30.1 img/s | ETA~1m19s | GPU~2822 MiB
# [batch 1000/1546] loss(b)=0.0604 | loss(µ50)=0.0716 | lr=5e-06 | 30.1 img/s | ETA~1m13s | GPU~2822 MiB
# [batch 1050/1546] loss(b)=0.0766 | loss(µ50)=0.0692 | lr=5e-06 | 30.4 img/s | ETA~1m6s | GPU~2822 MiB
# [batch 1100/1546] loss(b)=0.0531 | loss(µ50)=0.0740 | lr=5e-06 | 29.7 img/s | ETA~0m59s | GPU~2822 MiB
# [batch 1150/1546] loss(b)=0.0847 | loss(µ50)=0.0724 | lr=5e-06 | 29.6 img/s | ETA~0m53s | GPU~2822 MiB
# [batch 1200/1546] loss(b)=0.0708 | loss(µ50)=0.0721 | lr=5e-06 | 30.0 img/s | ETA~0m46s | GPU~2822 MiB
# [batch 1250/1546] loss(b)=0.0690 | loss(µ50)=0.0736 | lr=5e-06 | 30.2 img/s | ETA~0m39s | GPU~2822 MiB
# [batch 1300/1546] loss(b)=0.1069 | loss(µ50)=0.0744 | lr=5e-06 | 29.2 img/s | ETA~0m33s | GPU~2822 MiB
# [batch 1350/1546] loss(b)=0.0996 | loss(µ50)=0.0741 | lr=5e-06 | 30.2 img/s | ETA~0m26s | GPU~2822 MiB
# [batch 1400/1546] loss(b)=0.0844 | loss(µ50)=0.0713 | lr=5e-06 | 30.0 img/s | ETA~0m19s | GPU~2822 MiB
# [batch 1450/1546] loss(b)=0.0881 | loss(µ50)=0.0685 | lr=5e-06 | 30.3 img/s | ETA~0m12s | GPU~2822 MiB
# [batch 1500/1546] loss(b)=0.0522 | loss(µ50)=0.0705 | lr=5e-06 | 30.2 img/s | ETA~0m6s | GPU~2822 MiB
# [batch 1546/1546] loss(b)=0.0739 | loss(µ50)=0.0742 | lr=5e-06 | 10.9 img/s | ETA~0m0s | GPU~2822 MiB
# FIN TRAIN
# INICIO val_loss (batches=442) ...
# [val_loss   50/442] loss=0.1264 | 11.65 it/s
# [val_loss  100/442] loss=0.1025 | 11.93 it/s
# [val_loss  150/442] loss=0.1502 | 12.07 it/s
# [val_loss  200/442] loss=0.1944 | 12.16 it/s
# [val_loss  250/442] loss=0.0821 | 12.22 it/s
# [val_loss  300/442] loss=0.1446 | 12.24 it/s
# [val_loss  350/442] loss=0.0916 | 12.26 it/s
# [val_loss  400/442] loss=0.1508 | 12.27 it/s
# [val_loss  442/442] loss=0.1301 | 12.31 it/s
# FIN val_loss  (0.6 min)
# INICIO val_prf (batches=442) ...
# [val_prf    50/442] 13.21 it/s | TP=124 FP=48 FN=76
# [val_prf   100/442] 13.49 it/s | TP=308 FP=68 FN=92
# [val_prf   150/442] 13.64 it/s | TP=499 FP=86 FN=101
# [val_prf   200/442] 13.70 it/s | TP=679 FP=103 FN=121
# [val_prf   250/442] 13.74 it/s | TP=864 FP=127 FN=136
# [val_prf   300/442] 13.74 it/s | TP=1038 FP=151 FN=162
# [val_prf   350/442] 13.72 it/s | TP=1202 FP=178 FN=198
# [val_prf   400/442] 13.72 it/s | TP=1383 FP=190 FN=217
# [val_prf   442/442] 13.62 it/s | TP=1527 FP=209 FN=239
# FIN val_prf  (0.5 min)
# INICIO val_mAP (batches=442) ...
# FIN val_mAP  (0.6 min)
# [RESUMEN ÉPOCA 18] lr→5e-06 | dur=5.2 min | train_loss=0.0717 | val_loss=0.1369 | val_rec=0.842 | val_f2=0.846 | val_mAP50=0.833 | val_mAP=0.356
#
# ================================================================================
# INICIO ÉPOCA 19/20  |  train_batches: 1546  |  batch_size: 4
# GPU: NVIDIA A100-SXM4-40GB  |  VRAM total: 39.6 GB
# ================================================================================
# [batch   50/1546] loss(b)=0.0538 | loss(µ50)=0.0657 | lr=5e-06 | 30.0 img/s | ETA~3m23s | GPU~2821 MiB
# [batch  100/1546] loss(b)=0.0608 | loss(µ50)=0.0720 | lr=5e-06 | 30.1 img/s | ETA~3m13s | GPU~2821 MiB
# [batch  150/1546] loss(b)=0.0368 | loss(µ50)=0.0694 | lr=5e-06 | 30.1 img/s | ETA~3m7s | GPU~2821 MiB
# [batch  200/1546] loss(b)=0.0646 | loss(µ50)=0.0728 | lr=5e-06 | 29.9 img/s | ETA~2m59s | GPU~2821 MiB
# [batch  250/1546] loss(b)=0.0710 | loss(µ50)=0.0760 | lr=5e-06 | 30.0 img/s | ETA~2m55s | GPU~2821 MiB
# [batch  300/1546] loss(b)=0.0895 | loss(µ50)=0.0753 | lr=5e-06 | 29.9 img/s | ETA~2m46s | GPU~2821 MiB
# [batch  350/1546] loss(b)=0.0579 | loss(µ50)=0.0725 | lr=5e-06 | 29.2 img/s | ETA~2m40s | GPU~2821 MiB
# [batch  400/1546] loss(b)=0.0717 | loss(µ50)=0.0707 | lr=5e-06 | 30.0 img/s | ETA~2m35s | GPU~2821 MiB
# [batch  450/1546] loss(b)=0.0488 | loss(µ50)=0.0686 | lr=5e-06 | 29.9 img/s | ETA~2m29s | GPU~2821 MiB
# [batch  500/1546] loss(b)=0.0827 | loss(µ50)=0.0700 | lr=5e-06 | 30.3 img/s | ETA~2m19s | GPU~2821 MiB
# [batch  550/1546] loss(b)=0.0848 | loss(µ50)=0.0725 | lr=5e-06 | 30.1 img/s | ETA~2m14s | GPU~2821 MiB
# [batch  600/1546] loss(b)=0.0789 | loss(µ50)=0.0706 | lr=5e-06 | 28.4 img/s | ETA~2m6s | GPU~2821 MiB
# [batch  650/1546] loss(b)=0.0612 | loss(µ50)=0.0707 | lr=5e-06 | 29.8 img/s | ETA~2m0s | GPU~2821 MiB
# [batch  700/1546] loss(b)=0.0432 | loss(µ50)=0.0711 | lr=5e-06 | 30.3 img/s | ETA~1m53s | GPU~2821 MiB
# [batch  750/1546] loss(b)=0.0877 | loss(µ50)=0.0690 | lr=5e-06 | 30.1 img/s | ETA~1m46s | GPU~2821 MiB
# [batch  800/1546] loss(b)=0.0550 | loss(µ50)=0.0751 | lr=5e-06 | 29.8 img/s | ETA~1m39s | GPU~2821 MiB
# [batch  850/1546] loss(b)=0.0772 | loss(µ50)=0.0778 | lr=5e-06 | 29.6 img/s | ETA~1m32s | GPU~2821 MiB
# [batch  900/1546] loss(b)=0.0936 | loss(µ50)=0.0753 | lr=5e-06 | 29.9 img/s | ETA~1m26s | GPU~2821 MiB
# [batch  950/1546] loss(b)=0.0518 | loss(µ50)=0.0728 | lr=5e-06 | 29.5 img/s | ETA~1m19s | GPU~2821 MiB
# [batch 1000/1546] loss(b)=0.0545 | loss(µ50)=0.0704 | lr=5e-06 | 30.0 img/s | ETA~1m13s | GPU~2821 MiB
# [batch 1050/1546] loss(b)=0.0775 | loss(µ50)=0.0734 | lr=5e-06 | 29.5 img/s | ETA~1m6s | GPU~2821 MiB
# [batch 1100/1546] loss(b)=0.0723 | loss(µ50)=0.0697 | lr=5e-06 | 30.0 img/s | ETA~1m0s | GPU~2821 MiB
# [batch 1150/1546] loss(b)=0.0657 | loss(µ50)=0.0708 | lr=5e-06 | 30.0 img/s | ETA~0m53s | GPU~2821 MiB
# [batch 1200/1546] loss(b)=0.0712 | loss(µ50)=0.0710 | lr=5e-06 | 30.0 img/s | ETA~0m46s | GPU~2821 MiB
# [batch 1250/1546] loss(b)=0.0696 | loss(µ50)=0.0674 | lr=5e-06 | 30.1 img/s | ETA~0m39s | GPU~2821 MiB
# [batch 1300/1546] loss(b)=0.0978 | loss(µ50)=0.0774 | lr=5e-06 | 29.9 img/s | ETA~0m32s | GPU~2821 MiB
# [batch 1350/1546] loss(b)=0.0321 | loss(µ50)=0.0741 | lr=5e-06 | 29.2 img/s | ETA~0m26s | GPU~2821 MiB
# [batch 1400/1546] loss(b)=0.0555 | loss(µ50)=0.0708 | lr=5e-06 | 29.9 img/s | ETA~0m19s | GPU~2821 MiB
# [batch 1450/1546] loss(b)=0.0898 | loss(µ50)=0.0682 | lr=5e-06 | 29.6 img/s | ETA~0m12s | GPU~2821 MiB
# [batch 1500/1546] loss(b)=0.0626 | loss(µ50)=0.0700 | lr=5e-06 | 30.0 img/s | ETA~0m6s | GPU~2821 MiB
# [batch 1546/1546] loss(b)=0.1506 | loss(µ50)=0.0723 | lr=5e-06 | 10.9 img/s | ETA~0m0s | GPU~2821 MiB
# FIN TRAIN
# INICIO val_loss (batches=442) ...
# [val_loss   50/442] loss=0.1269 | 11.75 it/s
# [val_loss  100/442] loss=0.1043 | 12.06 it/s
# [val_loss  150/442] loss=0.1438 | 12.10 it/s
# [val_loss  200/442] loss=0.1915 | 12.07 it/s
# [val_loss  250/442] loss=0.0847 | 12.08 it/s
# [val_loss  300/442] loss=0.1403 | 12.01 it/s
# [val_loss  350/442] loss=0.0905 | 11.99 it/s
# [val_loss  400/442] loss=0.1478 | 11.97 it/s
# [val_loss  442/442] loss=0.1339 | 11.94 it/s
# FIN val_loss  (0.6 min)
# INICIO val_prf (batches=442) ...
# [val_prf    50/442] 12.73 it/s | TP=124 FP=50 FN=76
# [val_prf   100/442] 13.00 it/s | TP=308 FP=70 FN=92
# [val_prf   150/442] 13.04 it/s | TP=499 FP=88 FN=101
# [val_prf   200/442] 12.98 it/s | TP=679 FP=105 FN=121
# [val_prf   250/442] 13.03 it/s | TP=864 FP=129 FN=136
# [val_prf   300/442] 13.07 it/s | TP=1038 FP=153 FN=162
# [val_prf   350/442] 13.08 it/s | TP=1202 FP=180 FN=198
# [val_prf   400/442] 13.09 it/s | TP=1383 FP=192 FN=217
# [val_prf   442/442] 12.93 it/s | TP=1527 FP=211 FN=239
# FIN val_prf  (0.6 min)
# INICIO val_mAP (batches=442) ...
# FIN val_mAP  (0.6 min)
# [RESUMEN ÉPOCA 19] lr→5e-06 | dur=5.2 min | train_loss=0.0717 | val_loss=0.1371 | val_rec=0.842 | val_f2=0.846 | val_mAP50=0.833 | val_mAP=0.356
#
# ================================================================================
# INICIO ÉPOCA 20/20  |  train_batches: 1546  |  batch_size: 4
# GPU: NVIDIA A100-SXM4-40GB  |  VRAM total: 39.6 GB
# ================================================================================
# [batch   50/1546] loss(b)=0.0719 | loss(µ50)=0.0711 | lr=5e-06 | 29.0 img/s | ETA~3m28s | GPU~2821 MiB
# [batch  100/1546] loss(b)=0.0720 | loss(µ50)=0.0713 | lr=5e-06 | 29.9 img/s | ETA~3m17s | GPU~2821 MiB
# [batch  150/1546] loss(b)=0.0899 | loss(µ50)=0.0754 | lr=5e-06 | 29.9 img/s | ETA~3m9s | GPU~2821 MiB
# [batch  200/1546] loss(b)=0.0577 | loss(µ50)=0.0744 | lr=5e-06 | 28.6 img/s | ETA~3m1s | GPU~2821 MiB
# [batch  250/1546] loss(b)=0.0471 | loss(µ50)=0.0724 | lr=5e-06 | 30.1 img/s | ETA~2m53s | GPU~2821 MiB
# [batch  300/1546] loss(b)=0.0736 | loss(µ50)=0.0732 | lr=5e-06 | 29.8 img/s | ETA~2m45s | GPU~2821 MiB
# [batch  350/1546] loss(b)=0.0826 | loss(µ50)=0.0682 | lr=5e-06 | 29.8 img/s | ETA~2m42s | GPU~2821 MiB
# [batch  400/1546] loss(b)=0.0537 | loss(µ50)=0.0751 | lr=5e-06 | 29.9 img/s | ETA~2m35s | GPU~2821 MiB
# [batch  450/1546] loss(b)=0.0439 | loss(µ50)=0.0707 | lr=5e-06 | 28.9 img/s | ETA~2m30s | GPU~2821 MiB
# [batch  500/1546] loss(b)=0.0496 | loss(µ50)=0.0721 | lr=5e-06 | 29.5 img/s | ETA~2m23s | GPU~2821 MiB
# [batch  550/1546] loss(b)=0.0791 | loss(µ50)=0.0736 | lr=5e-06 | 29.1 img/s | ETA~2m17s | GPU~2822 MiB
# [batch  600/1546] loss(b)=0.0893 | loss(µ50)=0.0747 | lr=5e-06 | 29.7 img/s | ETA~2m9s | GPU~2822 MiB
# [batch  650/1546] loss(b)=0.0915 | loss(µ50)=0.0723 | lr=5e-06 | 29.1 img/s | ETA~2m2s | GPU~2822 MiB
# [batch  700/1546] loss(b)=0.0920 | loss(µ50)=0.0692 | lr=5e-06 | 29.3 img/s | ETA~1m55s | GPU~2822 MiB
# [batch  750/1546] loss(b)=0.0771 | loss(µ50)=0.0681 | lr=5e-06 | 29.6 img/s | ETA~1m48s | GPU~2822 MiB
# [batch  800/1546] loss(b)=0.0589 | loss(µ50)=0.0686 | lr=5e-06 | 29.3 img/s | ETA~1m42s | GPU~2822 MiB
# [batch  850/1546] loss(b)=0.0934 | loss(µ50)=0.0740 | lr=5e-06 | 29.0 img/s | ETA~1m34s | GPU~2822 MiB
# [batch  900/1546] loss(b)=0.1003 | loss(µ50)=0.0729 | lr=5e-06 | 29.0 img/s | ETA~1m28s | GPU~2822 MiB
# [batch  950/1546] loss(b)=0.0662 | loss(µ50)=0.0701 | lr=5e-06 | 28.7 img/s | ETA~1m22s | GPU~2822 MiB
# [batch 1000/1546] loss(b)=0.0465 | loss(µ50)=0.0699 | lr=5e-06 | 29.8 img/s | ETA~1m13s | GPU~2822 MiB
# [batch 1050/1546] loss(b)=0.0689 | loss(µ50)=0.0726 | lr=5e-06 | 29.7 img/s | ETA~1m7s | GPU~2822 MiB
# [batch 1100/1546] loss(b)=0.0952 | loss(µ50)=0.0757 | lr=5e-06 | 30.3 img/s | ETA~0m59s | GPU~2822 MiB
# [batch 1150/1546] loss(b)=0.0816 | loss(µ50)=0.0691 | lr=5e-06 | 29.7 img/s | ETA~0m53s | GPU~2822 MiB
# [batch 1200/1546] loss(b)=0.0697 | loss(µ50)=0.0709 | lr=5e-06 | 30.0 img/s | ETA~0m46s | GPU~2822 MiB
# [batch 1250/1546] loss(b)=0.0695 | loss(µ50)=0.0733 | lr=5e-06 | 30.4 img/s | ETA~0m39s | GPU~2822 MiB
# [batch 1300/1546] loss(b)=0.0732 | loss(µ50)=0.0699 | lr=5e-06 | 30.1 img/s | ETA~0m32s | GPU~2822 MiB
# [batch 1350/1546] loss(b)=0.0624 | loss(µ50)=0.0685 | lr=5e-06 | 29.7 img/s | ETA~0m26s | GPU~2822 MiB
# [batch 1400/1546] loss(b)=0.0530 | loss(µ50)=0.0684 | lr=5e-06 | 29.5 img/s | ETA~0m20s | GPU~2822 MiB
# [batch 1450/1546] loss(b)=0.0434 | loss(µ50)=0.0701 | lr=5e-06 | 29.5 img/s | ETA~0m13s | GPU~2822 MiB
# [batch 1500/1546] loss(b)=0.0994 | loss(µ50)=0.0703 | lr=5e-06 | 29.5 img/s | ETA~0m6s | GPU~2822 MiB
# [batch 1546/1546] loss(b)=0.0774 | loss(µ50)=0.0749 | lr=5e-06 | 10.7 img/s | ETA~0m0s | GPU~2822 MiB
# FIN TRAIN
# INICIO val_loss (batches=442) ...
# [val_loss   50/442] loss=0.1252 | 11.24 it/s
# [val_loss  100/442] loss=0.1025 | 11.63 it/s
# [val_loss  150/442] loss=0.1437 | 11.80 it/s
# [val_loss  200/442] loss=0.2002 | 11.87 it/s
# [val_loss  250/442] loss=0.0838 | 11.95 it/s
# [val_loss  300/442] loss=0.1379 | 12.00 it/s
# [val_loss  350/442] loss=0.0882 | 11.99 it/s
# [val_loss  400/442] loss=0.1459 | 11.99 it/s
# [val_loss  442/442] loss=0.1305 | 11.99 it/s
# FIN val_loss  (0.6 min)
# INICIO val_prf (batches=442) ...
# [val_prf    50/442] 12.51 it/s | TP=125 FP=49 FN=75
# [val_prf   100/442] 12.85 it/s | TP=309 FP=69 FN=91
# [val_prf   150/442] 12.93 it/s | TP=500 FP=87 FN=100
# [val_prf   200/442] 12.99 it/s | TP=680 FP=104 FN=120
# [val_prf   250/442] 13.06 it/s | TP=865 FP=128 FN=135
# [val_prf   300/442] 13.07 it/s | TP=1039 FP=152 FN=161
# [val_prf   350/442] 13.04 it/s | TP=1203 FP=179 FN=197
# [val_prf   400/442] 13.04 it/s | TP=1384 FP=191 FN=216
# [val_prf   442/442] 13.08 it/s | TP=1528 FP=210 FN=238
# FIN val_prf  (0.6 min)
# INICIO val_mAP (batches=442) ...
# FIN val_mAP  (0.6 min)
# [RESUMEN ÉPOCA 20] lr→5e-07 | dur=5.3 min | train_loss=0.0716 | val_loss=0.1372 | val_rec=0.843 | val_f2=0.847 | val_mAP50=0.833 | val_mAP=0.355

# %%
# ---------------------------------------
# 8) Graficar métricas por epoch
# ---------------------------------------

def _get(h, *keys, default=np.nan):
    cur = h
    for k in keys:
        if cur is None or not isinstance(cur, dict) or k not in cur:
            return default
        cur = cur[k]
    return cur if cur is not None else default

epochs = [h["epoch"] for h in history]

# Series base (loss + LR)
train_loss = [_get(h, "train", "loss_total") for h in history]
val_loss   = [_get(h, "valid", "loss_total") for h in history]

train_cls  = [_get(h, "train", "loss_classifier") for h in history]
train_box  = [_get(h, "train", "loss_box_reg") for h in history]
train_obj  = [_get(h, "train", "loss_objectness") for h in history]
train_rpn  = [_get(h, "train", "loss_rpn_box_reg") for h in history]

val_cls    = [_get(h, "valid", "loss_classifier") for h in history]
val_box    = [_get(h, "valid", "loss_box_reg") for h in history]
val_obj    = [_get(h, "valid", "loss_objectness") for h in history]
val_rpn    = [_get(h, "valid", "loss_rpn_box_reg") for h in history]

lr_series  = [_get(h, "lr") for h in history]

# Series de métricas (macro)
val_prec = [_get(h, "valid_macro", "precision") for h in history]
val_rec  = [_get(h, "valid_macro", "recall") for h in history]
val_f1   = [_get(h, "valid_macro", "f1") for h in history]
val_f2   = [_get(h, "valid_macro", "f2") for h in history]

# mAP (si existe)
map50 = [_get(h, "valid_map", "map_50") for h in history]
map95 = [_get(h, "valid_map", "map") for h in history]
has_map = np.any(np.isfinite(map50)) or np.any(np.isfinite(map95))

# Loss total: train vs val
plt.figure()
plt.plot(epochs, train_loss, marker="o", label="train loss_total")
plt.plot(epochs, val_loss,   marker="o", label="val loss_total")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss total (train vs val)")
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()

# Breakdown de losses (train vs val)
plt.figure()
plt.plot(epochs, train_cls, marker="o", label="train loss_classifier")
plt.plot(epochs, val_cls,   marker="o", label="val loss_classifier")
plt.xlabel("Epoch"); plt.ylabel("Loss"); plt.title("Loss: classifier"); plt.grid(True, alpha=0.3); plt.legend(); plt.show()

plt.figure()
plt.plot(epochs, train_box, marker="o", label="train loss_box_reg")
plt.plot(epochs, val_box,   marker="o", label="val loss_box_reg")
plt.xlabel("Epoch"); plt.ylabel("Loss"); plt.title("Loss: box_reg"); plt.grid(True, alpha=0.3); plt.legend(); plt.show()

plt.figure()
plt.plot(epochs, train_obj, marker="o", label="train loss_objectness")
plt.plot(epochs, val_obj,   marker="o", label="val loss_objectness")
plt.xlabel("Epoch"); plt.ylabel("Loss"); plt.title("Loss: objectness"); plt.grid(True, alpha=0.3); plt.legend(); plt.show()

plt.figure()
plt.plot(epochs, train_rpn, marker="o", label="train loss_rpn_box_reg")
plt.plot(epochs, val_rpn,   marker="o", label="val loss_rpn_box_reg")
plt.xlabel("Epoch"); plt.ylabel("Loss"); plt.title("Loss: rpn_box_reg"); plt.grid(True, alpha=0.3); plt.legend(); plt.show()

# Métricas macro en VALID (precision/recall/F1/F2)
plt.figure()
plt.plot(epochs, val_prec, marker="o", label="val macro precision")
plt.plot(epochs, val_rec,  marker="o", label="val macro recall")
plt.plot(epochs, val_f1,   marker="o", label="val macro F1")
plt.plot(epochs, val_f2,   marker="o", label="val macro F2")
plt.xlabel("Epoch")
plt.ylabel("Score")
plt.ylim(0, 1.0)
plt.title("VALID macro metrics @ score_thresh / IoU")
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()

# mAP en VALID
if has_map:
    plt.figure()
    plt.plot(epochs, map50, marker="o", label="val mAP@0.5 (map_50)")
    plt.plot(epochs, map95, marker="o", label="val mAP@[0.5:0.95] (map)")
    plt.xlabel("Epoch")
    plt.ylabel("mAP")
    plt.ylim(0, 1.0)
    plt.title("VALID mAP (torchmetrics)")
    plt.grid(True, alpha=0.3)
    plt.legend()
    plt.show()
else:
    print("mAP no aparece en history.")

# Learning rate
plt.figure()
plt.plot(epochs, lr_series, marker="o")
plt.xlabel("Epoch")
plt.ylabel("LR")
plt.title("Learning Rate per epoch")
plt.grid(True, alpha=0.3)
plt.show()

# %%
print(f"Tiempo entrenamiento: {datetime.datetime.now() - INICIO_STEP}")
INICIO_STEP = datetime.datetime.now()
# Out:
# Tiempo entrenamiento: 1:44:32.655357

# %%
# ---------------------------------------
# 9) Guardado del modelo (pesos y checkpoint)
# ---------------------------------------

stamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
OUT_DIR = os.path.join(BASE_DIR, f"artifacts_{stamp}")
os.makedirs(OUT_DIR, exist_ok=True)

weights_path    = os.path.join(OUT_DIR, f"weights.pth")
checkpoint_path = os.path.join(OUT_DIR, f"frcnn_checkpoint.pth")
meta_path       = os.path.join(OUT_DIR, f"meta.json")

torch.save(model.state_dict(), weights_path)
print(f"[OK] Pesos guardados en: {weights_path}")

ckpt = {
    "model_state": model.state_dict(),
    "optimizer_state": optimizer.state_dict(),
    "epoch": EPOCHS,
    "num_classes": NUM_CLASSES,
    "class_names": CLASS_NAMES,
    "img_size": (416, 416),
    "lr": LR,
}
torch.save(ckpt, checkpoint_path)
print(f"[OK] Checkpoint guardado en: {checkpoint_path}")

meta = {
    "saved_at": stamp,
    "framework": "torchvision Faster R-CNN ResNet50-FPN",
    "device": str(device),
    "num_classes_with_bg": NUM_CLASSES_WITH_BG,
    "class_names": CLASS_NAMES,
    "train_imgs": len(train_ds),
    "valid_imgs": len(valid_ds),
    "test_imgs": len(test_ds),
    # "eval_valid_macro": eval_valid.get("macro", {}) if 'eval_valid' in locals() else {}
}
with open(meta_path, "w", encoding="utf-8") as f:
    json.dump(meta, f, indent=2, ensure_ascii=False)
print(f"[OK] Metadatos guardados en: {meta_path}")
# Out:
# [OK] Pesos guardados en: /content/drive/MyDrive/UBA/CEIA/Materias/Visión por Computadora II/google_colab_data/FasterR-CNN-ResNet50_notebook/artifacts_20251130_105928/weights.pth
# [OK] Checkpoint guardado en: /content/drive/MyDrive/UBA/CEIA/Materias/Visión por Computadora II/google_colab_data/FasterR-CNN-ResNet50_notebook/artifacts_20251130_105928/frcnn_checkpoint.pth
# [OK] Metadatos guardados en: /content/drive/MyDrive/UBA/CEIA/Materias/Visión por Computadora II/google_colab_data/FasterR-CNN-ResNet50_notebook/artifacts_20251130_105928/meta.json

# %%
print(f"Tiempo guardado modelo: {datetime.datetime.now() - INICIO_STEP}")
INICIO_STEP = datetime.datetime.now()
# Out:
# Tiempo guardado modelo: 0:00:01.435809

# %%
# ---------------------------------------
# 10) Matriz de confusión (valid y test)
# ---------------------------------------

def _greedy_match_iou(pred_boxes, gt_boxes, iou_thresh=0.5):
    if len(pred_boxes) == 0 or len(gt_boxes) == 0:
        return []

    ious = box_iou(pred_boxes, gt_boxes).cpu().numpy()
    matches = []
    used_pred = set()
    used_gt = set()

    # Recorremos pares en orden de IoU decreciente
    flat = [ (i, j, ious[i, j]) for i in range(ious.shape[0]) for j in range(ious.shape[1]) ]
    flat.sort(key=lambda x: x[2], reverse=True)

    for i, j, v in flat:
        if v < iou_thresh:
            break
        if (i not in used_pred) and (j not in used_gt):
            used_pred.add(i); used_gt.add(j)
            matches.append((i, j))
    return matches

def confusion_matrix_detection(model, loader, class_names, score_thresh=0.5, iou_thresh=0.5, normalize=True, title="Confusion Matrix"):
    model.eval()
    K = len(class_names)
    C = np.zeros((K+1, K+1), dtype=np.int64)  # filas=pred, cols=true ; ultimo índice = background
    bg = K  # índice background

    with torch.no_grad():
        for imgs, targets in loader:
            imgs = [img.to(device) for img in imgs]
            outs = model(imgs)

            for out, tgt in zip(outs, targets):
                # Filtrar por score
                keep = out["scores"].cpu().numpy() >= score_thresh
                p_boxes = out["boxes"][keep].cpu()
                p_labels = out["labels"][keep].cpu().numpy()  # en 1..K

                g_boxes  = tgt["boxes"].cpu()
                g_labels = tgt["labels"].cpu().numpy()        # en 1..K

                # Emparejar por IoU (class-agnostic) para poder medir confusiones entre clases
                matches = _greedy_match_iou(p_boxes, g_boxes, iou_thresh=iou_thresh)
                matched_pred = set(i for i, _ in matches)
                matched_gt   = set(j for _, j in matches)

                # Contar matches (pueden ser aciertos o confusiones de clase)
                for i, j in matches:
                    pred_c = int(p_labels[i]) - 1  # a 0..K-1
                    true_c = int(g_labels[j]) - 1
                    C[pred_c, true_c] += 1

                # Predicciones no emparejadas -> true = background
                for i in range(len(p_boxes)):
                    if i not in matched_pred:
                        pred_c = int(p_labels[i]) - 1
                        C[pred_c, bg] += 1

                # GT no emparejadas -> pred = background
                for j in range(len(g_boxes)):
                    if j not in matched_gt:
                        true_c = int(g_labels[j]) - 1
                        C[bg, true_c] += 1

    # Normalización por columna
    Cn = C.astype(float)
    if normalize:
        col_sums = Cn.sum(axis=0, keepdims=True)
        col_sums[col_sums == 0] = 1.0
        Cn = Cn / col_sums

    # Plot
    labels_plot = class_names + ["background"]
    fig, ax = plt.subplots(figsize=(8, 6))
    im = ax.imshow(Cn, interpolation='nearest', aspect='auto')
    ax.set_title(title)
    ax.set_xlabel("True")
    ax.set_ylabel("Predicted")
    ax.set_xticks(range(len(labels_plot)))
    ax.set_yticks(range(len(labels_plot)))
    ax.set_xticklabels(labels_plot, rotation=45, ha='right')
    ax.set_yticklabels(labels_plot)

    # Anotar valores
    for i in range(Cn.shape[0]):
        for j in range(Cn.shape[1]):
            val = Cn[i, j]
            txt = f"{val:.2f}" if normalize else str(C[i, j])
            ax.text(j, i, txt, ha='center', va='center', color='white' if val > 0.5 else 'black', fontsize=8)

    fig.colorbar(im, ax=ax, fraction=0.046, pad=0.04)
    plt.tight_layout()
    plt.show()

    return {"raw": C, "norm": Cn, "labels": labels_plot}

# Una matriz absoluta y normalizada para VALID y otra para TEST
confusion_matrix_detection(model, valid_dl, CLASS_NAMES, score_thresh=0.5, iou_thresh=0.5,
                           normalize=False, title="Matriz de confusión (Absoluta, VALID, IoU=0.5, score≥0.5)")
confusion_matrix_detection(model, valid_dl, CLASS_NAMES, score_thresh=0.5, iou_thresh=0.5,
                           normalize=True, title="Matriz de confusión (Normalizada, VALID, IoU=0.5, score≥0.5)")
confusion_matrix_detection(model, test_dl,  CLASS_NAMES, score_thresh=0.5, iou_thresh=0.5,
                           normalize=False, title="Matriz de confusión (Absoluta, TEST, IoU=0.5, score≥0.5)")
confusion_matrix_detection(model, test_dl,  CLASS_NAMES, score_thresh=0.5, iou_thresh=0.5,
                           normalize=True, title="Matriz de confusión (Normalizada, TEST, IoU=0.5, score≥0.5)")
# Out:
# {'raw': array([[159,   0,   0,   0,   0,   5],
#         [  0, 167,   0,   0,   0,  21],
#         [  0,   1,  84,   3,   0,  20],
#         [  1,   2,  10, 167,   1,  35],
#         [  0,   1,   0,   0, 181,  16],
#         [  6,  22,  24,  33,  21,   0]]),
#  'norm': array([[0.95783133, 0.        , 0.        , 0.        , 0.        ,
#          0.05154639],
#         [0.        , 0.86528497, 0.        , 0.        , 0.        ,
#          0.21649485],
#         [0.        , 0.00518135, 0.71186441, 0.01477833, 0.        ,
#          0.20618557],
#         [0.0060241 , 0.01036269, 0.08474576, 0.8226601 , 0.00492611,
#          0.36082474],
#         [0.        , 0.00518135, 0.        , 0.        , 0.89162562,
#          0.16494845],
#         [0.03614458, 0.11398964, 0.20338983, 0.16256158, 0.10344828,
#          0.        ]]),
#  'labels': ['Tijera',
#   'Navaja',
#   'Cuchillo',
#   'Cutter',
#   'Navaja multiuso',
#   'background']}

# %%
print(f"Tiempo matrices confusión: {datetime.datetime.now() - INICIO_STEP}")
INICIO_STEP = datetime.datetime.now()
# Out:
# Tiempo matrices confusión: 0:01:43.226388

# %%
# ---------------------------------------
# 11) Recolectar métricas y guardar en JSON
# ---------------------------------------

if 'train_loss_history' not in globals():
    train_loss_history = []

def summarize_eval(eval_dict, split_name):
    if eval_dict is None:
        return None
    per_class = []
    for (name, tp, fp, fn, prec, rec, f1) in eval_dict["per_class"]:
        per_class.append({
            "class": name,
            "tp": int(tp),
            "fp": int(fp),
            "fn": int(fn),
            "precision": float(prec),
            "recall": float(rec),
            "f1": float(f1),
        })
    # totales (sin background)
    TP = int(eval_dict["raw"]["TP"][1:].sum())
    FP = int(eval_dict["raw"]["FP"][1:].sum())
    FN = int(eval_dict["raw"]["FN"][1:].sum())
    return {
        "split": split_name,
        "macro": {
            "precision": float(eval_dict["macro"]["precision"]),
            "recall":    float(eval_dict["macro"]["recall"]),
            "f1":        float(eval_dict["macro"]["f1"]),
        },
        "totals": {"TP": TP, "FP": FP, "FN": FN},
        "per_class": per_class,
        "thresholds": {"iou": 0.5, "score": 0.5}
    }

def is_backbone_frozen(m):
    try:
        return all((not p.requires_grad) for p in m.backbone.parameters())
    except Exception:
        return None

opt_name = optimizer.__class__.__name__ if 'optimizer' in globals() else None
sch_name = lr_sched.__class__.__name__ if 'lr_sched' in globals() else None

# Build del JSON
stamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
payload = {
    "saved_at": stamp,
    "notebook": "CEIA_VpC2_TP_Opcion2.ipynb",
    "framework": "torchvision Faster R-CNN ResNet50-FPN",
    "device": str(device),
    "classes": CLASS_NAMES,
    "num_classes": len(CLASS_NAMES),
    "data": {
        "train_images": len(train_ds) if 'train_ds' in globals() else None,
        "valid_images": len(valid_ds) if 'valid_ds' in globals() else None,
        "test_images":  len(test_ds)  if 'test_ds'  in globals() else None,
    },
    "training": {
        "epochs": EPOCHS if 'EPOCHS' in globals() else None,
        "batch_size": BATCH_SIZE if 'BATCH_SIZE' in globals() else None,
        "lr": LR if 'LR' in globals() else None,
        "optimizer": opt_name,
        "scheduler": sch_name,
        "backbone_frozen": is_backbone_frozen(model),
        "loss_history": train_loss_history,  # lista de float por época
    },
}

path_metrics_full = os.path.join(OUT_DIR, "metrics_full.json")

with open(path_metrics_full, "w", encoding="utf-8") as f:
    json.dump(payload, f, indent=2, ensure_ascii=False)

print(f"[OK] Métricas guardadas:\n  - {path_metrics_full}")
# Out:
# [OK] Métricas guardadas:
#   - /content/drive/MyDrive/UBA/CEIA/Materias/Visión por Computadora II/google_colab_data/FasterR-CNN-ResNet50_notebook/artifacts_20251130_105928/metrics_full.json

# %%
print(f"Tiempo recolección métricas: {datetime.datetime.now() - INICIO_STEP}")
INICIO_STEP = datetime.datetime.now()
# Out:
# Tiempo recolección métricas: 0:00:00.022641

# %%
# ---------------------------------------
# 12) Curvas P-R por clase y mAP (mAP@0.5 y mAP@[0.5:0.95])
# ---------------------------------------


@torch.no_grad()
def _collect_predictions_and_gts(model, loader, device, num_classes, score_min=0.0):
    model.eval()
    preds_by_cls = {c: [] for c in range(1, num_classes+1)}
    gts_by_cls   = {c: [] for c in range(1, num_classes+1)}

    img_index = 0
    for imgs, targets in loader:
        imgs = [img.to(device) for img in imgs]
        outs = model(imgs)

        for out, tgt in zip(outs, targets):
            # GT
            gt_boxes  = tgt["boxes"].cpu().numpy()
            gt_labels = tgt["labels"].cpu().numpy()  # 1..K
            for b, lab in zip(gt_boxes, gt_labels):
                gts_by_cls[int(lab)].append((b[0], b[1], b[2], b[3], img_index))

            # Preds
            scores = out["scores"].cpu().numpy()
            keep = scores >= score_min
            p_boxes  = out["boxes"][keep].cpu().numpy()
            p_labels = out["labels"][keep].cpu().numpy()  # 1..K
            p_scores = scores[keep]

            for b, lab, sc in zip(p_boxes, p_labels, p_scores):
                preds_by_cls[int(lab)].append((float(sc), b[0], b[1], b[2], b[3], img_index))

            img_index += 1
    return preds_by_cls, gts_by_cls

def _ap_from_pr(precision, recall):
    if len(precision) == 0:
        return 0.0
    # Ordenar por recall ascendente
    order = np.argsort(recall)
    r = np.array(recall)[order]
    p = np.array(precision)[order]

    # Precision envelope: p[i] = max_{j>=i} p[j]
    for i in range(len(p)-2, -1, -1):
        p[i] = max(p[i], p[i+1])

    # Muestreamos 101 puntos de recall
    recall_grid = np.linspace(0, 1, 101)
    p_interp = np.zeros_like(recall_grid)
    for i, rg in enumerate(recall_grid):
        idx = np.where(r >= rg)[0]
        p_interp[i] = 0.0 if len(idx) == 0 else np.max(p[idx])
    return float(np.mean(p_interp))

def _pr_curve_for_class(preds_cls, gts_cls, iou_thresh=0.5):
    # Índice de GTs por imagen para acelerar matching
    gt_by_img = {}
    for (x1, y1, x2, y2, img_id) in gts_cls:
        gt_by_img.setdefault(img_id, []).append([x1, y1, x2, y2, False])  # False = no emparejada todavía

    # Ordenar predicciones por score descendente
    preds_cls = sorted(preds_cls, key=lambda x: x[0], reverse=True)

    tp = np.zeros(len(preds_cls), dtype=np.float32)
    fp = np.zeros(len(preds_cls), dtype=np.float32)
    total_gts = len(gts_cls)

    for i, (score, x1, y1, x2, y2, img_id) in enumerate(preds_cls):
        pred_box = np.array([[x1, y1, x2, y2]], dtype=np.float32)
        gts_list = gt_by_img.get(img_id, [])

        if len(gts_list) == 0:
            fp[i] = 1.0
            continue

        # IoU con todas las GTs de esta imagen para esta clase
        gt_boxes = np.array([g[:4] for g in gts_list], dtype=np.float32)
        ious = box_iou(torch.tensor(pred_box), torch.tensor(gt_boxes)).numpy()[0]

        # Mejor IoU
        best_idx = int(np.argmax(ious))
        best_iou = float(ious[best_idx])

        if best_iou >= iou_thresh and (not gts_list[best_idx][4]):  # no emparejada
            tp[i] = 1.0
            gts_list[best_idx][4] = True  # marcar como usada
        else:
            fp[i] = 1.0

    # Cálculo de precisión y recall acumulados
    cum_tp = np.cumsum(tp)
    cum_fp = np.cumsum(fp)
    precision = cum_tp / np.maximum(cum_tp + cum_fp, 1e-9)
    recall = cum_tp / max(total_gts, 1e-9)

    ap = _ap_from_pr(precision, recall)
    return precision, recall, ap, int(cum_tp[-1]) if len(cum_tp) else 0, int(cum_fp[-1]) if len(cum_fp) else 0, total_gts

def compute_map(model, loader, class_names, device, iou_list=(0.5,), score_min=0.0, plot_pr=True, title_prefix="VALID"):
    K = len(class_names)
    preds_by_cls, gts_by_cls = _collect_predictions_and_gts(model, loader, device, K, score_min=score_min)

    aps_per_iou = []
    pr_cache = {}  # para el primer IoU (plot)

    for iou in iou_list:
        ap_classes = []
        for cls_id in range(1, K+1):
            precision, recall, ap, tps, fps, total_gts = _pr_curve_for_class(preds_by_cls[cls_id], gts_by_cls[cls_id], iou_thresh=iou)
            ap_classes.append(ap)
            if iou == iou_list[0]:  # cachear para plot
                pr_cache[cls_id] = (precision, recall, ap, tps, fps, total_gts)

        mAP = float(np.mean(ap_classes)) if len(ap_classes) else 0.0
        aps_per_iou.append((iou, ap_classes, mAP))

    # Plot P-R (solo para el primer IoU)
    if plot_pr:
        cols = 2
        rows = int(np.ceil(K / cols))
        fig, axes = plt.subplots(rows, cols, figsize=(10, 4*rows), squeeze=False)
        i = 0
        for r in range(rows):
            for c in range(cols):
                ax = axes[r][c]
                i += 1
                if i <= K:
                    P, R, APc, TPc, FPc, GTc = pr_cache[i]
                    ax.plot(R, P)
                    ax.set_title(f"{class_names[i-1]} | AP@{iou_list[0]:.2f}={APc:.3f} | TP={TPc} FP={FPc} GT={GTc}")
                    ax.set_xlabel("Recall")
                    ax.set_ylabel("Precision")
                    ax.set_xlim(0, 1)
                    ax.set_ylim(0, 1)
                else:
                    ax.axis("off")
        plt.suptitle(f"Precision-Recall por clase ({title_prefix}, IoU={iou_list[0]:.2f})")
        plt.tight_layout()
        plt.show()

    # Reporte numérico
    for iou, ap_classes, mAP in aps_per_iou:
        print(f"\n=== Resultados AP/mAP @ IoU={iou:.2f} ({title_prefix}) ===")
        for ci, ap in enumerate(ap_classes, start=1):
            print(f"  {class_names[ci-1]:20s}: AP={ap:.3f}")
        print(f"  mAP@{iou:.2f}: {mAP:.3f}")

    return aps_per_iou  # lista de (iou, [AP_cls], mAP)

# Ejecutar en VALID
# mAP@0.5
aps_valid_05 = compute_map(model, valid_dl, CLASS_NAMES, device, iou_list=(0.5,), score_min=0.0, plot_pr=True, title_prefix="VALID")
# mAP@[0.5:0.95] (COCO)
iou_grid = tuple(np.round(np.arange(0.5, 0.96, 0.05), 2))
aps_valid_COCO = compute_map(model, valid_dl, CLASS_NAMES, device, iou_list=iou_grid, score_min=0.0, plot_pr=False, title_prefix="VALID")

# Ejecutar en TEST
aps_test_05 = compute_map(model, test_dl, CLASS_NAMES, device, iou_list=(0.5,), score_min=0.0, plot_pr=True, title_prefix="TEST")
aps_test_COCO = compute_map(model, test_dl, CLASS_NAMES, device, iou_list=iou_grid, score_min=0.0, plot_pr=False, title_prefix="TEST")
# Out:
# === Resultados AP/mAP @ IoU=0.50 (VALID) ===
#   Tijera              : AP=0.949
#   Navaja              : AP=0.879
#   Cuchillo            : AP=0.596
#   Cutter              : AP=0.823
#   Navaja multiuso     : AP=0.916
#   mAP@0.50: 0.833
#
# === Resultados AP/mAP @ IoU=0.50 (VALID) ===
#   Tijera              : AP=0.949
#   Navaja              : AP=0.879
#   Cuchillo            : AP=0.596
#   Cutter              : AP=0.823
#   Navaja multiuso     : AP=0.916
#   mAP@0.50: 0.833
#
# === Resultados AP/mAP @ IoU=0.55 (VALID) ===
#   Tijera              : AP=0.935
#   Navaja              : AP=0.799
#   Cuchillo            : AP=0.500
#   Cutter              : AP=0.788
#   Navaja multiuso     : AP=0.869
#   mAP@0.55: 0.778
#
# === Resultados AP/mAP @ IoU=0.60 (VALID) ===
#   Tijera              : AP=0.908
#   Navaja              : AP=0.688
#   Cuchillo            : AP=0.386
#   Cutter              : AP=0.712
#   Navaja multiuso     : AP=0.739
#   mAP@0.60: 0.687
#
# === Resultados AP/mAP @ IoU=0.65 (VALID) ===
#   Tijera              : AP=0.788
#   Navaja              : AP=0.557
#   Cuchillo            : AP=0.313
#   Cutter              : AP=0.571
#   Navaja multiuso     : AP=0.583
#   mAP@0.65: 0.562
#
# === Resultados AP/mAP @ IoU=0.70 (VALID) ===
#   Tijera              : AP=0.607
#   Navaja              : AP=0.376
#   Cuchillo            : AP=0.178
#   Cutter              : AP=0.402
#   Navaja multiuso     : AP=0.357
#   mAP@0.70: 0.384
#
# === Resultados AP/mAP @ IoU=0.75 (VALID) ===
#   Tijera              : AP=0.366
#   Navaja              : AP=0.187
#   Cuchillo            : AP=0.073
#   Cutter              : AP=0.217
#   Navaja multiuso     : AP=0.179
#   mAP@0.75: 0.205
#
# === Resultados AP/mAP @ IoU=0.80 (VALID) ===
#   Tijera              : AP=0.153
#   Navaja              : AP=0.071
#   Cuchillo            : AP=0.020
#   Cutter              : AP=0.118
#   Navaja multiuso     : AP=0.063
#   mAP@0.80: 0.085
#
# === Resultados AP/mAP @ IoU=0.85 (VALID) ===
#   Tijera              : AP=0.036
#   Navaja              : AP=0.016
#   Cuchillo            : AP=0.003
#   Cutter              : AP=0.031
#   Navaja multiuso     : AP=0.009
#   mAP@0.85: 0.019
#
# === Resultados AP/mAP @ IoU=0.90 (VALID) ===
#   Tijera              : AP=0.003
#   Navaja              : AP=0.002
#   Cuchillo            : AP=0.001
#   Cutter              : AP=0.003
#   Navaja multiuso     : AP=0.001
#   mAP@0.90: 0.002
#
# === Resultados AP/mAP @ IoU=0.95 (VALID) ===
#   Tijera              : AP=0.000
#   Navaja              : AP=0.000
#   Cuchillo            : AP=0.000
#   Cutter              : AP=0.000
#   Navaja multiuso     : AP=0.000
#   mAP@0.95: 0.000
# === Resultados AP/mAP @ IoU=0.50 (TEST) ===
#   Tijera              : AP=0.953
#   Navaja              : AP=0.859
#   Cuchillo            : AP=0.746
#   Cutter              : AP=0.805
#   Navaja multiuso     : AP=0.885
#   mAP@0.50: 0.850
#
# === Resultados AP/mAP @ IoU=0.50 (TEST) ===
#   Tijera              : AP=0.953
#   Navaja              : AP=0.859
#   Cuchillo            : AP=0.746
#   Cutter              : AP=0.805
#   Navaja multiuso     : AP=0.885
#   mAP@0.50: 0.850
#
# === Resultados AP/mAP @ IoU=0.55 (TEST) ===
#   Tijera              : AP=0.929
#   Navaja              : AP=0.821
#   Cuchillo            : AP=0.661
#   Cutter              : AP=0.784
#   Navaja multiuso     : AP=0.824
#   mAP@0.55: 0.804
#
# === Resultados AP/mAP @ IoU=0.60 (TEST) ===
#   Tijera              : AP=0.838
#   Navaja              : AP=0.741
#   Cuchillo            : AP=0.596
#   Cutter              : AP=0.725
#   Navaja multiuso     : AP=0.768
#   mAP@0.60: 0.733
#
# === Resultados AP/mAP @ IoU=0.65 (TEST) ===
#   Tijera              : AP=0.723
#   Navaja              : AP=0.609
#   Cuchillo            : AP=0.397
#   Cutter              : AP=0.613
#   Navaja multiuso     : AP=0.652
#   mAP@0.65: 0.599
#
# === Resultados AP/mAP @ IoU=0.70 (TEST) ===
#   Tijera              : AP=0.621
#   Navaja              : AP=0.410
#   Cuchillo            : AP=0.270
#   Cutter              : AP=0.433
#   Navaja multiuso     : AP=0.453
#   mAP@0.70: 0.437
#
# === Resultados AP/mAP @ IoU=0.75 (TEST) ===
#   Tijera              : AP=0.431
#   Navaja              : AP=0.268
#   Cuchillo            : AP=0.148
#   Cutter              : AP=0.241
#   Navaja multiuso     : AP=0.204
#   mAP@0.75: 0.258
#
# === Resultados AP/mAP @ IoU=0.80 (TEST) ===
#   Tijera              : AP=0.168
#   Navaja              : AP=0.083
#   Cuchillo            : AP=0.059
#   Cutter              : AP=0.097
#   Navaja multiuso     : AP=0.067
#   mAP@0.80: 0.095
#
# === Resultados AP/mAP @ IoU=0.85 (TEST) ===
#   Tijera              : AP=0.070
#   Navaja              : AP=0.013
#   Cuchillo            : AP=0.011
#   Cutter              : AP=0.020
#   Navaja multiuso     : AP=0.012
#   mAP@0.85: 0.025
#
# === Resultados AP/mAP @ IoU=0.90 (TEST) ===
#   Tijera              : AP=0.008
#   Navaja              : AP=0.009
#   Cuchillo            : AP=0.001
#   Cutter              : AP=0.001
#   Navaja multiuso     : AP=0.001
#   mAP@0.90: 0.004
#
# === Resultados AP/mAP @ IoU=0.95 (TEST) ===
#   Tijera              : AP=0.001
#   Navaja              : AP=0.001
#   Cuchillo            : AP=0.000
#   Cutter              : AP=0.000
#   Navaja multiuso     : AP=0.000
#   mAP@0.95: 0.000

# %%
print(f"Tiempo preparación curvas: {datetime.datetime.now() - INICIO_STEP}")
INICIO_STEP = datetime.datetime.now()
# Out:
# Tiempo preparación curvas: 0:01:47.363767

# %%
# ---------------------------------------
# 13) Barrido de umbral de score → Macro-F1 vs. score (en VALID)
# ---------------------------------------

@torch.no_grad()
def evaluate_prf1(model, loader, device, class_names, score_thresh=0.5, iou_thresh=0.5):
    model.eval()
    K = len(class_names)
    TP = np.zeros(K+1, dtype=np.int64)
    FP = np.zeros(K+1, dtype=np.int64)
    FN = np.zeros(K+1, dtype=np.int64)

    for imgs, targets in loader:
        imgs = [img.to(device) for img in imgs]
        outs = model(imgs)

        for out, tgt in zip(outs, targets):
            gt_boxes = tgt["boxes"].cpu()
            gt_labels = tgt["labels"].cpu()  # 1..K

            keep = out["scores"].cpu() >= score_thresh
            pred_boxes = out["boxes"][keep].cpu()
            pred_labels = out["labels"][keep].cpu()  # 1..K
            pred_scores = out["scores"][keep].cpu()

            if len(gt_boxes) == 0 and len(pred_boxes) == 0:
                continue

            ious = box_iou(pred_boxes, gt_boxes) if (len(pred_boxes)>0 and len(gt_boxes)>0) else torch.zeros((len(pred_boxes), len(gt_boxes)))

            matched_gt = set()
            matched_pred = set()

            # greedy por score desc, y match por clase + IoU
            order = torch.argsort(pred_scores, descending=True).cpu().numpy()
            for pi in order:
                best_j, best_iou = -1, 0.0
                for gj in range(len(gt_boxes)):
                    if gj in matched_gt:
                        continue
                    if pred_labels[pi].item() != gt_labels[gj].item():
                        continue
                    iou_val = float(ious[pi, gj].item())
                    if iou_val >= iou_thresh and iou_val > best_iou:
                        best_iou, best_j = iou_val, gj
                if best_j >= 0:
                    cls = int(pred_labels[pi].item())
                    TP[cls] += 1
                    matched_pred.add(pi)
                    matched_gt.add(best_j)

            for pi in range(len(pred_boxes)):
                if pi not in matched_pred:
                    cls = int(pred_labels[pi].item())
                    FP[cls] += 1

            for gj in range(len(gt_boxes)):
                if gj not in matched_gt:
                    cls = int(gt_labels[gj].item())
                    FN[cls] += 1

    results = []
    for cls in range(1, K+1):
        tp, fp, fn = TP[cls], FP[cls], FN[cls]
        prec = tp/(tp+fp) if (tp+fp)>0 else 0.0
        rec  = tp/(tp+fn) if (tp+fn)>0 else 0.0
        f1   = 2*prec*rec/(prec+rec) if (prec+rec)>0 else 0.0
        results.append((class_names[cls-1], tp, fp, fn, prec, rec, f1))

    macro_prec = float(np.mean([r[4] for r in results])) if results else 0.0
    macro_rec  = float(np.mean([r[5] for r in results])) if results else 0.0
    macro_f1   = float(np.mean([r[6] for r in results])) if results else 0.0

    return {"per_class": results, "macro": {"precision": macro_prec, "recall": macro_rec, "f1": macro_f1}}
    

def sweep_threshold_macro_f1(model, loader, device, class_names,
                             iou_thresh=0.5,
                             scores=np.linspace(0.05, 0.95, 19)):
    model.eval()
    macro_f1 = []
    for s in scores:
        out = evaluate_prf1(model, loader, device, class_names,
                            score_thresh=float(s), iou_thresh=float(iou_thresh))
        macro_f1.append(out["macro"]["f1"])
    macro_f1 = np.array(macro_f1, dtype=float)

    # Mejor umbral
    best_idx = int(np.argmax(macro_f1))
    best_score = float(scores[best_idx])
    best_macro_f1 = float(macro_f1[best_idx])

    # Print detallado
    print(f"\n=== Barrido de umbral (VALID, IoU={iou_thresh:.2f}) ===")
    for s, f in zip(scores, macro_f1):
        print(f"  score={s:>4.2f}  →  Macro-F1={f:0.3f}")
    print(f"\nMejor umbral: score={best_score:.2f}  →  Macro-F1={best_macro_f1:.3f}")

    # Plot
    plt.figure(figsize=(6,4))
    plt.plot(scores, macro_f1, marker='o')
    plt.title(f"VALID | Macro-F1 vs. score (IoU={iou_thresh:.2f})")
    plt.xlabel("score threshold")
    plt.ylabel("Macro-F1")
    plt.grid(True, linestyle="--", alpha=0.4)
    plt.tight_layout()
    plt.show()

    return {
        "scores": scores.tolist(),
        "macro_f1": macro_f1.tolist(),
        "best_score": best_score,
        "best_macro_f1": best_macro_f1
    }

# Ejecutar barrido en VALID
score_sweep_valid = sweep_threshold_macro_f1(model, valid_dl, device, CLASS_NAMES, iou_thresh=0.5)

if 'payload' in globals():
    payload.setdefault("results", {}).setdefault("valid", {})
    payload["results"]["valid"]["score_sweep"] = {
        "scores": score_sweep_valid["scores"],
        "macro_f1": score_sweep_valid["macro_f1"],
        "best_score": score_sweep_valid["best_score"],
        "best_macro_f1": score_sweep_valid["best_macro_f1"],
        "iou": 0.5
    }
    print("[OK] Barrido de umbral agregado al payload de métricas (VALID).")

# Usar el mejor umbral para inferencia/validación rápida:
BEST_SCORE_FOR_INFERENCE = score_sweep_valid["best_score"]
print(f"BEST_SCORE_FOR_INFERENCE = {BEST_SCORE_FOR_INFERENCE:.2f}")
# Out:
# === Barrido de umbral (VALID, IoU=0.50) ===
#   score=0.05  →  Macro-F1=0.761
#   score=0.10  →  Macro-F1=0.806
#   score=0.15  →  Macro-F1=0.824
#   score=0.20  →  Macro-F1=0.832
#   score=0.25  →  Macro-F1=0.839
#   score=0.30  →  Macro-F1=0.845
#   score=0.35  →  Macro-F1=0.847
#   score=0.40  →  Macro-F1=0.849
#   score=0.45  →  Macro-F1=0.852
#   score=0.50  →  Macro-F1=0.853
#   score=0.55  →  Macro-F1=0.851
#   score=0.60  →  Macro-F1=0.851
#   score=0.65  →  Macro-F1=0.853
#   score=0.70  →  Macro-F1=0.849
#   score=0.75  →  Macro-F1=0.850
#   score=0.80  →  Macro-F1=0.845
#   score=0.85  →  Macro-F1=0.841
#   score=0.90  →  Macro-F1=0.830
#   score=0.95  →  Macro-F1=0.813
#
# Mejor umbral: score=0.50  →  Macro-F1=0.853
# [OK] Barrido de umbral agregado al payload de métricas (VALID).
# BEST_SCORE_FOR_INFERENCE = 0.50

# %%
print(f"Tiempo preparación barrido umbral: {datetime.datetime.now() - INICIO_STEP}")
INICIO_STEP = datetime.datetime.now()
# Out:
# Tiempo preparación barrido umbral: 0:10:29.890650

# %%
print(f"Tiempo total ejecución: {datetime.datetime.now() - INICIO_EJECUCION}")
# Out:
# Tiempo total ejecución: 1:58:35.765188

# %% [markdown]
# ---

# %% [markdown]
# TODO:JA Summary de los resultados. Inetrpretacion de los resultados. Comparación con los resultados de la corrida anterior.

# %% [markdown]
# ---
